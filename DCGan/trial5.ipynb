# %%
import sys, os
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow.keras import datasets, optimizers, metrics, layers, Sequential, Model, Input, losses
from load_datasets import DataLoader
import time

# %%
os.environ['KMP_DUPLICATE_LIB_OK']='True'  #防止训练过程中的kernel发生crash的情形

# %%
# 卷积层的生成器和鉴别器
def generator_network_dcgan(h, w, c, noise_dim=100):  # 输入噪声和标签，输出假图
    h_, w_ = h // 8, w // 8
    input_noise = Input(shape=(noise_dim,))  # (b,100)
    x = layers.Dense(h_ * w_ * 256)(input_noise)  #全连接层用于调整噪声的维度
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)
    x = layers.Reshape((h_, w_, 256))(x)  # (b,h/4,w/4,256)
    
    x = layers.Conv2DTranspose(128, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/2,w/2,256)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)

    x = layers.Conv2DTranspose(64, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/2,w/2,128)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)

    x = layers.Conv2DTranspose(32, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h,w,64)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)
    x = layers.Conv2DTranspose(c, (3, 3), padding='same', activation='tanh')(x)  # (b,h,w,c)
    generator = Model(input_noise, x)
    return generator

# %%
def discriminator_network_dcgan(h, w, c):  # 输入图片和标签，输出待验证的值。输出1为真，0为假
    input_image = Input(shape=(h, w, c))  # (b,h,w,c)
    x = layers.Conv2D(32, (3, 3), strides=(2, 2), padding='same')(input_image)  # (b,h/2,w/2,64)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)  
    x = layers.Dropout(0.3)(x)  #改进：在鉴别器的层之间添加dropout

    x = layers.Conv2D(64, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/4,w/4,128)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)
    x = layers.Dropout(0.3)(x)

    x = layers.Conv2D(128, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/4,w/4,256)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)
    x = layers.Dropout(0.3)(x)
    
    x = layers.Conv2D(256, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/4,w/4,512)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)
    x = layers.Dropout(0.3)(x)

    x = layers.Flatten()(x)  # (b,h/4*w/4*512)
    validity = layers.Dense(1, activation=None)(x)  # (b,1) 最后一层，flatten后全连接层

    discriminator = Model(input_image, validity)
    return discriminator

# %%
# WGAN-GP梯度控制函数
def gradient_penalty(discriminator, batch_x, fake_image):
    #梯度惩罚项计算函数
    batchsz = batch_x.shape[0]

    #每个样本均随机采样t,用于插值
    t = tf.random.uniform([batchsz,1,1,1])
    #自动扩展为x的形状:[b,1,1,1] => [b,h,w,c]
    t = tf.broadcast_to(t, batch_x.shape)
    #在真假图片之间作线性插值
    interplate = t * batch_x + (1-t) * fake_image
    #在梯度环境中计算 D 对插值样本的梯度
    with tf.GradientTape() as tape:
        tape.watch([interplate])
        d_interplate_logits = discriminator(interplate)

        grads = tape.gradient(d_interplate_logits, interplate)

        #计算每个样本的梯度的范数:[b,h,w,c] => [b,-1]
        grads = tf.reshape(grads, [grads.shape[0],-1])
        gp = tf.norm(grads,axis=1)
        #计算梯度惩罚项
        gp = tf.reduce_mean((gp-1.)**2)

    return gp

# %%
def save_image(fake_image, fake_label=None, fake_num=16, save_to=''):  # X为4维的带批次的图片
    ''' 
    用于保存图片的函数
    '''
    plt.figure()
    _, h, w, c = fake_image.shape  #设定生成假图的shape（128*128*3）
    if fake_num > 1:
        for i in range(fake_num):
            plt.subplot(4, 4, i + 1)  #训练过程中的迭代以4*4=16（一次保存16张图片）
            if c == 3:  # 如果是bgr则转为rgb（通道的转换）
                plt.imshow(cv.cvtColor(fake_image[i], cv.COLOR_BGR2RGB))  #对于一般格式与BGR格式都予以显示
            if c == 1:  # 如果是灰图则显示灰图
                plt.imshow(np.squeeze(fake_image[i]), cmap='gray')
            if fake_label is not None:  # 如果有标签则传入标签（这是为了在真图与假图之间鉴别时用）
                plt.title(fake_label[i])
            plt.axis('off')
        plt.savefig(save_to)
        plt.close()
    else:  # fake_num=1时保存单张图片，否则按照多张图片的格式保存
        cv.imwrite(save_to, fake_image[0])
    print('输出图片已保存至:%s' % save_to)

# %%
def creat_dir(path):  #用于生成迭代过程中的图片以及保存后续生成的图像
    os.makedirs(path, exist_ok=True)

# %%
print('tf版本：', tf.__version__)
# 定义参数
batch_size = 5  # 每次训练的批次（太大可能会显存不够而报错，故在这里选择较小的值）
epochs = 200000  # 共迭代训练几次
g_lr = 0.0005  # 生成器学习率
d_lr = 0.0002  # 鉴别器学习率
fake_num = 16  # 生成的图片的个数（一般不改）
dataset_name = 'female'  # 数据集的名字  star_imgs  female  cat_vs_dog
h, w, c = 256, 256, 3  # 数据集图片的宽和高，也是生成图片的宽和高
noise_dim = 100  # 输入噪声的维度（一般不改）
save_step = 1000  # 每隔几次保存一次中间结果图和权重。如果是0，则不保存中间结果图和权重
# Out:
# tf版本： 2.7.0

# %%
# 创建文件夹
directory = './checkpoint5/' + dataset_name + '_%s×%s' % (h, w)  # 输出参数保存的文件夹，一般不改
image_dir = './result_image5/' + dataset_name + '_%s×%s' % (h, w)  # 输出图片保存的文件夹，一般不改
os.makedirs(directory, exist_ok=True)
os.makedirs(image_dir, exist_ok=True)
image_names = os.listdir(image_dir)

# %%
# 加载数据集和预处理
dataloader = DataLoader(dir_path=r'./datasets/%s' % dataset_name, dataset_name=dataset_name,
                        norm_range=(-1, 1), img_res=(h, w))
x_train = dataloader.load_datasets()  # 加载数据集
print('正在加载数据集...')
# Out:
# ./datasets/female [] ['3581.png', '2229.png', '6064.png', '5866.png', '5862.png', '1389.png', '3461.png', '900.png', '9765.png', '8475.png', '5627.png', '5139.png', '4985.png', '7784.png', '3012.png', '3389.png', '4843.png', '3413.png', '7193.png', '1089.png', '4793.png', '6679.png', '3993.png', '2812.png', '2142.png', '7656.png', '1783.png', '7585.png', '290.png', '4288.png', '31.png', '974.png', '35.png', '3906.png', '5631.png', '5011.png', '9335.png', '2942.png', '1351.png', '9682.png', '3494.png', '4380.png', '328.png', '7394.png', '3063.png', '690.png', '9701.png', '3106.png', '8176.png', '2781.png', '6031.png', '4497.png', '1956.png', '4605.png', '8624.png', '798.png', '923.png', '182.png', '6813.png', '5794.png', '4484.png', '3798.png', '3522.png', '465.png', '7378.png', '8646.png', '8148.png', '7139.png', '6317.png', '5906.png', '5643.png', '2543.png', '5478.png', '8035.png', '5221.png', '925.png', '865.png', '3924.png', '7136.png', '7289.png', '4425.png', '8614.png', '4277.png', '3361.png', '8961.png', '153.png', '1669.png', '3024.png', '5000.png', '5515.png', '4149.png', '1064.png', '5858.png', '3279.png', '1961.png', '2173.png', '3962.png', '277.png', '5542.png', '7532.png', '4301.png', '2982.png', '374.png', '2856.png', '1319.png', '5433.png', '9198.png', '3122.png', '9615.png', '9354.png', '4658.png', '6984.png', '4343.png', '6706.png', '4795.png', '8623.png', '8136.png', '4716.png', '834.png', '7025.png', '3256.png', '9525.png', '8487.png', '1032.png', '8364.png', '7347.png', '8257.png', '1816.png', '2426.png', '4148.png', '7684.png', '315.png', '1087.png', '7676.png', '49.png', '867.png', '8617.png', '7902.png', '1429.png', '2553.png', '1470.png', '1168.png', '8907.png', '9689.png', '187.png', '7828.png', '7319.png', '2595.png', '9268.png', '6274.png', '4977.png', '2427.png', '525.png', '8654.png', '5309.png', '4753.png', '4736.png', '3518.png', '6644.png', '6740.png', '9041.png', '4021.png', '6066.png', '484.png', '9748.png', '5679.png', '5705.png', '6728.png', '8096.png', '125.png', '2445.png', '2881.png', '5271.png', '5874.png', '2435.png', '8962.png', '9133.png', '250.png', '3432.png', '717.png', '8489.png', '2161.png', '5590.png', '8362.png', '4376.png', '6523.png', '8719.png', '7579.png', '589.png', '9777.png', '5811.png', '6833.png', '5200.png', '1146.png', '4773.png', '3597.png', '9163.png', '8902.png', '835.png', '4070.png', '4876.png', '8914.png', '642.png', '1423.png', '6290.png', '5346.png', '5625.png', '4491.png', '2439.png', '6059.png', '8451.png', '2233.png', '5920.png', '5981.png', '1649.png', '9565.png', '8412.png', '7340.png', '6430.png', '9564.png', '3125.png', '8145.png', '7079.png', '5153.png', '548.png', '5545.png', '7685.png', '1542.png', '6105.png', '1550.png', '6252.png', '3379.png', '9995.png', '8047.png', '5618.png', '1889.png', '3317.png', '9022.png', '6941.png', '2268.png', '4759.png', '118.png', '2137.png', '8682.png', '9971.png', '5599.png', '9854.png', '8286.png', '3033.png', '9687.png', '349.png', '1977.png', '8029.png', '2513.png', '6666.png', '6178.png', '2576.png', '4608.png', '7493.png', '6655.png', '1023.png', '6088.png', '8246.png', '2507.png', '7478.png', '7912.png', '4094.png', '5548.png', '8073.png', '2953.png', '7923.png', '5126.png', '8082.png', '3768.png', '9849.png', '3147.png', '2219.png', '8518.png', '830.png', '2691.png', '3276.png', '5114.png', '1033.png', '6301.png', '5379.png', '7488.png', '7406.png', '3935.png', '5763.png', '7332.png', '475.png', '6920.png', '4241.png', '5350.png', '3584.png', '4159.png', '8187.png', '2769.png', '8447.png', '9875.png', '426.png', '6351.png', '6593.png', '391.png', '3684.png', '9578.png', '1241.png', '7854.png', '1503.png', '2521.png', '9810.png', '3186.png', '2438.png', '12.png', '84.png', '3782.png', '3142.png', '4664.png', '4954.png', '3599.png', '5999.png', '5203.png', '7935.png', '4104.png', '2625.png', '5745.png', '6952.png', '9731.png', '5256.png', '7712.png', '850.png', '7187.png', '2004.png', '2132.png', '9473.png', '9 ...
# ['./datasets/female/3581.png' './datasets/female/2229.png'
#  './datasets/female/6064.png' ... './datasets/female/7223.png'
#  './datasets/female/5801.png' './datasets/female/9387.png']
# 正在加载数据集...

# %%
# 加载网络
generator = generator_network_dcgan(h, w, c, noise_dim=noise_dim)
discriminator = discriminator_network_dcgan(h, w, c)
# generator.summary()
# discriminator.summary()

# 如果采用Gelu作为激活函数，最好使用带动量的方法进行训练
g_optimizer = optimizers.Adam(lr=g_lr, beta_1=0.5)
d_optimizer = optimizers.Adam(lr=d_lr, beta_1=0.5)

# 设置随机种植可以让产生的图片不变，之后取消随机数种子
tf.random.set_seed(0)
noise_test = tf.random.normal([fake_num, noise_dim])
tf.random.set_seed(None)
# Out:
# 2022-12-24 13:21:01.014056: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-24 13:21:01.378646: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22308 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:9d:00.0, compute capability: 8.6
# /usr/local/lib/python3.8/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
generator.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  dense (Dense)               (None, 262144)            26476544
#
#  batch_normalization (BatchN  (None, 262144)           1048576
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 262144)            0
#
#  reshape (Reshape)           (None, 32, 32, 256)       0
#
#  conv2d_transpose (Conv2DTra  (None, 64, 64, 128)      295040
#  nspose)
#
#  batch_normalization_1 (Batc  (None, 64, 64, 128)      512
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 64, 64, 128)       0
#
#  conv2d_transpose_1 (Conv2DT  (None, 128, 128, 64)     73792
#  ranspose)
#
#  batch_normalization_2 (Batc  (None, 128, 128, 64)     256
#  hNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 128, 128, 64)      0
#
#  conv2d_transpose_2 (Conv2DT  (None, 256, 256, 32)     18464
#  ranspose)
#
#  batch_normalization_3 (Batc  (None, 256, 256, 32)     128
#  hNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 256, 256, 32)      0
#
#  conv2d_transpose_3 (Conv2DT  (None, 256, 256, 3)      867
#  ranspose)
#
# =================================================================
# Total params: 27,914,179
# Trainable params: 27,389,443
# Non-trainable params: 524,736
# _________________________________________________________________

# %%
discriminator.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv2d (Conv2D)             (None, 128, 128, 32)      896
#
#  batch_normalization_4 (Batc  (None, 128, 128, 32)     128
#  hNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 128, 128, 32)      0
#
#  dropout (Dropout)           (None, 128, 128, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        18496
#
#  batch_normalization_5 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 64, 64, 64)        0
#
#  dropout_1 (Dropout)         (None, 64, 64, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       73856
#
#  batch_normalization_6 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 32, 32, 128)       0
#
#  dropout_2 (Dropout)         (None, 32, 32, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)       295168
#
#  batch_normalization_7 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 16, 16, 256)       0
#
#  dropout_3 (Dropout)         (None, 16, 16, 256)       0
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense_1 (Dense)             (None, 1)                 65537
#
# =================================================================
# Total params: 455,873
# Trainable params: 454,913
# Non-trainable params: 960
# _________________________________________________________________

# %%
@tf.function  #tf.function用于加快运算速度
def train_step(x):
    # x = transform(x, dsize=(h, h), crop_size=(h, w))  # 使用随机裁剪
    # print('x:', x.shape)
    noise = tf.random.normal([x.shape[0], noise_dim])  # noise.shape=(b,100)
    with tf.GradientTape() as g_tape, tf.GradientTape() as d_tape:
        fake_image = generator(noise, training=True)  # (b, h, w, c)
        fake_out = discriminator(fake_image, training=True)  # (b, 1)
        real_out = discriminator(x, training=True)  # (b, 1)
        g_loss = tf.reduce_mean(
            losses.binary_crossentropy(y_true=tf.ones_like(fake_out), y_pred=fake_out, from_logits=True))  # 计算生成损失

        d1_loss = tf.reduce_mean(
            losses.binary_crossentropy(y_true=tf.ones_like(real_out), y_pred=real_out, from_logits=True))
        d2_loss = tf.reduce_mean(
            losses.binary_crossentropy(y_true=tf.zeros_like(fake_out), y_pred=fake_out, from_logits=True))  # 计算两个鉴别损失

        gp = gradient_penalty(discriminator, x, fake_image)  # 计算梯度惩罚项（wgan的内容，也可注释掉此行代码不使用）
        d_loss = d1_loss + d2_loss + 10.*gp
        #d_loss = d1_loss + d2_loss
    g_grads = g_tape.gradient(g_loss, generator.trainable_variables)
    d_grads = d_tape.gradient(d_loss, discriminator.trainable_variables)

    g_optimizer.apply_gradients(zip(g_grads, generator.trainable_variables))
    d_optimizer.apply_gradients(zip(d_grads, discriminator.trainable_variables))
    return [g_loss, d_loss]

# %%
# 创建保存参数
checkpoint = tf.train.Checkpoint(generator=generator,
                                 discriminator=discriminator)
checkpoint.restore(tf.train.latest_checkpoint(directory))  # 断点续训
manager = tf.train.CheckpointManager(checkpoint=checkpoint, directory=directory, max_to_keep=2,
                                     checkpoint_name=dataset_name)

max_num = max([int(image_name.split('.')[0][len(dataset_name):]) for image_name in image_names if
               image_name.endswith('png') or image_name.endswith('jpg')]) if image_names else 0  # 接着上次的往后保存

# %%
g_total_loss_list = []
d_total_loss_list = []

# 训练
print('数据加载完成，正在训练中...')
t1 = time.time()
for epoch in range(epochs):

    x_train = dataloader.load_batch(batch_size=batch_size)
    g_total_loss, d_total_loss = train_step(x_train)

    # 保存
    if save_step:
        if (epoch + 1) % save_step == 0 or epoch == 0:  # 每隔几个epoch保存一次
            fake_image = generator.predict(noise_test, batch_size=1)  # (b,h,w,c)
            fake_image = fake_image.reshape(-1, h, w, c) * 127.5 + 127.5  # (b,h,w,c)
            fake_image = np.clip(fake_image, 0, 255).astype('uint8')  # (b,h,w,c)
            save_to = image_dir + '/' + dataset_name + '%d.png' % (epoch + 1 + max_num)
            save_image(fake_image, fake_label=None, fake_num=fake_num, save_to=save_to)  # 保存图片
            manager.save(checkpoint_number=epoch + 1 + max_num)  # 保存参数
            g_total_loss_list.append(g_total_loss)
            d_total_loss_list.append(d_total_loss)  #每一定epoch后保存一次总损失值
            print('epoch:%d/%d:' % (epoch + 1 + max_num, epochs),
                  'g_total_loss:%.6f' % np.mean(g_total_loss),
                  'd_total_loss:%.6f' % np.mean(d_total_loss), '用时:%.6f' % (time.time() - t1))
            t1 = time.time()
    if epoch + 1 + max_num >= epochs:
        print('已跑完%s次' % epochs)
        break
manager.save(checkpoint_number=epochs)  # 训练完保存参数
# Out:
# 数据加载完成，正在训练中...
# 2022-12-24 13:21:12.823425: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8101
# 2022-12-24 13:21:14.068113: I tensorflow/stream_executor/cuda/cuda_blas.cc:1774] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 输出图片已保存至:./result_image5/female_256×256/female1.png
# epoch:1/200000: g_total_loss:0.898705 d_total_loss:8.275471 用时:4.649743
# 输出图片已保存至:./result_image5/female_256×256/female1000.png
# epoch:1000/200000: g_total_loss:2.218666 d_total_loss:0.254765 用时:26.883027
# 输出图片已保存至:./result_image5/female_256×256/female2000.png
# epoch:2000/200000: g_total_loss:3.558519 d_total_loss:0.215738 用时:26.354650
# 输出图片已保存至:./result_image5/female_256×256/female3000.png
# epoch:3000/200000: g_total_loss:1.184733 d_total_loss:0.634463 用时:26.122754
# 输出图片已保存至:./result_image5/female_256×256/female4000.png
# epoch:4000/200000: g_total_loss:1.223727 d_total_loss:0.503503 用时:25.396562
# 输出图片已保存至:./result_image5/female_256×256/female5000.png
# epoch:5000/200000: g_total_loss:1.259186 d_total_loss:0.596793 用时:25.888582
# 输出图片已保存至:./result_image5/female_256×256/female6000.png
# epoch:6000/200000: g_total_loss:2.263411 d_total_loss:0.370054 用时:25.581504
# 输出图片已保存至:./result_image5/female_256×256/female7000.png
# epoch:7000/200000: g_total_loss:0.666141 d_total_loss:0.923267 用时:26.128174
# 输出图片已保存至:./result_image5/female_256×256/female8000.png
# epoch:8000/200000: g_total_loss:2.102420 d_total_loss:0.576400 用时:26.276196
# 输出图片已保存至:./result_image5/female_256×256/female9000.png
# epoch:9000/200000: g_total_loss:2.161970 d_total_loss:0.749527 用时:26.497833
# 输出图片已保存至:./result_image5/female_256×256/female10000.png
# epoch:10000/200000: g_total_loss:0.954550 d_total_loss:0.918093 用时:26.392193
# 输出图片已保存至:./result_image5/female_256×256/female11000.png
# epoch:11000/200000: g_total_loss:0.362664 d_total_loss:1.393760 用时:25.684507
# 输出图片已保存至:./result_image5/female_256×256/female12000.png
# epoch:12000/200000: g_total_loss:1.474438 d_total_loss:0.446559 用时:25.522233
# 输出图片已保存至:./result_image5/female_256×256/female13000.png
# epoch:13000/200000: g_total_loss:3.132234 d_total_loss:1.095039 用时:25.782390
# 输出图片已保存至:./result_image5/female_256×256/female14000.png
# epoch:14000/200000: g_total_loss:0.815250 d_total_loss:0.732473 用时:26.015237
# 输出图片已保存至:./result_image5/female_256×256/female15000.png
# epoch:15000/200000: g_total_loss:1.194309 d_total_loss:0.672374 用时:26.246186
# 输出图片已保存至:./result_image5/female_256×256/female16000.png
# epoch:16000/200000: g_total_loss:1.791044 d_total_loss:1.994220 用时:26.020394
# 输出图片已保存至:./result_image5/female_256×256/female17000.png
# epoch:17000/200000: g_total_loss:0.767241 d_total_loss:1.013799 用时:25.875609
# 输出图片已保存至:./result_image5/female_256×256/female18000.png
# epoch:18000/200000: g_total_loss:1.926777 d_total_loss:0.688240 用时:27.235139
# 输出图片已保存至:./result_image5/female_256×256/female19000.png
# epoch:19000/200000: g_total_loss:1.418349 d_total_loss:0.493967 用时:25.886017
# 输出图片已保存至:./result_image5/female_256×256/female20000.png
# epoch:20000/200000: g_total_loss:1.147946 d_total_loss:0.801808 用时:27.111937
# 输出图片已保存至:./result_image5/female_256×256/female21000.png
# epoch:21000/200000: g_total_loss:3.268394 d_total_loss:0.718245 用时:26.705154
# 输出图片已保存至:./result_image5/female_256×256/female22000.png
# epoch:22000/200000: g_total_loss:1.300512 d_total_loss:0.896159 用时:26.067246
# 输出图片已保存至:./result_image5/female_256×256/female23000.png
# epoch:23000/200000: g_total_loss:1.434019 d_total_loss:0.648757 用时:26.401628
# 输出图片已保存至:./result_image5/female_256×256/female24000.png
# epoch:24000/200000: g_total_loss:1.207563 d_total_loss:0.794329 用时:27.375290
# 输出图片已保存至:./result_image5/female_256×256/female25000.png
# epoch:25000/200000: g_total_loss:1.299103 d_total_loss:1.218976 用时:26.922348
# 输出图片已保存至:./result_image5/female_256×256/female26000.png
# epoch:26000/200000: g_total_loss:1.236657 d_total_loss:0.519433 用时:25.059176
# 输出图片已保存至:./result_image5/female_256×256/female27000.png
# epoch:27000/200000: g_total_loss:1.608935 d_total_loss:0.593761 用时:25.367506
# 输出图片已保存至:./result_image5/female_256×256/female28000.png
# epoch:28000/200000: g_total_loss:2.311327 d_total_loss:0.858599 用时:27.483740
# 输出图片已保存至:./result_image5/female_256×256/female29000.png
# epoch:29000/200000: g_total_loss:1.875790 d_total_loss:0.701696 用时:26.307166
# 输出图片已保存至:./result_image5/female_256×256/female30000.png
# epoch:30000/200000: g_total_loss:0.986877 d_total_loss:0.772439 用时:26.254083
# 输出图片已保存至:./result_image5/female_256×256/female31000.png
# epoch:31000/200000: g_total_loss:2.493232 d_total_loss:0.284629 用时:25.813409
# 输出图片已保存至:./result_image5/female_256×256/female32000.png
# epoch:32000/200000: g_total_loss:1.308695 d_total_loss:1.046343 用时:25.963986
# 输出图片已保存至:./result_image5/female_256×256/female33000.png
# epoch:33000/200000: g_total_loss:2.081879 d_total_loss:0.584787 用时:26.318770
# 输出图片已保存至:./result_image5/female_256×256/female34000.png
# epoch:34000/200000: g_total_loss:1.477762 d_total_loss:0.626575 用时:25.933040
# 输出图片已保存至:./result_image5/female_256×256/female35000.png
# epoch:35000/200000: g_total_loss:2.693806 d_total_loss:0.998950 用时:26.848869
# 输出图片已保存至:./result_image5/female_256×256/female36000.png
# epoch:36000/200000: g_total_loss:2.831586 d_total_loss:0.380831 用时:26.627574
# 输出图片已保存至:./result_image5/female_256×256/female37000.png
# epoch:37000/200000: g_total_loss:1.900464 d_total_loss:1.052637 用时:26.222355
# 输出图片已保存至:./result_image5/female_256×256/female38000.png
# epoch:38000/200000: g_total_loss:1.067417 d_total_loss:0.897249 用时:26.215685
# 输出图片已保存至:./result_image5/female_256×256/female39000.png
# epoch:39000/200000: g_total_loss:1.714202 d_total_loss:0.772468 用时:26.349184
# 输出图片已保存至:./result_image5/female_256×256/female40000.png
# epoch:40000/200000: g_total_loss:1.321042 d_total_loss:0.592700 用时:29.192462
# 输出图片已保存至:./result_image5/female_256×256/female41000.png
# epoch:41000/200000: g_total_loss:1.505386 d_total_loss:0.489435 用时:26.261413
# 输出图片已保存至:./result_image5/female_256×256/female42000.png
# epoch:42000/200000: g_total_loss:1.923253 d_total_loss:0.933452 用时:26.788390
# 输出图片已保存至:./result_image5/female_256×256/female43000.png
# epoch:43000/200000: g_total_loss:1.673695 d_total_loss:0.664280 用时:26.493197
# 输出图片已保存至:./result_image5/female_256×256/female44000.png
# epoch:44000/200000: g_total_loss:0.792686 d_total_loss:1.072217 用时:25.808496
# 输出图片已保存至:./result_image5/female_256×256/female45000.png
# epoch:45000/200000: g_total_loss:1.564812 d_total_loss:0.723000 用时:25.284288
# 输出图片已保存至:./result_image5/female_256×256/female46000.png
# epoch:46000/200000: g_total_loss:2.211618 d_total_loss:0.958450 用时:25.921760
# 输出图片已保存至:./result_image5/female_256×256/female47000.png
# epoch:47000/200000: g_total_loss:0.412929 d_total_loss:1.329649 用时:26.170780
# 输出图片已保存至:./result_image5/female_256×256/female48000.png
# epoch:48000/200000: g_total_loss:1.644077 d_total_loss:0.838583 用时:26.309319
# 输出图片已保存至:./result_image5/female_256×256/female49000.png
# epoch:49000/200000: g_total_loss:1.762164 d_total_loss:0.766594 用时:25.823084
# 输出图片已保存至:./result_image5/female_256×256/female50000.png
# epoch:50000/200000: g_total_loss:1.768778 d_total_loss:0.636055 用时:26.178181
# 输出图片已保存至:./result_image5/female_256×256/female51000.png
# epoch:51000/200000: g_total_loss:1.899730 d_total_loss:0.669120 用时:26.893667
# 输出图片已保存至:./result_image5/female_256×256/female52000.png
# epoch:52000/200000: g_total_loss:2.308817 d_total_loss:0.950071 用时:26.200800
# 输出图片已保存至:./result_image5/female_256×256/female53000.png
# epoch:53000/200000: g_total_loss:1.348743 d_total_loss:0.991034 用时:26.483048
# 输出图片已保存至:./result_image5/female_256×256/female54000.png
# epoch:54000/200000: g_total_loss:1.450032 d_total_loss:0.982364 用时:25.493765
# 输出图片已保存至:./result_image5/female_256×256/female55000.png
# epoch:55000/200000: g_total_loss:0.671035 d_total_loss:0.964799 用时:25.838633
# 输出图片已保存至:./result_image5/female_256×256/female56000.png
# epoch:56000/200000: g_total_loss:2.250162 d_total_loss:1.463259 用时:26.139166
# 输出图片已保存至:./result_image5/female_256×256/female57000.png
# epoch:57000/200000: g_total_loss:0.958317 d_total_loss:0.854105 用时:26.852014
# 输出图片已保存至:./result_image5/female_256×256/female58000.png
# epoch:58000/200000: g_total_loss:1.073248 d_total_loss:0.864390 用时:25.819755
# 输出图片已保存至:./result_image5/female_256×256/female59000.png
# epoch:59000/200000: g_total_loss:2.101524 d_total_loss:0.618521 用时:26.252664
# 输出图片已保存至:./result_image5/female_256×256/female60000.png
# epoch:60000/200000: g_total_loss:0.780448 d_total_loss:1.141913 用时:25.293176
# 输出图片已保存至:./result_image5/female_256×256/female61000.png
# epoch:61000/200000: g_total_loss:1.208930 d_total_loss:0.897766 用时:25.594345
# 输出图片已保存至:./result_image5/female_256×256/female62000.png
# epoch:62000/200000: g_total_loss:1.266473 d_total_loss:0.727439 用时:26.498923
# 输出图片已保存至:./result_image5/female_256×256/female63000.png
# epoch:63000/200000: g_total_loss:1.268142 d_total_loss:1.122560 用时:26.534498
# 输出图片已保存至:./result_image5/female_256×256/female64000.png
# epoch:64000/200000: g_total_loss:0.979488 d_total_loss:0.786277 用时:25.990709
# 输出图片已保存至:./result_image5/female_256×256/female65000.png
# epoch:65000/200000: g_total_loss:1.916221 d_total_loss:0.821974 用时:25.984744
# 输出图片已保存至:./result_image5/female_256×256/female66000.png
# epoch:66000/200000: g_total_loss:1.094890 d_total_loss:0.959584 用时:25.760943
# 输出图片已保存至:./result_image5/female_256×256/female67000.png
# epoch:67000/200000: g_total_loss:1.828037 d_total_loss:0.563608 用时:26.052793
# 输出图片已保存至:./result_image5/female_256×256/female68000.png
# epoch:68000/200000: g_total_loss:1.939389 d_total_loss:0.803017 用时:26.413188
# 输出图片已保存至:./result_image5/female_256×256/female69000.png
# epoch:69000/200000: g_total_loss:1.764180 d_total_loss:0.792071 用时:26.480815
# 输出图片已保存至:./result_image5/female_256×256/female70000.png
# epoch:70000/200000: g_total_loss:1.100190 d_total_loss:1.158245 用时:24.180140
# 输出图片已保存至:./result_image5/female_256×256/female71000.png
# epoch:71000/200000: g_total_loss:1.820736 d_total_loss:1.910263 用时:25.853817
# 输出图片已保存至:./result_image5/female_256×256/female72000.png
# epoch:72000/200000: g_total_loss:1.111842 d_total_loss:0.789727 用时:25.867439
# 输出图片已保存至:./result_image5/female_256×256/female73000.png
# epoch:73000/200000: g_total_loss:1.792992 d_total_loss:0.970863 用时:26.603759
# 输出图片已保存至:./result_image5/female_256×256/female74000.png
# epoch:74000/200000: g_total_loss:1.992266 d_total_loss:0.451714 用时:26.529535
# 输出图片已保存至:./result_image5/female_256×256/female75000.png
# epoch:75000/200000: g_total_loss:1.352306 d_total_loss:0.758434 用时:25.488724
# 输出图片已保存至:./result_image5/female_256×256/female76000.png
# epoch:76000/200000: g_total_loss:0.864157 d_total_loss:1.591707 用时:25.687593
# 输出图片已保存至:./result_image5/female_256×256/female77000.png
# epoch:77000/200000: g_total_loss:1.681937 d_total_loss:0.868797 用时:23.707317
# 输出图片已保存至:./result_image5/female_256×256/female78000.png
# epoch:78000/200000: g_total_loss:0.667054 d_total_loss:1.315327 用时:25.986691
# 输出图片已保存至:./result_image5/female_256×256/female79000.png
# epoch:79000/200000: g_total_loss:0.593585 d_total_loss:1.394255 用时:26.419348
# 输出图片已保存至:./result_image5/female_256×256/female80000.png
# epoch:80000/200000: g_total_loss:0.683508 d_total_loss:1.080763 用时:25.801442
# 输出图片已保存至:./result_image5/female_256×256/female81000.png
# epoch:81000/200000: g_total_loss:0.862735 d_total_loss:0.871039 用时:26.022912
# 输出图片已保存至:./result_image5/female_256×256/female82000.png
# epoch:82000/200000: g_total_loss:0.502776 d_total_loss:1.391178 用时:26.230361
# 输出图片已保存至:./result_image5/female_256×256/female83000.png
# epoch:83000/200000: g_total_loss:0.980677 d_total_loss:0.974829 用时:24.862596
# 输出图片已保存至:./result_image5/female_256×256/female84000.png
# epoch:84000/200000: g_total_loss:1.257564 d_total_loss:1.185948 用时:26.098632
# 输出图片已保存至:./result_image5/female_256×256/female85000.png
# epoch:85000/200000: g_total_loss:1.533777 d_total_loss:0.757285 用时:25.693023
# 输出图片已保存至:./result_image5/female_256×256/female86000.png
# epoch:86000/200000: g_total_loss:1.339739 d_total_loss:1.100388 用时:26.745791
# 输出图片已保存至:./result_image5/female_256×256/female87000.png
# epoch:87000/200000: g_total_loss:1.076224 d_total_loss:1.296597 用时:26.142795
# 输出图片已保存至:./result_image5/female_256×256/female88000.png
# epoch:88000/200000: g_total_loss:0.853095 d_total_loss:0.804404 用时:26.282207
# 输出图片已保存至:./result_image5/female_256×256/female89000.png
# epoch:89000/200000: g_total_loss:1.500273 d_total_loss:1.106100 用时:25.101584
# 输出图片已保存至:./result_image5/female_256×256/female90000.png
# epoch:90000/200000: g_total_loss:1.567369 d_total_loss:0.915526 用时:26.218911
# 输出图片已保存至:./result_image5/female_256×256/female91000.png
# epoch:91000/200000: g_total_loss:1.112129 d_total_loss:0.661525 用时:25.678717
# 输出图片已保存至:./result_image5/female_256×256/female92000.png
# epoch:92000/200000: g_total_loss:1.539371 d_total_loss:0.924119 用时:25.146419
# 输出图片已保存至:./result_image5/female_256×256/female93000.png
# epoch:93000/200000: g_total_loss:1.170346 d_total_loss:0.616709 用时:26.067887
# 输出图片已保存至:./result_image5/female_256×256/female94000.png
# epoch:94000/200000: g_total_loss:1.014487 d_total_loss:0.706801 用时:26.087271
# 输出图片已保存至:./result_image5/female_256×256/female95000.png
# epoch:95000/200000: g_total_loss:1.710156 d_total_loss:0.944192 用时:23.810564
# 输出图片已保存至:./result_image5/female_256×256/female96000.png
# epoch:96000/200000: g_total_loss:1.526042 d_total_loss:0.852125 用时:25.875699
# 输出图片已保存至:./result_image5/female_256×256/female97000.png
# epoch:97000/200000: g_total_loss:1.018397 d_total_loss:0.925691 用时:25.900874
# 输出图片已保存至:./result_image5/female_256×256/female98000.png
# epoch:98000/200000: g_total_loss:1.348439 d_total_loss:0.690768 用时:26.278444
# 输出图片已保存至:./result_image5/female_256×256/female99000.png
# epoch:99000/200000: g_total_loss:1.447633 d_total_loss:1.020185 用时:25.615376
# 输出图片已保存至:./result_image5/female_256×256/female100000.png
# epoch:100000/200000: g_total_loss:0.934299 d_total_loss:1.156750 用时:26.177605
# 输出图片已保存至:./result_image5/female_256×256/female101000.png
# epoch:101000/200000: g_total_loss:0.814610 d_total_loss:0.790033 用时:25.929415
# 输出图片已保存至:./result_image5/female_256×256/female102000.png
# epoch:102000/200000: g_total_loss:0.658820 d_total_loss:1.436431 用时:25.559936
# 输出图片已保存至:./result_image5/female_256×256/female103000.png
# epoch:103000/200000: g_total_loss:1.123412 d_total_loss:0.756150 用时:25.753687
# 输出图片已保存至:./result_image5/female_256×256/female104000.png
# epoch:104000/200000: g_total_loss:1.586881 d_total_loss:0.934960 用时:26.126491
# 输出图片已保存至:./result_image5/female_256×256/female105000.png
# epoch:105000/200000: g_total_loss:1.433591 d_total_loss:1.079916 用时:26.930111
# 输出图片已保存至:./result_image5/female_256×256/female106000.png
# epoch:106000/200000: g_total_loss:0.811611 d_total_loss:1.213473 用时:25.667091
# 输出图片已保存至:./result_image5/female_256×256/female107000.png
# epoch:107000/200000: g_total_loss:0.806328 d_total_loss:1.316852 用时:26.128018
# 输出图片已保存至:./result_image5/female_256×256/female108000.png
# epoch:108000/200000: g_total_loss:1.482909 d_total_loss:0.602875 用时:26.346573
# 输出图片已保存至:./result_image5/female_256×256/female109000.png
# epoch:109000/200000: g_total_loss:0.956539 d_total_loss:0.990530 用时:26.393676
# 输出图片已保存至:./result_image5/female_256×256/female110000.png
# epoch:110000/200000: g_total_loss:1.163297 d_total_loss:0.931625 用时:26.364915
# 输出图片已保存至:./result_image5/female_256×256/female111000.png
# epoch:111000/200000: g_total_loss:1.269172 d_total_loss:0.959846 用时:25.777913
# 输出图片已保存至:./result_image5/female_256×256/female112000.png
# epoch:112000/200000: g_total_loss:1.241079 d_total_loss:0.952122 用时:26.204231
# 输出图片已保存至:./result_image5/female_256×256/female113000.png
# epoch:113000/200000: g_total_loss:1.514947 d_total_loss:1.167682 用时:25.822013
# 输出图片已保存至:./result_image5/female_256×256/female114000.png
# epoch:114000/200000: g_total_loss:1.644441 d_total_loss:0.916026 用时:24.896061
# 输出图片已保存至:./result_image5/female_256×256/female115000.png
# epoch:115000/200000: g_total_loss:1.561299 d_total_loss:0.634933 用时:25.998172
# 输出图片已保存至:./result_image5/female_256×256/female116000.png
# epoch:116000/200000: g_total_loss:0.401774 d_total_loss:1.693765 用时:26.083580
# 输出图片已保存至:./result_image5/female_256×256/female117000.png
# epoch:117000/200000: g_total_loss:1.091725 d_total_loss:0.825080 用时:25.388413
# 输出图片已保存至:./result_image5/female_256×256/female118000.png
# epoch:118000/200000: g_total_loss:1.713896 d_total_loss:1.119922 用时:25.328284
# 输出图片已保存至:./result_image5/female_256×256/female119000.png
# epoch:119000/200000: g_total_loss:1.441580 d_total_loss:1.171124 用时:26.103112
# 输出图片已保存至:./result_image5/female_256×256/female120000.png
# epoch:120000/200000: g_total_loss:1.019150 d_total_loss:0.844488 用时:25.718685
# 输出图片已保存至:./result_image5/female_256×256/female121000.png
# epoch:121000/200000: g_total_loss:1.177403 d_total_loss:1.023306 用时:25.950886
# 输出图片已保存至:./result_image5/female_256×256/female122000.png
# epoch:122000/200000: g_total_loss:1.235670 d_total_loss:1.122627 用时:25.780591
# 输出图片已保存至:./result_image5/female_256×256/female123000.png
# epoch:123000/200000: g_total_loss:1.336374 d_total_loss:1.035520 用时:26.214277
# 输出图片已保存至:./result_image5/female_256×256/female124000.png
# epoch:124000/200000: g_total_loss:1.523944 d_total_loss:0.702046 用时:25.969927
# 输出图片已保存至:./result_image5/female_256×256/female125000.png
# epoch:125000/200000: g_total_loss:0.678832 d_total_loss:1.133916 用时:26.223511
# 输出图片已保存至:./result_image5/female_256×256/female126000.png
# epoch:126000/200000: g_total_loss:1.780762 d_total_loss:0.634817 用时:25.471831
# 输出图片已保存至:./result_image5/female_256×256/female127000.png
# epoch:127000/200000: g_total_loss:1.338428 d_total_loss:1.010429 用时:26.446351
# 输出图片已保存至:./result_image5/female_256×256/female128000.png
# epoch:128000/200000: g_total_loss:0.501972 d_total_loss:1.404719 用时:26.300745
# 输出图片已保存至:./result_image5/female_256×256/female129000.png
# epoch:129000/200000: g_total_loss:1.274113 d_total_loss:1.007811 用时:25.960511
# 输出图片已保存至:./result_image5/female_256×256/female130000.png
# epoch:130000/200000: g_total_loss:1.421872 d_total_loss:0.821302 用时:27.763412
# 输出图片已保存至:./result_image5/female_256×256/female131000.png
# epoch:131000/200000: g_total_loss:0.560027 d_total_loss:1.243583 用时:26.735232
# 输出图片已保存至:./result_image5/female_256×256/female132000.png
# epoch:132000/200000: g_total_loss:1.557197 d_total_loss:1.383186 用时:26.478254
# 输出图片已保存至:./result_image5/female_256×256/female133000.png
# epoch:133000/200000: g_total_loss:0.966404 d_total_loss:0.929259 用时:26.218036
# 输出图片已保存至:./result_image5/female_256×256/female134000.png
# epoch:134000/200000: g_total_loss:1.205938 d_total_loss:0.972681 用时:25.535788
# 输出图片已保存至:./result_image5/female_256×256/female135000.png
# epoch:135000/200000: g_total_loss:1.220873 d_total_loss:1.186131 用时:25.663157
# 输出图片已保存至:./result_image5/female_256×256/female136000.png
# epoch:136000/200000: g_total_loss:1.067075 d_total_loss:0.914195 用时:26.148105
# 输出图片已保存至:./result_image5/female_256×256/female137000.png
# epoch:137000/200000: g_total_loss:0.923001 d_total_loss:1.032339 用时:25.902093
# 输出图片已保存至:./result_image5/female_256×256/female138000.png
# epoch:138000/200000: g_total_loss:1.961443 d_total_loss:1.165475 用时:25.923233
# 输出图片已保存至:./result_image5/female_256×256/female139000.png
# epoch:139000/200000: g_total_loss:0.826628 d_total_loss:1.193980 用时:25.883545
# 输出图片已保存至:./result_image5/female_256×256/female140000.png
# epoch:140000/200000: g_total_loss:0.893819 d_total_loss:1.434295 用时:25.342426
# 输出图片已保存至:./result_image5/female_256×256/female141000.png
# epoch:141000/200000: g_total_loss:1.378544 d_total_loss:0.985842 用时:25.889760
# 输出图片已保存至:./result_image5/female_256×256/female142000.png
# epoch:142000/200000: g_total_loss:1.709681 d_total_loss:0.921139 用时:26.670882
# 输出图片已保存至:./result_image5/female_256×256/female143000.png
# epoch:143000/200000: g_total_loss:0.972522 d_total_loss:0.990718 用时:26.140634
# 输出图片已保存至:./result_image5/female_256×256/female144000.png
# epoch:144000/200000: g_total_loss:1.378485 d_total_loss:1.228802 用时:26.169236
# 输出图片已保存至:./result_image5/female_256×256/female145000.png
# epoch:145000/200000: g_total_loss:1.396757 d_total_loss:0.870205 用时:24.939045
# 输出图片已保存至:./result_image5/female_256×256/female146000.png
# epoch:146000/200000: g_total_loss:1.079843 d_total_loss:0.682450 用时:25.812330
# 输出图片已保存至:./result_image5/female_256×256/female147000.png
# epoch:147000/200000: g_total_loss:1.443556 d_total_loss:1.250714 用时:26.490823
# 输出图片已保存至:./result_image5/female_256×256/female148000.png
# epoch:148000/200000: g_total_loss:1.869965 d_total_loss:1.328540 用时:25.831704
# 输出图片已保存至:./result_image5/female_256×256/female149000.png
# epoch:149000/200000: g_total_loss:1.169195 d_total_loss:1.046938 用时:25.636298
# 输出图片已保存至:./result_image5/female_256×256/female150000.png
# epoch:150000/200000: g_total_loss:1.261222 d_total_loss:0.965162 用时:25.472424
# 输出图片已保存至:./result_image5/female_256×256/female151000.png
# epoch:151000/200000: g_total_loss:1.501109 d_total_loss:1.317002 用时:25.890538
# 输出图片已保存至:./result_image5/female_256×256/female152000.png
# epoch:152000/200000: g_total_loss:1.071781 d_total_loss:0.697209 用时:26.172410
# 输出图片已保存至:./result_image5/female_256×256/female153000.png
# epoch:153000/200000: g_total_loss:1.181992 d_total_loss:0.838246 用时:26.298905
# 输出图片已保存至:./result_image5/female_256×256/female154000.png
# epoch:154000/200000: g_total_loss:1.362433 d_total_loss:0.914917 用时:25.761355
# 输出图片已保存至:./result_image5/female_256×256/female155000.png
# epoch:155000/200000: g_total_loss:0.523160 d_total_loss:1.332292 用时:25.701282
# 输出图片已保存至:./result_image5/female_256×256/female156000.png
# epoch:156000/200000: g_total_loss:1.181812 d_total_loss:1.565939 用时:25.820102
# 输出图片已保存至:./result_image5/female_256×256/female157000.png
# epoch:157000/200000: g_total_loss:1.011420 d_total_loss:1.094936 用时:25.837262
# 输出图片已保存至:./result_image5/female_256×256/female158000.png
# epoch:158000/200000: g_total_loss:0.798759 d_total_loss:1.092869 用时:26.458459
# 输出图片已保存至:./result_image5/female_256×256/female159000.png
# epoch:159000/200000: g_total_loss:1.334819 d_total_loss:1.164174 用时:26.281229
# 输出图片已保存至:./result_image5/female_256×256/female160000.png
# epoch:160000/200000: g_total_loss:0.931606 d_total_loss:1.663231 用时:25.802239
# 输出图片已保存至:./result_image5/female_256×256/female161000.png
# epoch:161000/200000: g_total_loss:0.820168 d_total_loss:1.341139 用时:25.526910
# 输出图片已保存至:./result_image5/female_256×256/female162000.png
# epoch:162000/200000: g_total_loss:0.727960 d_total_loss:1.564322 用时:25.736849
# 输出图片已保存至:./result_image5/female_256×256/female163000.png
# epoch:163000/200000: g_total_loss:1.348345 d_total_loss:0.770503 用时:27.171666
# 输出图片已保存至:./result_image5/female_256×256/female164000.png
# epoch:164000/200000: g_total_loss:1.063262 d_total_loss:1.294551 用时:25.907670
# 输出图片已保存至:./result_image5/female_256×256/female165000.png
# epoch:165000/200000: g_total_loss:0.654259 d_total_loss:1.008352 用时:26.426623
# 输出图片已保存至:./result_image5/female_256×256/female166000.png
# epoch:166000/200000: g_total_loss:0.914839 d_total_loss:1.081786 用时:27.410123
# 输出图片已保存至:./result_image5/female_256×256/female167000.png
# epoch:167000/200000: g_total_loss:0.857446 d_total_loss:1.018025 用时:26.190229
# 输出图片已保存至:./result_image5/female_256×256/female168000.png
# epoch:168000/200000: g_total_loss:1.829265 d_total_loss:0.734572 用时:25.458853
# 输出图片已保存至:./result_image5/female_256×256/female169000.png
# epoch:169000/200000: g_total_loss:0.542420 d_total_loss:1.158359 用时:25.437849
# 输出图片已保存至:./result_image5/female_256×256/female170000.png
# epoch:170000/200000: g_total_loss:1.917977 d_total_loss:1.020821 用时:26.415813
# 输出图片已保存至:./result_image5/female_256×256/female171000.png
# epoch:171000/200000: g_total_loss:1.383710 d_total_loss:0.688315 用时:24.639158
# 输出图片已保存至:./result_image5/female_256×256/female172000.png
# epoch:172000/200000: g_total_loss:0.741210 d_total_loss:0.957536 用时:25.528974
# 输出图片已保存至:./result_image5/female_256×256/female173000.png
# epoch:173000/200000: g_total_loss:1.243744 d_total_loss:1.624480 用时:24.942470
# 输出图片已保存至:./result_image5/female_256×256/female174000.png
# epoch:174000/200000: g_total_loss:0.986472 d_total_loss:1.254702 用时:25.555926
# 输出图片已保存至:./result_image5/female_256×256/female175000.png
# epoch:175000/200000: g_total_loss:0.832016 d_total_loss:0.936268 用时:25.562540
# 输出图片已保存至:./result_image5/female_256×256/female176000.png
# epoch:176000/200000: g_total_loss:0.969896 d_total_loss:0.850994 用时:25.713630
# 输出图片已保存至:./result_image5/female_256×256/female177000.png
# epoch:177000/200000: g_total_loss:0.775260 d_total_loss:1.217374 用时:25.778465
# 输出图片已保存至:./result_image5/female_256×256/female178000.png
# epoch:178000/200000: g_total_loss:1.309685 d_total_loss:0.899755 用时:26.261735
# 输出图片已保存至:./result_image5/female_256×256/female179000.png
# epoch:179000/200000: g_total_loss:1.219918 d_total_loss:0.794190 用时:25.273625
# 输出图片已保存至:./result_image5/female_256×256/female180000.png
# epoch:180000/200000: g_total_loss:1.967279 d_total_loss:0.631015 用时:26.235449
# 输出图片已保存至:./result_image5/female_256×256/female181000.png
# epoch:181000/200000: g_total_loss:1.265723 d_total_loss:0.912465 用时:24.749301
# 输出图片已保存至:./result_image5/female_256×256/female182000.png
# epoch:182000/200000: g_total_loss:1.648012 d_total_loss:1.282070 用时:24.958768
# 输出图片已保存至:./result_image5/female_256×256/female183000.png
# epoch:183000/200000: g_total_loss:2.015308 d_total_loss:1.061603 用时:25.394719
# 输出图片已保存至:./result_image5/female_256×256/female184000.png
# epoch:184000/200000: g_total_loss:1.335284 d_total_loss:0.500553 用时:24.761257
# 输出图片已保存至:./result_image5/female_256×256/female185000.png
# epoch:185000/200000: g_total_loss:1.381898 d_total_loss:1.048416 用时:25.622346
# 输出图片已保存至:./result_image5/female_256×256/female186000.png
# epoch:186000/200000: g_total_loss:1.330423 d_total_loss:0.905916 用时:23.995546
# 输出图片已保存至:./result_image5/female_256×256/female187000.png
# epoch:187000/200000: g_total_loss:1.379553 d_total_loss:1.199370 用时:24.861967
# 输出图片已保存至:./result_image5/female_256×256/female188000.png
# epoch:188000/200000: g_total_loss:1.986627 d_total_loss:0.595682 用时:25.553073
# 输出图片已保存至:./result_image5/female_256×256/female189000.png
# epoch:189000/200000: g_total_loss:1.618411 d_total_loss:0.775976 用时:26.112784
# 输出图片已保存至:./result_image5/female_256×256/female190000.png
# epoch:190000/200000: g_total_loss:0.725345 d_total_loss:1.206090 用时:25.984375
# 输出图片已保存至:./result_image5/female_256×256/female191000.png
# epoch:191000/200000: g_total_loss:1.397942 d_total_loss:0.668716 用时:23.159740
# 输出图片已保存至:./result_image5/female_256×256/female192000.png
# epoch:192000/200000: g_total_loss:1.580487 d_total_loss:0.589182 用时:26.477824
# 输出图片已保存至:./result_image5/female_256×256/female193000.png
# epoch:193000/200000: g_total_loss:1.023587 d_total_loss:1.031188 用时:26.441236
# 输出图片已保存至:./result_image5/female_256×256/female194000.png
# epoch:194000/200000: g_total_loss:0.935678 d_total_loss:1.037855 用时:25.943434
# 输出图片已保存至:./result_image5/female_256×256/female195000.png
# epoch:195000/200000: g_total_loss:1.562662 d_total_loss:1.058871 用时:24.278007
# 输出图片已保存至:./result_image5/female_256×256/female196000.png
# epoch:196000/200000: g_total_loss:0.904610 d_total_loss:0.765964 用时:26.349166
# 输出图片已保存至:./result_image5/female_256×256/female197000.png
# epoch:197000/200000: g_total_loss:1.170367 d_total_loss:1.520038 用时:27.226587
# 输出图片已保存至:./result_image5/female_256×256/female198000.png
# epoch:198000/200000: g_total_loss:1.160809 d_total_loss:0.861214 用时:25.673545
# 输出图片已保存至:./result_image5/female_256×256/female199000.png
# epoch:199000/200000: g_total_loss:1.285879 d_total_loss:0.821982 用时:26.157750
# 输出图片已保存至:./result_image5/female_256×256/female200000.png
# epoch:200000/200000: g_total_loss:0.717878 d_total_loss:1.331027 用时:25.879814
# 已跑完200000次
# './checkpoint5/female_256×256/female-200000'

# %%
plt.figure(figsize = (12,8))
epochtime = np.arange(0,201000,1000)
plt.plot(epochtime,g_total_loss_list,color='red',marker='o',linestyle='-',linewidth=1)
plt.xlabel('training epoch')
plt.xticks(rotation=45) # 旋转90度
plt.ylabel('total loss of generator')
plt.title('total loss of generator changed by epoch times')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize = (12,8))
epochtime = np.arange(1000,201000,1000)
plt.plot(epochtime,d_total_loss_list[1:],color='blue',marker='o',linestyle='-',linewidth=1)
plt.xlabel('training epoch')
plt.xticks(rotation=45) # 旋转90度
plt.ylabel('total loss of discriminator')
plt.title('total loss of discriminator changed by epoch times')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
print("mean of total loss of generator: {:.6f}".format(np.mean(g_total_loss_list)))
print("mean of total loss of discriminator: {:.6f}".format(np.mean(d_total_loss_list)))
# Out:
# mean of total loss of generator: 1.341015
# mean of total loss of discriminator: 0.987810

# %%
# 定义参数
batch_size = 1  # 每次测试的批次（太大可能会显存不够而报错，可调小再试）
fake_num = 500  # 生成的图片的个数
dataset_name = 'female'  # 数据集的名字  star_imgs
h, w, c = 256, 256, 3  # 数据集图片的宽和高，也是生成图片的宽和高
noise_dim = 100  # 输入噪声的维度（一般不改）

# %%
# 创建文件夹
directory = './checkpoint5/' + dataset_name + '_%s×%s' % (h, w)  # 输出参数保存的文件夹，一般不改
image_dir = './result_image5/' + dataset_name + '_%s×%s' % (h, w)  # 输出图片保存的文件夹，一般不改

# %%
# 搭建网络
generator = generator_network_dcgan(h, w, c, noise_dim=noise_dim)
discriminator = discriminator_network_dcgan(h, w, c)
# 加载参数
checkpoint = tf.train.Checkpoint(generator=generator,
                                 discriminator=discriminator)
checkpoint.restore(tf.train.latest_checkpoint(directory))  # 断点续训
# 预测
# noise_test = tf.random.normal([fake_num, 100])
noise_test = tf.random.uniform([fake_num, noise_dim], -1, 1)
fake_images = generator.predict(noise_test, batch_size=batch_size)  # (b,h,w,c)
fake_images = (fake_images.reshape(-1, h, w, c) * 127.5 + 127.5).astype('uint8')  # (b,h,w,c)

# %%
# 保存生成的图片
os.makedirs('test_from_dir5', exist_ok=True)
for i, fake_image in enumerate(fake_images):
    # i+=5000
    save_path = os.path.join('test_from_dir5', '%s.png' % (i + 1))
    cv.imwrite(save_path, fake_image)
    print('输出的单张图片已保存到：%s' % save_path)
# Out:
# 输出的单张图片已保存到：test_from_dir5/1.png
# 输出的单张图片已保存到：test_from_dir5/2.png
# 输出的单张图片已保存到：test_from_dir5/3.png
# 输出的单张图片已保存到：test_from_dir5/4.png
# 输出的单张图片已保存到：test_from_dir5/5.png
# 输出的单张图片已保存到：test_from_dir5/6.png
# 输出的单张图片已保存到：test_from_dir5/7.png
# 输出的单张图片已保存到：test_from_dir5/8.png
# 输出的单张图片已保存到：test_from_dir5/9.png
# 输出的单张图片已保存到：test_from_dir5/10.png
# 输出的单张图片已保存到：test_from_dir5/11.png
# 输出的单张图片已保存到：test_from_dir5/12.png
# 输出的单张图片已保存到：test_from_dir5/13.png
# 输出的单张图片已保存到：test_from_dir5/14.png
# 输出的单张图片已保存到：test_from_dir5/15.png
# 输出的单张图片已保存到：test_from_dir5/16.png
# 输出的单张图片已保存到：test_from_dir5/17.png
# 输出的单张图片已保存到：test_from_dir5/18.png
# 输出的单张图片已保存到：test_from_dir5/19.png
# 输出的单张图片已保存到：test_from_dir5/20.png
# 输出的单张图片已保存到：test_from_dir5/21.png
# 输出的单张图片已保存到：test_from_dir5/22.png
# 输出的单张图片已保存到：test_from_dir5/23.png
# 输出的单张图片已保存到：test_from_dir5/24.png
# 输出的单张图片已保存到：test_from_dir5/25.png
# 输出的单张图片已保存到：test_from_dir5/26.png
# 输出的单张图片已保存到：test_from_dir5/27.png
# 输出的单张图片已保存到：test_from_dir5/28.png
# 输出的单张图片已保存到：test_from_dir5/29.png
# 输出的单张图片已保存到：test_from_dir5/30.png
# 输出的单张图片已保存到：test_from_dir5/31.png
# 输出的单张图片已保存到：test_from_dir5/32.png
# 输出的单张图片已保存到：test_from_dir5/33.png
# 输出的单张图片已保存到：test_from_dir5/34.png
# 输出的单张图片已保存到：test_from_dir5/35.png
# 输出的单张图片已保存到：test_from_dir5/36.png
# 输出的单张图片已保存到：test_from_dir5/37.png
# 输出的单张图片已保存到：test_from_dir5/38.png
# 输出的单张图片已保存到：test_from_dir5/39.png
# 输出的单张图片已保存到：test_from_dir5/40.png
# 输出的单张图片已保存到：test_from_dir5/41.png
# 输出的单张图片已保存到：test_from_dir5/42.png
# 输出的单张图片已保存到：test_from_dir5/43.png
# 输出的单张图片已保存到：test_from_dir5/44.png
# 输出的单张图片已保存到：test_from_dir5/45.png
# 输出的单张图片已保存到：test_from_dir5/46.png
# 输出的单张图片已保存到：test_from_dir5/47.png
# 输出的单张图片已保存到：test_from_dir5/48.png
# 输出的单张图片已保存到：test_from_dir5/49.png
# 输出的单张图片已保存到：test_from_dir5/50.png
# 输出的单张图片已保存到：test_from_dir5/51.png
# 输出的单张图片已保存到：test_from_dir5/52.png
# 输出的单张图片已保存到：test_from_dir5/53.png
# 输出的单张图片已保存到：test_from_dir5/54.png
# 输出的单张图片已保存到：test_from_dir5/55.png
# 输出的单张图片已保存到：test_from_dir5/56.png
# 输出的单张图片已保存到：test_from_dir5/57.png
# 输出的单张图片已保存到：test_from_dir5/58.png
# 输出的单张图片已保存到：test_from_dir5/59.png
# 输出的单张图片已保存到：test_from_dir5/60.png
# 输出的单张图片已保存到：test_from_dir5/61.png
# 输出的单张图片已保存到：test_from_dir5/62.png
# 输出的单张图片已保存到：test_from_dir5/63.png
# 输出的单张图片已保存到：test_from_dir5/64.png
# 输出的单张图片已保存到：test_from_dir5/65.png
# 输出的单张图片已保存到：test_from_dir5/66.png
# 输出的单张图片已保存到：test_from_dir5/67.png
# 输出的单张图片已保存到：test_from_dir5/68.png
# 输出的单张图片已保存到：test_from_dir5/69.png
# 输出的单张图片已保存到：test_from_dir5/70.png
# 输出的单张图片已保存到：test_from_dir5/71.png
# 输出的单张图片已保存到：test_from_dir5/72.png
# 输出的单张图片已保存到：test_from_dir5/73.png
# 输出的单张图片已保存到：test_from_dir5/74.png
# 输出的单张图片已保存到：test_from_dir5/75.png
# 输出的单张图片已保存到：test_from_dir5/76.png
# 输出的单张图片已保存到：test_from_dir5/77.png
# 输出的单张图片已保存到：test_from_dir5/78.png
# 输出的单张图片已保存到：test_from_dir5/79.png
# 输出的单张图片已保存到：test_from_dir5/80.png
# 输出的单张图片已保存到：test_from_dir5/81.png
# 输出的单张图片已保存到：test_from_dir5/82.png
# 输出的单张图片已保存到：test_from_dir5/83.png
# 输出的单张图片已保存到：test_from_dir5/84.png
# 输出的单张图片已保存到：test_from_dir5/85.png
# 输出的单张图片已保存到：test_from_dir5/86.png
# 输出的单张图片已保存到：test_from_dir5/87.png
# 输出的单张图片已保存到：test_from_dir5/88.png
# 输出的单张图片已保存到：test_from_dir5/89.png
# 输出的单张图片已保存到：test_from_dir5/90.png
# 输出的单张图片已保存到：test_from_dir5/91.png
# 输出的单张图片已保存到：test_from_dir5/92.png
# 输出的单张图片已保存到：test_from_dir5/93.png
# 输出的单张图片已保存到：test_from_dir5/94.png
# 输出的单张图片已保存到：test_from_dir5/95.png
# 输出的单张图片已保存到：test_from_dir5/96.png
# 输出的单张图片已保存到：test_from_dir5/97.png
# 输出的单张图片已保存到：test_from_dir5/98.png
# 输出的单张图片已保存到：test_from_dir5/99.png
# 输出的单张图片已保存到：test_from_dir5/100.png
# 输出的单张图片已保存到：test_from_dir5/101.png
# 输出的单张图片已保存到：test_from_dir5/102.png
# 输出的单张图片已保存到：test_from_dir5/103.png
# 输出的单张图片已保存到：test_from_dir5/104.png
# 输出的单张图片已保存到：test_from_dir5/105.png
# 输出的单张图片已保存到：test_from_dir5/106.png
# 输出的单张图片已保存到：test_from_dir5/107.png
# 输出的单张图片已保存到：test_from_dir5/108.png
# 输出的单张图片已保存到：test_from_dir5/109.png
# 输出的单张图片已保存到：test_from_dir5/110.png
# 输出的单张图片已保存到：test_from_dir5/111.png
# 输出的单张图片已保存到：test_from_dir5/112.png
# 输出的单张图片已保存到：test_from_dir5/113.png
# 输出的单张图片已保存到：test_from_dir5/114.png
# 输出的单张图片已保存到：test_from_dir5/115.png
# 输出的单张图片已保存到：test_from_dir5/116.png
# 输出的单张图片已保存到：test_from_dir5/117.png
# 输出的单张图片已保存到：test_from_dir5/118.png
# 输出的单张图片已保存到：test_from_dir5/119.png
# 输出的单张图片已保存到：test_from_dir5/120.png
# 输出的单张图片已保存到：test_from_dir5/121.png
# 输出的单张图片已保存到：test_from_dir5/122.png
# 输出的单张图片已保存到：test_from_dir5/123.png
# 输出的单张图片已保存到：test_from_dir5/124.png
# 输出的单张图片已保存到：test_from_dir5/125.png
# 输出的单张图片已保存到：test_from_dir5/126.png
# 输出的单张图片已保存到：test_from_dir5/127.png
# 输出的单张图片已保存到：test_from_dir5/128.png
# 输出的单张图片已保存到：test_from_dir5/129.png
# 输出的单张图片已保存到：test_from_dir5/130.png
# 输出的单张图片已保存到：test_from_dir5/131.png
# 输出的单张图片已保存到：test_from_dir5/132.png
# 输出的单张图片已保存到：test_from_dir5/133.png
# 输出的单张图片已保存到：test_from_dir5/134.png
# 输出的单张图片已保存到：test_from_dir5/135.png
# 输出的单张图片已保存到：test_from_dir5/136.png
# 输出的单张图片已保存到：test_from_dir5/137.png
# 输出的单张图片已保存到：test_from_dir5/138.png
# 输出的单张图片已保存到：test_from_dir5/139.png
# 输出的单张图片已保存到：test_from_dir5/140.png
# 输出的单张图片已保存到：test_from_dir5/141.png
# 输出的单张图片已保存到：test_from_dir5/142.png
# 输出的单张图片已保存到：test_from_dir5/143.png
# 输出的单张图片已保存到：test_from_dir5/144.png
# 输出的单张图片已保存到：test_from_dir5/145.png
# 输出的单张图片已保存到：test_from_dir5/146.png
# 输出的单张图片已保存到：test_from_dir5/147.png
# 输出的单张图片已保存到：test_from_dir5/148.png
# 输出的单张图片已保存到：test_from_dir5/149.png
# 输出的单张图片已保存到：test_from_dir5/150.png
# 输出的单张图片已保存到：test_from_dir5/151.png
# 输出的单张图片已保存到：test_from_dir5/152.png
# 输出的单张图片已保存到：test_from_dir5/153.png
# 输出的单张图片已保存到：test_from_dir5/154.png
# 输出的单张图片已保存到：test_from_dir5/155.png
# 输出的单张图片已保存到：test_from_dir5/156.png
# 输出的单张图片已保存到：test_from_dir5/157.png
# 输出的单张图片已保存到：test_from_dir5/158.png
# 输出的单张图片已保存到：test_from_dir5/159.png
# 输出的单张图片已保存到：test_from_dir5/160.png
# 输出的单张图片已保存到：test_from_dir5/161.png
# 输出的单张图片已保存到：test_from_dir5/162.png
# 输出的单张图片已保存到：test_from_dir5/163.png
# 输出的单张图片已保存到：test_from_dir5/164.png
# 输出的单张图片已保存到：test_from_dir5/165.png
# 输出的单张图片已保存到：test_from_dir5/166.png
# 输出的单张图片已保存到：test_from_dir5/167.png
# 输出的单张图片已保存到：test_from_dir5/168.png
# 输出的单张图片已保存到：test_from_dir5/169.png
# 输出的单张图片已保存到：test_from_dir5/170.png
# 输出的单张图片已保存到：test_from_dir5/171.png
# 输出的单张图片已保存到：test_from_dir5/172.png
# 输出的单张图片已保存到：test_from_dir5/173.png
# 输出的单张图片已保存到：test_from_dir5/174.png
# 输出的单张图片已保存到：test_from_dir5/175.png
# 输出的单张图片已保存到：test_from_dir5/176.png
# 输出的单张图片已保存到：test_from_dir5/177.png
# 输出的单张图片已保存到：test_from_dir5/178.png
# 输出的单张图片已保存到：test_from_dir5/179.png
# 输出的单张图片已保存到：test_from_dir5/180.png
# 输出的单张图片已保存到：test_from_dir5/181.png
# 输出的单张图片已保存到：test_from_dir5/182.png
# 输出的单张图片已保存到：test_from_dir5/183.png
# 输出的单张图片已保存到：test_from_dir5/184.png
# 输出的单张图片已保存到：test_from_dir5/185.png
# 输出的单张图片已保存到：test_from_dir5/186.png
# 输出的单张图片已保存到：test_from_dir5/187.png
# 输出的单张图片已保存到：test_from_dir5/188.png
# 输出的单张图片已保存到：test_from_dir5/189.png
# 输出的单张图片已保存到：test_from_dir5/190.png
# 输出的单张图片已保存到：test_from_dir5/191.png
# 输出的单张图片已保存到：test_from_dir5/192.png
# 输出的单张图片已保存到：test_from_dir5/193.png
# 输出的单张图片已保存到：test_from_dir5/194.png
# 输出的单张图片已保存到：test_from_dir5/195.png
# 输出的单张图片已保存到：test_from_dir5/196.png
# 输出的单张图片已保存到：test_from_dir5/197.png
# 输出的单张图片已保存到：test_from_dir5/198.png
# 输出的单张图片已保存到：test_from_dir5/199.png
# 输出的单张图片已保存到：test_from_dir5/200.png
# 输出的单张图片已保存到：test_from_dir5/201.png
# 输出的单张图片已保存到：test_from_dir5/202.png
# 输出的单张图片已保存到：test_from_dir5/203.png
# 输出的单张图片已保存到：test_from_dir5/204.png
# 输出的单张图片已保存到：test_from_dir5/205.png
# 输出的单张图片已保存到：test_from_dir5/206.png
# 输出的单张图片已保存到：test_from_dir5/207.png
# 输出的单张图片已保存到：test_from_dir5/208.png
# 输出的单张图片已保存到：test_from_dir5/209.png
# 输出的单张图片已保存到：test_from_dir5/210.png
# 输出的单张图片已保存到：test_from_dir5/211.png
# 输出的单张图片已保存到：test_from_dir5/212.png
# 输出的单张图片已保存到：test_from_dir5/213.png
# 输出的单张图片已保存到：test_from_dir5/214.png
# 输出的单张图片已保存到：test_from_dir5/215.png
# 输出的单张图片已保存到：test_from_dir5/216.png
# 输出的单张图片已保存到：test_from_dir5/217.png
# 输出的单张图片已保存到：test_from_dir5/218.png
# 输出的单张图片已保存到：test_from_dir5/219.png
# 输出的单张图片已保存到：test_from_dir5/220.png
# 输出的单张图片已保存到：test_from_dir5/221.png
# 输出的单张图片已保存到：test_from_dir5/222.png
# 输出的单张图片已保存到：test_from_dir5/223.png
# 输出的单张图片已保存到：test_from_dir5/224.png
# 输出的单张图片已保存到：test_from_dir5/225.png
# 输出的单张图片已保存到：test_from_dir5/226.png
# 输出的单张图片已保存到：test_from_dir5/227.png
# 输出的单张图片已保存到：test_from_dir5/228.png
# 输出的单张图片已保存到：test_from_dir5/229.png
# 输出的单张图片已保存到：test_from_dir5/230.png
# 输出的单张图片已保存到：test_from_dir5/231.png
# 输出的单张图片已保存到：test_from_dir5/232.png
# 输出的单张图片已保存到：test_from_dir5/233.png
# 输出的单张图片已保存到：test_from_dir5/234.png
# 输出的单张图片已保存到：test_from_dir5/235.png
# 输出的单张图片已保存到：test_from_dir5/236.png
# 输出的单张图片已保存到：test_from_dir5/237.png
# 输出的单张图片已保存到：test_from_dir5/238.png
# 输出的单张图片已保存到：test_from_dir5/239.png
# 输出的单张图片已保存到：test_from_dir5/240.png
# 输出的单张图片已保存到：test_from_dir5/241.png
# 输出的单张图片已保存到：test_from_dir5/242.png
# 输出的单张图片已保存到：test_from_dir5/243.png
# 输出的单张图片已保存到：test_from_dir5/244.png
# 输出的单张图片已保存到：test_from_dir5/245.png
# 输出的单张图片已保存到：test_from_dir5/246.png
# 输出的单张图片已保存到：test_from_dir5/247.png
# 输出的单张图片已保存到：test_from_dir5/248.png
# 输出的单张图片已保存到：test_from_dir5/249.png
# 输出的单张图片已保存到：test_from_dir5/250.png
# 输出的单张图片已保存到：test_from_dir5/251.png
# 输出的单张图片已保存到：test_from_dir5/252.png
# 输出的单张图片已保存到：test_from_dir5/253.png
# 输出的单张图片已保存到：test_from_dir5/254.png
# 输出的单张图片已保存到：test_from_dir5/255.png
# 输出的单张图片已保存到：test_from_dir5/256.png
# 输出的单张图片已保存到：test_from_dir5/257.png
# 输出的单张图片已保存到：test_from_dir5/258.png
# 输出的单张图片已保存到：test_from_dir5/259.png
# 输出的单张图片已保存到：test_from_dir5/260.png
# 输出的单张图片已保存到：test_from_dir5/261.png
# 输出的单张图片已保存到：test_from_dir5/262.png
# 输出的单张图片已保存到：test_from_dir5/263.png
# 输出的单张图片已保存到：test_from_dir5/264.png
# 输出的单张图片已保存到：test_from_dir5/265.png
# 输出的单张图片已保存到：test_from_dir5/266.png
# 输出的单张图片已保存到：test_from_dir5/267.png
# 输出的单张图片已保存到：test_from_dir5/268.png
# 输出的单张图片已保存到：test_from_dir5/269.png
# 输出的单张图片已保存到：test_from_dir5/270.png
# 输出的单张图片已保存到：test_from_dir5/271.png
# 输出的单张图片已保存到：test_from_dir5/272.png
# 输出的单张图片已保存到：test_from_dir5/273.png
# 输出的单张图片已保存到：test_from_dir5/274.png
# 输出的单张图片已保存到：test_from_dir5/275.png
# 输出的单张图片已保存到：test_from_dir5/276.png
# 输出的单张图片已保存到：test_from_dir5/277.png
# 输出的单张图片已保存到：test_from_dir5/278.png
# 输出的单张图片已保存到：test_from_dir5/279.png
# 输出的单张图片已保存到：test_from_dir5/280.png
# 输出的单张图片已保存到：test_from_dir5/281.png
# 输出的单张图片已保存到：test_from_dir5/282.png
# 输出的单张图片已保存到：test_from_dir5/283.png
# 输出的单张图片已保存到：test_from_dir5/284.png
# 输出的单张图片已保存到：test_from_dir5/285.png
# 输出的单张图片已保存到：test_from_dir5/286.png
# 输出的单张图片已保存到：test_from_dir5/287.png
# 输出的单张图片已保存到：test_from_dir5/288.png
# 输出的单张图片已保存到：test_from_dir5/289.png
# 输出的单张图片已保存到：test_from_dir5/290.png
# 输出的单张图片已保存到：test_from_dir5/291.png
# 输出的单张图片已保存到：test_from_dir5/292.png
# 输出的单张图片已保存到：test_from_dir5/293.png
# 输出的单张图片已保存到：test_from_dir5/294.png
# 输出的单张图片已保存到：test_from_dir5/295.png
# 输出的单张图片已保存到：test_from_dir5/296.png
# 输出的单张图片已保存到：test_from_dir5/297.png
# 输出的单张图片已保存到：test_from_dir5/298.png
# 输出的单张图片已保存到：test_from_dir5/299.png
# 输出的单张图片已保存到：test_from_dir5/300.png
# 输出的单张图片已保存到：test_from_dir5/301.png
# 输出的单张图片已保存到：test_from_dir5/302.png
# 输出的单张图片已保存到：test_from_dir5/303.png
# 输出的单张图片已保存到：test_from_dir5/304.png
# 输出的单张图片已保存到：test_from_dir5/305.png
# 输出的单张图片已保存到：test_from_dir5/306.png
# 输出的单张图片已保存到：test_from_dir5/307.png
# 输出的单张图片已保存到：test_from_dir5/308.png
# 输出的单张图片已保存到：test_from_dir5/309.png
# 输出的单张图片已保存到：test_from_dir5/310.png
# 输出的单张图片已保存到：test_from_dir5/311.png
# 输出的单张图片已保存到：test_from_dir5/312.png
# 输出的单张图片已保存到：test_from_dir5/313.png
# 输出的单张图片已保存到：test_from_dir5/314.png
# 输出的单张图片已保存到：test_from_dir5/315.png
# 输出的单张图片已保存到：test_from_dir5/316.png
# 输出的单张图片已保存到：test_from_dir5/317.png
# 输出的单张图片已保存到：test_from_dir5/318.png
# 输出的单张图片已保存到：test_from_dir5/319.png
# 输出的单张图片已保存到：test_from_dir5/320.png
# 输出的单张图片已保存到：test_from_dir5/321.png
# 输出的单张图片已保存到：test_from_dir5/322.png
# 输出的单张图片已保存到：test_from_dir5/323.png
# 输出的单张图片已保存到：test_from_dir5/324.png
# 输出的单张图片已保存到：test_from_dir5/325.png
# 输出的单张图片已保存到：test_from_dir5/326.png
# 输出的单张图片已保存到：test_from_dir5/327.png
# 输出的单张图片已保存到：test_from_dir5/328.png
# 输出的单张图片已保存到：test_from_dir5/329.png
# 输出的单张图片已保存到：test_from_dir5/330.png
# 输出的单张图片已保存到：test_from_dir5/331.png
# 输出的单张图片已保存到：test_from_dir5/332.png
# 输出的单张图片已保存到：test_from_dir5/333.png
# 输出的单张图片已保存到：test_from_dir5/334.png
# 输出的单张图片已保存到：test_from_dir5/335.png
# 输出的单张图片已保存到：test_from_dir5/336.png
# 输出的单张图片已保存到：test_from_dir5/337.png
# 输出的单张图片已保存到：test_from_dir5/338.png
# 输出的单张图片已保存到：test_from_dir5/339.png
# 输出的单张图片已保存到：test_from_dir5/340.png
# 输出的单张图片已保存到：test_from_dir5/341.png
# 输出的单张图片已保存到：test_from_dir5/342.png
# 输出的单张图片已保存到：test_from_dir5/343.png
# 输出的单张图片已保存到：test_from_dir5/344.png
# 输出的单张图片已保存到：test_from_dir5/345.png
# 输出的单张图片已保存到：test_from_dir5/346.png
# 输出的单张图片已保存到：test_from_dir5/347.png
# 输出的单张图片已保存到：test_from_dir5/348.png
# 输出的单张图片已保存到：test_from_dir5/349.png
# 输出的单张图片已保存到：test_from_dir5/350.png
# 输出的单张图片已保存到：test_from_dir5/351.png
# 输出的单张图片已保存到：test_from_dir5/352.png
# 输出的单张图片已保存到：test_from_dir5/353.png
# 输出的单张图片已保存到：test_from_dir5/354.png
# 输出的单张图片已保存到：test_from_dir5/355.png
# 输出的单张图片已保存到：test_from_dir5/356.png
# 输出的单张图片已保存到：test_from_dir5/357.png
# 输出的单张图片已保存到：test_from_dir5/358.png
# 输出的单张图片已保存到：test_from_dir5/359.png
# 输出的单张图片已保存到：test_from_dir5/360.png
# 输出的单张图片已保存到：test_from_dir5/361.png
# 输出的单张图片已保存到：test_from_dir5/362.png
# 输出的单张图片已保存到：test_from_dir5/363.png
# 输出的单张图片已保存到：test_from_dir5/364.png
# 输出的单张图片已保存到：test_from_dir5/365.png
# 输出的单张图片已保存到：test_from_dir5/366.png
# 输出的单张图片已保存到：test_from_dir5/367.png
# 输出的单张图片已保存到：test_from_dir5/368.png
# 输出的单张图片已保存到：test_from_dir5/369.png
# 输出的单张图片已保存到：test_from_dir5/370.png
# 输出的单张图片已保存到：test_from_dir5/371.png
# 输出的单张图片已保存到：test_from_dir5/372.png
# 输出的单张图片已保存到：test_from_dir5/373.png
# 输出的单张图片已保存到：test_from_dir5/374.png
# 输出的单张图片已保存到：test_from_dir5/375.png
# 输出的单张图片已保存到：test_from_dir5/376.png
# 输出的单张图片已保存到：test_from_dir5/377.png
# 输出的单张图片已保存到：test_from_dir5/378.png
# 输出的单张图片已保存到：test_from_dir5/379.png
# 输出的单张图片已保存到：test_from_dir5/380.png
# 输出的单张图片已保存到：test_from_dir5/381.png
# 输出的单张图片已保存到：test_from_dir5/382.png
# 输出的单张图片已保存到：test_from_dir5/383.png
# 输出的单张图片已保存到：test_from_dir5/384.png
# 输出的单张图片已保存到：test_from_dir5/385.png
# 输出的单张图片已保存到：test_from_dir5/386.png
# 输出的单张图片已保存到：test_from_dir5/387.png
# 输出的单张图片已保存到：test_from_dir5/388.png
# 输出的单张图片已保存到：test_from_dir5/389.png
# 输出的单张图片已保存到：test_from_dir5/390.png
# 输出的单张图片已保存到：test_from_dir5/391.png
# 输出的单张图片已保存到：test_from_dir5/392.png
# 输出的单张图片已保存到：test_from_dir5/393.png
# 输出的单张图片已保存到：test_from_dir5/394.png
# 输出的单张图片已保存到：test_from_dir5/395.png
# 输出的单张图片已保存到：test_from_dir5/396.png
# 输出的单张图片已保存到：test_from_dir5/397.png
# 输出的单张图片已保存到：test_from_dir5/398.png
# 输出的单张图片已保存到：test_from_dir5/399.png
# 输出的单张图片已保存到：test_from_dir5/400.png
# 输出的单张图片已保存到：test_from_dir5/401.png
# 输出的单张图片已保存到：test_from_dir5/402.png
# 输出的单张图片已保存到：test_from_dir5/403.png
# 输出的单张图片已保存到：test_from_dir5/404.png
# 输出的单张图片已保存到：test_from_dir5/405.png
# 输出的单张图片已保存到：test_from_dir5/406.png
# 输出的单张图片已保存到：test_from_dir5/407.png
# 输出的单张图片已保存到：test_from_dir5/408.png
# 输出的单张图片已保存到：test_from_dir5/409.png
# 输出的单张图片已保存到：test_from_dir5/410.png
# 输出的单张图片已保存到：test_from_dir5/411.png
# 输出的单张图片已保存到：test_from_dir5/412.png
# 输出的单张图片已保存到：test_from_dir5/413.png
# 输出的单张图片已保存到：test_from_dir5/414.png
# 输出的单张图片已保存到：test_from_dir5/415.png
# 输出的单张图片已保存到：test_from_dir5/416.png
# 输出的单张图片已保存到：test_from_dir5/417.png
# 输出的单张图片已保存到：test_from_dir5/418.png
# 输出的单张图片已保存到：test_from_dir5/419.png
# 输出的单张图片已保存到：test_from_dir5/420.png
# 输出的单张图片已保存到：test_from_dir5/421.png
# 输出的单张图片已保存到：test_from_dir5/422.png
# 输出的单张图片已保存到：test_from_dir5/423.png
# 输出的单张图片已保存到：test_from_dir5/424.png
# 输出的单张图片已保存到：test_from_dir5/425.png
# 输出的单张图片已保存到：test_from_dir5/426.png
# 输出的单张图片已保存到：test_from_dir5/427.png
# 输出的单张图片已保存到：test_from_dir5/428.png
# 输出的单张图片已保存到：test_from_dir5/429.png
# 输出的单张图片已保存到：test_from_dir5/430.png
# 输出的单张图片已保存到：test_from_dir5/431.png
# 输出的单张图片已保存到：test_from_dir5/432.png
# 输出的单张图片已保存到：test_from_dir5/433.png
# 输出的单张图片已保存到：test_from_dir5/434.png
# 输出的单张图片已保存到：test_from_dir5/435.png
# 输出的单张图片已保存到：test_from_dir5/436.png
# 输出的单张图片已保存到：test_from_dir5/437.png
# 输出的单张图片已保存到：test_from_dir5/438.png
# 输出的单张图片已保存到：test_from_dir5/439.png
# 输出的单张图片已保存到：test_from_dir5/440.png
# 输出的单张图片已保存到：test_from_dir5/441.png
# 输出的单张图片已保存到：test_from_dir5/442.png
# 输出的单张图片已保存到：test_from_dir5/443.png
# 输出的单张图片已保存到：test_from_dir5/444.png
# 输出的单张图片已保存到：test_from_dir5/445.png
# 输出的单张图片已保存到：test_from_dir5/446.png
# 输出的单张图片已保存到：test_from_dir5/447.png
# 输出的单张图片已保存到：test_from_dir5/448.png
# 输出的单张图片已保存到：test_from_dir5/449.png
# 输出的单张图片已保存到：test_from_dir5/450.png
# 输出的单张图片已保存到：test_from_dir5/451.png
# 输出的单张图片已保存到：test_from_dir5/452.png
# 输出的单张图片已保存到：test_from_dir5/453.png
# 输出的单张图片已保存到：test_from_dir5/454.png
# 输出的单张图片已保存到：test_from_dir5/455.png
# 输出的单张图片已保存到：test_from_dir5/456.png
# 输出的单张图片已保存到：test_from_dir5/457.png
# 输出的单张图片已保存到：test_from_dir5/458.png
# 输出的单张图片已保存到：test_from_dir5/459.png
# 输出的单张图片已保存到：test_from_dir5/460.png
# 输出的单张图片已保存到：test_from_dir5/461.png
# 输出的单张图片已保存到：test_from_dir5/462.png
# 输出的单张图片已保存到：test_from_dir5/463.png
# 输出的单张图片已保存到：test_from_dir5/464.png
# 输出的单张图片已保存到：test_from_dir5/465.png
# 输出的单张图片已保存到：test_from_dir5/466.png
# 输出的单张图片已保存到：test_from_dir5/467.png
# 输出的单张图片已保存到：test_from_dir5/468.png
# 输出的单张图片已保存到：test_from_dir5/469.png
# 输出的单张图片已保存到：test_from_dir5/470.png
# 输出的单张图片已保存到：test_from_dir5/471.png
# 输出的单张图片已保存到：test_from_dir5/472.png
# 输出的单张图片已保存到：test_from_dir5/473.png
# 输出的单张图片已保存到：test_from_dir5/474.png
# 输出的单张图片已保存到：test_from_dir5/475.png
# 输出的单张图片已保存到：test_from_dir5/476.png
# 输出的单张图片已保存到：test_from_dir5/477.png
# 输出的单张图片已保存到：test_from_dir5/478.png
# 输出的单张图片已保存到：test_from_dir5/479.png
# 输出的单张图片已保存到：test_from_dir5/480.png
# 输出的单张图片已保存到：test_from_dir5/481.png
# 输出的单张图片已保存到：test_from_dir5/482.png
# 输出的单张图片已保存到：test_from_dir5/483.png
# 输出的单张图片已保存到：test_from_dir5/484.png
# 输出的单张图片已保存到：test_from_dir5/485.png
# 输出的单张图片已保存到：test_from_dir5/486.png
# 输出的单张图片已保存到：test_from_dir5/487.png
# 输出的单张图片已保存到：test_from_dir5/488.png
# 输出的单张图片已保存到：test_from_dir5/489.png
# 输出的单张图片已保存到：test_from_dir5/490.png
# 输出的单张图片已保存到：test_from_dir5/491.png
# 输出的单张图片已保存到：test_from_dir5/492.png
# 输出的单张图片已保存到：test_from_dir5/493.png
# 输出的单张图片已保存到：test_from_dir5/494.png
# 输出的单张图片已保存到：test_from_dir5/495.png
# 输出的单张图片已保存到：test_from_dir5/496.png
# 输出的单张图片已保存到：test_from_dir5/497.png
# 输出的单张图片已保存到：test_from_dir5/498.png
# 输出的单张图片已保存到：test_from_dir5/499.png
# 输出的单张图片已保存到：test_from_dir5/500.png

# %%
# 查看部分生成图片
plt.figure(figsize=(12,12))
for i in range(16):
    plt.subplot(4, 4, i + 1)
    if c == 3:
        fake_images[i] = cv.cvtColor(fake_images[i], cv.COLOR_BGR2RGB)
    plt.imshow(fake_images[i])
    plt.axis('off')
plt.show()
