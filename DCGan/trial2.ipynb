# %%
import sys, os
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow.keras import datasets, optimizers, metrics, layers, Sequential, Model, Input, losses
from load_datasets import DataLoader
import time

# %%
os.environ['KMP_DUPLICATE_LIB_OK']='True'  #防止训练过程中的kernel发生crash的情形

# %%
# 卷积层的生成器和鉴别器
def generator_network_dcgan(h, w, c, noise_dim=100):  # 输入噪声和标签，输出假图
    h_, w_ = h // 4, w // 4
    input_noise = Input(shape=(noise_dim,))  # (b,100)
    x = layers.Dense(h_ * w_ * 128)(input_noise)  #全连接层用于调整噪声的维度
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)
    x = layers.Reshape((h_, w_, 128))(x)  # (b,h/4,w/4,256)

    x = layers.Conv2DTranspose(64, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/2,w/2,128)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)

    x = layers.Conv2DTranspose(32, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h,w,64)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)
    x = layers.Conv2DTranspose(c, (3, 3), padding='same', activation='tanh')(x)  # (b,h,w,c)
    generator = Model(input_noise, x)
    return generator

# %%
def discriminator_network_dcgan(h, w, c):  # 输入图片和标签，输出待验证的值。输出1为真，0为假
    input_image = Input(shape=(h, w, c))  # (b,h,w,c)
    x = layers.Conv2D(32, (3, 3), strides=(2, 2), padding='same')(input_image)  # (b,h/2,w/2,64)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)
    x = layers.Dropout(0.3)(x)  #先不添加dropout层

    x = layers.Conv2D(64, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/4,w/4,128)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)
    x = layers.Dropout(0.3)(x)

    x = layers.Conv2D(128, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/4,w/4,256)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)
    x = layers.Dropout(0.3)(x)

    x = layers.Flatten()(x)  # (b,h/4*w/4*256)
    validity = layers.Dense(1, activation=None)(x)  # (b,1)

    discriminator = Model(input_image, validity)
    return discriminator

# %%
# WGAN-GP梯度控制函数
def gradient_penalty(discriminator, batch_x, fake_image):
    #梯度惩罚项计算函数
    batchsz = batch_x.shape[0]

    #每个样本均随机采样t,用于插值
    t = tf.random.uniform([batchsz,1,1,1])
    #自动扩展为x的形状:[b,1,1,1] => [b,h,w,c]
    t = tf.broadcast_to(t, batch_x.shape)
    #在真假图片之间作线性插值
    interplate = t * batch_x + (1-t) * fake_image
    #在梯度环境中计算 D 对插值样本的梯度
    with tf.GradientTape() as tape:
        tape.watch([interplate])
        d_interplate_logits = discriminator(interplate)

        grads = tape.gradient(d_interplate_logits, interplate)

        #计算每个样本的梯度的范数:[b,h,w,c] => [b,-1]
        grads = tf.reshape(grads, [grads.shape[0],-1])
        gp = tf.norm(grads,axis=1)
        #计算梯度惩罚项
        gp = tf.reduce_mean((gp-1.)**2)

    return gp

# %%
def save_image(fake_image, fake_label=None, fake_num=16, save_to=''):  # X为4维的带批次的图片
    ''' 
    用于保存图片的函数
    '''
    plt.figure()
    _, h, w, c = fake_image.shape  #设定生成假图的shape（128*128*3）
    if fake_num > 1:
        for i in range(fake_num):
            plt.subplot(4, 4, i + 1)  #训练过程中的迭代以4*4=16（一次保存16张图片）
            if c == 3:  # 如果是bgr则转为rgb（通道的转换）
                plt.imshow(cv.cvtColor(fake_image[i], cv.COLOR_BGR2RGB))  #对于一般格式与BGR格式都予以显示
            if c == 1:  # 如果是灰图则显示灰图
                plt.imshow(np.squeeze(fake_image[i]), cmap='gray')
            if fake_label is not None:  # 如果有标签则传入标签（这是为了在真图与假图之间鉴别时用）
                plt.title(fake_label[i])
            plt.axis('off')
        plt.savefig(save_to)
        plt.close()
    else:  # fake_num=1时保存单张图片，否则按照多张图片的格式保存
        cv.imwrite(save_to, fake_image[0])
    print('输出图片已保存至:%s' % save_to)

# %%
def creat_dir(path):  #用于生成迭代过程中的图片以及保存后续生成的图像
    os.makedirs(path, exist_ok=True)

# %%
print('tf版本：', tf.__version__)
# 定义参数
batch_size = 5  # 每次训练的批次（太大可能会显存不够而报错，故在这里选择较小的值）
epochs = 200000  # 共迭代训练几次
g_lr = 0.0005  # 生成器学习率
d_lr = 0.0002  # 鉴别器学习率
fake_num = 16  # 生成的图片的个数（一般不改）
dataset_name = 'female'  # 数据集的名字  star_imgs  female  cat_vs_dog
h, w, c = 256, 256, 3  # 数据集图片的宽和高，也是生成图片的宽和高
noise_dim = 100  # 输入噪声的维度（一般不改）
save_step = 1000  # 每隔几次保存一次中间结果图和权重。如果是0，则不保存中间结果图和权重
# Out:
# tf版本： 2.7.0

# %%
# 创建文件夹
directory = './checkpoint2/' + dataset_name + '_%s×%s' % (h, w)  # 输出参数保存的文件夹，一般不改
image_dir = './result_image2/' + dataset_name + '_%s×%s' % (h, w)  # 输出图片保存的文件夹，一般不改
os.makedirs(directory, exist_ok=True)
os.makedirs(image_dir, exist_ok=True)
image_names = os.listdir(image_dir)

# %%
# 加载数据集和预处理
dataloader = DataLoader(dir_path=r'./datasets/%s' % dataset_name, dataset_name=dataset_name,
                        norm_range=(-1, 1), img_res=(h, w))
x_train = dataloader.load_datasets()  # 加载数据集
print('正在加载数据集...')
# Out:
# ./datasets/female [] ['3581.png', '2229.png', '6064.png', '5866.png', '5862.png', '1389.png', '3461.png', '900.png', '9765.png', '8475.png', '5627.png', '5139.png', '4985.png', '7784.png', '3012.png', '3389.png', '4843.png', '3413.png', '7193.png', '1089.png', '4793.png', '6679.png', '3993.png', '2812.png', '2142.png', '7656.png', '1783.png', '7585.png', '290.png', '4288.png', '31.png', '974.png', '35.png', '3906.png', '5631.png', '5011.png', '9335.png', '2942.png', '1351.png', '9682.png', '3494.png', '4380.png', '328.png', '7394.png', '3063.png', '690.png', '9701.png', '3106.png', '8176.png', '2781.png', '6031.png', '4497.png', '1956.png', '4605.png', '8624.png', '798.png', '923.png', '182.png', '6813.png', '5794.png', '4484.png', '3798.png', '3522.png', '465.png', '7378.png', '8646.png', '8148.png', '7139.png', '6317.png', '5906.png', '5643.png', '2543.png', '5478.png', '8035.png', '5221.png', '925.png', '865.png', '3924.png', '7136.png', '7289.png', '4425.png', '8614.png', '4277.png', '3361.png', '8961.png', '153.png', '1669.png', '3024.png', '5000.png', '5515.png', '4149.png', '1064.png', '5858.png', '3279.png', '1961.png', '2173.png', '3962.png', '277.png', '5542.png', '7532.png', '4301.png', '2982.png', '374.png', '2856.png', '1319.png', '5433.png', '9198.png', '3122.png', '9615.png', '9354.png', '4658.png', '6984.png', '4343.png', '6706.png', '4795.png', '8623.png', '8136.png', '4716.png', '834.png', '7025.png', '3256.png', '9525.png', '8487.png', '1032.png', '8364.png', '7347.png', '8257.png', '1816.png', '2426.png', '4148.png', '7684.png', '315.png', '1087.png', '7676.png', '49.png', '867.png', '8617.png', '7902.png', '1429.png', '2553.png', '1470.png', '1168.png', '8907.png', '9689.png', '187.png', '7828.png', '7319.png', '2595.png', '9268.png', '6274.png', '4977.png', '2427.png', '525.png', '8654.png', '5309.png', '4753.png', '4736.png', '3518.png', '6644.png', '6740.png', '9041.png', '4021.png', '6066.png', '484.png', '9748.png', '5679.png', '5705.png', '6728.png', '8096.png', '125.png', '2445.png', '2881.png', '5271.png', '5874.png', '2435.png', '8962.png', '9133.png', '250.png', '3432.png', '717.png', '8489.png', '2161.png', '5590.png', '8362.png', '4376.png', '6523.png', '8719.png', '7579.png', '589.png', '9777.png', '5811.png', '6833.png', '5200.png', '1146.png', '4773.png', '3597.png', '9163.png', '8902.png', '835.png', '4070.png', '4876.png', '8914.png', '642.png', '1423.png', '6290.png', '5346.png', '5625.png', '4491.png', '2439.png', '6059.png', '8451.png', '2233.png', '5920.png', '5981.png', '1649.png', '9565.png', '8412.png', '7340.png', '6430.png', '9564.png', '3125.png', '8145.png', '7079.png', '5153.png', '548.png', '5545.png', '7685.png', '1542.png', '6105.png', '1550.png', '6252.png', '3379.png', '9995.png', '8047.png', '5618.png', '1889.png', '3317.png', '9022.png', '6941.png', '2268.png', '4759.png', '118.png', '2137.png', '8682.png', '9971.png', '5599.png', '9854.png', '8286.png', '3033.png', '9687.png', '349.png', '1977.png', '8029.png', '2513.png', '6666.png', '6178.png', '2576.png', '4608.png', '7493.png', '6655.png', '1023.png', '6088.png', '8246.png', '2507.png', '7478.png', '7912.png', '4094.png', '5548.png', '8073.png', '2953.png', '7923.png', '5126.png', '8082.png', '3768.png', '9849.png', '3147.png', '2219.png', '8518.png', '830.png', '2691.png', '3276.png', '5114.png', '1033.png', '6301.png', '5379.png', '7488.png', '7406.png', '3935.png', '5763.png', '7332.png', '475.png', '6920.png', '4241.png', '5350.png', '3584.png', '4159.png', '8187.png', '2769.png', '8447.png', '9875.png', '426.png', '6351.png', '6593.png', '391.png', '3684.png', '9578.png', '1241.png', '7854.png', '1503.png', '2521.png', '9810.png', '3186.png', '2438.png', '12.png', '84.png', '3782.png', '3142.png', '4664.png', '4954.png', '3599.png', '5999.png', '5203.png', '7935.png', '4104.png', '2625.png', '5745.png', '6952.png', '9731.png', '5256.png', '7712.png', '850.png', '7187.png', '2004.png', '2132.png', '9473.png', '9 ...
# ['./datasets/female/3581.png' './datasets/female/2229.png'
#  './datasets/female/6064.png' ... './datasets/female/7223.png'
#  './datasets/female/5801.png' './datasets/female/9387.png']
# 正在加载数据集...

# %%
# 加载网络
generator = generator_network_dcgan(h, w, c, noise_dim=noise_dim)
discriminator = discriminator_network_dcgan(h, w, c)
# generator.summary()
# discriminator.summary()

# 如果采用Gelu作为激活函数，最好使用带动量的方法进行训练
g_optimizer = optimizers.SGD(learning_rate=g_lr,momentum=0.9,nesterov=True)
d_optimizer = optimizers.SGD(learning_rate=d_lr,momentum=0.9,nesterov=True)

# 设置随机种植可以让产生的图片不变，之后取消随机数种子
tf.random.set_seed(0)
noise_test = tf.random.normal([fake_num, noise_dim])
tf.random.set_seed(None)
# Out:
# 2022-12-25 13:55:09.603545: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-25 13:55:09.971796: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22308 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:9d:00.0, compute capability: 8.6

# %%
generator.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  dense (Dense)               (None, 524288)            52953088
#
#  batch_normalization (BatchN  (None, 524288)           2097152
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 524288)            0
#
#  reshape (Reshape)           (None, 64, 64, 128)       0
#
#  conv2d_transpose (Conv2DTra  (None, 128, 128, 64)     73792
#  nspose)
#
#  batch_normalization_1 (Batc  (None, 128, 128, 64)     256
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 128, 128, 64)      0
#
#  conv2d_transpose_1 (Conv2DT  (None, 256, 256, 32)     18464
#  ranspose)
#
#  batch_normalization_2 (Batc  (None, 256, 256, 32)     128
#  hNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 256, 256, 32)      0
#
#  conv2d_transpose_2 (Conv2DT  (None, 256, 256, 3)      867
#  ranspose)
#
# =================================================================
# Total params: 55,143,747
# Trainable params: 54,094,979
# Non-trainable params: 1,048,768
# _________________________________________________________________

# %%
discriminator.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv2d (Conv2D)             (None, 128, 128, 32)      896
#
#  batch_normalization_3 (Batc  (None, 128, 128, 32)     128
#  hNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 128, 128, 32)      0
#
#  dropout (Dropout)           (None, 128, 128, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        18496
#
#  batch_normalization_4 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 64, 64, 64)        0
#
#  dropout_1 (Dropout)         (None, 64, 64, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       73856
#
#  batch_normalization_5 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 32, 32, 128)       0
#
#  dropout_2 (Dropout)         (None, 32, 32, 128)       0
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense_1 (Dense)             (None, 1)                 131073
#
# =================================================================
# Total params: 225,217
# Trainable params: 224,769
# Non-trainable params: 448
# _________________________________________________________________

# %%
@tf.function  #tf.function用于加快运算速度
def train_step(x):
    # x = transform(x, dsize=(h, h), crop_size=(h, w))  # 使用随机裁剪
    # print('x:', x.shape)
    noise = tf.random.normal([x.shape[0], noise_dim])  # noise.shape=(b,100)
    with tf.GradientTape() as g_tape, tf.GradientTape() as d_tape:
        fake_image = generator(noise, training=True)  # (b, h, w, c)
        fake_out = discriminator(fake_image, training=True)  # (b, 1)
        real_out = discriminator(x, training=True)  # (b, 1)
        g_loss = tf.reduce_mean(
            losses.binary_crossentropy(y_true=tf.ones_like(fake_out), y_pred=fake_out, from_logits=True))  # 计算生成损失

        d1_loss = tf.reduce_mean(
            losses.binary_crossentropy(y_true=tf.ones_like(real_out), y_pred=real_out, from_logits=True))
        d2_loss = tf.reduce_mean(
            losses.binary_crossentropy(y_true=tf.zeros_like(fake_out), y_pred=fake_out, from_logits=True))  # 计算两个鉴别损失

        gp = gradient_penalty(discriminator, x, fake_image)  # 计算梯度惩罚项（wgan的内容，也可注释掉此行代码不使用）
        d_loss = d1_loss + d2_loss + 10.*gp
        #d_loss = d1_loss + d2_loss
    g_grads = g_tape.gradient(g_loss, generator.trainable_variables)
    d_grads = d_tape.gradient(d_loss, discriminator.trainable_variables)

    g_optimizer.apply_gradients(zip(g_grads, generator.trainable_variables))
    d_optimizer.apply_gradients(zip(d_grads, discriminator.trainable_variables))
    return [g_loss, d_loss]

# %%
# 创建保存参数
checkpoint = tf.train.Checkpoint(generator=generator,
                                 discriminator=discriminator)
checkpoint.restore(tf.train.latest_checkpoint(directory))  # 断点续训
manager = tf.train.CheckpointManager(checkpoint=checkpoint, directory=directory, max_to_keep=2,
                                     checkpoint_name=dataset_name)

max_num = max([int(image_name.split('.')[0][len(dataset_name):]) for image_name in image_names if
               image_name.endswith('png') or image_name.endswith('jpg')]) if image_names else 0  # 接着上次的往后保存

# %%
g_total_loss_list = []
d_total_loss_list = []

# 训练
print('数据加载完成，正在训练中...')
t1 = time.time()
for epoch in range(epochs):

    x_train = dataloader.load_batch(batch_size=batch_size)
    g_total_loss, d_total_loss = train_step(x_train)

    # 保存
    if save_step:
        if (epoch + 1) % save_step == 0 or epoch == 0:  # 每隔几个epoch保存一次
            fake_image = generator.predict(noise_test, batch_size=1)  # (b,h,w,c)
            fake_image = fake_image.reshape(-1, h, w, c) * 127.5 + 127.5  # (b,h,w,c)
            fake_image = np.clip(fake_image, 0, 255).astype('uint8')  # (b,h,w,c)
            save_to = image_dir + '/' + dataset_name + '%d.png' % (epoch + 1 + max_num)
            save_image(fake_image, fake_label=None, fake_num=fake_num, save_to=save_to)  # 保存图片
            manager.save(checkpoint_number=epoch + 1 + max_num)  # 保存参数
            g_total_loss_list.append(g_total_loss)
            d_total_loss_list.append(d_total_loss)  #每一定epoch后保存一次总损失值
            print('epoch:%d/%d:' % (epoch + 1 + max_num, epochs),
                  'g_total_loss:%.6f' % np.mean(g_total_loss),
                  'd_total_loss:%.6f' % np.mean(d_total_loss), '用时:%.6f' % (time.time() - t1))
            t1 = time.time()
    if epoch + 1 + max_num >= epochs:
        print('已跑完%s次' % epochs)
        break
manager.save(checkpoint_number=epochs)  # 训练完保存参数
# Out:
# 数据加载完成，正在训练中...
# 2022-12-23 19:12:33.992326: I tensorflow/stream_executor/cuda/cuda_blas.cc:1774] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2022-12-23 19:12:34.533615: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8101
# 输出图片已保存至:./result_image2/female_256×256/female1.png
# epoch:1/200000: g_total_loss:1.306516 d_total_loss:6.612443 用时:4.465204
# 输出图片已保存至:./result_image2/female_256×256/female1000.png
# epoch:1000/200000: g_total_loss:3.601285 d_total_loss:0.182949 用时:25.544898
# 输出图片已保存至:./result_image2/female_256×256/female2000.png
# epoch:2000/200000: g_total_loss:3.999136 d_total_loss:0.212200 用时:23.662782
# 输出图片已保存至:./result_image2/female_256×256/female3000.png
# epoch:3000/200000: g_total_loss:4.524771 d_total_loss:2.030717 用时:23.373988
# 输出图片已保存至:./result_image2/female_256×256/female4000.png
# epoch:4000/200000: g_total_loss:7.835453 d_total_loss:2.999294 用时:23.760232
# 输出图片已保存至:./result_image2/female_256×256/female5000.png
# epoch:5000/200000: g_total_loss:3.469107 d_total_loss:1.333084 用时:22.465312
# 输出图片已保存至:./result_image2/female_256×256/female6000.png
# epoch:6000/200000: g_total_loss:4.196644 d_total_loss:0.518966 用时:23.222250
# 输出图片已保存至:./result_image2/female_256×256/female7000.png
# epoch:7000/200000: g_total_loss:1.109437 d_total_loss:2.761449 用时:23.598761
# 输出图片已保存至:./result_image2/female_256×256/female8000.png
# epoch:8000/200000: g_total_loss:2.687760 d_total_loss:0.602971 用时:24.237396
# 输出图片已保存至:./result_image2/female_256×256/female9000.png
# epoch:9000/200000: g_total_loss:5.546678 d_total_loss:0.894299 用时:23.046050
# 输出图片已保存至:./result_image2/female_256×256/female10000.png
# epoch:10000/200000: g_total_loss:2.845386 d_total_loss:0.429706 用时:24.474740
# 输出图片已保存至:./result_image2/female_256×256/female11000.png
# epoch:11000/200000: g_total_loss:1.740595 d_total_loss:0.658694 用时:25.309347
# 输出图片已保存至:./result_image2/female_256×256/female12000.png
# epoch:12000/200000: g_total_loss:4.780177 d_total_loss:0.084962 用时:23.597873
# 输出图片已保存至:./result_image2/female_256×256/female13000.png
# epoch:13000/200000: g_total_loss:10.050365 d_total_loss:0.006403 用时:23.083779
# 输出图片已保存至:./result_image2/female_256×256/female14000.png
# epoch:14000/200000: g_total_loss:6.312886 d_total_loss:0.111600 用时:24.930781
# 输出图片已保存至:./result_image2/female_256×256/female15000.png
# epoch:15000/200000: g_total_loss:6.041420 d_total_loss:0.138511 用时:23.215411
# 输出图片已保存至:./result_image2/female_256×256/female16000.png
# epoch:16000/200000: g_total_loss:3.544549 d_total_loss:0.525426 用时:23.575247
# 输出图片已保存至:./result_image2/female_256×256/female17000.png
# epoch:17000/200000: g_total_loss:8.402575 d_total_loss:0.100930 用时:25.128047
# 输出图片已保存至:./result_image2/female_256×256/female18000.png
# epoch:18000/200000: g_total_loss:3.600777 d_total_loss:0.243825 用时:27.081166
# 输出图片已保存至:./result_image2/female_256×256/female19000.png
# epoch:19000/200000: g_total_loss:3.854989 d_total_loss:1.643812 用时:23.956355
# 输出图片已保存至:./result_image2/female_256×256/female20000.png
# epoch:20000/200000: g_total_loss:5.114653 d_total_loss:0.229172 用时:23.906700
# 输出图片已保存至:./result_image2/female_256×256/female21000.png
# epoch:21000/200000: g_total_loss:4.448626 d_total_loss:0.381789 用时:26.634393
# 输出图片已保存至:./result_image2/female_256×256/female22000.png
# epoch:22000/200000: g_total_loss:5.073556 d_total_loss:0.104737 用时:22.899042
# 输出图片已保存至:./result_image2/female_256×256/female23000.png
# epoch:23000/200000: g_total_loss:2.759619 d_total_loss:0.221000 用时:26.316329
# 输出图片已保存至:./result_image2/female_256×256/female24000.png
# epoch:24000/200000: g_total_loss:2.155279 d_total_loss:0.345080 用时:23.190465
# 输出图片已保存至:./result_image2/female_256×256/female25000.png
# epoch:25000/200000: g_total_loss:2.392848 d_total_loss:0.226078 用时:24.871939
# 输出图片已保存至:./result_image2/female_256×256/female26000.png
# epoch:26000/200000: g_total_loss:0.613007 d_total_loss:1.308904 用时:24.023156
# 输出图片已保存至:./result_image2/female_256×256/female27000.png
# epoch:27000/200000: g_total_loss:0.919856 d_total_loss:0.613318 用时:22.898096
# 输出图片已保存至:./result_image2/female_256×256/female28000.png
# epoch:28000/200000: g_total_loss:2.411139 d_total_loss:0.341199 用时:23.623322
# 输出图片已保存至:./result_image2/female_256×256/female29000.png
# epoch:29000/200000: g_total_loss:2.289255 d_total_loss:1.716696 用时:23.729493
# 输出图片已保存至:./result_image2/female_256×256/female30000.png
# epoch:30000/200000: g_total_loss:3.380045 d_total_loss:0.377619 用时:24.001727
# 输出图片已保存至:./result_image2/female_256×256/female31000.png
# epoch:31000/200000: g_total_loss:2.730756 d_total_loss:0.190312 用时:23.742493
# 输出图片已保存至:./result_image2/female_256×256/female32000.png
# epoch:32000/200000: g_total_loss:1.786019 d_total_loss:0.408473 用时:23.832820
# 输出图片已保存至:./result_image2/female_256×256/female33000.png
# epoch:33000/200000: g_total_loss:2.711880 d_total_loss:0.276056 用时:22.908344
# 输出图片已保存至:./result_image2/female_256×256/female34000.png
# epoch:34000/200000: g_total_loss:0.853764 d_total_loss:0.953459 用时:23.055662
# 输出图片已保存至:./result_image2/female_256×256/female35000.png
# epoch:35000/200000: g_total_loss:1.875199 d_total_loss:0.464702 用时:23.436742
# 输出图片已保存至:./result_image2/female_256×256/female36000.png
# epoch:36000/200000: g_total_loss:0.339236 d_total_loss:1.474212 用时:23.157008
# 输出图片已保存至:./result_image2/female_256×256/female37000.png
# epoch:37000/200000: g_total_loss:3.203241 d_total_loss:0.213750 用时:23.480488
# 输出图片已保存至:./result_image2/female_256×256/female38000.png
# epoch:38000/200000: g_total_loss:9.924803 d_total_loss:0.021826 用时:24.025151
# 输出图片已保存至:./result_image2/female_256×256/female39000.png
# epoch:39000/200000: g_total_loss:6.648271 d_total_loss:0.007449 用时:23.173883
# 输出图片已保存至:./result_image2/female_256×256/female40000.png
# epoch:40000/200000: g_total_loss:6.726213 d_total_loss:0.050883 用时:23.725546
# 输出图片已保存至:./result_image2/female_256×256/female41000.png
# epoch:41000/200000: g_total_loss:7.408025 d_total_loss:0.004858 用时:22.962918
# 输出图片已保存至:./result_image2/female_256×256/female42000.png
# epoch:42000/200000: g_total_loss:2.478108 d_total_loss:0.880834 用时:23.218659
# 输出图片已保存至:./result_image2/female_256×256/female43000.png
# epoch:43000/200000: g_total_loss:1.716614 d_total_loss:0.409899 用时:25.562128
# 输出图片已保存至:./result_image2/female_256×256/female44000.png
# epoch:44000/200000: g_total_loss:3.066457 d_total_loss:0.138060 用时:23.811229
# 输出图片已保存至:./result_image2/female_256×256/female45000.png
# epoch:45000/200000: g_total_loss:2.487144 d_total_loss:0.457231 用时:23.895046
# 输出图片已保存至:./result_image2/female_256×256/female46000.png
# epoch:46000/200000: g_total_loss:3.911903 d_total_loss:0.193856 用时:22.752967
# 输出图片已保存至:./result_image2/female_256×256/female47000.png
# epoch:47000/200000: g_total_loss:3.652229 d_total_loss:0.160040 用时:23.437926
# 输出图片已保存至:./result_image2/female_256×256/female48000.png
# epoch:48000/200000: g_total_loss:3.159545 d_total_loss:0.398679 用时:22.496041
# 输出图片已保存至:./result_image2/female_256×256/female49000.png
# epoch:49000/200000: g_total_loss:2.218245 d_total_loss:0.225329 用时:23.453964
# 输出图片已保存至:./result_image2/female_256×256/female50000.png
# epoch:50000/200000: g_total_loss:2.705708 d_total_loss:0.172665 用时:22.662915
# 输出图片已保存至:./result_image2/female_256×256/female51000.png
# epoch:51000/200000: g_total_loss:2.623001 d_total_loss:0.267926 用时:24.502884
# 输出图片已保存至:./result_image2/female_256×256/female52000.png
# epoch:52000/200000: g_total_loss:1.495440 d_total_loss:0.479927 用时:23.489067
# 输出图片已保存至:./result_image2/female_256×256/female53000.png
# epoch:53000/200000: g_total_loss:3.467826 d_total_loss:0.919507 用时:22.614027
# 输出图片已保存至:./result_image2/female_256×256/female54000.png
# epoch:54000/200000: g_total_loss:2.114289 d_total_loss:0.598661 用时:23.469040
# 输出图片已保存至:./result_image2/female_256×256/female55000.png
# epoch:55000/200000: g_total_loss:4.310337 d_total_loss:0.150097 用时:22.493275
# 输出图片已保存至:./result_image2/female_256×256/female56000.png
# epoch:56000/200000: g_total_loss:2.718097 d_total_loss:0.470794 用时:23.299594
# 输出图片已保存至:./result_image2/female_256×256/female57000.png
# epoch:57000/200000: g_total_loss:3.321456 d_total_loss:0.416146 用时:23.572938
# 输出图片已保存至:./result_image2/female_256×256/female58000.png
# epoch:58000/200000: g_total_loss:1.654367 d_total_loss:0.366457 用时:23.308683
# 输出图片已保存至:./result_image2/female_256×256/female59000.png
# epoch:59000/200000: g_total_loss:2.280811 d_total_loss:0.157150 用时:23.687303
# 输出图片已保存至:./result_image2/female_256×256/female60000.png
# epoch:60000/200000: g_total_loss:1.999259 d_total_loss:0.733854 用时:23.508620
# 输出图片已保存至:./result_image2/female_256×256/female61000.png
# epoch:61000/200000: g_total_loss:0.642477 d_total_loss:2.162623 用时:22.642372
# 输出图片已保存至:./result_image2/female_256×256/female62000.png
# epoch:62000/200000: g_total_loss:3.870943 d_total_loss:0.160913 用时:23.420117
# 输出图片已保存至:./result_image2/female_256×256/female63000.png
# epoch:63000/200000: g_total_loss:3.319796 d_total_loss:0.237953 用时:22.452161
# 输出图片已保存至:./result_image2/female_256×256/female64000.png
# epoch:64000/200000: g_total_loss:3.523111 d_total_loss:0.262150 用时:23.271086
# 输出图片已保存至:./result_image2/female_256×256/female65000.png
# epoch:65000/200000: g_total_loss:1.915452 d_total_loss:1.567136 用时:22.579332
# 输出图片已保存至:./result_image2/female_256×256/female66000.png
# epoch:66000/200000: g_total_loss:2.126253 d_total_loss:0.359396 用时:22.308919
# 输出图片已保存至:./result_image2/female_256×256/female67000.png
# epoch:67000/200000: g_total_loss:1.086645 d_total_loss:1.108867 用时:22.268942
# 输出图片已保存至:./result_image2/female_256×256/female68000.png
# epoch:68000/200000: g_total_loss:2.771085 d_total_loss:0.570184 用时:22.484583
# 输出图片已保存至:./result_image2/female_256×256/female69000.png
# epoch:69000/200000: g_total_loss:1.855402 d_total_loss:0.300303 用时:22.384779
# 输出图片已保存至:./result_image2/female_256×256/female70000.png
# epoch:70000/200000: g_total_loss:2.267938 d_total_loss:0.329216 用时:22.503716
# 输出图片已保存至:./result_image2/female_256×256/female71000.png
# epoch:71000/200000: g_total_loss:1.264697 d_total_loss:0.418108 用时:22.634030
# 输出图片已保存至:./result_image2/female_256×256/female72000.png
# epoch:72000/200000: g_total_loss:2.300879 d_total_loss:0.559942 用时:22.517759
# 输出图片已保存至:./result_image2/female_256×256/female73000.png
# epoch:73000/200000: g_total_loss:2.360957 d_total_loss:0.363723 用时:23.129048
# 输出图片已保存至:./result_image2/female_256×256/female74000.png
# epoch:74000/200000: g_total_loss:1.990356 d_total_loss:0.362076 用时:23.192122
# 输出图片已保存至:./result_image2/female_256×256/female75000.png
# epoch:75000/200000: g_total_loss:1.523379 d_total_loss:0.722832 用时:22.979185
# 输出图片已保存至:./result_image2/female_256×256/female76000.png
# epoch:76000/200000: g_total_loss:2.575366 d_total_loss:0.356829 用时:24.693296
# 输出图片已保存至:./result_image2/female_256×256/female77000.png
# epoch:77000/200000: g_total_loss:1.817387 d_total_loss:0.831682 用时:23.478433
# 输出图片已保存至:./result_image2/female_256×256/female78000.png
# epoch:78000/200000: g_total_loss:1.795915 d_total_loss:0.494120 用时:22.997892
# 输出图片已保存至:./result_image2/female_256×256/female79000.png
# epoch:79000/200000: g_total_loss:1.552889 d_total_loss:0.489931 用时:24.196502
# 输出图片已保存至:./result_image2/female_256×256/female80000.png
# epoch:80000/200000: g_total_loss:1.704840 d_total_loss:0.727074 用时:23.718885
# 输出图片已保存至:./result_image2/female_256×256/female81000.png
# epoch:81000/200000: g_total_loss:1.785279 d_total_loss:0.478392 用时:22.880966
# 输出图片已保存至:./result_image2/female_256×256/female82000.png
# epoch:82000/200000: g_total_loss:1.373117 d_total_loss:0.780942 用时:23.143635
# 输出图片已保存至:./result_image2/female_256×256/female83000.png
# epoch:83000/200000: g_total_loss:1.905265 d_total_loss:0.798667 用时:23.428862
# 输出图片已保存至:./result_image2/female_256×256/female84000.png
# epoch:84000/200000: g_total_loss:1.524937 d_total_loss:0.701540 用时:23.269477
# 输出图片已保存至:./result_image2/female_256×256/female85000.png
# epoch:85000/200000: g_total_loss:1.840183 d_total_loss:0.465563 用时:23.306275
# 输出图片已保存至:./result_image2/female_256×256/female86000.png
# epoch:86000/200000: g_total_loss:2.520761 d_total_loss:0.285073 用时:24.692690
# 输出图片已保存至:./result_image2/female_256×256/female87000.png
# epoch:87000/200000: g_total_loss:1.422030 d_total_loss:0.728320 用时:22.832409
# 输出图片已保存至:./result_image2/female_256×256/female88000.png
# epoch:88000/200000: g_total_loss:1.150836 d_total_loss:0.595627 用时:22.737808
# 输出图片已保存至:./result_image2/female_256×256/female89000.png
# epoch:89000/200000: g_total_loss:2.311837 d_total_loss:0.202045 用时:22.863424
# 输出图片已保存至:./result_image2/female_256×256/female90000.png
# epoch:90000/200000: g_total_loss:1.559170 d_total_loss:0.503862 用时:24.477639
# 输出图片已保存至:./result_image2/female_256×256/female91000.png
# epoch:91000/200000: g_total_loss:0.866793 d_total_loss:1.194178 用时:23.653256
# 输出图片已保存至:./result_image2/female_256×256/female92000.png
# epoch:92000/200000: g_total_loss:1.221751 d_total_loss:0.921337 用时:23.511346
# 输出图片已保存至:./result_image2/female_256×256/female93000.png
# epoch:93000/200000: g_total_loss:2.099664 d_total_loss:0.359906 用时:24.213655
# 输出图片已保存至:./result_image2/female_256×256/female94000.png
# epoch:94000/200000: g_total_loss:2.671518 d_total_loss:0.381845 用时:23.258294
# 输出图片已保存至:./result_image2/female_256×256/female95000.png
# epoch:95000/200000: g_total_loss:1.968083 d_total_loss:0.554925 用时:24.741956
# 输出图片已保存至:./result_image2/female_256×256/female96000.png
# epoch:96000/200000: g_total_loss:2.400509 d_total_loss:0.292250 用时:25.154714
# 输出图片已保存至:./result_image2/female_256×256/female97000.png
# epoch:97000/200000: g_total_loss:2.361174 d_total_loss:0.371681 用时:24.410818
# 输出图片已保存至:./result_image2/female_256×256/female98000.png
# epoch:98000/200000: g_total_loss:2.080918 d_total_loss:0.325442 用时:24.886557
# 输出图片已保存至:./result_image2/female_256×256/female99000.png
# epoch:99000/200000: g_total_loss:1.584698 d_total_loss:0.373543 用时:23.067161
# 输出图片已保存至:./result_image2/female_256×256/female100000.png
# epoch:100000/200000: g_total_loss:1.508403 d_total_loss:0.469989 用时:24.565936
# 输出图片已保存至:./result_image2/female_256×256/female101000.png
# epoch:101000/200000: g_total_loss:2.056766 d_total_loss:0.465588 用时:23.127959
# 输出图片已保存至:./result_image2/female_256×256/female102000.png
# epoch:102000/200000: g_total_loss:1.510886 d_total_loss:0.454675 用时:24.777118
# 输出图片已保存至:./result_image2/female_256×256/female103000.png
# epoch:103000/200000: g_total_loss:2.842850 d_total_loss:1.254103 用时:24.482963
# 输出图片已保存至:./result_image2/female_256×256/female104000.png
# epoch:104000/200000: g_total_loss:1.705583 d_total_loss:0.740582 用时:23.084101
# 输出图片已保存至:./result_image2/female_256×256/female105000.png
# epoch:105000/200000: g_total_loss:2.544513 d_total_loss:0.142467 用时:22.748608
# 输出图片已保存至:./result_image2/female_256×256/female106000.png
# epoch:106000/200000: g_total_loss:2.430738 d_total_loss:0.819163 用时:22.663643
# 输出图片已保存至:./result_image2/female_256×256/female107000.png
# epoch:107000/200000: g_total_loss:1.462317 d_total_loss:0.672373 用时:23.413184
# 输出图片已保存至:./result_image2/female_256×256/female108000.png
# epoch:108000/200000: g_total_loss:2.544126 d_total_loss:0.432298 用时:25.681487
# 输出图片已保存至:./result_image2/female_256×256/female109000.png
# epoch:109000/200000: g_total_loss:1.310949 d_total_loss:0.481460 用时:22.921901
# 输出图片已保存至:./result_image2/female_256×256/female110000.png
# epoch:110000/200000: g_total_loss:2.162221 d_total_loss:0.296106 用时:22.861148
# 输出图片已保存至:./result_image2/female_256×256/female111000.png
# epoch:111000/200000: g_total_loss:2.707831 d_total_loss:0.968862 用时:23.841314
# 输出图片已保存至:./result_image2/female_256×256/female112000.png
# epoch:112000/200000: g_total_loss:3.050043 d_total_loss:0.512802 用时:23.194971
# 输出图片已保存至:./result_image2/female_256×256/female113000.png
# epoch:113000/200000: g_total_loss:2.208452 d_total_loss:0.416949 用时:23.564482
# 输出图片已保存至:./result_image2/female_256×256/female114000.png
# epoch:114000/200000: g_total_loss:2.160131 d_total_loss:0.620419 用时:22.965718
# 输出图片已保存至:./result_image2/female_256×256/female115000.png
# epoch:115000/200000: g_total_loss:1.344858 d_total_loss:1.670551 用时:22.934699
# 输出图片已保存至:./result_image2/female_256×256/female116000.png
# epoch:116000/200000: g_total_loss:1.267069 d_total_loss:0.464945 用时:22.997187
# 输出图片已保存至:./result_image2/female_256×256/female117000.png
# epoch:117000/200000: g_total_loss:1.477609 d_total_loss:0.522654 用时:22.082868
# 输出图片已保存至:./result_image2/female_256×256/female118000.png
# epoch:118000/200000: g_total_loss:1.793860 d_total_loss:0.274736 用时:22.993356
# 输出图片已保存至:./result_image2/female_256×256/female119000.png
# epoch:119000/200000: g_total_loss:2.068202 d_total_loss:0.277118 用时:22.755256
# 输出图片已保存至:./result_image2/female_256×256/female120000.png
# epoch:120000/200000: g_total_loss:2.337950 d_total_loss:0.345815 用时:22.588599
# 输出图片已保存至:./result_image2/female_256×256/female121000.png
# epoch:121000/200000: g_total_loss:2.290318 d_total_loss:0.356983 用时:22.707274
# 输出图片已保存至:./result_image2/female_256×256/female122000.png
# epoch:122000/200000: g_total_loss:2.261857 d_total_loss:0.251400 用时:22.899571
# 输出图片已保存至:./result_image2/female_256×256/female123000.png
# epoch:123000/200000: g_total_loss:1.804324 d_total_loss:0.501225 用时:23.091332
# 输出图片已保存至:./result_image2/female_256×256/female124000.png
# epoch:124000/200000: g_total_loss:1.944235 d_total_loss:0.298688 用时:22.925028
# 输出图片已保存至:./result_image2/female_256×256/female125000.png
# epoch:125000/200000: g_total_loss:2.462147 d_total_loss:0.202546 用时:23.040126
# 输出图片已保存至:./result_image2/female_256×256/female126000.png
# epoch:126000/200000: g_total_loss:1.548980 d_total_loss:0.417550 用时:23.920714
# 输出图片已保存至:./result_image2/female_256×256/female127000.png
# epoch:127000/200000: g_total_loss:2.891216 d_total_loss:0.290944 用时:22.869686
# 输出图片已保存至:./result_image2/female_256×256/female128000.png
# epoch:128000/200000: g_total_loss:2.504631 d_total_loss:0.429756 用时:23.881942
# 输出图片已保存至:./result_image2/female_256×256/female129000.png
# epoch:129000/200000: g_total_loss:1.876475 d_total_loss:0.617370 用时:23.396265
# 输出图片已保存至:./result_image2/female_256×256/female130000.png
# epoch:130000/200000: g_total_loss:2.071125 d_total_loss:0.751185 用时:23.023760
# 输出图片已保存至:./result_image2/female_256×256/female131000.png
# epoch:131000/200000: g_total_loss:2.265967 d_total_loss:0.284093 用时:24.830169
# 输出图片已保存至:./result_image2/female_256×256/female132000.png
# epoch:132000/200000: g_total_loss:1.921118 d_total_loss:0.347915 用时:24.264818
# 输出图片已保存至:./result_image2/female_256×256/female133000.png
# epoch:133000/200000: g_total_loss:4.215010 d_total_loss:1.249504 用时:23.271757
# 输出图片已保存至:./result_image2/female_256×256/female134000.png
# epoch:134000/200000: g_total_loss:1.408456 d_total_loss:0.397299 用时:23.143009
# 输出图片已保存至:./result_image2/female_256×256/female135000.png
# epoch:135000/200000: g_total_loss:2.197771 d_total_loss:0.366183 用时:22.893887
# 输出图片已保存至:./result_image2/female_256×256/female136000.png
# epoch:136000/200000: g_total_loss:2.614018 d_total_loss:0.296249 用时:23.006976
# 输出图片已保存至:./result_image2/female_256×256/female137000.png
# epoch:137000/200000: g_total_loss:1.319476 d_total_loss:0.445719 用时:22.787998
# 输出图片已保存至:./result_image2/female_256×256/female138000.png
# epoch:138000/200000: g_total_loss:2.564437 d_total_loss:0.272325 用时:23.501087
# 输出图片已保存至:./result_image2/female_256×256/female139000.png
# epoch:139000/200000: g_total_loss:2.149863 d_total_loss:0.314436 用时:22.886237
# 输出图片已保存至:./result_image2/female_256×256/female140000.png
# epoch:140000/200000: g_total_loss:3.112583 d_total_loss:0.732935 用时:22.494004
# 输出图片已保存至:./result_image2/female_256×256/female141000.png
# epoch:141000/200000: g_total_loss:2.374355 d_total_loss:0.419370 用时:25.582534
# 输出图片已保存至:./result_image2/female_256×256/female142000.png
# epoch:142000/200000: g_total_loss:2.385887 d_total_loss:0.579664 用时:23.165667
# 输出图片已保存至:./result_image2/female_256×256/female143000.png
# epoch:143000/200000: g_total_loss:1.662676 d_total_loss:0.416043 用时:23.480564
# 输出图片已保存至:./result_image2/female_256×256/female144000.png
# epoch:144000/200000: g_total_loss:2.448442 d_total_loss:0.684702 用时:23.577701
# 输出图片已保存至:./result_image2/female_256×256/female145000.png
# epoch:145000/200000: g_total_loss:2.549558 d_total_loss:0.373366 用时:23.445490
# 输出图片已保存至:./result_image2/female_256×256/female146000.png
# epoch:146000/200000: g_total_loss:2.066887 d_total_loss:0.357429 用时:23.158593
# 输出图片已保存至:./result_image2/female_256×256/female147000.png
# epoch:147000/200000: g_total_loss:1.755625 d_total_loss:0.433399 用时:23.293638
# 输出图片已保存至:./result_image2/female_256×256/female148000.png
# epoch:148000/200000: g_total_loss:0.668112 d_total_loss:0.875637 用时:22.503458
# 输出图片已保存至:./result_image2/female_256×256/female149000.png
# epoch:149000/200000: g_total_loss:1.140900 d_total_loss:0.531287 用时:22.985982
# 输出图片已保存至:./result_image2/female_256×256/female150000.png
# epoch:150000/200000: g_total_loss:0.553200 d_total_loss:1.122883 用时:22.958971
# 输出图片已保存至:./result_image2/female_256×256/female151000.png
# epoch:151000/200000: g_total_loss:2.446272 d_total_loss:0.200416 用时:24.169713
# 输出图片已保存至:./result_image2/female_256×256/female152000.png
# epoch:152000/200000: g_total_loss:1.884599 d_total_loss:0.316984 用时:22.883091
# 输出图片已保存至:./result_image2/female_256×256/female153000.png
# epoch:153000/200000: g_total_loss:1.472477 d_total_loss:0.934691 用时:23.895511
# 输出图片已保存至:./result_image2/female_256×256/female154000.png
# epoch:154000/200000: g_total_loss:2.677367 d_total_loss:0.399218 用时:25.561596
# 输出图片已保存至:./result_image2/female_256×256/female155000.png
# epoch:155000/200000: g_total_loss:2.097050 d_total_loss:0.641330 用时:24.405149
# 输出图片已保存至:./result_image2/female_256×256/female156000.png
# epoch:156000/200000: g_total_loss:1.260117 d_total_loss:0.602948 用时:23.008448
# 输出图片已保存至:./result_image2/female_256×256/female157000.png
# epoch:157000/200000: g_total_loss:1.312438 d_total_loss:0.698559 用时:25.775746
# 输出图片已保存至:./result_image2/female_256×256/female158000.png
# epoch:158000/200000: g_total_loss:2.931534 d_total_loss:0.354636 用时:23.635678
# 输出图片已保存至:./result_image2/female_256×256/female159000.png
# epoch:159000/200000: g_total_loss:0.970987 d_total_loss:0.594755 用时:22.931922
# 输出图片已保存至:./result_image2/female_256×256/female160000.png
# epoch:160000/200000: g_total_loss:2.520392 d_total_loss:0.484962 用时:22.935953
# 输出图片已保存至:./result_image2/female_256×256/female161000.png
# epoch:161000/200000: g_total_loss:1.045136 d_total_loss:0.859079 用时:22.542179
# 输出图片已保存至:./result_image2/female_256×256/female162000.png
# epoch:162000/200000: g_total_loss:4.777909 d_total_loss:0.056516 用时:23.910722
# 输出图片已保存至:./result_image2/female_256×256/female163000.png
# epoch:163000/200000: g_total_loss:8.278671 d_total_loss:0.013607 用时:23.784575
# 输出图片已保存至:./result_image2/female_256×256/female164000.png
# epoch:164000/200000: g_total_loss:2.399122 d_total_loss:0.323500 用时:24.642158
# 输出图片已保存至:./result_image2/female_256×256/female165000.png
# epoch:165000/200000: g_total_loss:6.215024 d_total_loss:0.055768 用时:23.185421
# 输出图片已保存至:./result_image2/female_256×256/female166000.png
# epoch:166000/200000: g_total_loss:6.836340 d_total_loss:0.010399 用时:23.337647
# 输出图片已保存至:./result_image2/female_256×256/female167000.png
# epoch:167000/200000: g_total_loss:7.487260 d_total_loss:0.005195 用时:23.103691
# 输出图片已保存至:./result_image2/female_256×256/female168000.png
# epoch:168000/200000: g_total_loss:7.130346 d_total_loss:0.021994 用时:24.501546
# 输出图片已保存至:./result_image2/female_256×256/female169000.png
# epoch:169000/200000: g_total_loss:8.150775 d_total_loss:0.004150 用时:24.121893
# 输出图片已保存至:./result_image2/female_256×256/female170000.png
# epoch:170000/200000: g_total_loss:6.772372 d_total_loss:0.004201 用时:23.388588
# 输出图片已保存至:./result_image2/female_256×256/female171000.png
# epoch:171000/200000: g_total_loss:6.695920 d_total_loss:0.017678 用时:25.885967
# 输出图片已保存至:./result_image2/female_256×256/female172000.png
# epoch:172000/200000: g_total_loss:8.027369 d_total_loss:0.010937 用时:24.242411
# 输出图片已保存至:./result_image2/female_256×256/female173000.png
# epoch:173000/200000: g_total_loss:6.571255 d_total_loss:0.540660 用时:23.954026
# 输出图片已保存至:./result_image2/female_256×256/female174000.png
# epoch:174000/200000: g_total_loss:4.019875 d_total_loss:0.373500 用时:22.838323
# 输出图片已保存至:./result_image2/female_256×256/female175000.png
# epoch:175000/200000: g_total_loss:5.358010 d_total_loss:0.036611 用时:23.049666
# 输出图片已保存至:./result_image2/female_256×256/female176000.png
# epoch:176000/200000: g_total_loss:6.564137 d_total_loss:0.011681 用时:23.330661
# 输出图片已保存至:./result_image2/female_256×256/female177000.png
# epoch:177000/200000: g_total_loss:6.355773 d_total_loss:0.011285 用时:23.131549
# 输出图片已保存至:./result_image2/female_256×256/female178000.png
# epoch:178000/200000: g_total_loss:5.968983 d_total_loss:0.033298 用时:23.892398
# 输出图片已保存至:./result_image2/female_256×256/female179000.png
# epoch:179000/200000: g_total_loss:6.376290 d_total_loss:0.010476 用时:23.724942
# 输出图片已保存至:./result_image2/female_256×256/female180000.png
# epoch:180000/200000: g_total_loss:7.328281 d_total_loss:0.005746 用时:23.554573
# 输出图片已保存至:./result_image2/female_256×256/female181000.png
# epoch:181000/200000: g_total_loss:8.844889 d_total_loss:0.001311 用时:23.993456
# 输出图片已保存至:./result_image2/female_256×256/female182000.png
# epoch:182000/200000: g_total_loss:9.870988 d_total_loss:0.003771 用时:24.067816
# 输出图片已保存至:./result_image2/female_256×256/female183000.png
# epoch:183000/200000: g_total_loss:8.765562 d_total_loss:0.007635 用时:23.176817
# 输出图片已保存至:./result_image2/female_256×256/female184000.png
# epoch:184000/200000: g_total_loss:4.890352 d_total_loss:0.018480 用时:23.520015
# 输出图片已保存至:./result_image2/female_256×256/female185000.png
# epoch:185000/200000: g_total_loss:6.770106 d_total_loss:0.004534 用时:23.029737
# 输出图片已保存至:./result_image2/female_256×256/female186000.png
# epoch:186000/200000: g_total_loss:6.580499 d_total_loss:0.004635 用时:22.640138
# 输出图片已保存至:./result_image2/female_256×256/female187000.png
# epoch:187000/200000: g_total_loss:8.335671 d_total_loss:0.005332 用时:22.710020
# 输出图片已保存至:./result_image2/female_256×256/female188000.png
# epoch:188000/200000: g_total_loss:6.982736 d_total_loss:0.004400 用时:22.907268
# 输出图片已保存至:./result_image2/female_256×256/female189000.png
# epoch:189000/200000: g_total_loss:7.941722 d_total_loss:0.003771 用时:23.681565
# 输出图片已保存至:./result_image2/female_256×256/female190000.png
# epoch:190000/200000: g_total_loss:7.501340 d_total_loss:0.003766 用时:25.244339
# 输出图片已保存至:./result_image2/female_256×256/female191000.png
# epoch:191000/200000: g_total_loss:7.306551 d_total_loss:0.008940 用时:24.423879
# 输出图片已保存至:./result_image2/female_256×256/female192000.png
# epoch:192000/200000: g_total_loss:9.043424 d_total_loss:0.005337 用时:24.888048
# 输出图片已保存至:./result_image2/female_256×256/female193000.png
# epoch:193000/200000: g_total_loss:8.863096 d_total_loss:0.000953 用时:24.063788
# 输出图片已保存至:./result_image2/female_256×256/female194000.png
# epoch:194000/200000: g_total_loss:7.727133 d_total_loss:0.011444 用时:23.822543
# 输出图片已保存至:./result_image2/female_256×256/female195000.png
# epoch:195000/200000: g_total_loss:8.426565 d_total_loss:0.009017 用时:23.449861
# 输出图片已保存至:./result_image2/female_256×256/female196000.png
# epoch:196000/200000: g_total_loss:1.440130 d_total_loss:0.422806 用时:24.339209
# 输出图片已保存至:./result_image2/female_256×256/female197000.png
# epoch:197000/200000: g_total_loss:3.778008 d_total_loss:0.063548 用时:22.672643
# 输出图片已保存至:./result_image2/female_256×256/female198000.png
# epoch:198000/200000: g_total_loss:6.699155 d_total_loss:0.013973 用时:24.589803
# 输出图片已保存至:./result_image2/female_256×256/female199000.png
# epoch:199000/200000: g_total_loss:4.283405 d_total_loss:0.080698 用时:23.009144
# 输出图片已保存至:./result_image2/female_256×256/female200000.png
# epoch:200000/200000: g_total_loss:6.012511 d_total_loss:0.006729 用时:24.166114
# 已跑完200000次
# './checkpoint2/female_256×256/female-200000'

# %%
plt.figure(figsize = (12,8))
epochtime = np.arange(0,201000,1000)
plt.plot(epochtime,g_total_loss_list,color='red',marker='o',linestyle='-',linewidth=1)
plt.xlabel('training epoch')
plt.xticks(rotation=45) # 旋转90度
plt.ylabel('total loss of generator')
plt.title('total loss of generator changed by epoch times')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize = (12,8))
epochtime = np.arange(1000,201000,1000)
plt.plot(epochtime,d_total_loss_list[1:],color='blue',marker='o',linestyle='-',linewidth=1)
plt.xlabel('training epoch')
plt.xticks(rotation=45) # 旋转90度
plt.ylabel('total loss of discriminator')
plt.title('total loss of discriminator changed by epoch times')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
print("mean of total loss of generator: {:.6f}".format(np.mean(g_total_loss_list)))
print("mean of total loss of discriminator: {:.6f}".format(np.mean(d_total_loss_list)))
# Out:
# mean of total loss of generator: 3.388218
# mean of total loss of discriminator: 0.485367

# %%
# 定义参数
batch_size = 1  # 每次测试的批次（太大可能会显存不够而报错，可调小再试）
fake_num = 500  # 生成的图片的个数
dataset_name = 'female'  # 数据集的名字  star_imgs
h, w, c = 256, 256, 3  # 数据集图片的宽和高，也是生成图片的宽和高
noise_dim = 100  # 输入噪声的维度（一般不改）

# %%
# 创建文件夹
directory = './checkpoint2/' + dataset_name + '_%s×%s' % (h, w)  # 输出参数保存的文件夹，一般不改
image_dir = './result_image2/' + dataset_name + '_%s×%s' % (h, w)  # 输出图片保存的文件夹，一般不改

# %%
# 搭建网络
generator = generator_network_dcgan(h, w, c, noise_dim=noise_dim)
discriminator = discriminator_network_dcgan(h, w, c)
# 加载参数
checkpoint = tf.train.Checkpoint(generator=generator,
                                 discriminator=discriminator)
checkpoint.restore(tf.train.latest_checkpoint(directory))  # 断点续训
# 预测
# noise_test = tf.random.normal([fake_num, 100])
noise_test = tf.random.uniform([fake_num, noise_dim], -1, 1)
fake_images = generator.predict(noise_test, batch_size=batch_size)  # (b,h,w,c)
fake_images = (fake_images.reshape(-1, h, w, c) * 127.5 + 127.5).astype('uint8')  # (b,h,w,c)
# Out:
# 2022-12-25 13:55:23.281119: I tensorflow/stream_executor/cuda/cuda_blas.cc:1774] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2022-12-25 13:55:23.827789: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8101

# %%
# 保存生成的图片
os.makedirs('test_from_dir2', exist_ok=True)
for i, fake_image in enumerate(fake_images):
    # i+=5000
    save_path = os.path.join('test_from_dir2', '%s.png' % (i + 1))
    cv.imwrite(save_path, fake_image)
    print('输出的单张图片已保存到：%s' % save_path)
# Out:
# 输出的单张图片已保存到：test_from_dir2/1.png
# 输出的单张图片已保存到：test_from_dir2/2.png
# 输出的单张图片已保存到：test_from_dir2/3.png
# 输出的单张图片已保存到：test_from_dir2/4.png
# 输出的单张图片已保存到：test_from_dir2/5.png
# 输出的单张图片已保存到：test_from_dir2/6.png
# 输出的单张图片已保存到：test_from_dir2/7.png
# 输出的单张图片已保存到：test_from_dir2/8.png
# 输出的单张图片已保存到：test_from_dir2/9.png
# 输出的单张图片已保存到：test_from_dir2/10.png
# 输出的单张图片已保存到：test_from_dir2/11.png
# 输出的单张图片已保存到：test_from_dir2/12.png
# 输出的单张图片已保存到：test_from_dir2/13.png
# 输出的单张图片已保存到：test_from_dir2/14.png
# 输出的单张图片已保存到：test_from_dir2/15.png
# 输出的单张图片已保存到：test_from_dir2/16.png
# 输出的单张图片已保存到：test_from_dir2/17.png
# 输出的单张图片已保存到：test_from_dir2/18.png
# 输出的单张图片已保存到：test_from_dir2/19.png
# 输出的单张图片已保存到：test_from_dir2/20.png
# 输出的单张图片已保存到：test_from_dir2/21.png
# 输出的单张图片已保存到：test_from_dir2/22.png
# 输出的单张图片已保存到：test_from_dir2/23.png
# 输出的单张图片已保存到：test_from_dir2/24.png
# 输出的单张图片已保存到：test_from_dir2/25.png
# 输出的单张图片已保存到：test_from_dir2/26.png
# 输出的单张图片已保存到：test_from_dir2/27.png
# 输出的单张图片已保存到：test_from_dir2/28.png
# 输出的单张图片已保存到：test_from_dir2/29.png
# 输出的单张图片已保存到：test_from_dir2/30.png
# 输出的单张图片已保存到：test_from_dir2/31.png
# 输出的单张图片已保存到：test_from_dir2/32.png
# 输出的单张图片已保存到：test_from_dir2/33.png
# 输出的单张图片已保存到：test_from_dir2/34.png
# 输出的单张图片已保存到：test_from_dir2/35.png
# 输出的单张图片已保存到：test_from_dir2/36.png
# 输出的单张图片已保存到：test_from_dir2/37.png
# 输出的单张图片已保存到：test_from_dir2/38.png
# 输出的单张图片已保存到：test_from_dir2/39.png
# 输出的单张图片已保存到：test_from_dir2/40.png
# 输出的单张图片已保存到：test_from_dir2/41.png
# 输出的单张图片已保存到：test_from_dir2/42.png
# 输出的单张图片已保存到：test_from_dir2/43.png
# 输出的单张图片已保存到：test_from_dir2/44.png
# 输出的单张图片已保存到：test_from_dir2/45.png
# 输出的单张图片已保存到：test_from_dir2/46.png
# 输出的单张图片已保存到：test_from_dir2/47.png
# 输出的单张图片已保存到：test_from_dir2/48.png
# 输出的单张图片已保存到：test_from_dir2/49.png
# 输出的单张图片已保存到：test_from_dir2/50.png
# 输出的单张图片已保存到：test_from_dir2/51.png
# 输出的单张图片已保存到：test_from_dir2/52.png
# 输出的单张图片已保存到：test_from_dir2/53.png
# 输出的单张图片已保存到：test_from_dir2/54.png
# 输出的单张图片已保存到：test_from_dir2/55.png
# 输出的单张图片已保存到：test_from_dir2/56.png
# 输出的单张图片已保存到：test_from_dir2/57.png
# 输出的单张图片已保存到：test_from_dir2/58.png
# 输出的单张图片已保存到：test_from_dir2/59.png
# 输出的单张图片已保存到：test_from_dir2/60.png
# 输出的单张图片已保存到：test_from_dir2/61.png
# 输出的单张图片已保存到：test_from_dir2/62.png
# 输出的单张图片已保存到：test_from_dir2/63.png
# 输出的单张图片已保存到：test_from_dir2/64.png
# 输出的单张图片已保存到：test_from_dir2/65.png
# 输出的单张图片已保存到：test_from_dir2/66.png
# 输出的单张图片已保存到：test_from_dir2/67.png
# 输出的单张图片已保存到：test_from_dir2/68.png
# 输出的单张图片已保存到：test_from_dir2/69.png
# 输出的单张图片已保存到：test_from_dir2/70.png
# 输出的单张图片已保存到：test_from_dir2/71.png
# 输出的单张图片已保存到：test_from_dir2/72.png
# 输出的单张图片已保存到：test_from_dir2/73.png
# 输出的单张图片已保存到：test_from_dir2/74.png
# 输出的单张图片已保存到：test_from_dir2/75.png
# 输出的单张图片已保存到：test_from_dir2/76.png
# 输出的单张图片已保存到：test_from_dir2/77.png
# 输出的单张图片已保存到：test_from_dir2/78.png
# 输出的单张图片已保存到：test_from_dir2/79.png
# 输出的单张图片已保存到：test_from_dir2/80.png
# 输出的单张图片已保存到：test_from_dir2/81.png
# 输出的单张图片已保存到：test_from_dir2/82.png
# 输出的单张图片已保存到：test_from_dir2/83.png
# 输出的单张图片已保存到：test_from_dir2/84.png
# 输出的单张图片已保存到：test_from_dir2/85.png
# 输出的单张图片已保存到：test_from_dir2/86.png
# 输出的单张图片已保存到：test_from_dir2/87.png
# 输出的单张图片已保存到：test_from_dir2/88.png
# 输出的单张图片已保存到：test_from_dir2/89.png
# 输出的单张图片已保存到：test_from_dir2/90.png
# 输出的单张图片已保存到：test_from_dir2/91.png
# 输出的单张图片已保存到：test_from_dir2/92.png
# 输出的单张图片已保存到：test_from_dir2/93.png
# 输出的单张图片已保存到：test_from_dir2/94.png
# 输出的单张图片已保存到：test_from_dir2/95.png
# 输出的单张图片已保存到：test_from_dir2/96.png
# 输出的单张图片已保存到：test_from_dir2/97.png
# 输出的单张图片已保存到：test_from_dir2/98.png
# 输出的单张图片已保存到：test_from_dir2/99.png
# 输出的单张图片已保存到：test_from_dir2/100.png
# 输出的单张图片已保存到：test_from_dir2/101.png
# 输出的单张图片已保存到：test_from_dir2/102.png
# 输出的单张图片已保存到：test_from_dir2/103.png
# 输出的单张图片已保存到：test_from_dir2/104.png
# 输出的单张图片已保存到：test_from_dir2/105.png
# 输出的单张图片已保存到：test_from_dir2/106.png
# 输出的单张图片已保存到：test_from_dir2/107.png
# 输出的单张图片已保存到：test_from_dir2/108.png
# 输出的单张图片已保存到：test_from_dir2/109.png
# 输出的单张图片已保存到：test_from_dir2/110.png
# 输出的单张图片已保存到：test_from_dir2/111.png
# 输出的单张图片已保存到：test_from_dir2/112.png
# 输出的单张图片已保存到：test_from_dir2/113.png
# 输出的单张图片已保存到：test_from_dir2/114.png
# 输出的单张图片已保存到：test_from_dir2/115.png
# 输出的单张图片已保存到：test_from_dir2/116.png
# 输出的单张图片已保存到：test_from_dir2/117.png
# 输出的单张图片已保存到：test_from_dir2/118.png
# 输出的单张图片已保存到：test_from_dir2/119.png
# 输出的单张图片已保存到：test_from_dir2/120.png
# 输出的单张图片已保存到：test_from_dir2/121.png
# 输出的单张图片已保存到：test_from_dir2/122.png
# 输出的单张图片已保存到：test_from_dir2/123.png
# 输出的单张图片已保存到：test_from_dir2/124.png
# 输出的单张图片已保存到：test_from_dir2/125.png
# 输出的单张图片已保存到：test_from_dir2/126.png
# 输出的单张图片已保存到：test_from_dir2/127.png
# 输出的单张图片已保存到：test_from_dir2/128.png
# 输出的单张图片已保存到：test_from_dir2/129.png
# 输出的单张图片已保存到：test_from_dir2/130.png
# 输出的单张图片已保存到：test_from_dir2/131.png
# 输出的单张图片已保存到：test_from_dir2/132.png
# 输出的单张图片已保存到：test_from_dir2/133.png
# 输出的单张图片已保存到：test_from_dir2/134.png
# 输出的单张图片已保存到：test_from_dir2/135.png
# 输出的单张图片已保存到：test_from_dir2/136.png
# 输出的单张图片已保存到：test_from_dir2/137.png
# 输出的单张图片已保存到：test_from_dir2/138.png
# 输出的单张图片已保存到：test_from_dir2/139.png
# 输出的单张图片已保存到：test_from_dir2/140.png
# 输出的单张图片已保存到：test_from_dir2/141.png
# 输出的单张图片已保存到：test_from_dir2/142.png
# 输出的单张图片已保存到：test_from_dir2/143.png
# 输出的单张图片已保存到：test_from_dir2/144.png
# 输出的单张图片已保存到：test_from_dir2/145.png
# 输出的单张图片已保存到：test_from_dir2/146.png
# 输出的单张图片已保存到：test_from_dir2/147.png
# 输出的单张图片已保存到：test_from_dir2/148.png
# 输出的单张图片已保存到：test_from_dir2/149.png
# 输出的单张图片已保存到：test_from_dir2/150.png
# 输出的单张图片已保存到：test_from_dir2/151.png
# 输出的单张图片已保存到：test_from_dir2/152.png
# 输出的单张图片已保存到：test_from_dir2/153.png
# 输出的单张图片已保存到：test_from_dir2/154.png
# 输出的单张图片已保存到：test_from_dir2/155.png
# 输出的单张图片已保存到：test_from_dir2/156.png
# 输出的单张图片已保存到：test_from_dir2/157.png
# 输出的单张图片已保存到：test_from_dir2/158.png
# 输出的单张图片已保存到：test_from_dir2/159.png
# 输出的单张图片已保存到：test_from_dir2/160.png
# 输出的单张图片已保存到：test_from_dir2/161.png
# 输出的单张图片已保存到：test_from_dir2/162.png
# 输出的单张图片已保存到：test_from_dir2/163.png
# 输出的单张图片已保存到：test_from_dir2/164.png
# 输出的单张图片已保存到：test_from_dir2/165.png
# 输出的单张图片已保存到：test_from_dir2/166.png
# 输出的单张图片已保存到：test_from_dir2/167.png
# 输出的单张图片已保存到：test_from_dir2/168.png
# 输出的单张图片已保存到：test_from_dir2/169.png
# 输出的单张图片已保存到：test_from_dir2/170.png
# 输出的单张图片已保存到：test_from_dir2/171.png
# 输出的单张图片已保存到：test_from_dir2/172.png
# 输出的单张图片已保存到：test_from_dir2/173.png
# 输出的单张图片已保存到：test_from_dir2/174.png
# 输出的单张图片已保存到：test_from_dir2/175.png
# 输出的单张图片已保存到：test_from_dir2/176.png
# 输出的单张图片已保存到：test_from_dir2/177.png
# 输出的单张图片已保存到：test_from_dir2/178.png
# 输出的单张图片已保存到：test_from_dir2/179.png
# 输出的单张图片已保存到：test_from_dir2/180.png
# 输出的单张图片已保存到：test_from_dir2/181.png
# 输出的单张图片已保存到：test_from_dir2/182.png
# 输出的单张图片已保存到：test_from_dir2/183.png
# 输出的单张图片已保存到：test_from_dir2/184.png
# 输出的单张图片已保存到：test_from_dir2/185.png
# 输出的单张图片已保存到：test_from_dir2/186.png
# 输出的单张图片已保存到：test_from_dir2/187.png
# 输出的单张图片已保存到：test_from_dir2/188.png
# 输出的单张图片已保存到：test_from_dir2/189.png
# 输出的单张图片已保存到：test_from_dir2/190.png
# 输出的单张图片已保存到：test_from_dir2/191.png
# 输出的单张图片已保存到：test_from_dir2/192.png
# 输出的单张图片已保存到：test_from_dir2/193.png
# 输出的单张图片已保存到：test_from_dir2/194.png
# 输出的单张图片已保存到：test_from_dir2/195.png
# 输出的单张图片已保存到：test_from_dir2/196.png
# 输出的单张图片已保存到：test_from_dir2/197.png
# 输出的单张图片已保存到：test_from_dir2/198.png
# 输出的单张图片已保存到：test_from_dir2/199.png
# 输出的单张图片已保存到：test_from_dir2/200.png
# 输出的单张图片已保存到：test_from_dir2/201.png
# 输出的单张图片已保存到：test_from_dir2/202.png
# 输出的单张图片已保存到：test_from_dir2/203.png
# 输出的单张图片已保存到：test_from_dir2/204.png
# 输出的单张图片已保存到：test_from_dir2/205.png
# 输出的单张图片已保存到：test_from_dir2/206.png
# 输出的单张图片已保存到：test_from_dir2/207.png
# 输出的单张图片已保存到：test_from_dir2/208.png
# 输出的单张图片已保存到：test_from_dir2/209.png
# 输出的单张图片已保存到：test_from_dir2/210.png
# 输出的单张图片已保存到：test_from_dir2/211.png
# 输出的单张图片已保存到：test_from_dir2/212.png
# 输出的单张图片已保存到：test_from_dir2/213.png
# 输出的单张图片已保存到：test_from_dir2/214.png
# 输出的单张图片已保存到：test_from_dir2/215.png
# 输出的单张图片已保存到：test_from_dir2/216.png
# 输出的单张图片已保存到：test_from_dir2/217.png
# 输出的单张图片已保存到：test_from_dir2/218.png
# 输出的单张图片已保存到：test_from_dir2/219.png
# 输出的单张图片已保存到：test_from_dir2/220.png
# 输出的单张图片已保存到：test_from_dir2/221.png
# 输出的单张图片已保存到：test_from_dir2/222.png
# 输出的单张图片已保存到：test_from_dir2/223.png
# 输出的单张图片已保存到：test_from_dir2/224.png
# 输出的单张图片已保存到：test_from_dir2/225.png
# 输出的单张图片已保存到：test_from_dir2/226.png
# 输出的单张图片已保存到：test_from_dir2/227.png
# 输出的单张图片已保存到：test_from_dir2/228.png
# 输出的单张图片已保存到：test_from_dir2/229.png
# 输出的单张图片已保存到：test_from_dir2/230.png
# 输出的单张图片已保存到：test_from_dir2/231.png
# 输出的单张图片已保存到：test_from_dir2/232.png
# 输出的单张图片已保存到：test_from_dir2/233.png
# 输出的单张图片已保存到：test_from_dir2/234.png
# 输出的单张图片已保存到：test_from_dir2/235.png
# 输出的单张图片已保存到：test_from_dir2/236.png
# 输出的单张图片已保存到：test_from_dir2/237.png
# 输出的单张图片已保存到：test_from_dir2/238.png
# 输出的单张图片已保存到：test_from_dir2/239.png
# 输出的单张图片已保存到：test_from_dir2/240.png
# 输出的单张图片已保存到：test_from_dir2/241.png
# 输出的单张图片已保存到：test_from_dir2/242.png
# 输出的单张图片已保存到：test_from_dir2/243.png
# 输出的单张图片已保存到：test_from_dir2/244.png
# 输出的单张图片已保存到：test_from_dir2/245.png
# 输出的单张图片已保存到：test_from_dir2/246.png
# 输出的单张图片已保存到：test_from_dir2/247.png
# 输出的单张图片已保存到：test_from_dir2/248.png
# 输出的单张图片已保存到：test_from_dir2/249.png
# 输出的单张图片已保存到：test_from_dir2/250.png
# 输出的单张图片已保存到：test_from_dir2/251.png
# 输出的单张图片已保存到：test_from_dir2/252.png
# 输出的单张图片已保存到：test_from_dir2/253.png
# 输出的单张图片已保存到：test_from_dir2/254.png
# 输出的单张图片已保存到：test_from_dir2/255.png
# 输出的单张图片已保存到：test_from_dir2/256.png
# 输出的单张图片已保存到：test_from_dir2/257.png
# 输出的单张图片已保存到：test_from_dir2/258.png
# 输出的单张图片已保存到：test_from_dir2/259.png
# 输出的单张图片已保存到：test_from_dir2/260.png
# 输出的单张图片已保存到：test_from_dir2/261.png
# 输出的单张图片已保存到：test_from_dir2/262.png
# 输出的单张图片已保存到：test_from_dir2/263.png
# 输出的单张图片已保存到：test_from_dir2/264.png
# 输出的单张图片已保存到：test_from_dir2/265.png
# 输出的单张图片已保存到：test_from_dir2/266.png
# 输出的单张图片已保存到：test_from_dir2/267.png
# 输出的单张图片已保存到：test_from_dir2/268.png
# 输出的单张图片已保存到：test_from_dir2/269.png
# 输出的单张图片已保存到：test_from_dir2/270.png
# 输出的单张图片已保存到：test_from_dir2/271.png
# 输出的单张图片已保存到：test_from_dir2/272.png
# 输出的单张图片已保存到：test_from_dir2/273.png
# 输出的单张图片已保存到：test_from_dir2/274.png
# 输出的单张图片已保存到：test_from_dir2/275.png
# 输出的单张图片已保存到：test_from_dir2/276.png
# 输出的单张图片已保存到：test_from_dir2/277.png
# 输出的单张图片已保存到：test_from_dir2/278.png
# 输出的单张图片已保存到：test_from_dir2/279.png
# 输出的单张图片已保存到：test_from_dir2/280.png
# 输出的单张图片已保存到：test_from_dir2/281.png
# 输出的单张图片已保存到：test_from_dir2/282.png
# 输出的单张图片已保存到：test_from_dir2/283.png
# 输出的单张图片已保存到：test_from_dir2/284.png
# 输出的单张图片已保存到：test_from_dir2/285.png
# 输出的单张图片已保存到：test_from_dir2/286.png
# 输出的单张图片已保存到：test_from_dir2/287.png
# 输出的单张图片已保存到：test_from_dir2/288.png
# 输出的单张图片已保存到：test_from_dir2/289.png
# 输出的单张图片已保存到：test_from_dir2/290.png
# 输出的单张图片已保存到：test_from_dir2/291.png
# 输出的单张图片已保存到：test_from_dir2/292.png
# 输出的单张图片已保存到：test_from_dir2/293.png
# 输出的单张图片已保存到：test_from_dir2/294.png
# 输出的单张图片已保存到：test_from_dir2/295.png
# 输出的单张图片已保存到：test_from_dir2/296.png
# 输出的单张图片已保存到：test_from_dir2/297.png
# 输出的单张图片已保存到：test_from_dir2/298.png
# 输出的单张图片已保存到：test_from_dir2/299.png
# 输出的单张图片已保存到：test_from_dir2/300.png
# 输出的单张图片已保存到：test_from_dir2/301.png
# 输出的单张图片已保存到：test_from_dir2/302.png
# 输出的单张图片已保存到：test_from_dir2/303.png
# 输出的单张图片已保存到：test_from_dir2/304.png
# 输出的单张图片已保存到：test_from_dir2/305.png
# 输出的单张图片已保存到：test_from_dir2/306.png
# 输出的单张图片已保存到：test_from_dir2/307.png
# 输出的单张图片已保存到：test_from_dir2/308.png
# 输出的单张图片已保存到：test_from_dir2/309.png
# 输出的单张图片已保存到：test_from_dir2/310.png
# 输出的单张图片已保存到：test_from_dir2/311.png
# 输出的单张图片已保存到：test_from_dir2/312.png
# 输出的单张图片已保存到：test_from_dir2/313.png
# 输出的单张图片已保存到：test_from_dir2/314.png
# 输出的单张图片已保存到：test_from_dir2/315.png
# 输出的单张图片已保存到：test_from_dir2/316.png
# 输出的单张图片已保存到：test_from_dir2/317.png
# 输出的单张图片已保存到：test_from_dir2/318.png
# 输出的单张图片已保存到：test_from_dir2/319.png
# 输出的单张图片已保存到：test_from_dir2/320.png
# 输出的单张图片已保存到：test_from_dir2/321.png
# 输出的单张图片已保存到：test_from_dir2/322.png
# 输出的单张图片已保存到：test_from_dir2/323.png
# 输出的单张图片已保存到：test_from_dir2/324.png
# 输出的单张图片已保存到：test_from_dir2/325.png
# 输出的单张图片已保存到：test_from_dir2/326.png
# 输出的单张图片已保存到：test_from_dir2/327.png
# 输出的单张图片已保存到：test_from_dir2/328.png
# 输出的单张图片已保存到：test_from_dir2/329.png
# 输出的单张图片已保存到：test_from_dir2/330.png
# 输出的单张图片已保存到：test_from_dir2/331.png
# 输出的单张图片已保存到：test_from_dir2/332.png
# 输出的单张图片已保存到：test_from_dir2/333.png
# 输出的单张图片已保存到：test_from_dir2/334.png
# 输出的单张图片已保存到：test_from_dir2/335.png
# 输出的单张图片已保存到：test_from_dir2/336.png
# 输出的单张图片已保存到：test_from_dir2/337.png
# 输出的单张图片已保存到：test_from_dir2/338.png
# 输出的单张图片已保存到：test_from_dir2/339.png
# 输出的单张图片已保存到：test_from_dir2/340.png
# 输出的单张图片已保存到：test_from_dir2/341.png
# 输出的单张图片已保存到：test_from_dir2/342.png
# 输出的单张图片已保存到：test_from_dir2/343.png
# 输出的单张图片已保存到：test_from_dir2/344.png
# 输出的单张图片已保存到：test_from_dir2/345.png
# 输出的单张图片已保存到：test_from_dir2/346.png
# 输出的单张图片已保存到：test_from_dir2/347.png
# 输出的单张图片已保存到：test_from_dir2/348.png
# 输出的单张图片已保存到：test_from_dir2/349.png
# 输出的单张图片已保存到：test_from_dir2/350.png
# 输出的单张图片已保存到：test_from_dir2/351.png
# 输出的单张图片已保存到：test_from_dir2/352.png
# 输出的单张图片已保存到：test_from_dir2/353.png
# 输出的单张图片已保存到：test_from_dir2/354.png
# 输出的单张图片已保存到：test_from_dir2/355.png
# 输出的单张图片已保存到：test_from_dir2/356.png
# 输出的单张图片已保存到：test_from_dir2/357.png
# 输出的单张图片已保存到：test_from_dir2/358.png
# 输出的单张图片已保存到：test_from_dir2/359.png
# 输出的单张图片已保存到：test_from_dir2/360.png
# 输出的单张图片已保存到：test_from_dir2/361.png
# 输出的单张图片已保存到：test_from_dir2/362.png
# 输出的单张图片已保存到：test_from_dir2/363.png
# 输出的单张图片已保存到：test_from_dir2/364.png
# 输出的单张图片已保存到：test_from_dir2/365.png
# 输出的单张图片已保存到：test_from_dir2/366.png
# 输出的单张图片已保存到：test_from_dir2/367.png
# 输出的单张图片已保存到：test_from_dir2/368.png
# 输出的单张图片已保存到：test_from_dir2/369.png
# 输出的单张图片已保存到：test_from_dir2/370.png
# 输出的单张图片已保存到：test_from_dir2/371.png
# 输出的单张图片已保存到：test_from_dir2/372.png
# 输出的单张图片已保存到：test_from_dir2/373.png
# 输出的单张图片已保存到：test_from_dir2/374.png
# 输出的单张图片已保存到：test_from_dir2/375.png
# 输出的单张图片已保存到：test_from_dir2/376.png
# 输出的单张图片已保存到：test_from_dir2/377.png
# 输出的单张图片已保存到：test_from_dir2/378.png
# 输出的单张图片已保存到：test_from_dir2/379.png
# 输出的单张图片已保存到：test_from_dir2/380.png
# 输出的单张图片已保存到：test_from_dir2/381.png
# 输出的单张图片已保存到：test_from_dir2/382.png
# 输出的单张图片已保存到：test_from_dir2/383.png
# 输出的单张图片已保存到：test_from_dir2/384.png
# 输出的单张图片已保存到：test_from_dir2/385.png
# 输出的单张图片已保存到：test_from_dir2/386.png
# 输出的单张图片已保存到：test_from_dir2/387.png
# 输出的单张图片已保存到：test_from_dir2/388.png
# 输出的单张图片已保存到：test_from_dir2/389.png
# 输出的单张图片已保存到：test_from_dir2/390.png
# 输出的单张图片已保存到：test_from_dir2/391.png
# 输出的单张图片已保存到：test_from_dir2/392.png
# 输出的单张图片已保存到：test_from_dir2/393.png
# 输出的单张图片已保存到：test_from_dir2/394.png
# 输出的单张图片已保存到：test_from_dir2/395.png
# 输出的单张图片已保存到：test_from_dir2/396.png
# 输出的单张图片已保存到：test_from_dir2/397.png
# 输出的单张图片已保存到：test_from_dir2/398.png
# 输出的单张图片已保存到：test_from_dir2/399.png
# 输出的单张图片已保存到：test_from_dir2/400.png
# 输出的单张图片已保存到：test_from_dir2/401.png
# 输出的单张图片已保存到：test_from_dir2/402.png
# 输出的单张图片已保存到：test_from_dir2/403.png
# 输出的单张图片已保存到：test_from_dir2/404.png
# 输出的单张图片已保存到：test_from_dir2/405.png
# 输出的单张图片已保存到：test_from_dir2/406.png
# 输出的单张图片已保存到：test_from_dir2/407.png
# 输出的单张图片已保存到：test_from_dir2/408.png
# 输出的单张图片已保存到：test_from_dir2/409.png
# 输出的单张图片已保存到：test_from_dir2/410.png
# 输出的单张图片已保存到：test_from_dir2/411.png
# 输出的单张图片已保存到：test_from_dir2/412.png
# 输出的单张图片已保存到：test_from_dir2/413.png
# 输出的单张图片已保存到：test_from_dir2/414.png
# 输出的单张图片已保存到：test_from_dir2/415.png
# 输出的单张图片已保存到：test_from_dir2/416.png
# 输出的单张图片已保存到：test_from_dir2/417.png
# 输出的单张图片已保存到：test_from_dir2/418.png
# 输出的单张图片已保存到：test_from_dir2/419.png
# 输出的单张图片已保存到：test_from_dir2/420.png
# 输出的单张图片已保存到：test_from_dir2/421.png
# 输出的单张图片已保存到：test_from_dir2/422.png
# 输出的单张图片已保存到：test_from_dir2/423.png
# 输出的单张图片已保存到：test_from_dir2/424.png
# 输出的单张图片已保存到：test_from_dir2/425.png
# 输出的单张图片已保存到：test_from_dir2/426.png
# 输出的单张图片已保存到：test_from_dir2/427.png
# 输出的单张图片已保存到：test_from_dir2/428.png
# 输出的单张图片已保存到：test_from_dir2/429.png
# 输出的单张图片已保存到：test_from_dir2/430.png
# 输出的单张图片已保存到：test_from_dir2/431.png
# 输出的单张图片已保存到：test_from_dir2/432.png
# 输出的单张图片已保存到：test_from_dir2/433.png
# 输出的单张图片已保存到：test_from_dir2/434.png
# 输出的单张图片已保存到：test_from_dir2/435.png
# 输出的单张图片已保存到：test_from_dir2/436.png
# 输出的单张图片已保存到：test_from_dir2/437.png
# 输出的单张图片已保存到：test_from_dir2/438.png
# 输出的单张图片已保存到：test_from_dir2/439.png
# 输出的单张图片已保存到：test_from_dir2/440.png
# 输出的单张图片已保存到：test_from_dir2/441.png
# 输出的单张图片已保存到：test_from_dir2/442.png
# 输出的单张图片已保存到：test_from_dir2/443.png
# 输出的单张图片已保存到：test_from_dir2/444.png
# 输出的单张图片已保存到：test_from_dir2/445.png
# 输出的单张图片已保存到：test_from_dir2/446.png
# 输出的单张图片已保存到：test_from_dir2/447.png
# 输出的单张图片已保存到：test_from_dir2/448.png
# 输出的单张图片已保存到：test_from_dir2/449.png
# 输出的单张图片已保存到：test_from_dir2/450.png
# 输出的单张图片已保存到：test_from_dir2/451.png
# 输出的单张图片已保存到：test_from_dir2/452.png
# 输出的单张图片已保存到：test_from_dir2/453.png
# 输出的单张图片已保存到：test_from_dir2/454.png
# 输出的单张图片已保存到：test_from_dir2/455.png
# 输出的单张图片已保存到：test_from_dir2/456.png
# 输出的单张图片已保存到：test_from_dir2/457.png
# 输出的单张图片已保存到：test_from_dir2/458.png
# 输出的单张图片已保存到：test_from_dir2/459.png
# 输出的单张图片已保存到：test_from_dir2/460.png
# 输出的单张图片已保存到：test_from_dir2/461.png
# 输出的单张图片已保存到：test_from_dir2/462.png
# 输出的单张图片已保存到：test_from_dir2/463.png
# 输出的单张图片已保存到：test_from_dir2/464.png
# 输出的单张图片已保存到：test_from_dir2/465.png
# 输出的单张图片已保存到：test_from_dir2/466.png
# 输出的单张图片已保存到：test_from_dir2/467.png
# 输出的单张图片已保存到：test_from_dir2/468.png
# 输出的单张图片已保存到：test_from_dir2/469.png
# 输出的单张图片已保存到：test_from_dir2/470.png
# 输出的单张图片已保存到：test_from_dir2/471.png
# 输出的单张图片已保存到：test_from_dir2/472.png
# 输出的单张图片已保存到：test_from_dir2/473.png
# 输出的单张图片已保存到：test_from_dir2/474.png
# 输出的单张图片已保存到：test_from_dir2/475.png
# 输出的单张图片已保存到：test_from_dir2/476.png
# 输出的单张图片已保存到：test_from_dir2/477.png
# 输出的单张图片已保存到：test_from_dir2/478.png
# 输出的单张图片已保存到：test_from_dir2/479.png
# 输出的单张图片已保存到：test_from_dir2/480.png
# 输出的单张图片已保存到：test_from_dir2/481.png
# 输出的单张图片已保存到：test_from_dir2/482.png
# 输出的单张图片已保存到：test_from_dir2/483.png
# 输出的单张图片已保存到：test_from_dir2/484.png
# 输出的单张图片已保存到：test_from_dir2/485.png
# 输出的单张图片已保存到：test_from_dir2/486.png
# 输出的单张图片已保存到：test_from_dir2/487.png
# 输出的单张图片已保存到：test_from_dir2/488.png
# 输出的单张图片已保存到：test_from_dir2/489.png
# 输出的单张图片已保存到：test_from_dir2/490.png
# 输出的单张图片已保存到：test_from_dir2/491.png
# 输出的单张图片已保存到：test_from_dir2/492.png
# 输出的单张图片已保存到：test_from_dir2/493.png
# 输出的单张图片已保存到：test_from_dir2/494.png
# 输出的单张图片已保存到：test_from_dir2/495.png
# 输出的单张图片已保存到：test_from_dir2/496.png
# 输出的单张图片已保存到：test_from_dir2/497.png
# 输出的单张图片已保存到：test_from_dir2/498.png
# 输出的单张图片已保存到：test_from_dir2/499.png
# 输出的单张图片已保存到：test_from_dir2/500.png

# %%
# 查看部分生成图片
plt.figure(figsize=(12,12))
for i in range(16):
    plt.subplot(4, 4, i + 1)
    if c == 3:
        fake_images[i] = cv.cvtColor(fake_images[i], cv.COLOR_BGR2RGB)
    plt.imshow(fake_images[i])
    plt.axis('off')
plt.show()
