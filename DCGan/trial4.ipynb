# %%
import sys, os
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow.keras import datasets, optimizers, metrics, layers, Sequential, Model, Input, losses
from load_datasets import DataLoader
import time

# %%
os.environ['KMP_DUPLICATE_LIB_OK']='True'  #防止训练过程中的kernel发生crash的情形

# %%
# 卷积层的生成器和鉴别器
def generator_network_dcgan(h, w, c, noise_dim=100):  # 输入噪声和标签，输出假图
    h_, w_ = h // 8, w // 8
    input_noise = Input(shape=(noise_dim,))  # (b,100)
    x = layers.Dense(h_ * w_ * 256)(input_noise)  #全连接层用于调整噪声的维度
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)
    x = layers.Reshape((h_, w_, 256))(x)  # (b,h/4,w/4,256)
    
    x = layers.Conv2DTranspose(128, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/2,w/2,256)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)

    x = layers.Conv2DTranspose(64, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/2,w/2,128)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)

    x = layers.Conv2DTranspose(32, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h,w,64)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)
    x = layers.Conv2DTranspose(c, (3, 3), padding='same', activation='tanh')(x)  # (b,h,w,c)
    generator = Model(input_noise, x)
    return generator

# %%
def discriminator_network_dcgan(h, w, c):  # 输入图片和标签，输出待验证的值。输出1为真，0为假
    input_image = Input(shape=(h, w, c))  # (b,h,w,c)
    x = layers.Conv2D(32, (3, 3), strides=(2, 2), padding='same')(input_image)  # (b,h/2,w/2,64)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)  
    x = layers.Dropout(0.3)(x)  #改进：在鉴别器的层之间添加dropout

    x = layers.Conv2D(64, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/4,w/4,128)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)
    x = layers.Dropout(0.3)(x)

    x = layers.Conv2D(128, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/4,w/4,256)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)
    x = layers.Dropout(0.3)(x)
    
    x = layers.Conv2D(256, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/4,w/4,512)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)
    x = layers.Dropout(0.3)(x)

    x = layers.Flatten()(x)  # (b,h/4*w/4*512)
    validity = layers.Dense(1, activation=None)(x)  # (b,1) 最后一层，flatten后全连接层

    discriminator = Model(input_image, validity)
    return discriminator

# %%
# WGAN-GP梯度控制函数
def gradient_penalty(discriminator, batch_x, fake_image):
    #梯度惩罚项计算函数
    batchsz = batch_x.shape[0]

    #每个样本均随机采样t,用于插值
    t = tf.random.uniform([batchsz,1,1,1])
    #自动扩展为x的形状:[b,1,1,1] => [b,h,w,c]
    t = tf.broadcast_to(t, batch_x.shape)
    #在真假图片之间作线性插值
    interplate = t * batch_x + (1-t) * fake_image
    #在梯度环境中计算 D 对插值样本的梯度
    with tf.GradientTape() as tape:
        tape.watch([interplate])
        d_interplate_logits = discriminator(interplate)

        grads = tape.gradient(d_interplate_logits, interplate)

        #计算每个样本的梯度的范数:[b,h,w,c] => [b,-1]
        grads = tf.reshape(grads, [grads.shape[0],-1])
        gp = tf.norm(grads,axis=1)
        #计算梯度惩罚项
        gp = tf.reduce_mean((gp-1.)**2)

    return gp

# %%
def save_image(fake_image, fake_label=None, fake_num=16, save_to=''):  # X为4维的带批次的图片
    ''' 
    用于保存图片的函数
    '''
    plt.figure()
    _, h, w, c = fake_image.shape  #设定生成假图的shape（128*128*3）
    if fake_num > 1:
        for i in range(fake_num):
            plt.subplot(4, 4, i + 1)  #训练过程中的迭代以4*4=16（一次保存16张图片）
            if c == 3:  # 如果是bgr则转为rgb（通道的转换）
                plt.imshow(cv.cvtColor(fake_image[i], cv.COLOR_BGR2RGB))  #对于一般格式与BGR格式都予以显示
            if c == 1:  # 如果是灰图则显示灰图
                plt.imshow(np.squeeze(fake_image[i]), cmap='gray')
            if fake_label is not None:  # 如果有标签则传入标签（这是为了在真图与假图之间鉴别时用）
                plt.title(fake_label[i])
            plt.axis('off')
        plt.savefig(save_to)
        plt.close()
    else:  # fake_num=1时保存单张图片，否则按照多张图片的格式保存
        cv.imwrite(save_to, fake_image[0])
    print('输出图片已保存至:%s' % save_to)

# %%
def creat_dir(path):  #用于生成迭代过程中的图片以及保存后续生成的图像
    os.makedirs(path, exist_ok=True)

# %%
print('tf版本：', tf.__version__)
# 定义参数
batch_size = 5  # 每次训练的批次（太大可能会显存不够而报错，故在这里选择较小的值）
epochs = 200000  # 共迭代训练几次
g_lr = 0.0005  # 生成器学习率
d_lr = 0.0002  # 鉴别器学习率
fake_num = 16  # 生成的图片的个数（一般不改）
dataset_name = 'female'  # 数据集的名字  star_imgs  female  cat_vs_dog
h, w, c = 256, 256, 3  # 数据集图片的宽和高，也是生成图片的宽和高
noise_dim = 100  # 输入噪声的维度（一般不改）
save_step = 1000  # 每隔几次保存一次中间结果图和权重。如果是0，则不保存中间结果图和权重
# Out:
# tf版本： 2.7.0

# %%
# 创建文件夹
directory = './checkpoint5/' + dataset_name + '_%s×%s' % (h, w)  # 输出参数保存的文件夹，一般不改
image_dir = './result_image5/' + dataset_name + '_%s×%s' % (h, w)  # 输出图片保存的文件夹，一般不改
os.makedirs(directory, exist_ok=True)
os.makedirs(image_dir, exist_ok=True)
image_names = os.listdir(image_dir)

# %%
# 加载数据集和预处理
dataloader = DataLoader(dir_path=r'./datasets/%s' % dataset_name, dataset_name=dataset_name,
                        norm_range=(-1, 1), img_res=(h, w))
x_train = dataloader.load_datasets()  # 加载数据集
print('正在加载数据集...')
# Out:
# ./datasets/female [] ['3581.png', '2229.png', '6064.png', '5866.png', '5862.png', '1389.png', '3461.png', '900.png', '9765.png', '8475.png', '5627.png', '5139.png', '4985.png', '7784.png', '3012.png', '3389.png', '4843.png', '3413.png', '7193.png', '1089.png', '4793.png', '6679.png', '3993.png', '2812.png', '2142.png', '7656.png', '1783.png', '7585.png', '290.png', '4288.png', '31.png', '974.png', '35.png', '3906.png', '5631.png', '5011.png', '9335.png', '2942.png', '1351.png', '9682.png', '3494.png', '4380.png', '328.png', '7394.png', '3063.png', '690.png', '9701.png', '3106.png', '8176.png', '2781.png', '6031.png', '4497.png', '1956.png', '4605.png', '8624.png', '798.png', '923.png', '182.png', '6813.png', '5794.png', '4484.png', '3798.png', '3522.png', '465.png', '7378.png', '8646.png', '8148.png', '7139.png', '6317.png', '5906.png', '5643.png', '2543.png', '5478.png', '8035.png', '5221.png', '925.png', '865.png', '3924.png', '7136.png', '7289.png', '4425.png', '8614.png', '4277.png', '3361.png', '8961.png', '153.png', '1669.png', '3024.png', '5000.png', '5515.png', '4149.png', '1064.png', '5858.png', '3279.png', '1961.png', '2173.png', '3962.png', '277.png', '5542.png', '7532.png', '4301.png', '2982.png', '374.png', '2856.png', '1319.png', '5433.png', '9198.png', '3122.png', '9615.png', '9354.png', '4658.png', '6984.png', '4343.png', '6706.png', '4795.png', '8623.png', '8136.png', '4716.png', '834.png', '7025.png', '3256.png', '9525.png', '8487.png', '1032.png', '8364.png', '7347.png', '8257.png', '1816.png', '2426.png', '4148.png', '7684.png', '315.png', '1087.png', '7676.png', '49.png', '867.png', '8617.png', '7902.png', '1429.png', '2553.png', '1470.png', '1168.png', '8907.png', '9689.png', '187.png', '7828.png', '7319.png', '2595.png', '9268.png', '6274.png', '4977.png', '2427.png', '525.png', '8654.png', '5309.png', '4753.png', '4736.png', '3518.png', '6644.png', '6740.png', '9041.png', '4021.png', '6066.png', '484.png', '9748.png', '5679.png', '5705.png', '6728.png', '8096.png', '125.png', '2445.png', '2881.png', '5271.png', '5874.png', '2435.png', '8962.png', '9133.png', '250.png', '3432.png', '717.png', '8489.png', '2161.png', '5590.png', '8362.png', '4376.png', '6523.png', '8719.png', '7579.png', '589.png', '9777.png', '5811.png', '6833.png', '5200.png', '1146.png', '4773.png', '3597.png', '9163.png', '8902.png', '835.png', '4070.png', '4876.png', '8914.png', '642.png', '1423.png', '6290.png', '5346.png', '5625.png', '4491.png', '2439.png', '6059.png', '8451.png', '2233.png', '5920.png', '5981.png', '1649.png', '9565.png', '8412.png', '7340.png', '6430.png', '9564.png', '3125.png', '8145.png', '7079.png', '5153.png', '548.png', '5545.png', '7685.png', '1542.png', '6105.png', '1550.png', '6252.png', '3379.png', '9995.png', '8047.png', '5618.png', '1889.png', '3317.png', '9022.png', '6941.png', '2268.png', '4759.png', '118.png', '2137.png', '8682.png', '9971.png', '5599.png', '9854.png', '8286.png', '3033.png', '9687.png', '349.png', '1977.png', '8029.png', '2513.png', '6666.png', '6178.png', '2576.png', '4608.png', '7493.png', '6655.png', '1023.png', '6088.png', '8246.png', '2507.png', '7478.png', '7912.png', '4094.png', '5548.png', '8073.png', '2953.png', '7923.png', '5126.png', '8082.png', '3768.png', '9849.png', '3147.png', '2219.png', '8518.png', '830.png', '2691.png', '3276.png', '5114.png', '1033.png', '6301.png', '5379.png', '7488.png', '7406.png', '3935.png', '5763.png', '7332.png', '475.png', '6920.png', '4241.png', '5350.png', '3584.png', '4159.png', '8187.png', '2769.png', '8447.png', '9875.png', '426.png', '6351.png', '6593.png', '391.png', '3684.png', '9578.png', '1241.png', '7854.png', '1503.png', '2521.png', '9810.png', '3186.png', '2438.png', '12.png', '84.png', '3782.png', '3142.png', '4664.png', '4954.png', '3599.png', '5999.png', '5203.png', '7935.png', '4104.png', '2625.png', '5745.png', '6952.png', '9731.png', '5256.png', '7712.png', '850.png', '7187.png', '2004.png', '2132.png', '9473.png', '9 ...
# ['./datasets/female/3581.png' './datasets/female/2229.png'
#  './datasets/female/6064.png' ... './datasets/female/7223.png'
#  './datasets/female/5801.png' './datasets/female/9387.png']
# 正在加载数据集...

# %%
# 加载网络
generator = generator_network_dcgan(h, w, c, noise_dim=noise_dim)
discriminator = discriminator_network_dcgan(h, w, c)
# generator.summary()
# discriminator.summary()

# 如果采用Gelu作为激活函数，最好使用带动量的方法进行训练
g_optimizer = optimizers.RMSprop(learning_rate=g_lr)
d_optimizer = optimizers.RMSprop(learning_rate=g_lr)

# 设置随机种植可以让产生的图片不变，之后取消随机数种子
tf.random.set_seed(0)
noise_test = tf.random.normal([fake_num, noise_dim])
tf.random.set_seed(None)
# Out:
# 2022-12-24 11:33:52.683526: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-24 11:33:53.046124: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22308 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:50:00.0, compute capability: 8.6

# %%
generator.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  dense (Dense)               (None, 262144)            26476544
#
#  batch_normalization (BatchN  (None, 262144)           1048576
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 262144)            0
#
#  reshape (Reshape)           (None, 32, 32, 256)       0
#
#  conv2d_transpose (Conv2DTra  (None, 64, 64, 128)      295040
#  nspose)
#
#  batch_normalization_1 (Batc  (None, 64, 64, 128)      512
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 64, 64, 128)       0
#
#  conv2d_transpose_1 (Conv2DT  (None, 128, 128, 64)     73792
#  ranspose)
#
#  batch_normalization_2 (Batc  (None, 128, 128, 64)     256
#  hNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 128, 128, 64)      0
#
#  conv2d_transpose_2 (Conv2DT  (None, 256, 256, 32)     18464
#  ranspose)
#
#  batch_normalization_3 (Batc  (None, 256, 256, 32)     128
#  hNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 256, 256, 32)      0
#
#  conv2d_transpose_3 (Conv2DT  (None, 256, 256, 3)      867
#  ranspose)
#
# =================================================================
# Total params: 27,914,179
# Trainable params: 27,389,443
# Non-trainable params: 524,736
# _________________________________________________________________

# %%
discriminator.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv2d (Conv2D)             (None, 128, 128, 32)      896
#
#  batch_normalization_4 (Batc  (None, 128, 128, 32)     128
#  hNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 128, 128, 32)      0
#
#  dropout (Dropout)           (None, 128, 128, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        18496
#
#  batch_normalization_5 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 64, 64, 64)        0
#
#  dropout_1 (Dropout)         (None, 64, 64, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       73856
#
#  batch_normalization_6 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 32, 32, 128)       0
#
#  dropout_2 (Dropout)         (None, 32, 32, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)       295168
#
#  batch_normalization_7 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 16, 16, 256)       0
#
#  dropout_3 (Dropout)         (None, 16, 16, 256)       0
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense_1 (Dense)             (None, 1)                 65537
#
# =================================================================
# Total params: 455,873
# Trainable params: 454,913
# Non-trainable params: 960
# _________________________________________________________________

# %%
@tf.function  #tf.function用于加快运算速度
def train_step(x):
    # x = transform(x, dsize=(h, h), crop_size=(h, w))  # 使用随机裁剪
    # print('x:', x.shape)
    noise = tf.random.normal([x.shape[0], noise_dim])  # noise.shape=(b,100)
    with tf.GradientTape() as g_tape, tf.GradientTape() as d_tape:
        fake_image = generator(noise, training=True)  # (b, h, w, c)
        fake_out = discriminator(fake_image, training=True)  # (b, 1)
        real_out = discriminator(x, training=True)  # (b, 1)
        g_loss = tf.reduce_mean(
            losses.binary_crossentropy(y_true=tf.ones_like(fake_out), y_pred=fake_out, from_logits=True))  # 计算生成损失

        d1_loss = tf.reduce_mean(
            losses.binary_crossentropy(y_true=tf.ones_like(real_out), y_pred=real_out, from_logits=True))
        d2_loss = tf.reduce_mean(
            losses.binary_crossentropy(y_true=tf.zeros_like(fake_out), y_pred=fake_out, from_logits=True))  # 计算两个鉴别损失

        gp = gradient_penalty(discriminator, x, fake_image)  # 计算梯度惩罚项（wgan的内容，也可注释掉此行代码不使用）
        d_loss = d1_loss + d2_loss + 10.*gp
        #d_loss = d1_loss + d2_loss
    g_grads = g_tape.gradient(g_loss, generator.trainable_variables)
    d_grads = d_tape.gradient(d_loss, discriminator.trainable_variables)

    g_optimizer.apply_gradients(zip(g_grads, generator.trainable_variables))
    d_optimizer.apply_gradients(zip(d_grads, discriminator.trainable_variables))
    return [g_loss, d_loss]

# %%
# 创建保存参数
checkpoint = tf.train.Checkpoint(generator=generator,
                                 discriminator=discriminator)
checkpoint.restore(tf.train.latest_checkpoint(directory))  # 断点续训
manager = tf.train.CheckpointManager(checkpoint=checkpoint, directory=directory, max_to_keep=2,
                                     checkpoint_name=dataset_name)

max_num = max([int(image_name.split('.')[0][len(dataset_name):]) for image_name in image_names if
               image_name.endswith('png') or image_name.endswith('jpg')]) if image_names else 0  # 接着上次的往后保存

# %%
g_total_loss_list = []
d_total_loss_list = []

# 训练
print('数据加载完成，正在训练中...')
t1 = time.time()
for epoch in range(epochs):

    x_train = dataloader.load_batch(batch_size=batch_size)
    g_total_loss, d_total_loss = train_step(x_train)

    # 保存
    if save_step:
        if (epoch + 1) % save_step == 0 or epoch == 0:  # 每隔几个epoch保存一次
            fake_image = generator.predict(noise_test, batch_size=1)  # (b,h,w,c)
            fake_image = fake_image.reshape(-1, h, w, c) * 127.5 + 127.5  # (b,h,w,c)
            fake_image = np.clip(fake_image, 0, 255).astype('uint8')  # (b,h,w,c)
            save_to = image_dir + '/' + dataset_name + '%d.png' % (epoch + 1 + max_num)
            save_image(fake_image, fake_label=None, fake_num=fake_num, save_to=save_to)  # 保存图片
            manager.save(checkpoint_number=epoch + 1 + max_num)  # 保存参数
            g_total_loss_list.append(g_total_loss)
            d_total_loss_list.append(d_total_loss)  #每一定epoch后保存一次总损失值
            print('epoch:%d/%d:' % (epoch + 1 + max_num, epochs),
                  'g_total_loss:%.6f' % np.mean(g_total_loss),
                  'd_total_loss:%.6f' % np.mean(d_total_loss), '用时:%.6f' % (time.time() - t1))
            t1 = time.time()
    if epoch + 1 + max_num >= epochs:
        print('已跑完%s次' % epochs)
        break
manager.save(checkpoint_number=epochs)  # 训练完保存参数
# Out:
# 数据加载完成，正在训练中...
# 2022-12-24 11:34:07.126733: I tensorflow/stream_executor/cuda/cuda_blas.cc:1774] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2022-12-24 11:34:07.657527: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8101
# 输出图片已保存至:./result_image4/female_256×256/female1.png
# epoch:1/200000: g_total_loss:1.049208 d_total_loss:9.143286 用时:5.209961
# 输出图片已保存至:./result_image4/female_256×256/female1000.png
# epoch:1000/200000: g_total_loss:6.551953 d_total_loss:2.664647 用时:27.494865
# 输出图片已保存至:./result_image4/female_256×256/female2000.png
# epoch:2000/200000: g_total_loss:4.096442 d_total_loss:1.001851 用时:28.056077
# 输出图片已保存至:./result_image4/female_256×256/female3000.png
# epoch:3000/200000: g_total_loss:0.331410 d_total_loss:1.417284 用时:27.188029
# 输出图片已保存至:./result_image4/female_256×256/female4000.png
# epoch:4000/200000: g_total_loss:0.343621 d_total_loss:1.462283 用时:27.397776
# 输出图片已保存至:./result_image4/female_256×256/female5000.png
# epoch:5000/200000: g_total_loss:1.097868 d_total_loss:0.858042 用时:27.324257
# 输出图片已保存至:./result_image4/female_256×256/female6000.png
# epoch:6000/200000: g_total_loss:2.379101 d_total_loss:1.063642 用时:27.647650
# 输出图片已保存至:./result_image4/female_256×256/female7000.png
# epoch:7000/200000: g_total_loss:2.740286 d_total_loss:0.983648 用时:28.123703
# 输出图片已保存至:./result_image4/female_256×256/female8000.png
# epoch:8000/200000: g_total_loss:2.130855 d_total_loss:0.674750 用时:27.879293
# 输出图片已保存至:./result_image4/female_256×256/female9000.png
# epoch:9000/200000: g_total_loss:1.327784 d_total_loss:0.776953 用时:27.224275
# 输出图片已保存至:./result_image4/female_256×256/female10000.png
# epoch:10000/200000: g_total_loss:1.408227 d_total_loss:0.623264 用时:27.280088
# 输出图片已保存至:./result_image4/female_256×256/female11000.png
# epoch:11000/200000: g_total_loss:2.971473 d_total_loss:0.935078 用时:27.337627
# 输出图片已保存至:./result_image4/female_256×256/female12000.png
# epoch:12000/200000: g_total_loss:2.158922 d_total_loss:1.024599 用时:27.461848
# 输出图片已保存至:./result_image4/female_256×256/female13000.png
# epoch:13000/200000: g_total_loss:2.920044 d_total_loss:0.481087 用时:26.777487
# 输出图片已保存至:./result_image4/female_256×256/female14000.png
# epoch:14000/200000: g_total_loss:2.347970 d_total_loss:0.729291 用时:26.986562
# 输出图片已保存至:./result_image4/female_256×256/female15000.png
# epoch:15000/200000: g_total_loss:1.826594 d_total_loss:0.777102 用时:27.259233
# 输出图片已保存至:./result_image4/female_256×256/female16000.png
# epoch:16000/200000: g_total_loss:1.099176 d_total_loss:0.646104 用时:27.170303
# 输出图片已保存至:./result_image4/female_256×256/female17000.png
# epoch:17000/200000: g_total_loss:0.501681 d_total_loss:1.246590 用时:27.107638
# 输出图片已保存至:./result_image4/female_256×256/female18000.png
# epoch:18000/200000: g_total_loss:0.936148 d_total_loss:1.021823 用时:27.519661
# 输出图片已保存至:./result_image4/female_256×256/female19000.png
# epoch:19000/200000: g_total_loss:1.873653 d_total_loss:0.481021 用时:27.258487
# 输出图片已保存至:./result_image4/female_256×256/female20000.png
# epoch:20000/200000: g_total_loss:0.608841 d_total_loss:1.346654 用时:27.318020
# 输出图片已保存至:./result_image4/female_256×256/female21000.png
# epoch:21000/200000: g_total_loss:1.845080 d_total_loss:0.443358 用时:27.439274
# 输出图片已保存至:./result_image4/female_256×256/female22000.png
# epoch:22000/200000: g_total_loss:2.169413 d_total_loss:1.160475 用时:27.390920
# 输出图片已保存至:./result_image4/female_256×256/female23000.png
# epoch:23000/200000: g_total_loss:1.283306 d_total_loss:0.581999 用时:27.193804
# 输出图片已保存至:./result_image4/female_256×256/female24000.png
# epoch:24000/200000: g_total_loss:1.176029 d_total_loss:0.682861 用时:26.844903
# 输出图片已保存至:./result_image4/female_256×256/female25000.png
# epoch:25000/200000: g_total_loss:1.070829 d_total_loss:0.792877 用时:27.644391
# 输出图片已保存至:./result_image4/female_256×256/female26000.png
# epoch:26000/200000: g_total_loss:1.001947 d_total_loss:0.702507 用时:27.101165
# 输出图片已保存至:./result_image4/female_256×256/female27000.png
# epoch:27000/200000: g_total_loss:2.395315 d_total_loss:0.930972 用时:27.391558
# 输出图片已保存至:./result_image4/female_256×256/female28000.png
# epoch:28000/200000: g_total_loss:0.434552 d_total_loss:1.591252 用时:27.114445
# 输出图片已保存至:./result_image4/female_256×256/female29000.png
# epoch:29000/200000: g_total_loss:0.747782 d_total_loss:1.034697 用时:27.384089
# 输出图片已保存至:./result_image4/female_256×256/female30000.png
# epoch:30000/200000: g_total_loss:1.504775 d_total_loss:1.126196 用时:27.317378
# 输出图片已保存至:./result_image4/female_256×256/female31000.png
# epoch:31000/200000: g_total_loss:1.700904 d_total_loss:1.048544 用时:27.586067
# 输出图片已保存至:./result_image4/female_256×256/female32000.png
# epoch:32000/200000: g_total_loss:0.460262 d_total_loss:1.698238 用时:27.233103
# 输出图片已保存至:./result_image4/female_256×256/female33000.png
# epoch:33000/200000: g_total_loss:0.541013 d_total_loss:1.179888 用时:28.364277
# 输出图片已保存至:./result_image4/female_256×256/female34000.png
# epoch:34000/200000: g_total_loss:1.296530 d_total_loss:0.585176 用时:27.313454
# 输出图片已保存至:./result_image4/female_256×256/female35000.png
# epoch:35000/200000: g_total_loss:1.546748 d_total_loss:1.408327 用时:27.633324
# 输出图片已保存至:./result_image4/female_256×256/female36000.png
# epoch:36000/200000: g_total_loss:1.146030 d_total_loss:0.966022 用时:27.415130
# 输出图片已保存至:./result_image4/female_256×256/female37000.png
# epoch:37000/200000: g_total_loss:1.260929 d_total_loss:1.544702 用时:27.419908
# 输出图片已保存至:./result_image4/female_256×256/female38000.png
# epoch:38000/200000: g_total_loss:0.954120 d_total_loss:0.849505 用时:27.205526
# 输出图片已保存至:./result_image4/female_256×256/female39000.png
# epoch:39000/200000: g_total_loss:2.895071 d_total_loss:1.251537 用时:27.270163
# 输出图片已保存至:./result_image4/female_256×256/female40000.png
# epoch:40000/200000: g_total_loss:1.497824 d_total_loss:0.672322 用时:27.290132
# 输出图片已保存至:./result_image4/female_256×256/female41000.png
# epoch:41000/200000: g_total_loss:2.313967 d_total_loss:0.851386 用时:27.373495
# 输出图片已保存至:./result_image4/female_256×256/female42000.png
# epoch:42000/200000: g_total_loss:1.884295 d_total_loss:0.935330 用时:27.290316
# 输出图片已保存至:./result_image4/female_256×256/female43000.png
# epoch:43000/200000: g_total_loss:1.696605 d_total_loss:0.964747 用时:27.067396
# 输出图片已保存至:./result_image4/female_256×256/female44000.png
# epoch:44000/200000: g_total_loss:1.176797 d_total_loss:1.369571 用时:27.291911
# 输出图片已保存至:./result_image4/female_256×256/female45000.png
# epoch:45000/200000: g_total_loss:0.753018 d_total_loss:1.112406 用时:27.206519
# 输出图片已保存至:./result_image4/female_256×256/female46000.png
# epoch:46000/200000: g_total_loss:1.488508 d_total_loss:0.615783 用时:27.190853
# 输出图片已保存至:./result_image4/female_256×256/female47000.png
# epoch:47000/200000: g_total_loss:1.516981 d_total_loss:0.629431 用时:26.897248
# 输出图片已保存至:./result_image4/female_256×256/female48000.png
# epoch:48000/200000: g_total_loss:1.413240 d_total_loss:0.521234 用时:27.387762
# 输出图片已保存至:./result_image4/female_256×256/female49000.png
# epoch:49000/200000: g_total_loss:1.330715 d_total_loss:0.693599 用时:27.441043
# 输出图片已保存至:./result_image4/female_256×256/female50000.png
# epoch:50000/200000: g_total_loss:0.248000 d_total_loss:1.915758 用时:27.416370
# 输出图片已保存至:./result_image4/female_256×256/female51000.png
# epoch:51000/200000: g_total_loss:0.779867 d_total_loss:1.533392 用时:27.531670
# 输出图片已保存至:./result_image4/female_256×256/female52000.png
# epoch:52000/200000: g_total_loss:0.545541 d_total_loss:1.120950 用时:27.251817
# 输出图片已保存至:./result_image4/female_256×256/female53000.png
# epoch:53000/200000: g_total_loss:1.584649 d_total_loss:1.178639 用时:25.935677
# 输出图片已保存至:./result_image4/female_256×256/female54000.png
# epoch:54000/200000: g_total_loss:1.058018 d_total_loss:1.014115 用时:27.449445
# 输出图片已保存至:./result_image4/female_256×256/female55000.png
# epoch:55000/200000: g_total_loss:1.658568 d_total_loss:0.762623 用时:27.441784
# 输出图片已保存至:./result_image4/female_256×256/female56000.png
# epoch:56000/200000: g_total_loss:1.326135 d_total_loss:0.997331 用时:27.036774
# 输出图片已保存至:./result_image4/female_256×256/female57000.png
# epoch:57000/200000: g_total_loss:2.021784 d_total_loss:0.745927 用时:27.161491
# 输出图片已保存至:./result_image4/female_256×256/female58000.png
# epoch:58000/200000: g_total_loss:1.818952 d_total_loss:0.701626 用时:27.362014
# 输出图片已保存至:./result_image4/female_256×256/female59000.png
# epoch:59000/200000: g_total_loss:1.339227 d_total_loss:0.801713 用时:27.301100
# 输出图片已保存至:./result_image4/female_256×256/female60000.png
# epoch:60000/200000: g_total_loss:0.750849 d_total_loss:1.142752 用时:27.499283
# 输出图片已保存至:./result_image4/female_256×256/female61000.png
# epoch:61000/200000: g_total_loss:0.425328 d_total_loss:1.435372 用时:27.224594
# 输出图片已保存至:./result_image4/female_256×256/female62000.png
# epoch:62000/200000: g_total_loss:2.087587 d_total_loss:0.802209 用时:27.851431
# 输出图片已保存至:./result_image4/female_256×256/female63000.png
# epoch:63000/200000: g_total_loss:0.672486 d_total_loss:1.445348 用时:27.304238
# 输出图片已保存至:./result_image4/female_256×256/female64000.png
# epoch:64000/200000: g_total_loss:1.138732 d_total_loss:0.935540 用时:27.380942
# 输出图片已保存至:./result_image4/female_256×256/female65000.png
# epoch:65000/200000: g_total_loss:0.367628 d_total_loss:1.523080 用时:27.222101
# 输出图片已保存至:./result_image4/female_256×256/female66000.png
# epoch:66000/200000: g_total_loss:0.951966 d_total_loss:0.900132 用时:26.715566
# 输出图片已保存至:./result_image4/female_256×256/female67000.png
# epoch:67000/200000: g_total_loss:2.156018 d_total_loss:0.619531 用时:27.294445
# 输出图片已保存至:./result_image4/female_256×256/female68000.png
# epoch:68000/200000: g_total_loss:2.056138 d_total_loss:1.372728 用时:27.327462
# 输出图片已保存至:./result_image4/female_256×256/female69000.png
# epoch:69000/200000: g_total_loss:1.453572 d_total_loss:1.313628 用时:26.717119
# 输出图片已保存至:./result_image4/female_256×256/female70000.png
# epoch:70000/200000: g_total_loss:0.649153 d_total_loss:0.989881 用时:27.409237
# 输出图片已保存至:./result_image4/female_256×256/female71000.png
# epoch:71000/200000: g_total_loss:0.588469 d_total_loss:1.722449 用时:27.571722
# 输出图片已保存至:./result_image4/female_256×256/female72000.png
# epoch:72000/200000: g_total_loss:1.644630 d_total_loss:1.086460 用时:27.424701
# 输出图片已保存至:./result_image4/female_256×256/female73000.png
# epoch:73000/200000: g_total_loss:1.905523 d_total_loss:0.794389 用时:27.293570
# 输出图片已保存至:./result_image4/female_256×256/female74000.png
# epoch:74000/200000: g_total_loss:1.265969 d_total_loss:0.954950 用时:27.552572
# 输出图片已保存至:./result_image4/female_256×256/female75000.png
# epoch:75000/200000: g_total_loss:1.315646 d_total_loss:1.346833 用时:27.339833
# 输出图片已保存至:./result_image4/female_256×256/female76000.png
# epoch:76000/200000: g_total_loss:1.306020 d_total_loss:1.546032 用时:25.261611
# 输出图片已保存至:./result_image4/female_256×256/female77000.png
# epoch:77000/200000: g_total_loss:1.188295 d_total_loss:0.804131 用时:27.005452
# 输出图片已保存至:./result_image4/female_256×256/female78000.png
# epoch:78000/200000: g_total_loss:1.312098 d_total_loss:1.799920 用时:27.449940
# 输出图片已保存至:./result_image4/female_256×256/female79000.png
# epoch:79000/200000: g_total_loss:1.340786 d_total_loss:1.150438 用时:27.455994
# 输出图片已保存至:./result_image4/female_256×256/female80000.png
# epoch:80000/200000: g_total_loss:0.928185 d_total_loss:0.981039 用时:27.982594
# 输出图片已保存至:./result_image4/female_256×256/female81000.png
# epoch:81000/200000: g_total_loss:0.663920 d_total_loss:1.355109 用时:27.341964
# 输出图片已保存至:./result_image4/female_256×256/female82000.png
# epoch:82000/200000: g_total_loss:1.650884 d_total_loss:0.936521 用时:27.505510
# 输出图片已保存至:./result_image4/female_256×256/female83000.png
# epoch:83000/200000: g_total_loss:0.895095 d_total_loss:1.083612 用时:27.314290
# 输出图片已保存至:./result_image4/female_256×256/female84000.png
# epoch:84000/200000: g_total_loss:0.841232 d_total_loss:0.712073 用时:27.393492
# 输出图片已保存至:./result_image4/female_256×256/female85000.png
# epoch:85000/200000: g_total_loss:0.698268 d_total_loss:1.113089 用时:27.363687
# 输出图片已保存至:./result_image4/female_256×256/female86000.png
# epoch:86000/200000: g_total_loss:1.127336 d_total_loss:1.138756 用时:27.613470
# 输出图片已保存至:./result_image4/female_256×256/female87000.png
# epoch:87000/200000: g_total_loss:1.213371 d_total_loss:0.924672 用时:27.115230
# 输出图片已保存至:./result_image4/female_256×256/female88000.png
# epoch:88000/200000: g_total_loss:0.494641 d_total_loss:1.298526 用时:27.080000
# 输出图片已保存至:./result_image4/female_256×256/female89000.png
# epoch:89000/200000: g_total_loss:0.876985 d_total_loss:1.093901 用时:27.251287
# 输出图片已保存至:./result_image4/female_256×256/female90000.png
# epoch:90000/200000: g_total_loss:1.638365 d_total_loss:1.651569 用时:27.225031
# 输出图片已保存至:./result_image4/female_256×256/female91000.png
# epoch:91000/200000: g_total_loss:0.311750 d_total_loss:1.724252 用时:27.026454
# 输出图片已保存至:./result_image4/female_256×256/female92000.png
# epoch:92000/200000: g_total_loss:1.608833 d_total_loss:1.242250 用时:27.374416
# 输出图片已保存至:./result_image4/female_256×256/female93000.png
# epoch:93000/200000: g_total_loss:0.702384 d_total_loss:1.303978 用时:28.024894
# 输出图片已保存至:./result_image4/female_256×256/female94000.png
# epoch:94000/200000: g_total_loss:1.726449 d_total_loss:0.521454 用时:27.495590
# 输出图片已保存至:./result_image4/female_256×256/female95000.png
# epoch:95000/200000: g_total_loss:0.590972 d_total_loss:1.347434 用时:27.449780
# 输出图片已保存至:./result_image4/female_256×256/female96000.png
# epoch:96000/200000: g_total_loss:0.631482 d_total_loss:1.313496 用时:27.326842
# 输出图片已保存至:./result_image4/female_256×256/female97000.png
# epoch:97000/200000: g_total_loss:0.810331 d_total_loss:0.984345 用时:27.442424
# 输出图片已保存至:./result_image4/female_256×256/female98000.png
# epoch:98000/200000: g_total_loss:0.979542 d_total_loss:0.934385 用时:27.510441
# 输出图片已保存至:./result_image4/female_256×256/female99000.png
# epoch:99000/200000: g_total_loss:1.110034 d_total_loss:1.435069 用时:27.420577
# 输出图片已保存至:./result_image4/female_256×256/female100000.png
# epoch:100000/200000: g_total_loss:1.053172 d_total_loss:1.122030 用时:27.295286
# 输出图片已保存至:./result_image4/female_256×256/female101000.png
# epoch:101000/200000: g_total_loss:1.153858 d_total_loss:0.544897 用时:27.722655
# 输出图片已保存至:./result_image4/female_256×256/female102000.png
# epoch:102000/200000: g_total_loss:0.931217 d_total_loss:1.187578 用时:26.834115
# 输出图片已保存至:./result_image4/female_256×256/female103000.png
# epoch:103000/200000: g_total_loss:0.709790 d_total_loss:0.994726 用时:28.437073
# 输出图片已保存至:./result_image4/female_256×256/female104000.png
# epoch:104000/200000: g_total_loss:1.185161 d_total_loss:0.963811 用时:27.077331
# 输出图片已保存至:./result_image4/female_256×256/female105000.png
# epoch:105000/200000: g_total_loss:1.210361 d_total_loss:0.949654 用时:27.352424
# 输出图片已保存至:./result_image4/female_256×256/female106000.png
# epoch:106000/200000: g_total_loss:1.068138 d_total_loss:0.957206 用时:27.634792
# 输出图片已保存至:./result_image4/female_256×256/female107000.png
# epoch:107000/200000: g_total_loss:1.192131 d_total_loss:0.814709 用时:27.447913
# 输出图片已保存至:./result_image4/female_256×256/female108000.png
# epoch:108000/200000: g_total_loss:1.101185 d_total_loss:1.309109 用时:25.968845
# 输出图片已保存至:./result_image4/female_256×256/female109000.png
# epoch:109000/200000: g_total_loss:1.348157 d_total_loss:0.753504 用时:27.440880
# 输出图片已保存至:./result_image4/female_256×256/female110000.png
# epoch:110000/200000: g_total_loss:0.796402 d_total_loss:1.102421 用时:27.321812
# 输出图片已保存至:./result_image4/female_256×256/female111000.png
# epoch:111000/200000: g_total_loss:0.492580 d_total_loss:1.379258 用时:27.398729
# 输出图片已保存至:./result_image4/female_256×256/female112000.png
# epoch:112000/200000: g_total_loss:2.059810 d_total_loss:0.419932 用时:27.366858
# 输出图片已保存至:./result_image4/female_256×256/female113000.png
# epoch:113000/200000: g_total_loss:1.159075 d_total_loss:0.789870 用时:27.503697
# 输出图片已保存至:./result_image4/female_256×256/female114000.png
# epoch:114000/200000: g_total_loss:0.827790 d_total_loss:1.207748 用时:27.156310
# 输出图片已保存至:./result_image4/female_256×256/female115000.png
# epoch:115000/200000: g_total_loss:1.690612 d_total_loss:0.879089 用时:27.400331
# 输出图片已保存至:./result_image4/female_256×256/female116000.png
# epoch:116000/200000: g_total_loss:1.650577 d_total_loss:0.765317 用时:27.024852
# 输出图片已保存至:./result_image4/female_256×256/female117000.png
# epoch:117000/200000: g_total_loss:1.644945 d_total_loss:1.143517 用时:27.313291
# 输出图片已保存至:./result_image4/female_256×256/female118000.png
# epoch:118000/200000: g_total_loss:1.863333 d_total_loss:1.399943 用时:27.530594
# 输出图片已保存至:./result_image4/female_256×256/female119000.png
# epoch:119000/200000: g_total_loss:1.925997 d_total_loss:0.578739 用时:26.712260
# 输出图片已保存至:./result_image4/female_256×256/female120000.png
# epoch:120000/200000: g_total_loss:0.987078 d_total_loss:0.969411 用时:27.140809
# 输出图片已保存至:./result_image4/female_256×256/female121000.png
# epoch:121000/200000: g_total_loss:0.961466 d_total_loss:0.835382 用时:27.414523
# 输出图片已保存至:./result_image4/female_256×256/female122000.png
# epoch:122000/200000: g_total_loss:1.416328 d_total_loss:1.782552 用时:27.366319
# 输出图片已保存至:./result_image4/female_256×256/female123000.png
# epoch:123000/200000: g_total_loss:0.854855 d_total_loss:1.215581 用时:27.384372
# 输出图片已保存至:./result_image4/female_256×256/female124000.png
# epoch:124000/200000: g_total_loss:0.912035 d_total_loss:0.857792 用时:27.352176
# 输出图片已保存至:./result_image4/female_256×256/female125000.png
# epoch:125000/200000: g_total_loss:1.854540 d_total_loss:1.034284 用时:27.299092
# 输出图片已保存至:./result_image4/female_256×256/female126000.png
# epoch:126000/200000: g_total_loss:1.770743 d_total_loss:0.915565 用时:27.246662
# 输出图片已保存至:./result_image4/female_256×256/female127000.png
# epoch:127000/200000: g_total_loss:0.684959 d_total_loss:1.310237 用时:27.344753
# 输出图片已保存至:./result_image4/female_256×256/female128000.png
# epoch:128000/200000: g_total_loss:1.198075 d_total_loss:1.120151 用时:28.159416
# 输出图片已保存至:./result_image4/female_256×256/female129000.png
# epoch:129000/200000: g_total_loss:2.621609 d_total_loss:1.203441 用时:27.314397
# 输出图片已保存至:./result_image4/female_256×256/female130000.png
# epoch:130000/200000: g_total_loss:1.019095 d_total_loss:1.011454 用时:27.435199
# 输出图片已保存至:./result_image4/female_256×256/female131000.png
# epoch:131000/200000: g_total_loss:1.472403 d_total_loss:1.268101 用时:27.391467
# 输出图片已保存至:./result_image4/female_256×256/female132000.png
# epoch:132000/200000: g_total_loss:2.053858 d_total_loss:0.785096 用时:28.326710
# 输出图片已保存至:./result_image4/female_256×256/female133000.png
# epoch:133000/200000: g_total_loss:1.496480 d_total_loss:0.895042 用时:27.301776
# 输出图片已保存至:./result_image4/female_256×256/female134000.png
# epoch:134000/200000: g_total_loss:0.780023 d_total_loss:1.220461 用时:27.754776
# 输出图片已保存至:./result_image4/female_256×256/female135000.png
# epoch:135000/200000: g_total_loss:1.255506 d_total_loss:1.322457 用时:27.553230
# 输出图片已保存至:./result_image4/female_256×256/female136000.png
# epoch:136000/200000: g_total_loss:1.484093 d_total_loss:1.652703 用时:27.529216
# 输出图片已保存至:./result_image4/female_256×256/female137000.png
# epoch:137000/200000: g_total_loss:0.573886 d_total_loss:1.130520 用时:27.288520
# 输出图片已保存至:./result_image4/female_256×256/female138000.png
# epoch:138000/200000: g_total_loss:1.628767 d_total_loss:0.664628 用时:27.370675
# 输出图片已保存至:./result_image4/female_256×256/female139000.png
# epoch:139000/200000: g_total_loss:1.401351 d_total_loss:1.107672 用时:27.420987
# 输出图片已保存至:./result_image4/female_256×256/female140000.png
# epoch:140000/200000: g_total_loss:0.666017 d_total_loss:0.875054 用时:27.220262
# 输出图片已保存至:./result_image4/female_256×256/female141000.png
# epoch:141000/200000: g_total_loss:0.856093 d_total_loss:1.382171 用时:27.371275
# 输出图片已保存至:./result_image4/female_256×256/female142000.png
# epoch:142000/200000: g_total_loss:1.478373 d_total_loss:0.991722 用时:27.430463
# 输出图片已保存至:./result_image4/female_256×256/female143000.png
# epoch:143000/200000: g_total_loss:0.810795 d_total_loss:1.179871 用时:27.599383
# 输出图片已保存至:./result_image4/female_256×256/female144000.png
# epoch:144000/200000: g_total_loss:0.270663 d_total_loss:1.974589 用时:24.372502
# 输出图片已保存至:./result_image4/female_256×256/female145000.png
# epoch:145000/200000: g_total_loss:0.719881 d_total_loss:1.393394 用时:27.418924
# 输出图片已保存至:./result_image4/female_256×256/female146000.png
# epoch:146000/200000: g_total_loss:1.379120 d_total_loss:0.845549 用时:27.510245
# 输出图片已保存至:./result_image4/female_256×256/female147000.png
# epoch:147000/200000: g_total_loss:1.579642 d_total_loss:0.932783 用时:27.225413
# 输出图片已保存至:./result_image4/female_256×256/female148000.png
# epoch:148000/200000: g_total_loss:1.565499 d_total_loss:0.971535 用时:27.201596
# 输出图片已保存至:./result_image4/female_256×256/female149000.png
# epoch:149000/200000: g_total_loss:0.663655 d_total_loss:1.167731 用时:27.528374
# 输出图片已保存至:./result_image4/female_256×256/female150000.png
# epoch:150000/200000: g_total_loss:0.762853 d_total_loss:1.242779 用时:27.364376
# 输出图片已保存至:./result_image4/female_256×256/female151000.png
# epoch:151000/200000: g_total_loss:0.712911 d_total_loss:1.058227 用时:27.767390
# 输出图片已保存至:./result_image4/female_256×256/female152000.png
# epoch:152000/200000: g_total_loss:0.978778 d_total_loss:0.886082 用时:27.335814
# 输出图片已保存至:./result_image4/female_256×256/female153000.png
# epoch:153000/200000: g_total_loss:1.560922 d_total_loss:1.454013 用时:27.301963
# 输出图片已保存至:./result_image4/female_256×256/female154000.png
# epoch:154000/200000: g_total_loss:0.879567 d_total_loss:1.065140 用时:27.467330
# 输出图片已保存至:./result_image4/female_256×256/female155000.png
# epoch:155000/200000: g_total_loss:1.035025 d_total_loss:0.975448 用时:27.697569
# 输出图片已保存至:./result_image4/female_256×256/female156000.png
# epoch:156000/200000: g_total_loss:1.899769 d_total_loss:1.166550 用时:26.108295
# 输出图片已保存至:./result_image4/female_256×256/female157000.png
# epoch:157000/200000: g_total_loss:2.577687 d_total_loss:2.019208 用时:27.369073
# 输出图片已保存至:./result_image4/female_256×256/female158000.png
# epoch:158000/200000: g_total_loss:1.259519 d_total_loss:1.262480 用时:27.296522
# 输出图片已保存至:./result_image4/female_256×256/female159000.png
# epoch:159000/200000: g_total_loss:0.847755 d_total_loss:0.769859 用时:27.396203
# 输出图片已保存至:./result_image4/female_256×256/female160000.png
# epoch:160000/200000: g_total_loss:0.515176 d_total_loss:1.231376 用时:27.671147
# 输出图片已保存至:./result_image4/female_256×256/female161000.png
# epoch:161000/200000: g_total_loss:1.239618 d_total_loss:0.495167 用时:27.404007
# 输出图片已保存至:./result_image4/female_256×256/female162000.png
# epoch:162000/200000: g_total_loss:1.323435 d_total_loss:1.011929 用时:27.117346
# 输出图片已保存至:./result_image4/female_256×256/female163000.png
# epoch:163000/200000: g_total_loss:1.517534 d_total_loss:1.046455 用时:27.242939
# 输出图片已保存至:./result_image4/female_256×256/female164000.png
# epoch:164000/200000: g_total_loss:0.718536 d_total_loss:0.993575 用时:27.472880
# 输出图片已保存至:./result_image4/female_256×256/female165000.png
# epoch:165000/200000: g_total_loss:0.998620 d_total_loss:0.939507 用时:27.499219
# 输出图片已保存至:./result_image4/female_256×256/female166000.png
# epoch:166000/200000: g_total_loss:1.673540 d_total_loss:0.806442 用时:27.887331
# 输出图片已保存至:./result_image4/female_256×256/female167000.png
# epoch:167000/200000: g_total_loss:0.407839 d_total_loss:1.386671 用时:27.322604
# 输出图片已保存至:./result_image4/female_256×256/female168000.png
# epoch:168000/200000: g_total_loss:0.985960 d_total_loss:1.306035 用时:28.683172
# 输出图片已保存至:./result_image4/female_256×256/female169000.png
# epoch:169000/200000: g_total_loss:1.218578 d_total_loss:0.829440 用时:27.327696
# 输出图片已保存至:./result_image4/female_256×256/female170000.png
# epoch:170000/200000: g_total_loss:1.466490 d_total_loss:0.959898 用时:27.225463
# 输出图片已保存至:./result_image4/female_256×256/female171000.png
# epoch:171000/200000: g_total_loss:0.903521 d_total_loss:1.223627 用时:27.518120
# 输出图片已保存至:./result_image4/female_256×256/female172000.png
# epoch:172000/200000: g_total_loss:0.461627 d_total_loss:1.223783 用时:27.351077
# 输出图片已保存至:./result_image4/female_256×256/female173000.png
# epoch:173000/200000: g_total_loss:1.061095 d_total_loss:1.472138 用时:27.331960
# 输出图片已保存至:./result_image4/female_256×256/female174000.png
# epoch:174000/200000: g_total_loss:1.557363 d_total_loss:1.059699 用时:27.458383
# 输出图片已保存至:./result_image4/female_256×256/female175000.png
# epoch:175000/200000: g_total_loss:0.621219 d_total_loss:1.480261 用时:26.657168
# 输出图片已保存至:./result_image4/female_256×256/female176000.png
# epoch:176000/200000: g_total_loss:0.675911 d_total_loss:1.547254 用时:25.817536
# 输出图片已保存至:./result_image4/female_256×256/female177000.png
# epoch:177000/200000: g_total_loss:1.081946 d_total_loss:0.982471 用时:27.367483
# 输出图片已保存至:./result_image4/female_256×256/female178000.png
# epoch:178000/200000: g_total_loss:1.695205 d_total_loss:0.679808 用时:27.397445
# 输出图片已保存至:./result_image4/female_256×256/female179000.png
# epoch:179000/200000: g_total_loss:0.518645 d_total_loss:1.535677 用时:27.322843
# 输出图片已保存至:./result_image4/female_256×256/female180000.png
# epoch:180000/200000: g_total_loss:0.606526 d_total_loss:1.217085 用时:27.321212
# 输出图片已保存至:./result_image4/female_256×256/female181000.png
# epoch:181000/200000: g_total_loss:1.013708 d_total_loss:0.750839 用时:27.525625
# 输出图片已保存至:./result_image4/female_256×256/female182000.png
# epoch:182000/200000: g_total_loss:0.631441 d_total_loss:1.445249 用时:27.412867
# 输出图片已保存至:./result_image4/female_256×256/female183000.png
# epoch:183000/200000: g_total_loss:1.223068 d_total_loss:0.953040 用时:27.396250
# 输出图片已保存至:./result_image4/female_256×256/female184000.png
# epoch:184000/200000: g_total_loss:0.220052 d_total_loss:2.182386 用时:27.488865
# 输出图片已保存至:./result_image4/female_256×256/female185000.png
# epoch:185000/200000: g_total_loss:2.008716 d_total_loss:1.060424 用时:27.410540
# 输出图片已保存至:./result_image4/female_256×256/female186000.png
# epoch:186000/200000: g_total_loss:0.306802 d_total_loss:1.893546 用时:27.697997
# 输出图片已保存至:./result_image4/female_256×256/female187000.png
# epoch:187000/200000: g_total_loss:1.204544 d_total_loss:1.076918 用时:27.524061
# 输出图片已保存至:./result_image4/female_256×256/female188000.png
# epoch:188000/200000: g_total_loss:0.960556 d_total_loss:1.002120 用时:27.549292
# 输出图片已保存至:./result_image4/female_256×256/female189000.png
# epoch:189000/200000: g_total_loss:0.823783 d_total_loss:0.879770 用时:27.260278
# 输出图片已保存至:./result_image4/female_256×256/female190000.png
# epoch:190000/200000: g_total_loss:0.821799 d_total_loss:0.901050 用时:27.088651
# 输出图片已保存至:./result_image4/female_256×256/female191000.png
# epoch:191000/200000: g_total_loss:1.321287 d_total_loss:1.019598 用时:26.757959
# 输出图片已保存至:./result_image4/female_256×256/female192000.png
# epoch:192000/200000: g_total_loss:1.572019 d_total_loss:0.980983 用时:27.344049
# 输出图片已保存至:./result_image4/female_256×256/female193000.png
# epoch:193000/200000: g_total_loss:1.095418 d_total_loss:0.829917 用时:27.352424
# 输出图片已保存至:./result_image4/female_256×256/female194000.png
# epoch:194000/200000: g_total_loss:1.569674 d_total_loss:0.872468 用时:27.640369
# 输出图片已保存至:./result_image4/female_256×256/female195000.png
# epoch:195000/200000: g_total_loss:1.013361 d_total_loss:0.840236 用时:27.572920
# 输出图片已保存至:./result_image4/female_256×256/female196000.png
# epoch:196000/200000: g_total_loss:1.113637 d_total_loss:0.949566 用时:27.641955
# 输出图片已保存至:./result_image4/female_256×256/female197000.png
# epoch:197000/200000: g_total_loss:1.255491 d_total_loss:1.036256 用时:27.358130
# 输出图片已保存至:./result_image4/female_256×256/female198000.png
# epoch:198000/200000: g_total_loss:1.446025 d_total_loss:0.803569 用时:27.442816
# 输出图片已保存至:./result_image4/female_256×256/female199000.png
# epoch:199000/200000: g_total_loss:1.046886 d_total_loss:0.969489 用时:27.321037
# 输出图片已保存至:./result_image4/female_256×256/female200000.png
# epoch:200000/200000: g_total_loss:0.977479 d_total_loss:1.034904 用时:27.314102
# 已跑完200000次
# './checkpoint4/female_256×256/female-200000'

# %%
plt.figure(figsize = (12,8))
epochtime = np.arange(0,201000,1000)
plt.plot(epochtime,g_total_loss_list,color='red',marker='o',linestyle='-',linewidth=1)
plt.xlabel('training epoch')
plt.xticks(rotation=45) # 旋转90度
plt.ylabel('total loss of generator')
plt.title('total loss of generator changed by epoch times')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize = (12,8))
epochtime = np.arange(1000,201000,1000)
plt.plot(epochtime,d_total_loss_list[1:],color='blue',marker='o',linestyle='-',linewidth=1)
plt.xlabel('training epoch')
plt.xticks(rotation=45) # 旋转90度
plt.ylabel('total loss of discriminator')
plt.title('total loss of discriminator changed by epoch times')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
print("mean of total loss of generator: {:.6f}".format(np.mean(g_total_loss_list)))
print("mean of total loss of discriminator: {:.6f}".format(np.mean(d_total_loss_list)))
# Out:
# mean of total loss of generator: 1.266327
# mean of total loss of discriminator: 1.119143

# %%
# 定义参数
batch_size = 1  # 每次测试的批次（太大可能会显存不够而报错，可调小再试）
fake_num = 500  # 生成的图片的个数
dataset_name = 'female'  # 数据集的名字  star_imgs
h, w, c = 256, 256, 3  # 数据集图片的宽和高，也是生成图片的宽和高
noise_dim = 100  # 输入噪声的维度（一般不改）

# %%
# 创建文件夹
directory = './checkpoint4/' + dataset_name + '_%s×%s' % (h, w)  # 输出参数保存的文件夹，一般不改
image_dir = './result_image4/' + dataset_name + '_%s×%s' % (h, w)  # 输出图片保存的文件夹，一般不改

# %%
# 搭建网络
generator = generator_network_dcgan(h, w, c, noise_dim=noise_dim)
discriminator = discriminator_network_dcgan(h, w, c)
# 加载参数
checkpoint = tf.train.Checkpoint(generator=generator,
                                 discriminator=discriminator)
checkpoint.restore(tf.train.latest_checkpoint(directory))  # 断点续训
# 预测
# noise_test = tf.random.normal([fake_num, 100])
noise_test = tf.random.uniform([fake_num, noise_dim], -1, 1)
fake_images = generator.predict(noise_test, batch_size=batch_size)  # (b,h,w,c)
fake_images = (fake_images.reshape(-1, h, w, c) * 127.5 + 127.5).astype('uint8')  # (b,h,w,c)

# %%
# 保存生成的图片
os.makedirs('test_from_dir4', exist_ok=True)
for i, fake_image in enumerate(fake_images):
    # i+=5000
    save_path = os.path.join('test_from_dir4', '%s.png' % (i + 1))
    cv.imwrite(save_path, fake_image)
    print('输出的单张图片已保存到：%s' % save_path)
# Out:
# 输出的单张图片已保存到：test_from_dir4/1.png
# 输出的单张图片已保存到：test_from_dir4/2.png
# 输出的单张图片已保存到：test_from_dir4/3.png
# 输出的单张图片已保存到：test_from_dir4/4.png
# 输出的单张图片已保存到：test_from_dir4/5.png
# 输出的单张图片已保存到：test_from_dir4/6.png
# 输出的单张图片已保存到：test_from_dir4/7.png
# 输出的单张图片已保存到：test_from_dir4/8.png
# 输出的单张图片已保存到：test_from_dir4/9.png
# 输出的单张图片已保存到：test_from_dir4/10.png
# 输出的单张图片已保存到：test_from_dir4/11.png
# 输出的单张图片已保存到：test_from_dir4/12.png
# 输出的单张图片已保存到：test_from_dir4/13.png
# 输出的单张图片已保存到：test_from_dir4/14.png
# 输出的单张图片已保存到：test_from_dir4/15.png
# 输出的单张图片已保存到：test_from_dir4/16.png
# 输出的单张图片已保存到：test_from_dir4/17.png
# 输出的单张图片已保存到：test_from_dir4/18.png
# 输出的单张图片已保存到：test_from_dir4/19.png
# 输出的单张图片已保存到：test_from_dir4/20.png
# 输出的单张图片已保存到：test_from_dir4/21.png
# 输出的单张图片已保存到：test_from_dir4/22.png
# 输出的单张图片已保存到：test_from_dir4/23.png
# 输出的单张图片已保存到：test_from_dir4/24.png
# 输出的单张图片已保存到：test_from_dir4/25.png
# 输出的单张图片已保存到：test_from_dir4/26.png
# 输出的单张图片已保存到：test_from_dir4/27.png
# 输出的单张图片已保存到：test_from_dir4/28.png
# 输出的单张图片已保存到：test_from_dir4/29.png
# 输出的单张图片已保存到：test_from_dir4/30.png
# 输出的单张图片已保存到：test_from_dir4/31.png
# 输出的单张图片已保存到：test_from_dir4/32.png
# 输出的单张图片已保存到：test_from_dir4/33.png
# 输出的单张图片已保存到：test_from_dir4/34.png
# 输出的单张图片已保存到：test_from_dir4/35.png
# 输出的单张图片已保存到：test_from_dir4/36.png
# 输出的单张图片已保存到：test_from_dir4/37.png
# 输出的单张图片已保存到：test_from_dir4/38.png
# 输出的单张图片已保存到：test_from_dir4/39.png
# 输出的单张图片已保存到：test_from_dir4/40.png
# 输出的单张图片已保存到：test_from_dir4/41.png
# 输出的单张图片已保存到：test_from_dir4/42.png
# 输出的单张图片已保存到：test_from_dir4/43.png
# 输出的单张图片已保存到：test_from_dir4/44.png
# 输出的单张图片已保存到：test_from_dir4/45.png
# 输出的单张图片已保存到：test_from_dir4/46.png
# 输出的单张图片已保存到：test_from_dir4/47.png
# 输出的单张图片已保存到：test_from_dir4/48.png
# 输出的单张图片已保存到：test_from_dir4/49.png
# 输出的单张图片已保存到：test_from_dir4/50.png
# 输出的单张图片已保存到：test_from_dir4/51.png
# 输出的单张图片已保存到：test_from_dir4/52.png
# 输出的单张图片已保存到：test_from_dir4/53.png
# 输出的单张图片已保存到：test_from_dir4/54.png
# 输出的单张图片已保存到：test_from_dir4/55.png
# 输出的单张图片已保存到：test_from_dir4/56.png
# 输出的单张图片已保存到：test_from_dir4/57.png
# 输出的单张图片已保存到：test_from_dir4/58.png
# 输出的单张图片已保存到：test_from_dir4/59.png
# 输出的单张图片已保存到：test_from_dir4/60.png
# 输出的单张图片已保存到：test_from_dir4/61.png
# 输出的单张图片已保存到：test_from_dir4/62.png
# 输出的单张图片已保存到：test_from_dir4/63.png
# 输出的单张图片已保存到：test_from_dir4/64.png
# 输出的单张图片已保存到：test_from_dir4/65.png
# 输出的单张图片已保存到：test_from_dir4/66.png
# 输出的单张图片已保存到：test_from_dir4/67.png
# 输出的单张图片已保存到：test_from_dir4/68.png
# 输出的单张图片已保存到：test_from_dir4/69.png
# 输出的单张图片已保存到：test_from_dir4/70.png
# 输出的单张图片已保存到：test_from_dir4/71.png
# 输出的单张图片已保存到：test_from_dir4/72.png
# 输出的单张图片已保存到：test_from_dir4/73.png
# 输出的单张图片已保存到：test_from_dir4/74.png
# 输出的单张图片已保存到：test_from_dir4/75.png
# 输出的单张图片已保存到：test_from_dir4/76.png
# 输出的单张图片已保存到：test_from_dir4/77.png
# 输出的单张图片已保存到：test_from_dir4/78.png
# 输出的单张图片已保存到：test_from_dir4/79.png
# 输出的单张图片已保存到：test_from_dir4/80.png
# 输出的单张图片已保存到：test_from_dir4/81.png
# 输出的单张图片已保存到：test_from_dir4/82.png
# 输出的单张图片已保存到：test_from_dir4/83.png
# 输出的单张图片已保存到：test_from_dir4/84.png
# 输出的单张图片已保存到：test_from_dir4/85.png
# 输出的单张图片已保存到：test_from_dir4/86.png
# 输出的单张图片已保存到：test_from_dir4/87.png
# 输出的单张图片已保存到：test_from_dir4/88.png
# 输出的单张图片已保存到：test_from_dir4/89.png
# 输出的单张图片已保存到：test_from_dir4/90.png
# 输出的单张图片已保存到：test_from_dir4/91.png
# 输出的单张图片已保存到：test_from_dir4/92.png
# 输出的单张图片已保存到：test_from_dir4/93.png
# 输出的单张图片已保存到：test_from_dir4/94.png
# 输出的单张图片已保存到：test_from_dir4/95.png
# 输出的单张图片已保存到：test_from_dir4/96.png
# 输出的单张图片已保存到：test_from_dir4/97.png
# 输出的单张图片已保存到：test_from_dir4/98.png
# 输出的单张图片已保存到：test_from_dir4/99.png
# 输出的单张图片已保存到：test_from_dir4/100.png
# 输出的单张图片已保存到：test_from_dir4/101.png
# 输出的单张图片已保存到：test_from_dir4/102.png
# 输出的单张图片已保存到：test_from_dir4/103.png
# 输出的单张图片已保存到：test_from_dir4/104.png
# 输出的单张图片已保存到：test_from_dir4/105.png
# 输出的单张图片已保存到：test_from_dir4/106.png
# 输出的单张图片已保存到：test_from_dir4/107.png
# 输出的单张图片已保存到：test_from_dir4/108.png
# 输出的单张图片已保存到：test_from_dir4/109.png
# 输出的单张图片已保存到：test_from_dir4/110.png
# 输出的单张图片已保存到：test_from_dir4/111.png
# 输出的单张图片已保存到：test_from_dir4/112.png
# 输出的单张图片已保存到：test_from_dir4/113.png
# 输出的单张图片已保存到：test_from_dir4/114.png
# 输出的单张图片已保存到：test_from_dir4/115.png
# 输出的单张图片已保存到：test_from_dir4/116.png
# 输出的单张图片已保存到：test_from_dir4/117.png
# 输出的单张图片已保存到：test_from_dir4/118.png
# 输出的单张图片已保存到：test_from_dir4/119.png
# 输出的单张图片已保存到：test_from_dir4/120.png
# 输出的单张图片已保存到：test_from_dir4/121.png
# 输出的单张图片已保存到：test_from_dir4/122.png
# 输出的单张图片已保存到：test_from_dir4/123.png
# 输出的单张图片已保存到：test_from_dir4/124.png
# 输出的单张图片已保存到：test_from_dir4/125.png
# 输出的单张图片已保存到：test_from_dir4/126.png
# 输出的单张图片已保存到：test_from_dir4/127.png
# 输出的单张图片已保存到：test_from_dir4/128.png
# 输出的单张图片已保存到：test_from_dir4/129.png
# 输出的单张图片已保存到：test_from_dir4/130.png
# 输出的单张图片已保存到：test_from_dir4/131.png
# 输出的单张图片已保存到：test_from_dir4/132.png
# 输出的单张图片已保存到：test_from_dir4/133.png
# 输出的单张图片已保存到：test_from_dir4/134.png
# 输出的单张图片已保存到：test_from_dir4/135.png
# 输出的单张图片已保存到：test_from_dir4/136.png
# 输出的单张图片已保存到：test_from_dir4/137.png
# 输出的单张图片已保存到：test_from_dir4/138.png
# 输出的单张图片已保存到：test_from_dir4/139.png
# 输出的单张图片已保存到：test_from_dir4/140.png
# 输出的单张图片已保存到：test_from_dir4/141.png
# 输出的单张图片已保存到：test_from_dir4/142.png
# 输出的单张图片已保存到：test_from_dir4/143.png
# 输出的单张图片已保存到：test_from_dir4/144.png
# 输出的单张图片已保存到：test_from_dir4/145.png
# 输出的单张图片已保存到：test_from_dir4/146.png
# 输出的单张图片已保存到：test_from_dir4/147.png
# 输出的单张图片已保存到：test_from_dir4/148.png
# 输出的单张图片已保存到：test_from_dir4/149.png
# 输出的单张图片已保存到：test_from_dir4/150.png
# 输出的单张图片已保存到：test_from_dir4/151.png
# 输出的单张图片已保存到：test_from_dir4/152.png
# 输出的单张图片已保存到：test_from_dir4/153.png
# 输出的单张图片已保存到：test_from_dir4/154.png
# 输出的单张图片已保存到：test_from_dir4/155.png
# 输出的单张图片已保存到：test_from_dir4/156.png
# 输出的单张图片已保存到：test_from_dir4/157.png
# 输出的单张图片已保存到：test_from_dir4/158.png
# 输出的单张图片已保存到：test_from_dir4/159.png
# 输出的单张图片已保存到：test_from_dir4/160.png
# 输出的单张图片已保存到：test_from_dir4/161.png
# 输出的单张图片已保存到：test_from_dir4/162.png
# 输出的单张图片已保存到：test_from_dir4/163.png
# 输出的单张图片已保存到：test_from_dir4/164.png
# 输出的单张图片已保存到：test_from_dir4/165.png
# 输出的单张图片已保存到：test_from_dir4/166.png
# 输出的单张图片已保存到：test_from_dir4/167.png
# 输出的单张图片已保存到：test_from_dir4/168.png
# 输出的单张图片已保存到：test_from_dir4/169.png
# 输出的单张图片已保存到：test_from_dir4/170.png
# 输出的单张图片已保存到：test_from_dir4/171.png
# 输出的单张图片已保存到：test_from_dir4/172.png
# 输出的单张图片已保存到：test_from_dir4/173.png
# 输出的单张图片已保存到：test_from_dir4/174.png
# 输出的单张图片已保存到：test_from_dir4/175.png
# 输出的单张图片已保存到：test_from_dir4/176.png
# 输出的单张图片已保存到：test_from_dir4/177.png
# 输出的单张图片已保存到：test_from_dir4/178.png
# 输出的单张图片已保存到：test_from_dir4/179.png
# 输出的单张图片已保存到：test_from_dir4/180.png
# 输出的单张图片已保存到：test_from_dir4/181.png
# 输出的单张图片已保存到：test_from_dir4/182.png
# 输出的单张图片已保存到：test_from_dir4/183.png
# 输出的单张图片已保存到：test_from_dir4/184.png
# 输出的单张图片已保存到：test_from_dir4/185.png
# 输出的单张图片已保存到：test_from_dir4/186.png
# 输出的单张图片已保存到：test_from_dir4/187.png
# 输出的单张图片已保存到：test_from_dir4/188.png
# 输出的单张图片已保存到：test_from_dir4/189.png
# 输出的单张图片已保存到：test_from_dir4/190.png
# 输出的单张图片已保存到：test_from_dir4/191.png
# 输出的单张图片已保存到：test_from_dir4/192.png
# 输出的单张图片已保存到：test_from_dir4/193.png
# 输出的单张图片已保存到：test_from_dir4/194.png
# 输出的单张图片已保存到：test_from_dir4/195.png
# 输出的单张图片已保存到：test_from_dir4/196.png
# 输出的单张图片已保存到：test_from_dir4/197.png
# 输出的单张图片已保存到：test_from_dir4/198.png
# 输出的单张图片已保存到：test_from_dir4/199.png
# 输出的单张图片已保存到：test_from_dir4/200.png
# 输出的单张图片已保存到：test_from_dir4/201.png
# 输出的单张图片已保存到：test_from_dir4/202.png
# 输出的单张图片已保存到：test_from_dir4/203.png
# 输出的单张图片已保存到：test_from_dir4/204.png
# 输出的单张图片已保存到：test_from_dir4/205.png
# 输出的单张图片已保存到：test_from_dir4/206.png
# 输出的单张图片已保存到：test_from_dir4/207.png
# 输出的单张图片已保存到：test_from_dir4/208.png
# 输出的单张图片已保存到：test_from_dir4/209.png
# 输出的单张图片已保存到：test_from_dir4/210.png
# 输出的单张图片已保存到：test_from_dir4/211.png
# 输出的单张图片已保存到：test_from_dir4/212.png
# 输出的单张图片已保存到：test_from_dir4/213.png
# 输出的单张图片已保存到：test_from_dir4/214.png
# 输出的单张图片已保存到：test_from_dir4/215.png
# 输出的单张图片已保存到：test_from_dir4/216.png
# 输出的单张图片已保存到：test_from_dir4/217.png
# 输出的单张图片已保存到：test_from_dir4/218.png
# 输出的单张图片已保存到：test_from_dir4/219.png
# 输出的单张图片已保存到：test_from_dir4/220.png
# 输出的单张图片已保存到：test_from_dir4/221.png
# 输出的单张图片已保存到：test_from_dir4/222.png
# 输出的单张图片已保存到：test_from_dir4/223.png
# 输出的单张图片已保存到：test_from_dir4/224.png
# 输出的单张图片已保存到：test_from_dir4/225.png
# 输出的单张图片已保存到：test_from_dir4/226.png
# 输出的单张图片已保存到：test_from_dir4/227.png
# 输出的单张图片已保存到：test_from_dir4/228.png
# 输出的单张图片已保存到：test_from_dir4/229.png
# 输出的单张图片已保存到：test_from_dir4/230.png
# 输出的单张图片已保存到：test_from_dir4/231.png
# 输出的单张图片已保存到：test_from_dir4/232.png
# 输出的单张图片已保存到：test_from_dir4/233.png
# 输出的单张图片已保存到：test_from_dir4/234.png
# 输出的单张图片已保存到：test_from_dir4/235.png
# 输出的单张图片已保存到：test_from_dir4/236.png
# 输出的单张图片已保存到：test_from_dir4/237.png
# 输出的单张图片已保存到：test_from_dir4/238.png
# 输出的单张图片已保存到：test_from_dir4/239.png
# 输出的单张图片已保存到：test_from_dir4/240.png
# 输出的单张图片已保存到：test_from_dir4/241.png
# 输出的单张图片已保存到：test_from_dir4/242.png
# 输出的单张图片已保存到：test_from_dir4/243.png
# 输出的单张图片已保存到：test_from_dir4/244.png
# 输出的单张图片已保存到：test_from_dir4/245.png
# 输出的单张图片已保存到：test_from_dir4/246.png
# 输出的单张图片已保存到：test_from_dir4/247.png
# 输出的单张图片已保存到：test_from_dir4/248.png
# 输出的单张图片已保存到：test_from_dir4/249.png
# 输出的单张图片已保存到：test_from_dir4/250.png
# 输出的单张图片已保存到：test_from_dir4/251.png
# 输出的单张图片已保存到：test_from_dir4/252.png
# 输出的单张图片已保存到：test_from_dir4/253.png
# 输出的单张图片已保存到：test_from_dir4/254.png
# 输出的单张图片已保存到：test_from_dir4/255.png
# 输出的单张图片已保存到：test_from_dir4/256.png
# 输出的单张图片已保存到：test_from_dir4/257.png
# 输出的单张图片已保存到：test_from_dir4/258.png
# 输出的单张图片已保存到：test_from_dir4/259.png
# 输出的单张图片已保存到：test_from_dir4/260.png
# 输出的单张图片已保存到：test_from_dir4/261.png
# 输出的单张图片已保存到：test_from_dir4/262.png
# 输出的单张图片已保存到：test_from_dir4/263.png
# 输出的单张图片已保存到：test_from_dir4/264.png
# 输出的单张图片已保存到：test_from_dir4/265.png
# 输出的单张图片已保存到：test_from_dir4/266.png
# 输出的单张图片已保存到：test_from_dir4/267.png
# 输出的单张图片已保存到：test_from_dir4/268.png
# 输出的单张图片已保存到：test_from_dir4/269.png
# 输出的单张图片已保存到：test_from_dir4/270.png
# 输出的单张图片已保存到：test_from_dir4/271.png
# 输出的单张图片已保存到：test_from_dir4/272.png
# 输出的单张图片已保存到：test_from_dir4/273.png
# 输出的单张图片已保存到：test_from_dir4/274.png
# 输出的单张图片已保存到：test_from_dir4/275.png
# 输出的单张图片已保存到：test_from_dir4/276.png
# 输出的单张图片已保存到：test_from_dir4/277.png
# 输出的单张图片已保存到：test_from_dir4/278.png
# 输出的单张图片已保存到：test_from_dir4/279.png
# 输出的单张图片已保存到：test_from_dir4/280.png
# 输出的单张图片已保存到：test_from_dir4/281.png
# 输出的单张图片已保存到：test_from_dir4/282.png
# 输出的单张图片已保存到：test_from_dir4/283.png
# 输出的单张图片已保存到：test_from_dir4/284.png
# 输出的单张图片已保存到：test_from_dir4/285.png
# 输出的单张图片已保存到：test_from_dir4/286.png
# 输出的单张图片已保存到：test_from_dir4/287.png
# 输出的单张图片已保存到：test_from_dir4/288.png
# 输出的单张图片已保存到：test_from_dir4/289.png
# 输出的单张图片已保存到：test_from_dir4/290.png
# 输出的单张图片已保存到：test_from_dir4/291.png
# 输出的单张图片已保存到：test_from_dir4/292.png
# 输出的单张图片已保存到：test_from_dir4/293.png
# 输出的单张图片已保存到：test_from_dir4/294.png
# 输出的单张图片已保存到：test_from_dir4/295.png
# 输出的单张图片已保存到：test_from_dir4/296.png
# 输出的单张图片已保存到：test_from_dir4/297.png
# 输出的单张图片已保存到：test_from_dir4/298.png
# 输出的单张图片已保存到：test_from_dir4/299.png
# 输出的单张图片已保存到：test_from_dir4/300.png
# 输出的单张图片已保存到：test_from_dir4/301.png
# 输出的单张图片已保存到：test_from_dir4/302.png
# 输出的单张图片已保存到：test_from_dir4/303.png
# 输出的单张图片已保存到：test_from_dir4/304.png
# 输出的单张图片已保存到：test_from_dir4/305.png
# 输出的单张图片已保存到：test_from_dir4/306.png
# 输出的单张图片已保存到：test_from_dir4/307.png
# 输出的单张图片已保存到：test_from_dir4/308.png
# 输出的单张图片已保存到：test_from_dir4/309.png
# 输出的单张图片已保存到：test_from_dir4/310.png
# 输出的单张图片已保存到：test_from_dir4/311.png
# 输出的单张图片已保存到：test_from_dir4/312.png
# 输出的单张图片已保存到：test_from_dir4/313.png
# 输出的单张图片已保存到：test_from_dir4/314.png
# 输出的单张图片已保存到：test_from_dir4/315.png
# 输出的单张图片已保存到：test_from_dir4/316.png
# 输出的单张图片已保存到：test_from_dir4/317.png
# 输出的单张图片已保存到：test_from_dir4/318.png
# 输出的单张图片已保存到：test_from_dir4/319.png
# 输出的单张图片已保存到：test_from_dir4/320.png
# 输出的单张图片已保存到：test_from_dir4/321.png
# 输出的单张图片已保存到：test_from_dir4/322.png
# 输出的单张图片已保存到：test_from_dir4/323.png
# 输出的单张图片已保存到：test_from_dir4/324.png
# 输出的单张图片已保存到：test_from_dir4/325.png
# 输出的单张图片已保存到：test_from_dir4/326.png
# 输出的单张图片已保存到：test_from_dir4/327.png
# 输出的单张图片已保存到：test_from_dir4/328.png
# 输出的单张图片已保存到：test_from_dir4/329.png
# 输出的单张图片已保存到：test_from_dir4/330.png
# 输出的单张图片已保存到：test_from_dir4/331.png
# 输出的单张图片已保存到：test_from_dir4/332.png
# 输出的单张图片已保存到：test_from_dir4/333.png
# 输出的单张图片已保存到：test_from_dir4/334.png
# 输出的单张图片已保存到：test_from_dir4/335.png
# 输出的单张图片已保存到：test_from_dir4/336.png
# 输出的单张图片已保存到：test_from_dir4/337.png
# 输出的单张图片已保存到：test_from_dir4/338.png
# 输出的单张图片已保存到：test_from_dir4/339.png
# 输出的单张图片已保存到：test_from_dir4/340.png
# 输出的单张图片已保存到：test_from_dir4/341.png
# 输出的单张图片已保存到：test_from_dir4/342.png
# 输出的单张图片已保存到：test_from_dir4/343.png
# 输出的单张图片已保存到：test_from_dir4/344.png
# 输出的单张图片已保存到：test_from_dir4/345.png
# 输出的单张图片已保存到：test_from_dir4/346.png
# 输出的单张图片已保存到：test_from_dir4/347.png
# 输出的单张图片已保存到：test_from_dir4/348.png
# 输出的单张图片已保存到：test_from_dir4/349.png
# 输出的单张图片已保存到：test_from_dir4/350.png
# 输出的单张图片已保存到：test_from_dir4/351.png
# 输出的单张图片已保存到：test_from_dir4/352.png
# 输出的单张图片已保存到：test_from_dir4/353.png
# 输出的单张图片已保存到：test_from_dir4/354.png
# 输出的单张图片已保存到：test_from_dir4/355.png
# 输出的单张图片已保存到：test_from_dir4/356.png
# 输出的单张图片已保存到：test_from_dir4/357.png
# 输出的单张图片已保存到：test_from_dir4/358.png
# 输出的单张图片已保存到：test_from_dir4/359.png
# 输出的单张图片已保存到：test_from_dir4/360.png
# 输出的单张图片已保存到：test_from_dir4/361.png
# 输出的单张图片已保存到：test_from_dir4/362.png
# 输出的单张图片已保存到：test_from_dir4/363.png
# 输出的单张图片已保存到：test_from_dir4/364.png
# 输出的单张图片已保存到：test_from_dir4/365.png
# 输出的单张图片已保存到：test_from_dir4/366.png
# 输出的单张图片已保存到：test_from_dir4/367.png
# 输出的单张图片已保存到：test_from_dir4/368.png
# 输出的单张图片已保存到：test_from_dir4/369.png
# 输出的单张图片已保存到：test_from_dir4/370.png
# 输出的单张图片已保存到：test_from_dir4/371.png
# 输出的单张图片已保存到：test_from_dir4/372.png
# 输出的单张图片已保存到：test_from_dir4/373.png
# 输出的单张图片已保存到：test_from_dir4/374.png
# 输出的单张图片已保存到：test_from_dir4/375.png
# 输出的单张图片已保存到：test_from_dir4/376.png
# 输出的单张图片已保存到：test_from_dir4/377.png
# 输出的单张图片已保存到：test_from_dir4/378.png
# 输出的单张图片已保存到：test_from_dir4/379.png
# 输出的单张图片已保存到：test_from_dir4/380.png
# 输出的单张图片已保存到：test_from_dir4/381.png
# 输出的单张图片已保存到：test_from_dir4/382.png
# 输出的单张图片已保存到：test_from_dir4/383.png
# 输出的单张图片已保存到：test_from_dir4/384.png
# 输出的单张图片已保存到：test_from_dir4/385.png
# 输出的单张图片已保存到：test_from_dir4/386.png
# 输出的单张图片已保存到：test_from_dir4/387.png
# 输出的单张图片已保存到：test_from_dir4/388.png
# 输出的单张图片已保存到：test_from_dir4/389.png
# 输出的单张图片已保存到：test_from_dir4/390.png
# 输出的单张图片已保存到：test_from_dir4/391.png
# 输出的单张图片已保存到：test_from_dir4/392.png
# 输出的单张图片已保存到：test_from_dir4/393.png
# 输出的单张图片已保存到：test_from_dir4/394.png
# 输出的单张图片已保存到：test_from_dir4/395.png
# 输出的单张图片已保存到：test_from_dir4/396.png
# 输出的单张图片已保存到：test_from_dir4/397.png
# 输出的单张图片已保存到：test_from_dir4/398.png
# 输出的单张图片已保存到：test_from_dir4/399.png
# 输出的单张图片已保存到：test_from_dir4/400.png
# 输出的单张图片已保存到：test_from_dir4/401.png
# 输出的单张图片已保存到：test_from_dir4/402.png
# 输出的单张图片已保存到：test_from_dir4/403.png
# 输出的单张图片已保存到：test_from_dir4/404.png
# 输出的单张图片已保存到：test_from_dir4/405.png
# 输出的单张图片已保存到：test_from_dir4/406.png
# 输出的单张图片已保存到：test_from_dir4/407.png
# 输出的单张图片已保存到：test_from_dir4/408.png
# 输出的单张图片已保存到：test_from_dir4/409.png
# 输出的单张图片已保存到：test_from_dir4/410.png
# 输出的单张图片已保存到：test_from_dir4/411.png
# 输出的单张图片已保存到：test_from_dir4/412.png
# 输出的单张图片已保存到：test_from_dir4/413.png
# 输出的单张图片已保存到：test_from_dir4/414.png
# 输出的单张图片已保存到：test_from_dir4/415.png
# 输出的单张图片已保存到：test_from_dir4/416.png
# 输出的单张图片已保存到：test_from_dir4/417.png
# 输出的单张图片已保存到：test_from_dir4/418.png
# 输出的单张图片已保存到：test_from_dir4/419.png
# 输出的单张图片已保存到：test_from_dir4/420.png
# 输出的单张图片已保存到：test_from_dir4/421.png
# 输出的单张图片已保存到：test_from_dir4/422.png
# 输出的单张图片已保存到：test_from_dir4/423.png
# 输出的单张图片已保存到：test_from_dir4/424.png
# 输出的单张图片已保存到：test_from_dir4/425.png
# 输出的单张图片已保存到：test_from_dir4/426.png
# 输出的单张图片已保存到：test_from_dir4/427.png
# 输出的单张图片已保存到：test_from_dir4/428.png
# 输出的单张图片已保存到：test_from_dir4/429.png
# 输出的单张图片已保存到：test_from_dir4/430.png
# 输出的单张图片已保存到：test_from_dir4/431.png
# 输出的单张图片已保存到：test_from_dir4/432.png
# 输出的单张图片已保存到：test_from_dir4/433.png
# 输出的单张图片已保存到：test_from_dir4/434.png
# 输出的单张图片已保存到：test_from_dir4/435.png
# 输出的单张图片已保存到：test_from_dir4/436.png
# 输出的单张图片已保存到：test_from_dir4/437.png
# 输出的单张图片已保存到：test_from_dir4/438.png
# 输出的单张图片已保存到：test_from_dir4/439.png
# 输出的单张图片已保存到：test_from_dir4/440.png
# 输出的单张图片已保存到：test_from_dir4/441.png
# 输出的单张图片已保存到：test_from_dir4/442.png
# 输出的单张图片已保存到：test_from_dir4/443.png
# 输出的单张图片已保存到：test_from_dir4/444.png
# 输出的单张图片已保存到：test_from_dir4/445.png
# 输出的单张图片已保存到：test_from_dir4/446.png
# 输出的单张图片已保存到：test_from_dir4/447.png
# 输出的单张图片已保存到：test_from_dir4/448.png
# 输出的单张图片已保存到：test_from_dir4/449.png
# 输出的单张图片已保存到：test_from_dir4/450.png
# 输出的单张图片已保存到：test_from_dir4/451.png
# 输出的单张图片已保存到：test_from_dir4/452.png
# 输出的单张图片已保存到：test_from_dir4/453.png
# 输出的单张图片已保存到：test_from_dir4/454.png
# 输出的单张图片已保存到：test_from_dir4/455.png
# 输出的单张图片已保存到：test_from_dir4/456.png
# 输出的单张图片已保存到：test_from_dir4/457.png
# 输出的单张图片已保存到：test_from_dir4/458.png
# 输出的单张图片已保存到：test_from_dir4/459.png
# 输出的单张图片已保存到：test_from_dir4/460.png
# 输出的单张图片已保存到：test_from_dir4/461.png
# 输出的单张图片已保存到：test_from_dir4/462.png
# 输出的单张图片已保存到：test_from_dir4/463.png
# 输出的单张图片已保存到：test_from_dir4/464.png
# 输出的单张图片已保存到：test_from_dir4/465.png
# 输出的单张图片已保存到：test_from_dir4/466.png
# 输出的单张图片已保存到：test_from_dir4/467.png
# 输出的单张图片已保存到：test_from_dir4/468.png
# 输出的单张图片已保存到：test_from_dir4/469.png
# 输出的单张图片已保存到：test_from_dir4/470.png
# 输出的单张图片已保存到：test_from_dir4/471.png
# 输出的单张图片已保存到：test_from_dir4/472.png
# 输出的单张图片已保存到：test_from_dir4/473.png
# 输出的单张图片已保存到：test_from_dir4/474.png
# 输出的单张图片已保存到：test_from_dir4/475.png
# 输出的单张图片已保存到：test_from_dir4/476.png
# 输出的单张图片已保存到：test_from_dir4/477.png
# 输出的单张图片已保存到：test_from_dir4/478.png
# 输出的单张图片已保存到：test_from_dir4/479.png
# 输出的单张图片已保存到：test_from_dir4/480.png
# 输出的单张图片已保存到：test_from_dir4/481.png
# 输出的单张图片已保存到：test_from_dir4/482.png
# 输出的单张图片已保存到：test_from_dir4/483.png
# 输出的单张图片已保存到：test_from_dir4/484.png
# 输出的单张图片已保存到：test_from_dir4/485.png
# 输出的单张图片已保存到：test_from_dir4/486.png
# 输出的单张图片已保存到：test_from_dir4/487.png
# 输出的单张图片已保存到：test_from_dir4/488.png
# 输出的单张图片已保存到：test_from_dir4/489.png
# 输出的单张图片已保存到：test_from_dir4/490.png
# 输出的单张图片已保存到：test_from_dir4/491.png
# 输出的单张图片已保存到：test_from_dir4/492.png
# 输出的单张图片已保存到：test_from_dir4/493.png
# 输出的单张图片已保存到：test_from_dir4/494.png
# 输出的单张图片已保存到：test_from_dir4/495.png
# 输出的单张图片已保存到：test_from_dir4/496.png
# 输出的单张图片已保存到：test_from_dir4/497.png
# 输出的单张图片已保存到：test_from_dir4/498.png
# 输出的单张图片已保存到：test_from_dir4/499.png
# 输出的单张图片已保存到：test_from_dir4/500.png

# %%
# 查看部分生成图片
plt.figure(figsize=(12,12))
for i in range(16):
    plt.subplot(4, 4, i + 1)
    if c == 3:
        fake_images[i] = cv.cvtColor(fake_images[i], cv.COLOR_BGR2RGB)
    plt.imshow(fake_images[i])
    plt.axis('off')
plt.show()
