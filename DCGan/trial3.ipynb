# %%
import sys, os
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow.keras import datasets, optimizers, metrics, layers, Sequential, Model, Input, losses
from load_datasets import DataLoader
import time

# %%
os.environ['KMP_DUPLICATE_LIB_OK']='True'  #防止训练过程中的kernel发生crash的情形

# %%
# 卷积层的生成器和鉴别器
def generator_network_dcgan(h, w, c, noise_dim=100):  # 输入噪声和标签，输出假图
    h_, w_ = h // 4, w // 4
    input_noise = Input(shape=(noise_dim,))  # (b,100)
    x = layers.Dense(h_ * w_ * 128)(input_noise)  #全连接层用于调整噪声的维度
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)
    x = layers.Reshape((h_, w_, 128))(x)  # (b,h/4,w/4,256)

    x = layers.Conv2DTranspose(64, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/2,w/2,128)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)

    x = layers.Conv2DTranspose(32, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h,w,64)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)
    x = layers.Conv2DTranspose(c, (3, 3), padding='same', activation='tanh')(x)  # (b,h,w,c)
    generator = Model(input_noise, x)
    return generator

# %%
def discriminator_network_dcgan(h, w, c):  # 输入图片和标签，输出待验证的值。输出1为真，0为假
    input_image = Input(shape=(h, w, c))  # (b,h,w,c)
    x = layers.Conv2D(32, (3, 3), strides=(2, 2), padding='same')(input_image)  # (b,h/2,w/2,64)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)  
    x = layers.Dropout(0.3)(x)  #改进：在鉴别器的层之间添加dropout

    x = layers.Conv2D(64, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/4,w/4,128)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)
    x = layers.Dropout(0.3)(x)

    x = layers.Conv2D(128, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/4,w/4,256)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)
    x = layers.Dropout(0.3)(x)
    
    x = layers.Conv2D(256, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/4,w/4,512)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)
    x = layers.Dropout(0.3)(x)

    x = layers.Flatten()(x)  # (b,h/4*w/4*512)
    validity = layers.Dense(1, activation=None)(x)  # (b,1) 最后一层，flatten后全连接层

    discriminator = Model(input_image, validity)
    return discriminator

# %%
# WGAN-GP梯度控制函数
def gradient_penalty(discriminator, batch_x, fake_image):
    #梯度惩罚项计算函数
    batchsz = batch_x.shape[0]

    #每个样本均随机采样t,用于插值
    t = tf.random.uniform([batchsz,1,1,1])
    #自动扩展为x的形状:[b,1,1,1] => [b,h,w,c]
    t = tf.broadcast_to(t, batch_x.shape)
    #在真假图片之间作线性插值
    interplate = t * batch_x + (1-t) * fake_image
    #在梯度环境中计算 D 对插值样本的梯度
    with tf.GradientTape() as tape:
        tape.watch([interplate])
        d_interplate_logits = discriminator(interplate)

        grads = tape.gradient(d_interplate_logits, interplate)

        #计算每个样本的梯度的范数:[b,h,w,c] => [b,-1]
        grads = tf.reshape(grads, [grads.shape[0],-1])
        gp = tf.norm(grads,axis=1)
        #计算梯度惩罚项
        gp = tf.reduce_mean((gp-1.)**2)

    return gp

# %%
def save_image(fake_image, fake_label=None, fake_num=16, save_to=''):  # X为4维的带批次的图片
    ''' 
    用于保存图片的函数
    '''
    plt.figure()
    _, h, w, c = fake_image.shape  #设定生成假图的shape（128*128*3）
    if fake_num > 1:
        for i in range(fake_num):
            plt.subplot(4, 4, i + 1)  #训练过程中的迭代以4*4=16（一次保存16张图片）
            if c == 3:  # 如果是bgr则转为rgb（通道的转换）
                plt.imshow(cv.cvtColor(fake_image[i], cv.COLOR_BGR2RGB))  #对于一般格式与BGR格式都予以显示
            if c == 1:  # 如果是灰图则显示灰图
                plt.imshow(np.squeeze(fake_image[i]), cmap='gray')
            if fake_label is not None:  # 如果有标签则传入标签（这是为了在真图与假图之间鉴别时用）
                plt.title(fake_label[i])
            plt.axis('off')
        plt.savefig(save_to)
        plt.close()
    else:  # fake_num=1时保存单张图片，否则按照多张图片的格式保存
        cv.imwrite(save_to, fake_image[0])
    print('输出图片已保存至:%s' % save_to)

# %%
def creat_dir(path):  #用于生成迭代过程中的图片以及保存后续生成的图像
    os.makedirs(path, exist_ok=True)

# %%
print('tf版本：', tf.__version__)
# 定义参数
batch_size = 5  # 每次训练的批次（太大可能会显存不够而报错，故在这里选择较小的值）
epochs = 200000  # 共迭代训练几次
g_lr = 0.0005  # 生成器学习率
d_lr = 0.0002  # 鉴别器学习率
fake_num = 16  # 生成的图片的个数（一般不改）
dataset_name = 'female'  # 数据集的名字  star_imgs  female  cat_vs_dog
h, w, c = 256, 256, 3  # 数据集图片的宽和高，也是生成图片的宽和高
noise_dim = 100  # 输入噪声的维度（一般不改）
save_step = 1000  # 每隔几次保存一次中间结果图和权重。如果是0，则不保存中间结果图和权重
# Out:
# tf版本： 2.7.0

# %%
# 创建文件夹
directory = './checkpoint3/' + dataset_name + '_%s×%s' % (h, w)  # 输出参数保存的文件夹，一般不改
image_dir = './result_image3/' + dataset_name + '_%s×%s' % (h, w)  # 输出图片保存的文件夹，一般不改
os.makedirs(directory, exist_ok=True)
os.makedirs(image_dir, exist_ok=True)
image_names = os.listdir(image_dir)

# %%
# 加载数据集和预处理
dataloader = DataLoader(dir_path=r'./datasets/%s' % dataset_name, dataset_name=dataset_name,
                        norm_range=(-1, 1), img_res=(h, w))
x_train = dataloader.load_datasets()  # 加载数据集
print('正在加载数据集...')
# Out:
# ./datasets/female [] ['3581.png', '2229.png', '6064.png', '5866.png', '5862.png', '1389.png', '3461.png', '900.png', '9765.png', '8475.png', '5627.png', '5139.png', '4985.png', '7784.png', '3012.png', '3389.png', '4843.png', '3413.png', '7193.png', '1089.png', '4793.png', '6679.png', '3993.png', '2812.png', '2142.png', '7656.png', '1783.png', '7585.png', '290.png', '4288.png', '31.png', '974.png', '35.png', '3906.png', '5631.png', '5011.png', '9335.png', '2942.png', '1351.png', '9682.png', '3494.png', '4380.png', '328.png', '7394.png', '3063.png', '690.png', '9701.png', '3106.png', '8176.png', '2781.png', '6031.png', '4497.png', '1956.png', '4605.png', '8624.png', '798.png', '923.png', '182.png', '6813.png', '5794.png', '4484.png', '3798.png', '3522.png', '465.png', '7378.png', '8646.png', '8148.png', '7139.png', '6317.png', '5906.png', '5643.png', '2543.png', '5478.png', '8035.png', '5221.png', '925.png', '865.png', '3924.png', '7136.png', '7289.png', '4425.png', '8614.png', '4277.png', '3361.png', '8961.png', '153.png', '1669.png', '3024.png', '5000.png', '5515.png', '4149.png', '1064.png', '5858.png', '3279.png', '1961.png', '2173.png', '3962.png', '277.png', '5542.png', '7532.png', '4301.png', '2982.png', '374.png', '2856.png', '1319.png', '5433.png', '9198.png', '3122.png', '9615.png', '9354.png', '4658.png', '6984.png', '4343.png', '6706.png', '4795.png', '8623.png', '8136.png', '4716.png', '834.png', '7025.png', '3256.png', '9525.png', '8487.png', '1032.png', '8364.png', '7347.png', '8257.png', '1816.png', '2426.png', '4148.png', '7684.png', '315.png', '1087.png', '7676.png', '49.png', '867.png', '8617.png', '7902.png', '1429.png', '2553.png', '1470.png', '1168.png', '8907.png', '9689.png', '187.png', '7828.png', '7319.png', '2595.png', '9268.png', '6274.png', '4977.png', '2427.png', '525.png', '8654.png', '5309.png', '4753.png', '4736.png', '3518.png', '6644.png', '6740.png', '9041.png', '4021.png', '6066.png', '484.png', '9748.png', '5679.png', '5705.png', '6728.png', '8096.png', '125.png', '2445.png', '2881.png', '5271.png', '5874.png', '2435.png', '8962.png', '9133.png', '250.png', '3432.png', '717.png', '8489.png', '2161.png', '5590.png', '8362.png', '4376.png', '6523.png', '8719.png', '7579.png', '589.png', '9777.png', '5811.png', '6833.png', '5200.png', '1146.png', '4773.png', '3597.png', '9163.png', '8902.png', '835.png', '4070.png', '4876.png', '8914.png', '642.png', '1423.png', '6290.png', '5346.png', '5625.png', '4491.png', '2439.png', '6059.png', '8451.png', '2233.png', '5920.png', '5981.png', '1649.png', '9565.png', '8412.png', '7340.png', '6430.png', '9564.png', '3125.png', '8145.png', '7079.png', '5153.png', '548.png', '5545.png', '7685.png', '1542.png', '6105.png', '1550.png', '6252.png', '3379.png', '9995.png', '8047.png', '5618.png', '1889.png', '3317.png', '9022.png', '6941.png', '2268.png', '4759.png', '118.png', '2137.png', '8682.png', '9971.png', '5599.png', '9854.png', '8286.png', '3033.png', '9687.png', '349.png', '1977.png', '8029.png', '2513.png', '6666.png', '6178.png', '2576.png', '4608.png', '7493.png', '6655.png', '1023.png', '6088.png', '8246.png', '2507.png', '7478.png', '7912.png', '4094.png', '5548.png', '8073.png', '2953.png', '7923.png', '5126.png', '8082.png', '3768.png', '9849.png', '3147.png', '2219.png', '8518.png', '830.png', '2691.png', '3276.png', '5114.png', '1033.png', '6301.png', '5379.png', '7488.png', '7406.png', '3935.png', '5763.png', '7332.png', '475.png', '6920.png', '4241.png', '5350.png', '3584.png', '4159.png', '8187.png', '2769.png', '8447.png', '9875.png', '426.png', '6351.png', '6593.png', '391.png', '3684.png', '9578.png', '1241.png', '7854.png', '1503.png', '2521.png', '9810.png', '3186.png', '2438.png', '12.png', '84.png', '3782.png', '3142.png', '4664.png', '4954.png', '3599.png', '5999.png', '5203.png', '7935.png', '4104.png', '2625.png', '5745.png', '6952.png', '9731.png', '5256.png', '7712.png', '850.png', '7187.png', '2004.png', '2132.png', '9473.png', '9 ...
# ['./datasets/female/3581.png' './datasets/female/2229.png'
#  './datasets/female/6064.png' ... './datasets/female/7223.png'
#  './datasets/female/5801.png' './datasets/female/9387.png']
# 正在加载数据集...

# %%
# 加载网络
generator = generator_network_dcgan(h, w, c, noise_dim=noise_dim)
discriminator = discriminator_network_dcgan(h, w, c)
# generator.summary()
# discriminator.summary()

# 如果采用Gelu作为激活函数，最好使用带动量的方法进行训练
g_optimizer = optimizers.RMSprop(learning_rate=g_lr)
d_optimizer = optimizers.RMSprop(learning_rate=g_lr)

# 设置随机种植可以让产生的图片不变，之后取消随机数种子
tf.random.set_seed(0)
noise_test = tf.random.normal([fake_num, noise_dim])
tf.random.set_seed(None)
# Out:
# 2022-12-23 20:45:36.804733: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-23 20:45:37.179570: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22308 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:50:00.0, compute capability: 8.6

# %%
generator.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  dense (Dense)               (None, 524288)            52953088
#
#  batch_normalization (BatchN  (None, 524288)           2097152
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 524288)            0
#
#  reshape (Reshape)           (None, 64, 64, 128)       0
#
#  conv2d_transpose (Conv2DTra  (None, 128, 128, 64)     73792
#  nspose)
#
#  batch_normalization_1 (Batc  (None, 128, 128, 64)     256
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 128, 128, 64)      0
#
#  conv2d_transpose_1 (Conv2DT  (None, 256, 256, 32)     18464
#  ranspose)
#
#  batch_normalization_2 (Batc  (None, 256, 256, 32)     128
#  hNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 256, 256, 32)      0
#
#  conv2d_transpose_2 (Conv2DT  (None, 256, 256, 3)      867
#  ranspose)
#
# =================================================================
# Total params: 55,143,747
# Trainable params: 54,094,979
# Non-trainable params: 1,048,768
# _________________________________________________________________

# %%
discriminator.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv2d (Conv2D)             (None, 128, 128, 32)      896
#
#  batch_normalization_3 (Batc  (None, 128, 128, 32)     128
#  hNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 128, 128, 32)      0
#
#  dropout (Dropout)           (None, 128, 128, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        18496
#
#  batch_normalization_4 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 64, 64, 64)        0
#
#  dropout_1 (Dropout)         (None, 64, 64, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       73856
#
#  batch_normalization_5 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 32, 32, 128)       0
#
#  dropout_2 (Dropout)         (None, 32, 32, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)       295168
#
#  batch_normalization_6 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 16, 16, 256)       0
#
#  dropout_3 (Dropout)         (None, 16, 16, 256)       0
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense_1 (Dense)             (None, 1)                 65537
#
# =================================================================
# Total params: 455,873
# Trainable params: 454,913
# Non-trainable params: 960
# _________________________________________________________________

# %%
@tf.function  #tf.function用于加快运算速度
def train_step(x):
    # x = transform(x, dsize=(h, h), crop_size=(h, w))  # 使用随机裁剪
    # print('x:', x.shape)
    noise = tf.random.normal([x.shape[0], noise_dim])  # noise.shape=(b,100)
    with tf.GradientTape() as g_tape, tf.GradientTape() as d_tape:
        fake_image = generator(noise, training=True)  # (b, h, w, c)
        fake_out = discriminator(fake_image, training=True)  # (b, 1)
        real_out = discriminator(x, training=True)  # (b, 1)
        g_loss = tf.reduce_mean(
            losses.binary_crossentropy(y_true=tf.ones_like(fake_out), y_pred=fake_out, from_logits=True))  # 计算生成损失

        d1_loss = tf.reduce_mean(
            losses.binary_crossentropy(y_true=tf.ones_like(real_out), y_pred=real_out, from_logits=True))
        d2_loss = tf.reduce_mean(
            losses.binary_crossentropy(y_true=tf.zeros_like(fake_out), y_pred=fake_out, from_logits=True))  # 计算两个鉴别损失

        gp = gradient_penalty(discriminator, x, fake_image)  # 计算梯度惩罚项（wgan的内容，也可注释掉此行代码不使用）
        d_loss = d1_loss + d2_loss + 10.*gp
        #d_loss = d1_loss + d2_loss
    g_grads = g_tape.gradient(g_loss, generator.trainable_variables)
    d_grads = d_tape.gradient(d_loss, discriminator.trainable_variables)

    g_optimizer.apply_gradients(zip(g_grads, generator.trainable_variables))
    d_optimizer.apply_gradients(zip(d_grads, discriminator.trainable_variables))
    return [g_loss, d_loss]

# %%
# 创建保存参数
checkpoint = tf.train.Checkpoint(generator=generator,
                                 discriminator=discriminator)
checkpoint.restore(tf.train.latest_checkpoint(directory))  # 断点续训
manager = tf.train.CheckpointManager(checkpoint=checkpoint, directory=directory, max_to_keep=2,
                                     checkpoint_name=dataset_name)

max_num = max([int(image_name.split('.')[0][len(dataset_name):]) for image_name in image_names if
               image_name.endswith('png') or image_name.endswith('jpg')]) if image_names else 0  # 接着上次的往后保存

# %%
g_total_loss_list = []
d_total_loss_list = []

# 训练
print('数据加载完成，正在训练中...')
t1 = time.time()
for epoch in range(epochs):

    x_train = dataloader.load_batch(batch_size=batch_size)
    g_total_loss, d_total_loss = train_step(x_train)

    # 保存
    if save_step:
        if (epoch + 1) % save_step == 0 or epoch == 0:  # 每隔几个epoch保存一次
            fake_image = generator.predict(noise_test, batch_size=1)  # (b,h,w,c)
            fake_image = fake_image.reshape(-1, h, w, c) * 127.5 + 127.5  # (b,h,w,c)
            fake_image = np.clip(fake_image, 0, 255).astype('uint8')  # (b,h,w,c)
            save_to = image_dir + '/' + dataset_name + '%d.png' % (epoch + 1 + max_num)
            save_image(fake_image, fake_label=None, fake_num=fake_num, save_to=save_to)  # 保存图片
            manager.save(checkpoint_number=epoch + 1 + max_num)  # 保存参数
            g_total_loss_list.append(g_total_loss)
            d_total_loss_list.append(d_total_loss)  #每一定epoch后保存一次总损失值
            print('epoch:%d/%d:' % (epoch + 1 + max_num, epochs),
                  'g_total_loss:%.6f' % np.mean(g_total_loss),
                  'd_total_loss:%.6f' % np.mean(d_total_loss), '用时:%.6f' % (time.time() - t1))
            t1 = time.time()
    if epoch + 1 + max_num >= epochs:
        print('已跑完%s次' % epochs)
        break
manager.save(checkpoint_number=epochs)  # 训练完保存参数
# Out:
# 数据加载完成，正在训练中...
# 2022-12-23 20:45:51.966517: I tensorflow/stream_executor/cuda/cuda_blas.cc:1774] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2022-12-23 20:45:52.505327: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8101
# 输出图片已保存至:./result_image3/female_256×256/female1.png
# epoch:1/200000: g_total_loss:0.471130 d_total_loss:8.495335 用时:5.064187
# 输出图片已保存至:./result_image3/female_256×256/female1000.png
# epoch:1000/200000: g_total_loss:4.759295 d_total_loss:0.027003 用时:28.986319
# 输出图片已保存至:./result_image3/female_256×256/female2000.png
# epoch:2000/200000: g_total_loss:7.888490 d_total_loss:1.190943 用时:27.295191
# 输出图片已保存至:./result_image3/female_256×256/female3000.png
# epoch:3000/200000: g_total_loss:3.734600 d_total_loss:0.064552 用时:27.488166
# 输出图片已保存至:./result_image3/female_256×256/female4000.png
# epoch:4000/200000: g_total_loss:6.983789 d_total_loss:3.041047 用时:27.093906
# 输出图片已保存至:./result_image3/female_256×256/female5000.png
# epoch:5000/200000: g_total_loss:1.579669 d_total_loss:0.338331 用时:29.044782
# 输出图片已保存至:./result_image3/female_256×256/female6000.png
# epoch:6000/200000: g_total_loss:4.818685 d_total_loss:0.365530 用时:28.415459
# 输出图片已保存至:./result_image3/female_256×256/female7000.png
# epoch:7000/200000: g_total_loss:1.411716 d_total_loss:0.475943 用时:28.107316
# 输出图片已保存至:./result_image3/female_256×256/female8000.png
# epoch:8000/200000: g_total_loss:0.501187 d_total_loss:1.164718 用时:27.736457
# 输出图片已保存至:./result_image3/female_256×256/female9000.png
# epoch:9000/200000: g_total_loss:5.632953 d_total_loss:1.484502 用时:27.553050
# 输出图片已保存至:./result_image3/female_256×256/female10000.png
# epoch:10000/200000: g_total_loss:3.724132 d_total_loss:0.150925 用时:27.021671
# 输出图片已保存至:./result_image3/female_256×256/female11000.png
# epoch:11000/200000: g_total_loss:5.223822 d_total_loss:0.362816 用时:27.903435
# 输出图片已保存至:./result_image3/female_256×256/female12000.png
# epoch:12000/200000: g_total_loss:1.372051 d_total_loss:0.609044 用时:27.295742
# 输出图片已保存至:./result_image3/female_256×256/female13000.png
# epoch:13000/200000: g_total_loss:6.713559 d_total_loss:1.874128 用时:28.137036
# 输出图片已保存至:./result_image3/female_256×256/female14000.png
# epoch:14000/200000: g_total_loss:3.457396 d_total_loss:0.388579 用时:27.735225
# 输出图片已保存至:./result_image3/female_256×256/female15000.png
# epoch:15000/200000: g_total_loss:0.399180 d_total_loss:2.300476 用时:28.358251
# 输出图片已保存至:./result_image3/female_256×256/female16000.png
# epoch:16000/200000: g_total_loss:4.225108 d_total_loss:0.129492 用时:26.699423
# 输出图片已保存至:./result_image3/female_256×256/female17000.png
# epoch:17000/200000: g_total_loss:2.583964 d_total_loss:0.318061 用时:28.252347
# 输出图片已保存至:./result_image3/female_256×256/female18000.png
# epoch:18000/200000: g_total_loss:6.669431 d_total_loss:1.255541 用时:28.781762
# 输出图片已保存至:./result_image3/female_256×256/female19000.png
# epoch:19000/200000: g_total_loss:2.842974 d_total_loss:0.384499 用时:29.022938
# 输出图片已保存至:./result_image3/female_256×256/female20000.png
# epoch:20000/200000: g_total_loss:2.239641 d_total_loss:0.395471 用时:27.100507
# 输出图片已保存至:./result_image3/female_256×256/female21000.png
# epoch:21000/200000: g_total_loss:6.036351 d_total_loss:1.621854 用时:27.159573
# 输出图片已保存至:./result_image3/female_256×256/female22000.png
# epoch:22000/200000: g_total_loss:1.478092 d_total_loss:0.825683 用时:27.570111
# 输出图片已保存至:./result_image3/female_256×256/female23000.png
# epoch:23000/200000: g_total_loss:3.615388 d_total_loss:0.125743 用时:27.457147
# 输出图片已保存至:./result_image3/female_256×256/female24000.png
# epoch:24000/200000: g_total_loss:2.212358 d_total_loss:0.951415 用时:27.608407
# 输出图片已保存至:./result_image3/female_256×256/female25000.png
# epoch:25000/200000: g_total_loss:1.941166 d_total_loss:0.586633 用时:27.199783
# 输出图片已保存至:./result_image3/female_256×256/female26000.png
# epoch:26000/200000: g_total_loss:3.969861 d_total_loss:0.443328 用时:27.620457
# 输出图片已保存至:./result_image3/female_256×256/female27000.png
# epoch:27000/200000: g_total_loss:1.711391 d_total_loss:0.837538 用时:27.131960
# 输出图片已保存至:./result_image3/female_256×256/female28000.png
# epoch:28000/200000: g_total_loss:3.198546 d_total_loss:0.191346 用时:26.666973
# 输出图片已保存至:./result_image3/female_256×256/female29000.png
# epoch:29000/200000: g_total_loss:3.216082 d_total_loss:0.211595 用时:27.309828
# 输出图片已保存至:./result_image3/female_256×256/female30000.png
# epoch:30000/200000: g_total_loss:3.990168 d_total_loss:0.344326 用时:27.297433
# 输出图片已保存至:./result_image3/female_256×256/female31000.png
# epoch:31000/200000: g_total_loss:3.312481 d_total_loss:0.513697 用时:27.131532
# 输出图片已保存至:./result_image3/female_256×256/female32000.png
# epoch:32000/200000: g_total_loss:1.072959 d_total_loss:0.778000 用时:26.990332
# 输出图片已保存至:./result_image3/female_256×256/female33000.png
# epoch:33000/200000: g_total_loss:1.881248 d_total_loss:0.374920 用时:27.666015
# 输出图片已保存至:./result_image3/female_256×256/female34000.png
# epoch:34000/200000: g_total_loss:2.192853 d_total_loss:0.503300 用时:28.438780
# 输出图片已保存至:./result_image3/female_256×256/female35000.png
# epoch:35000/200000: g_total_loss:0.608734 d_total_loss:1.146307 用时:26.444820
# 输出图片已保存至:./result_image3/female_256×256/female36000.png
# epoch:36000/200000: g_total_loss:1.178512 d_total_loss:0.551010 用时:27.518433
# 输出图片已保存至:./result_image3/female_256×256/female37000.png
# epoch:37000/200000: g_total_loss:1.685615 d_total_loss:0.817349 用时:27.395387
# 输出图片已保存至:./result_image3/female_256×256/female38000.png
# epoch:38000/200000: g_total_loss:4.342598 d_total_loss:0.652052 用时:27.332358
# 输出图片已保存至:./result_image3/female_256×256/female39000.png
# epoch:39000/200000: g_total_loss:1.633612 d_total_loss:0.426163 用时:26.883526
# 输出图片已保存至:./result_image3/female_256×256/female40000.png
# epoch:40000/200000: g_total_loss:2.811857 d_total_loss:0.403741 用时:27.770506
# 输出图片已保存至:./result_image3/female_256×256/female41000.png
# epoch:41000/200000: g_total_loss:3.280026 d_total_loss:1.371260 用时:27.556847
# 输出图片已保存至:./result_image3/female_256×256/female42000.png
# epoch:42000/200000: g_total_loss:2.503754 d_total_loss:0.266986 用时:27.463928
# 输出图片已保存至:./result_image3/female_256×256/female43000.png
# epoch:43000/200000: g_total_loss:0.543752 d_total_loss:1.038659 用时:27.014111
# 输出图片已保存至:./result_image3/female_256×256/female44000.png
# epoch:44000/200000: g_total_loss:2.966630 d_total_loss:1.024345 用时:27.002400
# 输出图片已保存至:./result_image3/female_256×256/female45000.png
# epoch:45000/200000: g_total_loss:1.185591 d_total_loss:0.957046 用时:27.303817
# 输出图片已保存至:./result_image3/female_256×256/female46000.png
# epoch:46000/200000: g_total_loss:2.072988 d_total_loss:0.547830 用时:27.966781
# 输出图片已保存至:./result_image3/female_256×256/female47000.png
# epoch:47000/200000: g_total_loss:3.465762 d_total_loss:0.257374 用时:27.361932
# 输出图片已保存至:./result_image3/female_256×256/female48000.png
# epoch:48000/200000: g_total_loss:1.943309 d_total_loss:0.446356 用时:26.642723
# 输出图片已保存至:./result_image3/female_256×256/female49000.png
# epoch:49000/200000: g_total_loss:2.532599 d_total_loss:0.262866 用时:27.229935
# 输出图片已保存至:./result_image3/female_256×256/female50000.png
# epoch:50000/200000: g_total_loss:3.329998 d_total_loss:0.302476 用时:27.068509
# 输出图片已保存至:./result_image3/female_256×256/female51000.png
# epoch:51000/200000: g_total_loss:3.645575 d_total_loss:0.772732 用时:27.234181
# 输出图片已保存至:./result_image3/female_256×256/female52000.png
# epoch:52000/200000: g_total_loss:3.057525 d_total_loss:0.304012 用时:27.144898
# 输出图片已保存至:./result_image3/female_256×256/female53000.png
# epoch:53000/200000: g_total_loss:2.147097 d_total_loss:1.000347 用时:26.632700
# 输出图片已保存至:./result_image3/female_256×256/female54000.png
# epoch:54000/200000: g_total_loss:2.063651 d_total_loss:0.401172 用时:27.331804
# 输出图片已保存至:./result_image3/female_256×256/female55000.png
# epoch:55000/200000: g_total_loss:3.964595 d_total_loss:0.655519 用时:27.397702
# 输出图片已保存至:./result_image3/female_256×256/female56000.png
# epoch:56000/200000: g_total_loss:2.428215 d_total_loss:1.303237 用时:27.586067
# 输出图片已保存至:./result_image3/female_256×256/female57000.png
# epoch:57000/200000: g_total_loss:1.787510 d_total_loss:0.379398 用时:27.080510
# 输出图片已保存至:./result_image3/female_256×256/female58000.png
# epoch:58000/200000: g_total_loss:2.767779 d_total_loss:0.139901 用时:27.360565
# 输出图片已保存至:./result_image3/female_256×256/female59000.png
# epoch:59000/200000: g_total_loss:2.783721 d_total_loss:0.909441 用时:27.559067
# 输出图片已保存至:./result_image3/female_256×256/female60000.png
# epoch:60000/200000: g_total_loss:3.296986 d_total_loss:1.448516 用时:27.003701
# 输出图片已保存至:./result_image3/female_256×256/female61000.png
# epoch:61000/200000: g_total_loss:2.501811 d_total_loss:0.220650 用时:27.028349
# 输出图片已保存至:./result_image3/female_256×256/female62000.png
# epoch:62000/200000: g_total_loss:3.099453 d_total_loss:0.341968 用时:28.232818
# 输出图片已保存至:./result_image3/female_256×256/female63000.png
# epoch:63000/200000: g_total_loss:1.373134 d_total_loss:0.873081 用时:26.748537
# 输出图片已保存至:./result_image3/female_256×256/female64000.png
# epoch:64000/200000: g_total_loss:1.867579 d_total_loss:0.347086 用时:27.135730
# 输出图片已保存至:./result_image3/female_256×256/female65000.png
# epoch:65000/200000: g_total_loss:1.455889 d_total_loss:0.479195 用时:27.578136
# 输出图片已保存至:./result_image3/female_256×256/female66000.png
# epoch:66000/200000: g_total_loss:1.916314 d_total_loss:0.830930 用时:26.448231
# 输出图片已保存至:./result_image3/female_256×256/female67000.png
# epoch:67000/200000: g_total_loss:0.545087 d_total_loss:1.160579 用时:27.662389
# 输出图片已保存至:./result_image3/female_256×256/female68000.png
# epoch:68000/200000: g_total_loss:1.615391 d_total_loss:0.465676 用时:28.013288
# 输出图片已保存至:./result_image3/female_256×256/female69000.png
# epoch:69000/200000: g_total_loss:3.265184 d_total_loss:0.311970 用时:27.186223
# 输出图片已保存至:./result_image3/female_256×256/female70000.png
# epoch:70000/200000: g_total_loss:2.641057 d_total_loss:0.433876 用时:27.534696
# 输出图片已保存至:./result_image3/female_256×256/female71000.png
# epoch:71000/200000: g_total_loss:2.232615 d_total_loss:0.414521 用时:26.849476
# 输出图片已保存至:./result_image3/female_256×256/female72000.png
# epoch:72000/200000: g_total_loss:1.867992 d_total_loss:0.371010 用时:27.265214
# 输出图片已保存至:./result_image3/female_256×256/female73000.png
# epoch:73000/200000: g_total_loss:1.166004 d_total_loss:0.756956 用时:27.109305
# 输出图片已保存至:./result_image3/female_256×256/female74000.png
# epoch:74000/200000: g_total_loss:0.654303 d_total_loss:1.172168 用时:27.244251
# 输出图片已保存至:./result_image3/female_256×256/female75000.png
# epoch:75000/200000: g_total_loss:1.715232 d_total_loss:0.526549 用时:27.000178
# 输出图片已保存至:./result_image3/female_256×256/female76000.png
# epoch:76000/200000: g_total_loss:1.170069 d_total_loss:0.657722 用时:26.781638
# 输出图片已保存至:./result_image3/female_256×256/female77000.png
# epoch:77000/200000: g_total_loss:0.711835 d_total_loss:0.902589 用时:26.557237
# 输出图片已保存至:./result_image3/female_256×256/female78000.png
# epoch:78000/200000: g_total_loss:1.086596 d_total_loss:0.772124 用时:26.830605
# 输出图片已保存至:./result_image3/female_256×256/female79000.png
# epoch:79000/200000: g_total_loss:2.533082 d_total_loss:0.542427 用时:27.442253
# 输出图片已保存至:./result_image3/female_256×256/female80000.png
# epoch:80000/200000: g_total_loss:3.294736 d_total_loss:1.100638 用时:27.617191
# 输出图片已保存至:./result_image3/female_256×256/female81000.png
# epoch:81000/200000: g_total_loss:0.848179 d_total_loss:0.845994 用时:27.596861
# 输出图片已保存至:./result_image3/female_256×256/female82000.png
# epoch:82000/200000: g_total_loss:2.721835 d_total_loss:0.802071 用时:27.887501
# 输出图片已保存至:./result_image3/female_256×256/female83000.png
# epoch:83000/200000: g_total_loss:1.037069 d_total_loss:1.176771 用时:27.014693
# 输出图片已保存至:./result_image3/female_256×256/female84000.png
# epoch:84000/200000: g_total_loss:1.401870 d_total_loss:1.141637 用时:27.336853
# 输出图片已保存至:./result_image3/female_256×256/female85000.png
# epoch:85000/200000: g_total_loss:2.485857 d_total_loss:0.402724 用时:27.014265
# 输出图片已保存至:./result_image3/female_256×256/female86000.png
# epoch:86000/200000: g_total_loss:1.821174 d_total_loss:1.758186 用时:26.931882
# 输出图片已保存至:./result_image3/female_256×256/female87000.png
# epoch:87000/200000: g_total_loss:1.452082 d_total_loss:0.546743 用时:27.513379
# 输出图片已保存至:./result_image3/female_256×256/female88000.png
# epoch:88000/200000: g_total_loss:0.931599 d_total_loss:0.926044 用时:27.610657
# 输出图片已保存至:./result_image3/female_256×256/female89000.png
# epoch:89000/200000: g_total_loss:1.450764 d_total_loss:0.517315 用时:27.336987
# 输出图片已保存至:./result_image3/female_256×256/female90000.png
# epoch:90000/200000: g_total_loss:3.773811 d_total_loss:1.602154 用时:27.252264
# 输出图片已保存至:./result_image3/female_256×256/female91000.png
# epoch:91000/200000: g_total_loss:2.783700 d_total_loss:0.492817 用时:26.874868
# 输出图片已保存至:./result_image3/female_256×256/female92000.png
# epoch:92000/200000: g_total_loss:3.327951 d_total_loss:0.488849 用时:27.757541
# 输出图片已保存至:./result_image3/female_256×256/female93000.png
# epoch:93000/200000: g_total_loss:2.234553 d_total_loss:0.787097 用时:26.985323
# 输出图片已保存至:./result_image3/female_256×256/female94000.png
# epoch:94000/200000: g_total_loss:1.020639 d_total_loss:0.815629 用时:27.502155
# 输出图片已保存至:./result_image3/female_256×256/female95000.png
# epoch:95000/200000: g_total_loss:2.281780 d_total_loss:0.305689 用时:27.265197
# 输出图片已保存至:./result_image3/female_256×256/female96000.png
# epoch:96000/200000: g_total_loss:2.760156 d_total_loss:0.388563 用时:27.156553
# 输出图片已保存至:./result_image3/female_256×256/female97000.png
# epoch:97000/200000: g_total_loss:3.067241 d_total_loss:0.733615 用时:26.761586
# 输出图片已保存至:./result_image3/female_256×256/female98000.png
# epoch:98000/200000: g_total_loss:1.920326 d_total_loss:0.724414 用时:26.904477
# 输出图片已保存至:./result_image3/female_256×256/female99000.png
# epoch:99000/200000: g_total_loss:3.114192 d_total_loss:0.808094 用时:27.756322
# 输出图片已保存至:./result_image3/female_256×256/female100000.png
# epoch:100000/200000: g_total_loss:2.107317 d_total_loss:0.285621 用时:27.250714
# 输出图片已保存至:./result_image3/female_256×256/female101000.png
# epoch:101000/200000: g_total_loss:3.680632 d_total_loss:0.233702 用时:26.791044
# 输出图片已保存至:./result_image3/female_256×256/female102000.png
# epoch:102000/200000: g_total_loss:4.851888 d_total_loss:1.066447 用时:27.330084
# 输出图片已保存至:./result_image3/female_256×256/female103000.png
# epoch:103000/200000: g_total_loss:2.083690 d_total_loss:0.739224 用时:27.844930
# 输出图片已保存至:./result_image3/female_256×256/female104000.png
# epoch:104000/200000: g_total_loss:2.797023 d_total_loss:0.917704 用时:26.792083
# 输出图片已保存至:./result_image3/female_256×256/female105000.png
# epoch:105000/200000: g_total_loss:0.718798 d_total_loss:0.871020 用时:27.581634
# 输出图片已保存至:./result_image3/female_256×256/female106000.png
# epoch:106000/200000: g_total_loss:1.430429 d_total_loss:0.737827 用时:27.069849
# 输出图片已保存至:./result_image3/female_256×256/female107000.png
# epoch:107000/200000: g_total_loss:2.048238 d_total_loss:0.409632 用时:27.545417
# 输出图片已保存至:./result_image3/female_256×256/female108000.png
# epoch:108000/200000: g_total_loss:1.938206 d_total_loss:0.477763 用时:26.996490
# 输出图片已保存至:./result_image3/female_256×256/female109000.png
# epoch:109000/200000: g_total_loss:2.365679 d_total_loss:0.328358 用时:26.910764
# 输出图片已保存至:./result_image3/female_256×256/female110000.png
# epoch:110000/200000: g_total_loss:2.261701 d_total_loss:0.870224 用时:27.302329
# 输出图片已保存至:./result_image3/female_256×256/female111000.png
# epoch:111000/200000: g_total_loss:2.004001 d_total_loss:0.411489 用时:27.333561
# 输出图片已保存至:./result_image3/female_256×256/female112000.png
# epoch:112000/200000: g_total_loss:1.493806 d_total_loss:0.481947 用时:27.422062
# 输出图片已保存至:./result_image3/female_256×256/female113000.png
# epoch:113000/200000: g_total_loss:1.396343 d_total_loss:0.727728 用时:27.030934
# 输出图片已保存至:./result_image3/female_256×256/female114000.png
# epoch:114000/200000: g_total_loss:1.248704 d_total_loss:0.682535 用时:27.095000
# 输出图片已保存至:./result_image3/female_256×256/female115000.png
# epoch:115000/200000: g_total_loss:1.924814 d_total_loss:0.614148 用时:26.963793
# 输出图片已保存至:./result_image3/female_256×256/female116000.png
# epoch:116000/200000: g_total_loss:2.946287 d_total_loss:0.663639 用时:27.519472
# 输出图片已保存至:./result_image3/female_256×256/female117000.png
# epoch:117000/200000: g_total_loss:1.937741 d_total_loss:0.473193 用时:27.197771
# 输出图片已保存至:./result_image3/female_256×256/female118000.png
# epoch:118000/200000: g_total_loss:2.596647 d_total_loss:0.666748 用时:27.001178
# 输出图片已保存至:./result_image3/female_256×256/female119000.png
# epoch:119000/200000: g_total_loss:2.464358 d_total_loss:0.403531 用时:27.409183
# 输出图片已保存至:./result_image3/female_256×256/female120000.png
# epoch:120000/200000: g_total_loss:0.166381 d_total_loss:2.107254 用时:27.816495
# 输出图片已保存至:./result_image3/female_256×256/female121000.png
# epoch:121000/200000: g_total_loss:2.538286 d_total_loss:1.558542 用时:27.058274
# 输出图片已保存至:./result_image3/female_256×256/female122000.png
# epoch:122000/200000: g_total_loss:1.538493 d_total_loss:0.357288 用时:27.564958
# 输出图片已保存至:./result_image3/female_256×256/female123000.png
# epoch:123000/200000: g_total_loss:2.448395 d_total_loss:0.779948 用时:28.208477
# 输出图片已保存至:./result_image3/female_256×256/female124000.png
# epoch:124000/200000: g_total_loss:0.340844 d_total_loss:1.607830 用时:27.768121
# 输出图片已保存至:./result_image3/female_256×256/female125000.png
# epoch:125000/200000: g_total_loss:1.746662 d_total_loss:0.736844 用时:26.718313
# 输出图片已保存至:./result_image3/female_256×256/female126000.png
# epoch:126000/200000: g_total_loss:2.353639 d_total_loss:0.553405 用时:27.252005
# 输出图片已保存至:./result_image3/female_256×256/female127000.png
# epoch:127000/200000: g_total_loss:1.408569 d_total_loss:0.663363 用时:27.491036
# 输出图片已保存至:./result_image3/female_256×256/female128000.png
# epoch:128000/200000: g_total_loss:1.312626 d_total_loss:0.761358 用时:27.602275
# 输出图片已保存至:./result_image3/female_256×256/female129000.png
# epoch:129000/200000: g_total_loss:0.974095 d_total_loss:0.847985 用时:27.326021
# 输出图片已保存至:./result_image3/female_256×256/female130000.png
# epoch:130000/200000: g_total_loss:1.538509 d_total_loss:0.461579 用时:27.402380
# 输出图片已保存至:./result_image3/female_256×256/female131000.png
# epoch:131000/200000: g_total_loss:1.226339 d_total_loss:0.778836 用时:27.115669
# 输出图片已保存至:./result_image3/female_256×256/female132000.png
# epoch:132000/200000: g_total_loss:2.109690 d_total_loss:0.352745 用时:28.212898
# 输出图片已保存至:./result_image3/female_256×256/female133000.png
# epoch:133000/200000: g_total_loss:0.832928 d_total_loss:0.798308 用时:26.981905
# 输出图片已保存至:./result_image3/female_256×256/female134000.png
# epoch:134000/200000: g_total_loss:1.991772 d_total_loss:0.538023 用时:26.650756
# 输出图片已保存至:./result_image3/female_256×256/female135000.png
# epoch:135000/200000: g_total_loss:0.644393 d_total_loss:1.255644 用时:27.953460
# 输出图片已保存至:./result_image3/female_256×256/female136000.png
# epoch:136000/200000: g_total_loss:0.740681 d_total_loss:1.484616 用时:27.324332
# 输出图片已保存至:./result_image3/female_256×256/female137000.png
# epoch:137000/200000: g_total_loss:1.261155 d_total_loss:0.775161 用时:27.008763
# 输出图片已保存至:./result_image3/female_256×256/female138000.png
# epoch:138000/200000: g_total_loss:1.183854 d_total_loss:0.658829 用时:27.219895
# 输出图片已保存至:./result_image3/female_256×256/female139000.png
# epoch:139000/200000: g_total_loss:1.213559 d_total_loss:0.982829 用时:27.039422
# 输出图片已保存至:./result_image3/female_256×256/female140000.png
# epoch:140000/200000: g_total_loss:0.928163 d_total_loss:0.700022 用时:27.485462
# 输出图片已保存至:./result_image3/female_256×256/female141000.png
# epoch:141000/200000: g_total_loss:2.479771 d_total_loss:0.987823 用时:27.820664
# 输出图片已保存至:./result_image3/female_256×256/female142000.png
# epoch:142000/200000: g_total_loss:1.626135 d_total_loss:0.579029 用时:27.537596
# 输出图片已保存至:./result_image3/female_256×256/female143000.png
# epoch:143000/200000: g_total_loss:1.707577 d_total_loss:0.476931 用时:26.118669
# 输出图片已保存至:./result_image3/female_256×256/female144000.png
# epoch:144000/200000: g_total_loss:1.618546 d_total_loss:0.826875 用时:26.946487
# 输出图片已保存至:./result_image3/female_256×256/female145000.png
# epoch:145000/200000: g_total_loss:2.032994 d_total_loss:1.682384 用时:27.369609
# 输出图片已保存至:./result_image3/female_256×256/female146000.png
# epoch:146000/200000: g_total_loss:1.580792 d_total_loss:0.813505 用时:27.753943
# 输出图片已保存至:./result_image3/female_256×256/female147000.png
# epoch:147000/200000: g_total_loss:0.861334 d_total_loss:0.882195 用时:27.333879
# 输出图片已保存至:./result_image3/female_256×256/female148000.png
# epoch:148000/200000: g_total_loss:2.152903 d_total_loss:0.541191 用时:27.100041
# 输出图片已保存至:./result_image3/female_256×256/female149000.png
# epoch:149000/200000: g_total_loss:1.184466 d_total_loss:0.689570 用时:27.953687
# 输出图片已保存至:./result_image3/female_256×256/female150000.png
# epoch:150000/200000: g_total_loss:0.808073 d_total_loss:0.878775 用时:27.477704
# 输出图片已保存至:./result_image3/female_256×256/female151000.png
# epoch:151000/200000: g_total_loss:2.734707 d_total_loss:0.550201 用时:27.283623
# 输出图片已保存至:./result_image3/female_256×256/female152000.png
# epoch:152000/200000: g_total_loss:0.651465 d_total_loss:1.160218 用时:27.032393
# 输出图片已保存至:./result_image3/female_256×256/female153000.png
# epoch:153000/200000: g_total_loss:1.190093 d_total_loss:0.599444 用时:27.135641
# 输出图片已保存至:./result_image3/female_256×256/female154000.png
# epoch:154000/200000: g_total_loss:1.787452 d_total_loss:0.720729 用时:27.420138
# 输出图片已保存至:./result_image3/female_256×256/female155000.png
# epoch:155000/200000: g_total_loss:1.646590 d_total_loss:0.611549 用时:27.138757
# 输出图片已保存至:./result_image3/female_256×256/female156000.png
# epoch:156000/200000: g_total_loss:0.729651 d_total_loss:1.019076 用时:27.047376
# 输出图片已保存至:./result_image3/female_256×256/female157000.png
# epoch:157000/200000: g_total_loss:0.719712 d_total_loss:0.842929 用时:27.239435
# 输出图片已保存至:./result_image3/female_256×256/female158000.png
# epoch:158000/200000: g_total_loss:3.028462 d_total_loss:1.718077 用时:27.592471
# 输出图片已保存至:./result_image3/female_256×256/female159000.png
# epoch:159000/200000: g_total_loss:2.114635 d_total_loss:0.336720 用时:27.440081
# 输出图片已保存至:./result_image3/female_256×256/female160000.png
# epoch:160000/200000: g_total_loss:2.371827 d_total_loss:0.345255 用时:28.039812
# 输出图片已保存至:./result_image3/female_256×256/female161000.png
# epoch:161000/200000: g_total_loss:0.732513 d_total_loss:1.136763 用时:27.879860
# 输出图片已保存至:./result_image3/female_256×256/female162000.png
# epoch:162000/200000: g_total_loss:2.294717 d_total_loss:0.492621 用时:26.919757
# 输出图片已保存至:./result_image3/female_256×256/female163000.png
# epoch:163000/200000: g_total_loss:1.936845 d_total_loss:0.238136 用时:27.281808
# 输出图片已保存至:./result_image3/female_256×256/female164000.png
# epoch:164000/200000: g_total_loss:2.296511 d_total_loss:0.650322 用时:26.929201
# 输出图片已保存至:./result_image3/female_256×256/female165000.png
# epoch:165000/200000: g_total_loss:1.741585 d_total_loss:0.664102 用时:27.234968
# 输出图片已保存至:./result_image3/female_256×256/female166000.png
# epoch:166000/200000: g_total_loss:1.845692 d_total_loss:1.314318 用时:27.195530
# 输出图片已保存至:./result_image3/female_256×256/female167000.png
# epoch:167000/200000: g_total_loss:0.439680 d_total_loss:1.279575 用时:27.352647
# 输出图片已保存至:./result_image3/female_256×256/female168000.png
# epoch:168000/200000: g_total_loss:0.786681 d_total_loss:0.887925 用时:29.942175
# 输出图片已保存至:./result_image3/female_256×256/female169000.png
# epoch:169000/200000: g_total_loss:1.658989 d_total_loss:1.154751 用时:26.792550
# 输出图片已保存至:./result_image3/female_256×256/female170000.png
# epoch:170000/200000: g_total_loss:1.032842 d_total_loss:0.728853 用时:27.401595
# 输出图片已保存至:./result_image3/female_256×256/female171000.png
# epoch:171000/200000: g_total_loss:1.091306 d_total_loss:1.065114 用时:27.261326
# 输出图片已保存至:./result_image3/female_256×256/female172000.png
# epoch:172000/200000: g_total_loss:0.865546 d_total_loss:0.811584 用时:27.019449
# 输出图片已保存至:./result_image3/female_256×256/female173000.png
# epoch:173000/200000: g_total_loss:0.266075 d_total_loss:1.705989 用时:27.030326
# 输出图片已保存至:./result_image3/female_256×256/female174000.png
# epoch:174000/200000: g_total_loss:1.369913 d_total_loss:0.514516 用时:27.390941
# 输出图片已保存至:./result_image3/female_256×256/female175000.png
# epoch:175000/200000: g_total_loss:2.517614 d_total_loss:0.874160 用时:27.190994
# 输出图片已保存至:./result_image3/female_256×256/female176000.png
# epoch:176000/200000: g_total_loss:2.667408 d_total_loss:0.344187 用时:27.752945
# 输出图片已保存至:./result_image3/female_256×256/female177000.png
# epoch:177000/200000: g_total_loss:2.640796 d_total_loss:0.833556 用时:26.842939
# 输出图片已保存至:./result_image3/female_256×256/female178000.png
# epoch:178000/200000: g_total_loss:3.139093 d_total_loss:0.778397 用时:27.025047
# 输出图片已保存至:./result_image3/female_256×256/female179000.png
# epoch:179000/200000: g_total_loss:1.607814 d_total_loss:1.655337 用时:26.962605
# 输出图片已保存至:./result_image3/female_256×256/female180000.png
# epoch:180000/200000: g_total_loss:1.470107 d_total_loss:1.148537 用时:27.326832

# %%
plt.figure(figsize = (12,8))
epochtime = np.arange(0,201000,1000)
plt.plot(epochtime,g_total_loss_list,color='red',marker='o',linestyle='-',linewidth=1)
plt.xlabel('training epoch')
plt.xticks(rotation=45) # 旋转90度
plt.ylabel('total loss of generator')
plt.title('total loss of generator changed by epoch times')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize = (12,8))
epochtime = np.arange(1000,201000,1000)
plt.plot(epochtime,d_total_loss_list[1:],color='blue',marker='o',linestyle='-',linewidth=1)
plt.xlabel('training epoch')
plt.xticks(rotation=45) # 旋转90度
plt.ylabel('total loss of discriminator')
plt.title('total loss of discriminator changed by epoch times')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
print("mean of total loss of generator: {:.6f}".format(np.mean(g_total_loss_list)))
print("mean of total loss of discriminator: {:.6f}".format(np.mean(d_total_loss_list)))
# Out:
# mean of total loss of generator: 2.164618
# mean of total loss of discriminator: 0.803438

# %%
# 定义参数
batch_size = 1  # 每次测试的批次（太大可能会显存不够而报错，可调小再试）
fake_num = 500  # 生成的图片的个数
dataset_name = 'female'  # 数据集的名字  star_imgs
h, w, c = 256, 256, 3  # 数据集图片的宽和高，也是生成图片的宽和高
noise_dim = 100  # 输入噪声的维度（一般不改）

# %%
# 创建文件夹
directory = './checkpoint3/' + dataset_name + '_%s×%s' % (h, w)  # 输出参数保存的文件夹，一般不改
image_dir = './result_image3/' + dataset_name + '_%s×%s' % (h, w)  # 输出图片保存的文件夹，一般不改

# %%
# 搭建网络
generator = generator_network_dcgan(h, w, c, noise_dim=noise_dim)
discriminator = discriminator_network_dcgan(h, w, c)
# 加载参数
checkpoint = tf.train.Checkpoint(generator=generator,
                                 discriminator=discriminator)
checkpoint.restore(tf.train.latest_checkpoint(directory))  # 断点续训
# 预测
# noise_test = tf.random.normal([fake_num, 100])
noise_test = tf.random.uniform([fake_num, noise_dim], -1, 1)
fake_images = generator.predict(noise_test, batch_size=batch_size)  # (b,h,w,c)
fake_images = (fake_images.reshape(-1, h, w, c) * 127.5 + 127.5).astype('uint8')  # (b,h,w,c)

# %%
# 保存生成的图片
os.makedirs('test_from_dir3', exist_ok=True)
for i, fake_image in enumerate(fake_images):
    # i+=5000
    save_path = os.path.join('test_from_dir3', '%s.png' % (i + 1))
    cv.imwrite(save_path, fake_image)
    print('输出的单张图片已保存到：%s' % save_path)
# Out:
# 输出的单张图片已保存到：test_from_dir3/1.png
# 输出的单张图片已保存到：test_from_dir3/2.png
# 输出的单张图片已保存到：test_from_dir3/3.png
# 输出的单张图片已保存到：test_from_dir3/4.png
# 输出的单张图片已保存到：test_from_dir3/5.png
# 输出的单张图片已保存到：test_from_dir3/6.png
# 输出的单张图片已保存到：test_from_dir3/7.png
# 输出的单张图片已保存到：test_from_dir3/8.png
# 输出的单张图片已保存到：test_from_dir3/9.png
# 输出的单张图片已保存到：test_from_dir3/10.png
# 输出的单张图片已保存到：test_from_dir3/11.png
# 输出的单张图片已保存到：test_from_dir3/12.png
# 输出的单张图片已保存到：test_from_dir3/13.png
# 输出的单张图片已保存到：test_from_dir3/14.png
# 输出的单张图片已保存到：test_from_dir3/15.png
# 输出的单张图片已保存到：test_from_dir3/16.png
# 输出的单张图片已保存到：test_from_dir3/17.png
# 输出的单张图片已保存到：test_from_dir3/18.png
# 输出的单张图片已保存到：test_from_dir3/19.png
# 输出的单张图片已保存到：test_from_dir3/20.png
# 输出的单张图片已保存到：test_from_dir3/21.png
# 输出的单张图片已保存到：test_from_dir3/22.png
# 输出的单张图片已保存到：test_from_dir3/23.png
# 输出的单张图片已保存到：test_from_dir3/24.png
# 输出的单张图片已保存到：test_from_dir3/25.png
# 输出的单张图片已保存到：test_from_dir3/26.png
# 输出的单张图片已保存到：test_from_dir3/27.png
# 输出的单张图片已保存到：test_from_dir3/28.png
# 输出的单张图片已保存到：test_from_dir3/29.png
# 输出的单张图片已保存到：test_from_dir3/30.png
# 输出的单张图片已保存到：test_from_dir3/31.png
# 输出的单张图片已保存到：test_from_dir3/32.png
# 输出的单张图片已保存到：test_from_dir3/33.png
# 输出的单张图片已保存到：test_from_dir3/34.png
# 输出的单张图片已保存到：test_from_dir3/35.png
# 输出的单张图片已保存到：test_from_dir3/36.png
# 输出的单张图片已保存到：test_from_dir3/37.png
# 输出的单张图片已保存到：test_from_dir3/38.png
# 输出的单张图片已保存到：test_from_dir3/39.png
# 输出的单张图片已保存到：test_from_dir3/40.png
# 输出的单张图片已保存到：test_from_dir3/41.png
# 输出的单张图片已保存到：test_from_dir3/42.png
# 输出的单张图片已保存到：test_from_dir3/43.png
# 输出的单张图片已保存到：test_from_dir3/44.png
# 输出的单张图片已保存到：test_from_dir3/45.png
# 输出的单张图片已保存到：test_from_dir3/46.png
# 输出的单张图片已保存到：test_from_dir3/47.png
# 输出的单张图片已保存到：test_from_dir3/48.png
# 输出的单张图片已保存到：test_from_dir3/49.png
# 输出的单张图片已保存到：test_from_dir3/50.png
# 输出的单张图片已保存到：test_from_dir3/51.png
# 输出的单张图片已保存到：test_from_dir3/52.png
# 输出的单张图片已保存到：test_from_dir3/53.png
# 输出的单张图片已保存到：test_from_dir3/54.png
# 输出的单张图片已保存到：test_from_dir3/55.png
# 输出的单张图片已保存到：test_from_dir3/56.png
# 输出的单张图片已保存到：test_from_dir3/57.png
# 输出的单张图片已保存到：test_from_dir3/58.png
# 输出的单张图片已保存到：test_from_dir3/59.png
# 输出的单张图片已保存到：test_from_dir3/60.png
# 输出的单张图片已保存到：test_from_dir3/61.png
# 输出的单张图片已保存到：test_from_dir3/62.png
# 输出的单张图片已保存到：test_from_dir3/63.png
# 输出的单张图片已保存到：test_from_dir3/64.png
# 输出的单张图片已保存到：test_from_dir3/65.png
# 输出的单张图片已保存到：test_from_dir3/66.png
# 输出的单张图片已保存到：test_from_dir3/67.png
# 输出的单张图片已保存到：test_from_dir3/68.png
# 输出的单张图片已保存到：test_from_dir3/69.png
# 输出的单张图片已保存到：test_from_dir3/70.png
# 输出的单张图片已保存到：test_from_dir3/71.png
# 输出的单张图片已保存到：test_from_dir3/72.png
# 输出的单张图片已保存到：test_from_dir3/73.png
# 输出的单张图片已保存到：test_from_dir3/74.png
# 输出的单张图片已保存到：test_from_dir3/75.png
# 输出的单张图片已保存到：test_from_dir3/76.png
# 输出的单张图片已保存到：test_from_dir3/77.png
# 输出的单张图片已保存到：test_from_dir3/78.png
# 输出的单张图片已保存到：test_from_dir3/79.png
# 输出的单张图片已保存到：test_from_dir3/80.png
# 输出的单张图片已保存到：test_from_dir3/81.png
# 输出的单张图片已保存到：test_from_dir3/82.png
# 输出的单张图片已保存到：test_from_dir3/83.png
# 输出的单张图片已保存到：test_from_dir3/84.png
# 输出的单张图片已保存到：test_from_dir3/85.png
# 输出的单张图片已保存到：test_from_dir3/86.png
# 输出的单张图片已保存到：test_from_dir3/87.png
# 输出的单张图片已保存到：test_from_dir3/88.png
# 输出的单张图片已保存到：test_from_dir3/89.png
# 输出的单张图片已保存到：test_from_dir3/90.png
# 输出的单张图片已保存到：test_from_dir3/91.png
# 输出的单张图片已保存到：test_from_dir3/92.png
# 输出的单张图片已保存到：test_from_dir3/93.png
# 输出的单张图片已保存到：test_from_dir3/94.png
# 输出的单张图片已保存到：test_from_dir3/95.png
# 输出的单张图片已保存到：test_from_dir3/96.png
# 输出的单张图片已保存到：test_from_dir3/97.png
# 输出的单张图片已保存到：test_from_dir3/98.png
# 输出的单张图片已保存到：test_from_dir3/99.png
# 输出的单张图片已保存到：test_from_dir3/100.png
# 输出的单张图片已保存到：test_from_dir3/101.png
# 输出的单张图片已保存到：test_from_dir3/102.png
# 输出的单张图片已保存到：test_from_dir3/103.png
# 输出的单张图片已保存到：test_from_dir3/104.png
# 输出的单张图片已保存到：test_from_dir3/105.png
# 输出的单张图片已保存到：test_from_dir3/106.png
# 输出的单张图片已保存到：test_from_dir3/107.png
# 输出的单张图片已保存到：test_from_dir3/108.png
# 输出的单张图片已保存到：test_from_dir3/109.png
# 输出的单张图片已保存到：test_from_dir3/110.png
# 输出的单张图片已保存到：test_from_dir3/111.png
# 输出的单张图片已保存到：test_from_dir3/112.png
# 输出的单张图片已保存到：test_from_dir3/113.png
# 输出的单张图片已保存到：test_from_dir3/114.png
# 输出的单张图片已保存到：test_from_dir3/115.png
# 输出的单张图片已保存到：test_from_dir3/116.png
# 输出的单张图片已保存到：test_from_dir3/117.png
# 输出的单张图片已保存到：test_from_dir3/118.png
# 输出的单张图片已保存到：test_from_dir3/119.png
# 输出的单张图片已保存到：test_from_dir3/120.png
# 输出的单张图片已保存到：test_from_dir3/121.png
# 输出的单张图片已保存到：test_from_dir3/122.png
# 输出的单张图片已保存到：test_from_dir3/123.png
# 输出的单张图片已保存到：test_from_dir3/124.png
# 输出的单张图片已保存到：test_from_dir3/125.png
# 输出的单张图片已保存到：test_from_dir3/126.png
# 输出的单张图片已保存到：test_from_dir3/127.png
# 输出的单张图片已保存到：test_from_dir3/128.png
# 输出的单张图片已保存到：test_from_dir3/129.png
# 输出的单张图片已保存到：test_from_dir3/130.png
# 输出的单张图片已保存到：test_from_dir3/131.png
# 输出的单张图片已保存到：test_from_dir3/132.png
# 输出的单张图片已保存到：test_from_dir3/133.png
# 输出的单张图片已保存到：test_from_dir3/134.png
# 输出的单张图片已保存到：test_from_dir3/135.png
# 输出的单张图片已保存到：test_from_dir3/136.png
# 输出的单张图片已保存到：test_from_dir3/137.png
# 输出的单张图片已保存到：test_from_dir3/138.png
# 输出的单张图片已保存到：test_from_dir3/139.png
# 输出的单张图片已保存到：test_from_dir3/140.png
# 输出的单张图片已保存到：test_from_dir3/141.png
# 输出的单张图片已保存到：test_from_dir3/142.png
# 输出的单张图片已保存到：test_from_dir3/143.png
# 输出的单张图片已保存到：test_from_dir3/144.png
# 输出的单张图片已保存到：test_from_dir3/145.png
# 输出的单张图片已保存到：test_from_dir3/146.png
# 输出的单张图片已保存到：test_from_dir3/147.png
# 输出的单张图片已保存到：test_from_dir3/148.png
# 输出的单张图片已保存到：test_from_dir3/149.png
# 输出的单张图片已保存到：test_from_dir3/150.png
# 输出的单张图片已保存到：test_from_dir3/151.png
# 输出的单张图片已保存到：test_from_dir3/152.png
# 输出的单张图片已保存到：test_from_dir3/153.png
# 输出的单张图片已保存到：test_from_dir3/154.png
# 输出的单张图片已保存到：test_from_dir3/155.png
# 输出的单张图片已保存到：test_from_dir3/156.png
# 输出的单张图片已保存到：test_from_dir3/157.png
# 输出的单张图片已保存到：test_from_dir3/158.png
# 输出的单张图片已保存到：test_from_dir3/159.png
# 输出的单张图片已保存到：test_from_dir3/160.png
# 输出的单张图片已保存到：test_from_dir3/161.png
# 输出的单张图片已保存到：test_from_dir3/162.png
# 输出的单张图片已保存到：test_from_dir3/163.png
# 输出的单张图片已保存到：test_from_dir3/164.png
# 输出的单张图片已保存到：test_from_dir3/165.png
# 输出的单张图片已保存到：test_from_dir3/166.png
# 输出的单张图片已保存到：test_from_dir3/167.png
# 输出的单张图片已保存到：test_from_dir3/168.png
# 输出的单张图片已保存到：test_from_dir3/169.png
# 输出的单张图片已保存到：test_from_dir3/170.png
# 输出的单张图片已保存到：test_from_dir3/171.png
# 输出的单张图片已保存到：test_from_dir3/172.png
# 输出的单张图片已保存到：test_from_dir3/173.png
# 输出的单张图片已保存到：test_from_dir3/174.png
# 输出的单张图片已保存到：test_from_dir3/175.png
# 输出的单张图片已保存到：test_from_dir3/176.png
# 输出的单张图片已保存到：test_from_dir3/177.png
# 输出的单张图片已保存到：test_from_dir3/178.png
# 输出的单张图片已保存到：test_from_dir3/179.png
# 输出的单张图片已保存到：test_from_dir3/180.png
# 输出的单张图片已保存到：test_from_dir3/181.png
# 输出的单张图片已保存到：test_from_dir3/182.png
# 输出的单张图片已保存到：test_from_dir3/183.png
# 输出的单张图片已保存到：test_from_dir3/184.png
# 输出的单张图片已保存到：test_from_dir3/185.png
# 输出的单张图片已保存到：test_from_dir3/186.png
# 输出的单张图片已保存到：test_from_dir3/187.png
# 输出的单张图片已保存到：test_from_dir3/188.png
# 输出的单张图片已保存到：test_from_dir3/189.png
# 输出的单张图片已保存到：test_from_dir3/190.png
# 输出的单张图片已保存到：test_from_dir3/191.png
# 输出的单张图片已保存到：test_from_dir3/192.png
# 输出的单张图片已保存到：test_from_dir3/193.png
# 输出的单张图片已保存到：test_from_dir3/194.png
# 输出的单张图片已保存到：test_from_dir3/195.png
# 输出的单张图片已保存到：test_from_dir3/196.png
# 输出的单张图片已保存到：test_from_dir3/197.png
# 输出的单张图片已保存到：test_from_dir3/198.png
# 输出的单张图片已保存到：test_from_dir3/199.png
# 输出的单张图片已保存到：test_from_dir3/200.png
# 输出的单张图片已保存到：test_from_dir3/201.png
# 输出的单张图片已保存到：test_from_dir3/202.png
# 输出的单张图片已保存到：test_from_dir3/203.png
# 输出的单张图片已保存到：test_from_dir3/204.png
# 输出的单张图片已保存到：test_from_dir3/205.png
# 输出的单张图片已保存到：test_from_dir3/206.png
# 输出的单张图片已保存到：test_from_dir3/207.png
# 输出的单张图片已保存到：test_from_dir3/208.png
# 输出的单张图片已保存到：test_from_dir3/209.png
# 输出的单张图片已保存到：test_from_dir3/210.png
# 输出的单张图片已保存到：test_from_dir3/211.png
# 输出的单张图片已保存到：test_from_dir3/212.png
# 输出的单张图片已保存到：test_from_dir3/213.png
# 输出的单张图片已保存到：test_from_dir3/214.png
# 输出的单张图片已保存到：test_from_dir3/215.png
# 输出的单张图片已保存到：test_from_dir3/216.png
# 输出的单张图片已保存到：test_from_dir3/217.png
# 输出的单张图片已保存到：test_from_dir3/218.png
# 输出的单张图片已保存到：test_from_dir3/219.png
# 输出的单张图片已保存到：test_from_dir3/220.png
# 输出的单张图片已保存到：test_from_dir3/221.png
# 输出的单张图片已保存到：test_from_dir3/222.png
# 输出的单张图片已保存到：test_from_dir3/223.png
# 输出的单张图片已保存到：test_from_dir3/224.png
# 输出的单张图片已保存到：test_from_dir3/225.png
# 输出的单张图片已保存到：test_from_dir3/226.png
# 输出的单张图片已保存到：test_from_dir3/227.png
# 输出的单张图片已保存到：test_from_dir3/228.png
# 输出的单张图片已保存到：test_from_dir3/229.png
# 输出的单张图片已保存到：test_from_dir3/230.png
# 输出的单张图片已保存到：test_from_dir3/231.png
# 输出的单张图片已保存到：test_from_dir3/232.png
# 输出的单张图片已保存到：test_from_dir3/233.png
# 输出的单张图片已保存到：test_from_dir3/234.png
# 输出的单张图片已保存到：test_from_dir3/235.png
# 输出的单张图片已保存到：test_from_dir3/236.png
# 输出的单张图片已保存到：test_from_dir3/237.png
# 输出的单张图片已保存到：test_from_dir3/238.png
# 输出的单张图片已保存到：test_from_dir3/239.png
# 输出的单张图片已保存到：test_from_dir3/240.png
# 输出的单张图片已保存到：test_from_dir3/241.png
# 输出的单张图片已保存到：test_from_dir3/242.png
# 输出的单张图片已保存到：test_from_dir3/243.png
# 输出的单张图片已保存到：test_from_dir3/244.png
# 输出的单张图片已保存到：test_from_dir3/245.png
# 输出的单张图片已保存到：test_from_dir3/246.png
# 输出的单张图片已保存到：test_from_dir3/247.png
# 输出的单张图片已保存到：test_from_dir3/248.png
# 输出的单张图片已保存到：test_from_dir3/249.png
# 输出的单张图片已保存到：test_from_dir3/250.png
# 输出的单张图片已保存到：test_from_dir3/251.png
# 输出的单张图片已保存到：test_from_dir3/252.png
# 输出的单张图片已保存到：test_from_dir3/253.png
# 输出的单张图片已保存到：test_from_dir3/254.png
# 输出的单张图片已保存到：test_from_dir3/255.png
# 输出的单张图片已保存到：test_from_dir3/256.png
# 输出的单张图片已保存到：test_from_dir3/257.png
# 输出的单张图片已保存到：test_from_dir3/258.png
# 输出的单张图片已保存到：test_from_dir3/259.png
# 输出的单张图片已保存到：test_from_dir3/260.png
# 输出的单张图片已保存到：test_from_dir3/261.png
# 输出的单张图片已保存到：test_from_dir3/262.png
# 输出的单张图片已保存到：test_from_dir3/263.png
# 输出的单张图片已保存到：test_from_dir3/264.png
# 输出的单张图片已保存到：test_from_dir3/265.png
# 输出的单张图片已保存到：test_from_dir3/266.png
# 输出的单张图片已保存到：test_from_dir3/267.png
# 输出的单张图片已保存到：test_from_dir3/268.png
# 输出的单张图片已保存到：test_from_dir3/269.png
# 输出的单张图片已保存到：test_from_dir3/270.png
# 输出的单张图片已保存到：test_from_dir3/271.png
# 输出的单张图片已保存到：test_from_dir3/272.png
# 输出的单张图片已保存到：test_from_dir3/273.png
# 输出的单张图片已保存到：test_from_dir3/274.png
# 输出的单张图片已保存到：test_from_dir3/275.png
# 输出的单张图片已保存到：test_from_dir3/276.png
# 输出的单张图片已保存到：test_from_dir3/277.png
# 输出的单张图片已保存到：test_from_dir3/278.png
# 输出的单张图片已保存到：test_from_dir3/279.png
# 输出的单张图片已保存到：test_from_dir3/280.png
# 输出的单张图片已保存到：test_from_dir3/281.png
# 输出的单张图片已保存到：test_from_dir3/282.png
# 输出的单张图片已保存到：test_from_dir3/283.png
# 输出的单张图片已保存到：test_from_dir3/284.png
# 输出的单张图片已保存到：test_from_dir3/285.png
# 输出的单张图片已保存到：test_from_dir3/286.png
# 输出的单张图片已保存到：test_from_dir3/287.png
# 输出的单张图片已保存到：test_from_dir3/288.png
# 输出的单张图片已保存到：test_from_dir3/289.png
# 输出的单张图片已保存到：test_from_dir3/290.png
# 输出的单张图片已保存到：test_from_dir3/291.png
# 输出的单张图片已保存到：test_from_dir3/292.png
# 输出的单张图片已保存到：test_from_dir3/293.png
# 输出的单张图片已保存到：test_from_dir3/294.png
# 输出的单张图片已保存到：test_from_dir3/295.png
# 输出的单张图片已保存到：test_from_dir3/296.png
# 输出的单张图片已保存到：test_from_dir3/297.png
# 输出的单张图片已保存到：test_from_dir3/298.png
# 输出的单张图片已保存到：test_from_dir3/299.png
# 输出的单张图片已保存到：test_from_dir3/300.png
# 输出的单张图片已保存到：test_from_dir3/301.png
# 输出的单张图片已保存到：test_from_dir3/302.png
# 输出的单张图片已保存到：test_from_dir3/303.png
# 输出的单张图片已保存到：test_from_dir3/304.png
# 输出的单张图片已保存到：test_from_dir3/305.png
# 输出的单张图片已保存到：test_from_dir3/306.png
# 输出的单张图片已保存到：test_from_dir3/307.png
# 输出的单张图片已保存到：test_from_dir3/308.png
# 输出的单张图片已保存到：test_from_dir3/309.png
# 输出的单张图片已保存到：test_from_dir3/310.png
# 输出的单张图片已保存到：test_from_dir3/311.png
# 输出的单张图片已保存到：test_from_dir3/312.png
# 输出的单张图片已保存到：test_from_dir3/313.png
# 输出的单张图片已保存到：test_from_dir3/314.png
# 输出的单张图片已保存到：test_from_dir3/315.png
# 输出的单张图片已保存到：test_from_dir3/316.png
# 输出的单张图片已保存到：test_from_dir3/317.png
# 输出的单张图片已保存到：test_from_dir3/318.png
# 输出的单张图片已保存到：test_from_dir3/319.png
# 输出的单张图片已保存到：test_from_dir3/320.png
# 输出的单张图片已保存到：test_from_dir3/321.png
# 输出的单张图片已保存到：test_from_dir3/322.png
# 输出的单张图片已保存到：test_from_dir3/323.png
# 输出的单张图片已保存到：test_from_dir3/324.png
# 输出的单张图片已保存到：test_from_dir3/325.png
# 输出的单张图片已保存到：test_from_dir3/326.png
# 输出的单张图片已保存到：test_from_dir3/327.png
# 输出的单张图片已保存到：test_from_dir3/328.png
# 输出的单张图片已保存到：test_from_dir3/329.png
# 输出的单张图片已保存到：test_from_dir3/330.png
# 输出的单张图片已保存到：test_from_dir3/331.png
# 输出的单张图片已保存到：test_from_dir3/332.png
# 输出的单张图片已保存到：test_from_dir3/333.png
# 输出的单张图片已保存到：test_from_dir3/334.png
# 输出的单张图片已保存到：test_from_dir3/335.png
# 输出的单张图片已保存到：test_from_dir3/336.png
# 输出的单张图片已保存到：test_from_dir3/337.png
# 输出的单张图片已保存到：test_from_dir3/338.png
# 输出的单张图片已保存到：test_from_dir3/339.png
# 输出的单张图片已保存到：test_from_dir3/340.png
# 输出的单张图片已保存到：test_from_dir3/341.png
# 输出的单张图片已保存到：test_from_dir3/342.png
# 输出的单张图片已保存到：test_from_dir3/343.png
# 输出的单张图片已保存到：test_from_dir3/344.png
# 输出的单张图片已保存到：test_from_dir3/345.png
# 输出的单张图片已保存到：test_from_dir3/346.png
# 输出的单张图片已保存到：test_from_dir3/347.png
# 输出的单张图片已保存到：test_from_dir3/348.png
# 输出的单张图片已保存到：test_from_dir3/349.png
# 输出的单张图片已保存到：test_from_dir3/350.png
# 输出的单张图片已保存到：test_from_dir3/351.png
# 输出的单张图片已保存到：test_from_dir3/352.png
# 输出的单张图片已保存到：test_from_dir3/353.png
# 输出的单张图片已保存到：test_from_dir3/354.png
# 输出的单张图片已保存到：test_from_dir3/355.png
# 输出的单张图片已保存到：test_from_dir3/356.png
# 输出的单张图片已保存到：test_from_dir3/357.png
# 输出的单张图片已保存到：test_from_dir3/358.png
# 输出的单张图片已保存到：test_from_dir3/359.png
# 输出的单张图片已保存到：test_from_dir3/360.png
# 输出的单张图片已保存到：test_from_dir3/361.png
# 输出的单张图片已保存到：test_from_dir3/362.png
# 输出的单张图片已保存到：test_from_dir3/363.png
# 输出的单张图片已保存到：test_from_dir3/364.png
# 输出的单张图片已保存到：test_from_dir3/365.png
# 输出的单张图片已保存到：test_from_dir3/366.png
# 输出的单张图片已保存到：test_from_dir3/367.png
# 输出的单张图片已保存到：test_from_dir3/368.png
# 输出的单张图片已保存到：test_from_dir3/369.png
# 输出的单张图片已保存到：test_from_dir3/370.png
# 输出的单张图片已保存到：test_from_dir3/371.png
# 输出的单张图片已保存到：test_from_dir3/372.png
# 输出的单张图片已保存到：test_from_dir3/373.png
# 输出的单张图片已保存到：test_from_dir3/374.png
# 输出的单张图片已保存到：test_from_dir3/375.png
# 输出的单张图片已保存到：test_from_dir3/376.png
# 输出的单张图片已保存到：test_from_dir3/377.png
# 输出的单张图片已保存到：test_from_dir3/378.png
# 输出的单张图片已保存到：test_from_dir3/379.png
# 输出的单张图片已保存到：test_from_dir3/380.png
# 输出的单张图片已保存到：test_from_dir3/381.png
# 输出的单张图片已保存到：test_from_dir3/382.png
# 输出的单张图片已保存到：test_from_dir3/383.png
# 输出的单张图片已保存到：test_from_dir3/384.png
# 输出的单张图片已保存到：test_from_dir3/385.png
# 输出的单张图片已保存到：test_from_dir3/386.png
# 输出的单张图片已保存到：test_from_dir3/387.png
# 输出的单张图片已保存到：test_from_dir3/388.png
# 输出的单张图片已保存到：test_from_dir3/389.png
# 输出的单张图片已保存到：test_from_dir3/390.png
# 输出的单张图片已保存到：test_from_dir3/391.png
# 输出的单张图片已保存到：test_from_dir3/392.png
# 输出的单张图片已保存到：test_from_dir3/393.png
# 输出的单张图片已保存到：test_from_dir3/394.png
# 输出的单张图片已保存到：test_from_dir3/395.png
# 输出的单张图片已保存到：test_from_dir3/396.png
# 输出的单张图片已保存到：test_from_dir3/397.png
# 输出的单张图片已保存到：test_from_dir3/398.png
# 输出的单张图片已保存到：test_from_dir3/399.png
# 输出的单张图片已保存到：test_from_dir3/400.png
# 输出的单张图片已保存到：test_from_dir3/401.png
# 输出的单张图片已保存到：test_from_dir3/402.png
# 输出的单张图片已保存到：test_from_dir3/403.png
# 输出的单张图片已保存到：test_from_dir3/404.png
# 输出的单张图片已保存到：test_from_dir3/405.png
# 输出的单张图片已保存到：test_from_dir3/406.png
# 输出的单张图片已保存到：test_from_dir3/407.png
# 输出的单张图片已保存到：test_from_dir3/408.png
# 输出的单张图片已保存到：test_from_dir3/409.png
# 输出的单张图片已保存到：test_from_dir3/410.png
# 输出的单张图片已保存到：test_from_dir3/411.png
# 输出的单张图片已保存到：test_from_dir3/412.png
# 输出的单张图片已保存到：test_from_dir3/413.png
# 输出的单张图片已保存到：test_from_dir3/414.png
# 输出的单张图片已保存到：test_from_dir3/415.png
# 输出的单张图片已保存到：test_from_dir3/416.png
# 输出的单张图片已保存到：test_from_dir3/417.png
# 输出的单张图片已保存到：test_from_dir3/418.png
# 输出的单张图片已保存到：test_from_dir3/419.png
# 输出的单张图片已保存到：test_from_dir3/420.png
# 输出的单张图片已保存到：test_from_dir3/421.png
# 输出的单张图片已保存到：test_from_dir3/422.png
# 输出的单张图片已保存到：test_from_dir3/423.png
# 输出的单张图片已保存到：test_from_dir3/424.png
# 输出的单张图片已保存到：test_from_dir3/425.png
# 输出的单张图片已保存到：test_from_dir3/426.png
# 输出的单张图片已保存到：test_from_dir3/427.png
# 输出的单张图片已保存到：test_from_dir3/428.png
# 输出的单张图片已保存到：test_from_dir3/429.png
# 输出的单张图片已保存到：test_from_dir3/430.png
# 输出的单张图片已保存到：test_from_dir3/431.png
# 输出的单张图片已保存到：test_from_dir3/432.png
# 输出的单张图片已保存到：test_from_dir3/433.png
# 输出的单张图片已保存到：test_from_dir3/434.png
# 输出的单张图片已保存到：test_from_dir3/435.png
# 输出的单张图片已保存到：test_from_dir3/436.png
# 输出的单张图片已保存到：test_from_dir3/437.png
# 输出的单张图片已保存到：test_from_dir3/438.png
# 输出的单张图片已保存到：test_from_dir3/439.png
# 输出的单张图片已保存到：test_from_dir3/440.png
# 输出的单张图片已保存到：test_from_dir3/441.png
# 输出的单张图片已保存到：test_from_dir3/442.png
# 输出的单张图片已保存到：test_from_dir3/443.png
# 输出的单张图片已保存到：test_from_dir3/444.png
# 输出的单张图片已保存到：test_from_dir3/445.png
# 输出的单张图片已保存到：test_from_dir3/446.png
# 输出的单张图片已保存到：test_from_dir3/447.png
# 输出的单张图片已保存到：test_from_dir3/448.png
# 输出的单张图片已保存到：test_from_dir3/449.png
# 输出的单张图片已保存到：test_from_dir3/450.png
# 输出的单张图片已保存到：test_from_dir3/451.png
# 输出的单张图片已保存到：test_from_dir3/452.png
# 输出的单张图片已保存到：test_from_dir3/453.png
# 输出的单张图片已保存到：test_from_dir3/454.png
# 输出的单张图片已保存到：test_from_dir3/455.png
# 输出的单张图片已保存到：test_from_dir3/456.png
# 输出的单张图片已保存到：test_from_dir3/457.png
# 输出的单张图片已保存到：test_from_dir3/458.png
# 输出的单张图片已保存到：test_from_dir3/459.png
# 输出的单张图片已保存到：test_from_dir3/460.png
# 输出的单张图片已保存到：test_from_dir3/461.png
# 输出的单张图片已保存到：test_from_dir3/462.png
# 输出的单张图片已保存到：test_from_dir3/463.png
# 输出的单张图片已保存到：test_from_dir3/464.png
# 输出的单张图片已保存到：test_from_dir3/465.png
# 输出的单张图片已保存到：test_from_dir3/466.png
# 输出的单张图片已保存到：test_from_dir3/467.png
# 输出的单张图片已保存到：test_from_dir3/468.png
# 输出的单张图片已保存到：test_from_dir3/469.png
# 输出的单张图片已保存到：test_from_dir3/470.png
# 输出的单张图片已保存到：test_from_dir3/471.png
# 输出的单张图片已保存到：test_from_dir3/472.png
# 输出的单张图片已保存到：test_from_dir3/473.png
# 输出的单张图片已保存到：test_from_dir3/474.png
# 输出的单张图片已保存到：test_from_dir3/475.png
# 输出的单张图片已保存到：test_from_dir3/476.png
# 输出的单张图片已保存到：test_from_dir3/477.png
# 输出的单张图片已保存到：test_from_dir3/478.png
# 输出的单张图片已保存到：test_from_dir3/479.png
# 输出的单张图片已保存到：test_from_dir3/480.png
# 输出的单张图片已保存到：test_from_dir3/481.png
# 输出的单张图片已保存到：test_from_dir3/482.png
# 输出的单张图片已保存到：test_from_dir3/483.png
# 输出的单张图片已保存到：test_from_dir3/484.png
# 输出的单张图片已保存到：test_from_dir3/485.png
# 输出的单张图片已保存到：test_from_dir3/486.png
# 输出的单张图片已保存到：test_from_dir3/487.png
# 输出的单张图片已保存到：test_from_dir3/488.png
# 输出的单张图片已保存到：test_from_dir3/489.png
# 输出的单张图片已保存到：test_from_dir3/490.png
# 输出的单张图片已保存到：test_from_dir3/491.png
# 输出的单张图片已保存到：test_from_dir3/492.png
# 输出的单张图片已保存到：test_from_dir3/493.png
# 输出的单张图片已保存到：test_from_dir3/494.png
# 输出的单张图片已保存到：test_from_dir3/495.png
# 输出的单张图片已保存到：test_from_dir3/496.png
# 输出的单张图片已保存到：test_from_dir3/497.png
# 输出的单张图片已保存到：test_from_dir3/498.png
# 输出的单张图片已保存到：test_from_dir3/499.png
# 输出的单张图片已保存到：test_from_dir3/500.png

# %%
# 查看部分生成图片
plt.figure(figsize=(12,12))
for i in range(16):
    plt.subplot(4, 4, i + 1)
    if c == 3:
        fake_images[i] = cv.cvtColor(fake_images[i], cv.COLOR_BGR2RGB)
    plt.imshow(fake_images[i])
    plt.axis('off')
plt.show()
