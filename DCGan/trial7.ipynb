# %%
import sys, os
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow.keras import datasets, optimizers, metrics, layers, Sequential, Model, Input, losses
from load_datasets import DataLoader
import time

# %%
os.environ['KMP_DUPLICATE_LIB_OK']='True'  #防止训练过程中的kernel发生crash的情形

# %%
# 卷积层的生成器和鉴别器
def generator_network_dcgan(h, w, c, noise_dim=100):  # 输入噪声和标签，输出假图
    h_, w_ = h // 8, w // 8
    input_noise = Input(shape=(noise_dim,))  # (b,100)
    x = layers.Dense(h_ * w_ * 256)(input_noise)  #全连接层用于调整噪声的维度
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)
    x = layers.Reshape((h_, w_, 256))(x)  # (b,h/4,w/4,256)
    
    x = layers.Conv2DTranspose(128, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/2,w/2,256)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)

    x = layers.Conv2DTranspose(64, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/2,w/2,128)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)

    x = layers.Conv2DTranspose(32, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h,w,64)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = layers.LeakyReLU()(x)
    x = layers.Conv2DTranspose(c, (3, 3), padding='same', activation='tanh')(x)  # (b,h,w,c)
    generator = Model(input_noise, x)
    return generator

# %%
def discriminator_network_dcgan(h, w, c):  # 输入图片和标签，输出待验证的值。输出1为真，0为假
    input_image = Input(shape=(h, w, c))  # (b,h,w,c)
    x = layers.Conv2D(32, (3, 3), strides=(2, 2), padding='same')(input_image)  # (b,h/2,w/2,64)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = tf.keras.activations.gelu(x,approximate=False)
    x = layers.Dropout(0.3)(x)  #改进：在鉴别器的层之间添加dropout

    x = layers.Conv2D(64, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/4,w/4,128)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = tf.keras.activations.gelu(x,approximate=False)
    x = layers.Dropout(0.3)(x)

    x = layers.Conv2D(128, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/4,w/4,256)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = tf.keras.activations.gelu(x,approximate=False)
    x = layers.Dropout(0.3)(x)
    
    x = layers.Conv2D(256, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/4,w/4,512)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = tf.keras.activations.gelu(x,approximate=False)
    x = layers.Dropout(0.3)(x)

    x = layers.Flatten()(x)  # (b,h/4*w/4*512)
    validity = layers.Dense(1, activation=None)(x)  # (b,1) 最后一层，flatten后全连接层

    discriminator = Model(input_image, validity)
    return discriminator

# %%
# WGAN-GP梯度控制函数
def gradient_penalty(discriminator, batch_x, fake_image):
    #梯度惩罚项计算函数
    batchsz = batch_x.shape[0]

    #每个样本均随机采样t,用于插值
    t = tf.random.uniform([batchsz,1,1,1])
    #自动扩展为x的形状:[b,1,1,1] => [b,h,w,c]
    t = tf.broadcast_to(t, batch_x.shape)
    #在真假图片之间作线性插值
    interplate = t * batch_x + (1-t) * fake_image
    #在梯度环境中计算 D 对插值样本的梯度
    with tf.GradientTape() as tape:
        tape.watch([interplate])
        d_interplate_logits = discriminator(interplate)

        grads = tape.gradient(d_interplate_logits, interplate)

        #计算每个样本的梯度的范数:[b,h,w,c] => [b,-1]
        grads = tf.reshape(grads, [grads.shape[0],-1])
        gp = tf.norm(grads,axis=1)
        #计算梯度惩罚项
        gp = tf.reduce_mean((gp-1.)**2)

    return gp

# %%
def save_image(fake_image, fake_label=None, fake_num=16, save_to=''):  # X为4维的带批次的图片
    ''' 
    用于保存图片的函数
    '''
    plt.figure()
    _, h, w, c = fake_image.shape  #设定生成假图的shape（128*128*3）
    if fake_num > 1:
        for i in range(fake_num):
            plt.subplot(4, 4, i + 1)  #训练过程中的迭代以4*4=16（一次保存16张图片）
            if c == 3:  # 如果是bgr则转为rgb（通道的转换）
                plt.imshow(cv.cvtColor(fake_image[i], cv.COLOR_BGR2RGB))  #对于一般格式与BGR格式都予以显示
            if c == 1:  # 如果是灰图则显示灰图
                plt.imshow(np.squeeze(fake_image[i]), cmap='gray')
            if fake_label is not None:  # 如果有标签则传入标签（这是为了在真图与假图之间鉴别时用）
                plt.title(fake_label[i])
            plt.axis('off')
        plt.savefig(save_to)
        plt.close()
    else:  # fake_num=1时保存单张图片，否则按照多张图片的格式保存
        cv.imwrite(save_to, fake_image[0])
    print('输出图片已保存至:%s' % save_to)

# %%
def creat_dir(path):  #用于生成迭代过程中的图片以及保存后续生成的图像
    os.makedirs(path, exist_ok=True)

# %%
print('tf版本：', tf.__version__)
# 定义参数
batch_size = 5  # 每次训练的批次（太大可能会显存不够而报错，故在这里选择较小的值）
epochs = 200000  # 共迭代训练几次
g_lr = 0.0005  # 生成器学习率
d_lr = 0.0002  # 鉴别器学习率
fake_num = 16  # 生成的图片的个数（一般不改）
dataset_name = 'female'  # 数据集的名字  star_imgs  female  cat_vs_dog
h, w, c = 256, 256, 3  # 数据集图片的宽和高，也是生成图片的宽和高
noise_dim = 100  # 输入噪声的维度（一般不改）
save_step = 1000  # 每隔几次保存一次中间结果图和权重。如果是0，则不保存中间结果图和权重
# Out:
# tf版本： 2.7.0

# %%
# 创建文件夹
directory = './checkpoint7/' + dataset_name + '_%s×%s' % (h, w)  # 输出参数保存的文件夹，一般不改
image_dir = './result_image7/' + dataset_name + '_%s×%s' % (h, w)  # 输出图片保存的文件夹，一般不改
os.makedirs(directory, exist_ok=True)
os.makedirs(image_dir, exist_ok=True)
image_names = os.listdir(image_dir)

# %%
# 加载数据集和预处理
dataloader = DataLoader(dir_path=r'./datasets/%s' % dataset_name, dataset_name=dataset_name,
                        norm_range=(-1, 1), img_res=(h, w))
x_train = dataloader.load_datasets()  # 加载数据集
print('正在加载数据集...')
# Out:
# ./datasets/female [] ['3581.png', '2229.png', '6064.png', '5866.png', '5862.png', '1389.png', '3461.png', '900.png', '9765.png', '8475.png', '5627.png', '5139.png', '4985.png', '7784.png', '3012.png', '3389.png', '4843.png', '3413.png', '7193.png', '1089.png', '4793.png', '6679.png', '3993.png', '2812.png', '2142.png', '7656.png', '1783.png', '7585.png', '290.png', '4288.png', '31.png', '974.png', '35.png', '3906.png', '5631.png', '5011.png', '9335.png', '2942.png', '1351.png', '9682.png', '3494.png', '4380.png', '328.png', '7394.png', '3063.png', '690.png', '9701.png', '3106.png', '8176.png', '2781.png', '6031.png', '4497.png', '1956.png', '4605.png', '8624.png', '798.png', '923.png', '182.png', '6813.png', '5794.png', '4484.png', '3798.png', '3522.png', '465.png', '7378.png', '8646.png', '8148.png', '7139.png', '6317.png', '5906.png', '5643.png', '2543.png', '5478.png', '8035.png', '5221.png', '925.png', '865.png', '3924.png', '7136.png', '7289.png', '4425.png', '8614.png', '4277.png', '3361.png', '8961.png', '153.png', '1669.png', '3024.png', '5000.png', '5515.png', '4149.png', '1064.png', '5858.png', '3279.png', '1961.png', '2173.png', '3962.png', '277.png', '5542.png', '7532.png', '4301.png', '2982.png', '374.png', '2856.png', '1319.png', '5433.png', '9198.png', '3122.png', '9615.png', '9354.png', '4658.png', '6984.png', '4343.png', '6706.png', '4795.png', '8623.png', '8136.png', '4716.png', '834.png', '7025.png', '3256.png', '9525.png', '8487.png', '1032.png', '8364.png', '7347.png', '8257.png', '1816.png', '2426.png', '4148.png', '7684.png', '315.png', '1087.png', '7676.png', '49.png', '867.png', '8617.png', '7902.png', '1429.png', '2553.png', '1470.png', '1168.png', '8907.png', '9689.png', '187.png', '7828.png', '7319.png', '2595.png', '9268.png', '6274.png', '4977.png', '2427.png', '525.png', '8654.png', '5309.png', '4753.png', '4736.png', '3518.png', '6644.png', '6740.png', '9041.png', '4021.png', '6066.png', '484.png', '9748.png', '5679.png', '5705.png', '6728.png', '8096.png', '125.png', '2445.png', '2881.png', '5271.png', '5874.png', '2435.png', '8962.png', '9133.png', '250.png', '3432.png', '717.png', '8489.png', '2161.png', '5590.png', '8362.png', '4376.png', '6523.png', '8719.png', '7579.png', '589.png', '9777.png', '5811.png', '6833.png', '5200.png', '1146.png', '4773.png', '3597.png', '9163.png', '8902.png', '835.png', '4070.png', '4876.png', '8914.png', '642.png', '1423.png', '6290.png', '5346.png', '5625.png', '4491.png', '2439.png', '6059.png', '8451.png', '2233.png', '5920.png', '5981.png', '1649.png', '9565.png', '8412.png', '7340.png', '6430.png', '9564.png', '3125.png', '8145.png', '7079.png', '5153.png', '548.png', '5545.png', '7685.png', '1542.png', '6105.png', '1550.png', '6252.png', '3379.png', '9995.png', '8047.png', '5618.png', '1889.png', '3317.png', '9022.png', '6941.png', '2268.png', '4759.png', '118.png', '2137.png', '8682.png', '9971.png', '5599.png', '9854.png', '8286.png', '3033.png', '9687.png', '349.png', '1977.png', '8029.png', '2513.png', '6666.png', '6178.png', '2576.png', '4608.png', '7493.png', '6655.png', '1023.png', '6088.png', '8246.png', '2507.png', '7478.png', '7912.png', '4094.png', '5548.png', '8073.png', '2953.png', '7923.png', '5126.png', '8082.png', '3768.png', '9849.png', '3147.png', '2219.png', '8518.png', '830.png', '2691.png', '3276.png', '5114.png', '1033.png', '6301.png', '5379.png', '7488.png', '7406.png', '3935.png', '5763.png', '7332.png', '475.png', '6920.png', '4241.png', '5350.png', '3584.png', '4159.png', '8187.png', '2769.png', '8447.png', '9875.png', '426.png', '6351.png', '6593.png', '391.png', '3684.png', '9578.png', '1241.png', '7854.png', '1503.png', '2521.png', '9810.png', '3186.png', '2438.png', '12.png', '84.png', '3782.png', '3142.png', '4664.png', '4954.png', '3599.png', '5999.png', '5203.png', '7935.png', '4104.png', '2625.png', '5745.png', '6952.png', '9731.png', '5256.png', '7712.png', '850.png', '7187.png', '2004.png', '2132.png', '9473.png', '9 ...
# ['./datasets/female/3581.png' './datasets/female/2229.png'
#  './datasets/female/6064.png' ... './datasets/female/7223.png'
#  './datasets/female/5801.png' './datasets/female/9387.png']
# 正在加载数据集...

# %%
# 加载网络
generator = generator_network_dcgan(h, w, c, noise_dim=noise_dim)
discriminator = discriminator_network_dcgan(h, w, c)
# generator.summary()
# discriminator.summary()

# 如果采用Gelu作为激活函数，最好使用带动量的方法进行训练
g_optimizer = optimizers.Adam(lr=g_lr, beta_1=0.5)
d_optimizer = optimizers.Adam(lr=d_lr, beta_1=0.5)

# 设置随机种植可以让产生的图片不变，之后取消随机数种子
tf.random.set_seed(0)
noise_test = tf.random.normal([fake_num, noise_dim])
tf.random.set_seed(None)
# Out:
# 2022-12-24 19:54:06.678504: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-24 19:54:07.082278: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22308 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:9c:00.0, compute capability: 8.6
# /usr/local/lib/python3.8/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
generator.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  dense (Dense)               (None, 262144)            26476544
#
#  batch_normalization (BatchN  (None, 262144)           1048576
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 262144)            0
#
#  reshape (Reshape)           (None, 32, 32, 256)       0
#
#  conv2d_transpose (Conv2DTra  (None, 64, 64, 128)      295040
#  nspose)
#
#  batch_normalization_1 (Batc  (None, 64, 64, 128)      512
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 64, 64, 128)       0
#
#  conv2d_transpose_1 (Conv2DT  (None, 128, 128, 64)     73792
#  ranspose)
#
#  batch_normalization_2 (Batc  (None, 128, 128, 64)     256
#  hNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 128, 128, 64)      0
#
#  conv2d_transpose_2 (Conv2DT  (None, 256, 256, 32)     18464
#  ranspose)
#
#  batch_normalization_3 (Batc  (None, 256, 256, 32)     128
#  hNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 256, 256, 32)      0
#
#  conv2d_transpose_3 (Conv2DT  (None, 256, 256, 3)      867
#  ranspose)
#
# =================================================================
# Total params: 27,914,179
# Trainable params: 27,389,443
# Non-trainable params: 524,736
# _________________________________________________________________

# %%
discriminator.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv2d (Conv2D)             (None, 128, 128, 32)      896
#
#  batch_normalization_4 (Batc  (None, 128, 128, 32)     128
#  hNormalization)
#
#  tf.nn.gelu (TFOpLambda)     (None, 128, 128, 32)      0
#
#  dropout (Dropout)           (None, 128, 128, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        18496
#
#  batch_normalization_5 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  tf.nn.gelu_1 (TFOpLambda)   (None, 64, 64, 64)        0
#
#  dropout_1 (Dropout)         (None, 64, 64, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       73856
#
#  batch_normalization_6 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  tf.nn.gelu_2 (TFOpLambda)   (None, 32, 32, 128)       0
#
#  dropout_2 (Dropout)         (None, 32, 32, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)       295168
#
#  batch_normalization_7 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  tf.nn.gelu_3 (TFOpLambda)   (None, 16, 16, 256)       0
#
#  dropout_3 (Dropout)         (None, 16, 16, 256)       0
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense_1 (Dense)             (None, 1)                 65537
#
# =================================================================
# Total params: 455,873
# Trainable params: 454,913
# Non-trainable params: 960
# _________________________________________________________________

# %%
@tf.function  #tf.function用于加快运算速度
def train_step(x):
    # x = transform(x, dsize=(h, h), crop_size=(h, w))  # 使用随机裁剪
    # print('x:', x.shape)
    noise = tf.random.normal([x.shape[0], noise_dim])  # noise.shape=(b,100)
    with tf.GradientTape() as g_tape, tf.GradientTape() as d_tape:
        fake_image = generator(noise, training=True)  # (b, h, w, c)
        fake_out = discriminator(fake_image, training=True)  # (b, 1)
        real_out = discriminator(x, training=True)  # (b, 1)
        g_loss = tf.reduce_mean(
            losses.binary_crossentropy(y_true=tf.ones_like(fake_out), y_pred=fake_out, from_logits=True)) # 计算生成损失。此处换为MSE

        d1_loss = tf.reduce_mean(
            losses.binary_crossentropy(y_true=tf.ones_like(real_out), y_pred=real_out, from_logits=True))
        d2_loss = tf.reduce_mean(
            losses.binary_crossentropy(y_true=tf.zeros_like(fake_out), y_pred=fake_out, from_logits=True))  # 计算两个鉴别损失

        gp = gradient_penalty(discriminator, x, fake_image)  # 计算梯度惩罚项（wgan的内容，也可注释掉此行代码不使用）
        d_loss = d1_loss + d2_loss + 10.*gp
        #d_loss = d1_loss + d2_loss
    g_grads = g_tape.gradient(g_loss, generator.trainable_variables)
    d_grads = d_tape.gradient(d_loss, discriminator.trainable_variables)

    g_optimizer.apply_gradients(zip(g_grads, generator.trainable_variables))
    d_optimizer.apply_gradients(zip(d_grads, discriminator.trainable_variables))
    return [g_loss, d_loss]

# %%
# 创建保存参数
checkpoint = tf.train.Checkpoint(generator=generator,
                                 discriminator=discriminator)
checkpoint.restore(tf.train.latest_checkpoint(directory))  # 断点续训
manager = tf.train.CheckpointManager(checkpoint=checkpoint, directory=directory, max_to_keep=2,
                                     checkpoint_name=dataset_name)

max_num = max([int(image_name.split('.')[0][len(dataset_name):]) for image_name in image_names if
               image_name.endswith('png') or image_name.endswith('jpg')]) if image_names else 0  # 接着上次的往后保存

# %%
g_total_loss_list = []
d_total_loss_list = []

# 训练
print('数据加载完成，正在训练中...')
t1 = time.time()
for epoch in range(epochs):

    x_train = dataloader.load_batch(batch_size=batch_size)
    g_total_loss, d_total_loss = train_step(x_train)

    # 保存
    if save_step:
        if (epoch + 1) % save_step == 0 or epoch == 0:  # 每隔几个epoch保存一次
            fake_image = generator.predict(noise_test, batch_size=1)  # (b,h,w,c)
            fake_image = fake_image.reshape(-1, h, w, c) * 127.5 + 127.5  # (b,h,w,c)
            fake_image = np.clip(fake_image, 0, 255).astype('uint8')  # (b,h,w,c)
            save_to = image_dir + '/' + dataset_name + '%d.png' % (epoch + 1 + max_num)
            save_image(fake_image, fake_label=None, fake_num=fake_num, save_to=save_to)  # 保存图片
            manager.save(checkpoint_number=epoch + 1 + max_num)  # 保存参数
            g_total_loss_list.append(g_total_loss)
            d_total_loss_list.append(d_total_loss)  #每一定epoch后保存一次总损失值
            print('epoch:%d/%d:' % (epoch + 1 + max_num, epochs),
                  'g_total_loss:%.6f' % np.mean(g_total_loss),
                  'd_total_loss:%.6f' % np.mean(d_total_loss), '用时:%.6f' % (time.time() - t1))
            t1 = time.time()
    if epoch + 1 + max_num >= epochs:
        print('已跑完%s次' % epochs)
        break
manager.save(checkpoint_number=epochs)  # 训练完保存参数
# Out:
# 数据加载完成，正在训练中...
# 2022-12-24 19:54:16.835929: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8101
# 2022-12-24 19:54:18.112436: I tensorflow/stream_executor/cuda/cuda_blas.cc:1774] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 输出图片已保存至:./result_image7/female_256×256/female1.png
# epoch:1/200000: g_total_loss:0.595386 d_total_loss:10.630365 用时:5.388249
# 输出图片已保存至:./result_image7/female_256×256/female1000.png
# epoch:1000/200000: g_total_loss:5.010540 d_total_loss:0.378393 用时:26.931577
# 输出图片已保存至:./result_image7/female_256×256/female2000.png
# epoch:2000/200000: g_total_loss:1.518724 d_total_loss:0.525242 用时:28.589185
# 输出图片已保存至:./result_image7/female_256×256/female3000.png
# epoch:3000/200000: g_total_loss:2.509277 d_total_loss:0.964902 用时:29.348592
# 输出图片已保存至:./result_image7/female_256×256/female4000.png
# epoch:4000/200000: g_total_loss:2.215635 d_total_loss:0.344815 用时:28.056811
# 输出图片已保存至:./result_image7/female_256×256/female5000.png
# epoch:5000/200000: g_total_loss:2.182063 d_total_loss:2.485107 用时:28.623513
# 输出图片已保存至:./result_image7/female_256×256/female6000.png
# epoch:6000/200000: g_total_loss:2.285724 d_total_loss:1.325824 用时:28.863420
# 输出图片已保存至:./result_image7/female_256×256/female7000.png
# epoch:7000/200000: g_total_loss:2.558905 d_total_loss:0.424539 用时:28.751052
# 输出图片已保存至:./result_image7/female_256×256/female8000.png
# epoch:8000/200000: g_total_loss:1.694463 d_total_loss:0.882914 用时:28.147873
# 输出图片已保存至:./result_image7/female_256×256/female9000.png
# epoch:9000/200000: g_total_loss:3.278014 d_total_loss:0.548461 用时:28.817676
# 输出图片已保存至:./result_image7/female_256×256/female10000.png
# epoch:10000/200000: g_total_loss:1.981440 d_total_loss:1.872082 用时:28.681749
# 输出图片已保存至:./result_image7/female_256×256/female11000.png
# epoch:11000/200000: g_total_loss:4.068595 d_total_loss:0.791026 用时:28.143880
# 输出图片已保存至:./result_image7/female_256×256/female12000.png
# epoch:12000/200000: g_total_loss:3.966944 d_total_loss:0.334502 用时:28.572957
# 输出图片已保存至:./result_image7/female_256×256/female13000.png
# epoch:13000/200000: g_total_loss:1.613940 d_total_loss:0.475220 用时:28.331604
# 输出图片已保存至:./result_image7/female_256×256/female14000.png
# epoch:14000/200000: g_total_loss:3.918870 d_total_loss:0.692072 用时:28.278905
# 输出图片已保存至:./result_image7/female_256×256/female15000.png
# epoch:15000/200000: g_total_loss:4.322079 d_total_loss:0.729034 用时:28.525829
# 输出图片已保存至:./result_image7/female_256×256/female16000.png
# epoch:16000/200000: g_total_loss:2.796978 d_total_loss:0.365549 用时:28.470114
# 输出图片已保存至:./result_image7/female_256×256/female17000.png
# epoch:17000/200000: g_total_loss:3.228656 d_total_loss:1.937152 用时:28.733272
# 输出图片已保存至:./result_image7/female_256×256/female18000.png
# epoch:18000/200000: g_total_loss:2.794525 d_total_loss:1.086500 用时:29.294705
# 输出图片已保存至:./result_image7/female_256×256/female19000.png
# epoch:19000/200000: g_total_loss:2.445020 d_total_loss:0.329231 用时:29.424307
# 输出图片已保存至:./result_image7/female_256×256/female20000.png
# epoch:20000/200000: g_total_loss:1.839226 d_total_loss:1.119179 用时:28.299458
# 输出图片已保存至:./result_image7/female_256×256/female21000.png
# epoch:21000/200000: g_total_loss:1.567987 d_total_loss:0.598282 用时:29.341754
# 输出图片已保存至:./result_image7/female_256×256/female22000.png
# epoch:22000/200000: g_total_loss:2.161126 d_total_loss:0.577070 用时:36.131352
# 输出图片已保存至:./result_image7/female_256×256/female23000.png
# epoch:23000/200000: g_total_loss:0.501081 d_total_loss:1.664472 用时:52.982106
# 输出图片已保存至:./result_image7/female_256×256/female24000.png
# epoch:24000/200000: g_total_loss:1.536114 d_total_loss:0.296343 用时:38.700721
# 输出图片已保存至:./result_image7/female_256×256/female25000.png
# epoch:25000/200000: g_total_loss:0.946079 d_total_loss:1.295256 用时:35.396827
# 输出图片已保存至:./result_image7/female_256×256/female26000.png
# epoch:26000/200000: g_total_loss:2.414137 d_total_loss:0.610030 用时:32.907613
# 输出图片已保存至:./result_image7/female_256×256/female27000.png
# epoch:27000/200000: g_total_loss:1.369414 d_total_loss:0.519380 用时:29.981551
# 输出图片已保存至:./result_image7/female_256×256/female28000.png
# epoch:28000/200000: g_total_loss:0.879111 d_total_loss:1.198500 用时:29.777889
# 输出图片已保存至:./result_image7/female_256×256/female29000.png
# epoch:29000/200000: g_total_loss:4.149683 d_total_loss:1.336710 用时:29.727073
# 输出图片已保存至:./result_image7/female_256×256/female30000.png
# epoch:30000/200000: g_total_loss:1.922032 d_total_loss:0.608676 用时:29.240888
# 输出图片已保存至:./result_image7/female_256×256/female31000.png
# epoch:31000/200000: g_total_loss:2.613691 d_total_loss:0.579261 用时:28.651033
# 输出图片已保存至:./result_image7/female_256×256/female32000.png
# epoch:32000/200000: g_total_loss:2.722761 d_total_loss:0.681247 用时:28.774052
# 输出图片已保存至:./result_image7/female_256×256/female33000.png
# epoch:33000/200000: g_total_loss:3.571692 d_total_loss:1.137808 用时:28.149095
# 输出图片已保存至:./result_image7/female_256×256/female34000.png
# epoch:34000/200000: g_total_loss:4.035034 d_total_loss:0.674876 用时:29.096552
# 输出图片已保存至:./result_image7/female_256×256/female35000.png
# epoch:35000/200000: g_total_loss:1.679307 d_total_loss:0.846503 用时:28.865207
# 输出图片已保存至:./result_image7/female_256×256/female36000.png
# epoch:36000/200000: g_total_loss:4.151420 d_total_loss:1.371871 用时:29.540169
# 输出图片已保存至:./result_image7/female_256×256/female37000.png
# epoch:37000/200000: g_total_loss:1.958845 d_total_loss:0.395842 用时:28.708990
# 输出图片已保存至:./result_image7/female_256×256/female38000.png
# epoch:38000/200000: g_total_loss:2.107898 d_total_loss:0.832605 用时:28.247943
# 输出图片已保存至:./result_image7/female_256×256/female39000.png
# epoch:39000/200000: g_total_loss:3.981593 d_total_loss:0.560891 用时:28.753354
# 输出图片已保存至:./result_image7/female_256×256/female40000.png
# epoch:40000/200000: g_total_loss:2.548633 d_total_loss:1.207452 用时:29.223131
# 输出图片已保存至:./result_image7/female_256×256/female41000.png
# epoch:41000/200000: g_total_loss:1.585748 d_total_loss:0.560886 用时:28.233635
# 输出图片已保存至:./result_image7/female_256×256/female42000.png
# epoch:42000/200000: g_total_loss:0.872210 d_total_loss:1.364190 用时:28.945935
# 输出图片已保存至:./result_image7/female_256×256/female43000.png
# epoch:43000/200000: g_total_loss:1.515111 d_total_loss:1.544887 用时:28.893504
# 输出图片已保存至:./result_image7/female_256×256/female44000.png
# epoch:44000/200000: g_total_loss:1.702781 d_total_loss:0.343422 用时:28.927923
# 输出图片已保存至:./result_image7/female_256×256/female45000.png
# epoch:45000/200000: g_total_loss:0.522070 d_total_loss:1.811373 用时:27.918003
# 输出图片已保存至:./result_image7/female_256×256/female46000.png
# epoch:46000/200000: g_total_loss:2.257318 d_total_loss:0.408583 用时:29.226671
# 输出图片已保存至:./result_image7/female_256×256/female47000.png
# epoch:47000/200000: g_total_loss:2.618778 d_total_loss:0.423686 用时:28.314843
# 输出图片已保存至:./result_image7/female_256×256/female48000.png
# epoch:48000/200000: g_total_loss:1.120154 d_total_loss:1.699875 用时:28.990472
# 输出图片已保存至:./result_image7/female_256×256/female49000.png
# epoch:49000/200000: g_total_loss:3.083737 d_total_loss:0.935077 用时:28.721550
# 输出图片已保存至:./result_image7/female_256×256/female50000.png
# epoch:50000/200000: g_total_loss:1.141689 d_total_loss:0.669732 用时:28.912415
# 输出图片已保存至:./result_image7/female_256×256/female51000.png
# epoch:51000/200000: g_total_loss:1.031814 d_total_loss:0.705191 用时:28.998226
# 输出图片已保存至:./result_image7/female_256×256/female52000.png
# epoch:52000/200000: g_total_loss:1.916274 d_total_loss:1.535949 用时:29.019018
# 输出图片已保存至:./result_image7/female_256×256/female53000.png
# epoch:53000/200000: g_total_loss:1.751762 d_total_loss:0.634576 用时:29.216875
# 输出图片已保存至:./result_image7/female_256×256/female54000.png
# epoch:54000/200000: g_total_loss:2.002452 d_total_loss:1.892463 用时:27.281219
# 输出图片已保存至:./result_image7/female_256×256/female55000.png
# epoch:55000/200000: g_total_loss:1.972000 d_total_loss:0.860361 用时:29.108392
# 输出图片已保存至:./result_image7/female_256×256/female56000.png
# epoch:56000/200000: g_total_loss:1.814369 d_total_loss:0.842821 用时:28.691132
# 输出图片已保存至:./result_image7/female_256×256/female57000.png
# epoch:57000/200000: g_total_loss:1.444615 d_total_loss:0.555934 用时:28.176356
# 输出图片已保存至:./result_image7/female_256×256/female58000.png
# epoch:58000/200000: g_total_loss:1.556281 d_total_loss:1.343184 用时:28.045595
# 输出图片已保存至:./result_image7/female_256×256/female59000.png
# epoch:59000/200000: g_total_loss:0.737517 d_total_loss:1.926144 用时:27.646259
# 输出图片已保存至:./result_image7/female_256×256/female60000.png
# epoch:60000/200000: g_total_loss:1.432105 d_total_loss:1.036162 用时:28.831997
# 输出图片已保存至:./result_image7/female_256×256/female61000.png
# epoch:61000/200000: g_total_loss:1.329152 d_total_loss:0.804416 用时:29.183385
# 输出图片已保存至:./result_image7/female_256×256/female62000.png
# epoch:62000/200000: g_total_loss:0.890543 d_total_loss:1.016105 用时:28.920808
# 输出图片已保存至:./result_image7/female_256×256/female63000.png
# epoch:63000/200000: g_total_loss:1.051734 d_total_loss:0.871363 用时:29.543047
# 输出图片已保存至:./result_image7/female_256×256/female64000.png
# epoch:64000/200000: g_total_loss:0.904373 d_total_loss:0.781030 用时:28.623439
# 输出图片已保存至:./result_image7/female_256×256/female65000.png
# epoch:65000/200000: g_total_loss:1.302689 d_total_loss:0.746131 用时:30.020550
# 输出图片已保存至:./result_image7/female_256×256/female66000.png
# epoch:66000/200000: g_total_loss:1.835530 d_total_loss:0.778070 用时:30.116620
# 输出图片已保存至:./result_image7/female_256×256/female67000.png
# epoch:67000/200000: g_total_loss:1.382419 d_total_loss:0.654759 用时:28.432222
# 输出图片已保存至:./result_image7/female_256×256/female68000.png
# epoch:68000/200000: g_total_loss:1.247466 d_total_loss:0.920464 用时:28.470089
# 输出图片已保存至:./result_image7/female_256×256/female69000.png
# epoch:69000/200000: g_total_loss:1.284115 d_total_loss:1.017529 用时:29.447608
# 输出图片已保存至:./result_image7/female_256×256/female70000.png
# epoch:70000/200000: g_total_loss:0.854241 d_total_loss:1.256395 用时:28.563190
# 输出图片已保存至:./result_image7/female_256×256/female71000.png
# epoch:71000/200000: g_total_loss:2.124379 d_total_loss:0.262329 用时:27.995100
# 输出图片已保存至:./result_image7/female_256×256/female72000.png
# epoch:72000/200000: g_total_loss:0.607534 d_total_loss:1.738481 用时:27.237993
# 输出图片已保存至:./result_image7/female_256×256/female73000.png
# epoch:73000/200000: g_total_loss:1.411308 d_total_loss:1.196629 用时:27.422675
# 输出图片已保存至:./result_image7/female_256×256/female74000.png
# epoch:74000/200000: g_total_loss:1.626629 d_total_loss:0.674268 用时:28.052411
# 输出图片已保存至:./result_image7/female_256×256/female75000.png
# epoch:75000/200000: g_total_loss:1.107041 d_total_loss:0.857139 用时:29.296880
# 输出图片已保存至:./result_image7/female_256×256/female76000.png
# epoch:76000/200000: g_total_loss:1.648584 d_total_loss:0.970898 用时:28.729614
# 输出图片已保存至:./result_image7/female_256×256/female77000.png
# epoch:77000/200000: g_total_loss:1.849114 d_total_loss:0.924558 用时:28.956257
# 输出图片已保存至:./result_image7/female_256×256/female78000.png
# epoch:78000/200000: g_total_loss:2.264165 d_total_loss:1.318757 用时:29.318381
# 输出图片已保存至:./result_image7/female_256×256/female79000.png
# epoch:79000/200000: g_total_loss:1.841630 d_total_loss:0.428654 用时:30.790669
# 输出图片已保存至:./result_image7/female_256×256/female80000.png
# epoch:80000/200000: g_total_loss:1.981527 d_total_loss:0.405065 用时:28.509236
# 输出图片已保存至:./result_image7/female_256×256/female81000.png
# epoch:81000/200000: g_total_loss:1.136716 d_total_loss:0.704021 用时:27.859114
# 输出图片已保存至:./result_image7/female_256×256/female82000.png
# epoch:82000/200000: g_total_loss:2.537439 d_total_loss:0.208803 用时:29.787954
# 输出图片已保存至:./result_image7/female_256×256/female83000.png
# epoch:83000/200000: g_total_loss:2.039630 d_total_loss:1.690801 用时:28.962329
# 输出图片已保存至:./result_image7/female_256×256/female84000.png
# epoch:84000/200000: g_total_loss:1.673237 d_total_loss:1.040090 用时:29.881706
# 输出图片已保存至:./result_image7/female_256×256/female85000.png
# epoch:85000/200000: g_total_loss:0.992435 d_total_loss:1.009472 用时:28.274962
# 输出图片已保存至:./result_image7/female_256×256/female86000.png
# epoch:86000/200000: g_total_loss:1.034272 d_total_loss:0.790477 用时:28.426386
# 输出图片已保存至:./result_image7/female_256×256/female87000.png
# epoch:87000/200000: g_total_loss:0.358370 d_total_loss:1.981147 用时:28.891913
# 输出图片已保存至:./result_image7/female_256×256/female88000.png
# epoch:88000/200000: g_total_loss:1.052279 d_total_loss:1.278335 用时:28.398428
# 输出图片已保存至:./result_image7/female_256×256/female89000.png
# epoch:89000/200000: g_total_loss:3.198297 d_total_loss:0.479699 用时:29.861531
# 输出图片已保存至:./result_image7/female_256×256/female90000.png
# epoch:90000/200000: g_total_loss:1.589260 d_total_loss:0.751970 用时:34.033901
# 输出图片已保存至:./result_image7/female_256×256/female91000.png
# epoch:91000/200000: g_total_loss:0.790961 d_total_loss:1.227586 用时:52.983924
# 输出图片已保存至:./result_image7/female_256×256/female92000.png
# epoch:92000/200000: g_total_loss:2.127917 d_total_loss:1.573005 用时:40.890942
# 输出图片已保存至:./result_image7/female_256×256/female93000.png
# epoch:93000/200000: g_total_loss:0.916901 d_total_loss:1.556316 用时:36.356090
# 输出图片已保存至:./result_image7/female_256×256/female94000.png
# epoch:94000/200000: g_total_loss:2.529352 d_total_loss:0.549390 用时:30.772501
# 输出图片已保存至:./result_image7/female_256×256/female95000.png
# epoch:95000/200000: g_total_loss:0.717794 d_total_loss:1.323941 用时:30.387511
# 输出图片已保存至:./result_image7/female_256×256/female96000.png
# epoch:96000/200000: g_total_loss:0.899450 d_total_loss:1.563107 用时:31.631583
# 输出图片已保存至:./result_image7/female_256×256/female97000.png
# epoch:97000/200000: g_total_loss:2.148643 d_total_loss:0.824553 用时:45.124056
# 输出图片已保存至:./result_image7/female_256×256/female98000.png
# epoch:98000/200000: g_total_loss:0.978984 d_total_loss:1.124313 用时:57.062887
# 输出图片已保存至:./result_image7/female_256×256/female99000.png
# epoch:99000/200000: g_total_loss:1.031229 d_total_loss:0.823372 用时:46.798876
# 输出图片已保存至:./result_image7/female_256×256/female100000.png
# epoch:100000/200000: g_total_loss:1.692641 d_total_loss:0.329198 用时:38.009454
# 输出图片已保存至:./result_image7/female_256×256/female101000.png
# epoch:101000/200000: g_total_loss:0.832485 d_total_loss:0.894431 用时:36.073032
# 输出图片已保存至:./result_image7/female_256×256/female102000.png
# epoch:102000/200000: g_total_loss:2.543856 d_total_loss:0.410909 用时:33.196474
# 输出图片已保存至:./result_image7/female_256×256/female103000.png
# epoch:103000/200000: g_total_loss:2.414926 d_total_loss:1.098399 用时:31.685887
# 输出图片已保存至:./result_image7/female_256×256/female104000.png
# epoch:104000/200000: g_total_loss:2.949776 d_total_loss:0.738748 用时:31.113289
# 输出图片已保存至:./result_image7/female_256×256/female105000.png
# epoch:105000/200000: g_total_loss:2.936600 d_total_loss:0.276612 用时:29.690038
# 输出图片已保存至:./result_image7/female_256×256/female106000.png
# epoch:106000/200000: g_total_loss:1.197209 d_total_loss:0.984158 用时:29.688143
# 输出图片已保存至:./result_image7/female_256×256/female107000.png
# epoch:107000/200000: g_total_loss:1.870489 d_total_loss:2.498675 用时:28.294966
# 输出图片已保存至:./result_image7/female_256×256/female108000.png
# epoch:108000/200000: g_total_loss:1.913785 d_total_loss:0.890422 用时:28.868107
# 输出图片已保存至:./result_image7/female_256×256/female109000.png
# epoch:109000/200000: g_total_loss:3.493932 d_total_loss:0.384062 用时:28.242274
# 输出图片已保存至:./result_image7/female_256×256/female110000.png
# epoch:110000/200000: g_total_loss:2.352708 d_total_loss:1.259471 用时:29.035379
# 输出图片已保存至:./result_image7/female_256×256/female111000.png
# epoch:111000/200000: g_total_loss:1.837197 d_total_loss:0.684582 用时:28.536531
# 输出图片已保存至:./result_image7/female_256×256/female112000.png
# epoch:112000/200000: g_total_loss:1.381441 d_total_loss:2.808643 用时:28.755869
# 输出图片已保存至:./result_image7/female_256×256/female113000.png
# epoch:113000/200000: g_total_loss:2.264205 d_total_loss:1.063641 用时:28.652366
# 输出图片已保存至:./result_image7/female_256×256/female114000.png
# epoch:114000/200000: g_total_loss:2.212327 d_total_loss:1.117661 用时:28.748621
# 输出图片已保存至:./result_image7/female_256×256/female115000.png
# epoch:115000/200000: g_total_loss:3.540662 d_total_loss:0.776704 用时:28.731836
# 输出图片已保存至:./result_image7/female_256×256/female116000.png
# epoch:116000/200000: g_total_loss:1.734774 d_total_loss:0.674054 用时:29.307224
# 输出图片已保存至:./result_image7/female_256×256/female117000.png
# epoch:117000/200000: g_total_loss:1.528962 d_total_loss:1.064101 用时:30.300847
# 输出图片已保存至:./result_image7/female_256×256/female118000.png
# epoch:118000/200000: g_total_loss:1.498665 d_total_loss:1.039014 用时:28.504527
# 输出图片已保存至:./result_image7/female_256×256/female119000.png
# epoch:119000/200000: g_total_loss:2.437666 d_total_loss:1.582522 用时:28.143996
# 输出图片已保存至:./result_image7/female_256×256/female120000.png
# epoch:120000/200000: g_total_loss:2.676575 d_total_loss:1.177561 用时:28.226889
# 输出图片已保存至:./result_image7/female_256×256/female121000.png
# epoch:121000/200000: g_total_loss:1.336037 d_total_loss:0.573483 用时:29.308599
# 输出图片已保存至:./result_image7/female_256×256/female122000.png
# epoch:122000/200000: g_total_loss:2.147847 d_total_loss:1.554831 用时:28.450457
# 输出图片已保存至:./result_image7/female_256×256/female123000.png
# epoch:123000/200000: g_total_loss:3.383872 d_total_loss:1.817363 用时:29.108586
# 输出图片已保存至:./result_image7/female_256×256/female124000.png
# epoch:124000/200000: g_total_loss:3.703611 d_total_loss:1.364366 用时:29.298975
# 输出图片已保存至:./result_image7/female_256×256/female125000.png
# epoch:125000/200000: g_total_loss:0.991629 d_total_loss:1.175976 用时:29.015783
# 输出图片已保存至:./result_image7/female_256×256/female126000.png
# epoch:126000/200000: g_total_loss:1.344974 d_total_loss:0.798112 用时:27.997092
# 输出图片已保存至:./result_image7/female_256×256/female127000.png
# epoch:127000/200000: g_total_loss:1.382546 d_total_loss:0.674613 用时:29.465688
# 输出图片已保存至:./result_image7/female_256×256/female128000.png
# epoch:128000/200000: g_total_loss:2.498388 d_total_loss:1.200656 用时:27.699811
# 输出图片已保存至:./result_image7/female_256×256/female129000.png
# epoch:129000/200000: g_total_loss:2.089210 d_total_loss:0.837395 用时:29.262202
# 输出图片已保存至:./result_image7/female_256×256/female130000.png
# epoch:130000/200000: g_total_loss:1.381492 d_total_loss:0.852627 用时:29.451368
# 输出图片已保存至:./result_image7/female_256×256/female131000.png
# epoch:131000/200000: g_total_loss:1.455556 d_total_loss:1.362698 用时:28.358084
# 输出图片已保存至:./result_image7/female_256×256/female132000.png
# epoch:132000/200000: g_total_loss:1.636258 d_total_loss:0.809684 用时:29.084966
# 输出图片已保存至:./result_image7/female_256×256/female133000.png
# epoch:133000/200000: g_total_loss:2.183389 d_total_loss:0.450838 用时:28.069000
# 输出图片已保存至:./result_image7/female_256×256/female134000.png
# epoch:134000/200000: g_total_loss:1.228559 d_total_loss:0.591035 用时:28.393993
# 输出图片已保存至:./result_image7/female_256×256/female135000.png
# epoch:135000/200000: g_total_loss:1.940252 d_total_loss:0.528222 用时:29.126468
# 输出图片已保存至:./result_image7/female_256×256/female136000.png
# epoch:136000/200000: g_total_loss:1.587941 d_total_loss:0.738461 用时:29.216069
# 输出图片已保存至:./result_image7/female_256×256/female137000.png
# epoch:137000/200000: g_total_loss:1.538063 d_total_loss:0.634297 用时:29.225987
# 输出图片已保存至:./result_image7/female_256×256/female138000.png
# epoch:138000/200000: g_total_loss:0.932331 d_total_loss:0.790311 用时:29.011523
# 输出图片已保存至:./result_image7/female_256×256/female139000.png
# epoch:139000/200000: g_total_loss:2.167213 d_total_loss:1.232860 用时:28.744499
# 输出图片已保存至:./result_image7/female_256×256/female140000.png
# epoch:140000/200000: g_total_loss:2.072074 d_total_loss:1.135155 用时:28.967179
# 输出图片已保存至:./result_image7/female_256×256/female141000.png
# epoch:141000/200000: g_total_loss:1.103548 d_total_loss:1.295954 用时:28.578204
# 输出图片已保存至:./result_image7/female_256×256/female142000.png
# epoch:142000/200000: g_total_loss:1.205068 d_total_loss:1.227181 用时:28.634622
# 输出图片已保存至:./result_image7/female_256×256/female143000.png
# epoch:143000/200000: g_total_loss:2.001064 d_total_loss:0.720585 用时:28.807572
# 输出图片已保存至:./result_image7/female_256×256/female144000.png
# epoch:144000/200000: g_total_loss:1.536735 d_total_loss:0.862226 用时:28.288384
# 输出图片已保存至:./result_image7/female_256×256/female145000.png
# epoch:145000/200000: g_total_loss:2.654593 d_total_loss:0.251254 用时:29.041815
# 输出图片已保存至:./result_image7/female_256×256/female146000.png
# epoch:146000/200000: g_total_loss:2.447101 d_total_loss:0.557417 用时:29.132481
# 输出图片已保存至:./result_image7/female_256×256/female147000.png
# epoch:147000/200000: g_total_loss:1.035604 d_total_loss:0.897241 用时:28.242659
# 输出图片已保存至:./result_image7/female_256×256/female148000.png
# epoch:148000/200000: g_total_loss:0.586355 d_total_loss:1.218731 用时:29.796470
# 输出图片已保存至:./result_image7/female_256×256/female149000.png
# epoch:149000/200000: g_total_loss:1.050024 d_total_loss:2.340485 用时:29.154431
# 输出图片已保存至:./result_image7/female_256×256/female150000.png
# epoch:150000/200000: g_total_loss:0.680289 d_total_loss:2.438444 用时:29.221232
# 输出图片已保存至:./result_image7/female_256×256/female151000.png
# epoch:151000/200000: g_total_loss:0.676154 d_total_loss:1.390508 用时:29.797818
# 输出图片已保存至:./result_image7/female_256×256/female152000.png
# epoch:152000/200000: g_total_loss:2.430987 d_total_loss:0.595937 用时:29.205285
# 输出图片已保存至:./result_image7/female_256×256/female153000.png
# epoch:153000/200000: g_total_loss:1.691096 d_total_loss:1.031376 用时:29.782153
# 输出图片已保存至:./result_image7/female_256×256/female154000.png
# epoch:154000/200000: g_total_loss:1.304745 d_total_loss:0.844735 用时:29.056595
# 输出图片已保存至:./result_image7/female_256×256/female155000.png
# epoch:155000/200000: g_total_loss:0.926803 d_total_loss:1.103919 用时:29.860829
# 输出图片已保存至:./result_image7/female_256×256/female156000.png
# epoch:156000/200000: g_total_loss:1.566142 d_total_loss:1.210794 用时:28.656481
# 输出图片已保存至:./result_image7/female_256×256/female157000.png
# epoch:157000/200000: g_total_loss:1.367749 d_total_loss:1.237386 用时:28.116612
# 输出图片已保存至:./result_image7/female_256×256/female158000.png
# epoch:158000/200000: g_total_loss:2.022007 d_total_loss:1.168481 用时:28.545937
# 输出图片已保存至:./result_image7/female_256×256/female159000.png
# epoch:159000/200000: g_total_loss:0.834699 d_total_loss:0.894947 用时:30.042638
# 输出图片已保存至:./result_image7/female_256×256/female160000.png
# epoch:160000/200000: g_total_loss:1.633413 d_total_loss:0.461719 用时:29.458219
# 输出图片已保存至:./result_image7/female_256×256/female161000.png
# epoch:161000/200000: g_total_loss:1.689317 d_total_loss:1.578765 用时:28.958286
# 输出图片已保存至:./result_image7/female_256×256/female162000.png
# epoch:162000/200000: g_total_loss:1.504645 d_total_loss:0.458314 用时:28.852488
# 输出图片已保存至:./result_image7/female_256×256/female163000.png
# epoch:163000/200000: g_total_loss:1.078485 d_total_loss:0.766950 用时:28.356911
# 输出图片已保存至:./result_image7/female_256×256/female164000.png
# epoch:164000/200000: g_total_loss:1.201135 d_total_loss:1.999999 用时:29.929562
# 输出图片已保存至:./result_image7/female_256×256/female165000.png
# epoch:165000/200000: g_total_loss:2.674605 d_total_loss:0.941524 用时:32.168032
# 输出图片已保存至:./result_image7/female_256×256/female166000.png
# epoch:166000/200000: g_total_loss:1.234142 d_total_loss:1.187083 用时:29.489939
# 输出图片已保存至:./result_image7/female_256×256/female167000.png
# epoch:167000/200000: g_total_loss:1.134211 d_total_loss:2.154597 用时:28.363633
# 输出图片已保存至:./result_image7/female_256×256/female168000.png
# epoch:168000/200000: g_total_loss:1.724061 d_total_loss:1.542358 用时:28.057563
# 输出图片已保存至:./result_image7/female_256×256/female169000.png
# epoch:169000/200000: g_total_loss:0.823077 d_total_loss:0.969529 用时:28.556685
# 输出图片已保存至:./result_image7/female_256×256/female170000.png
# epoch:170000/200000: g_total_loss:1.678110 d_total_loss:0.776493 用时:30.491848
# 输出图片已保存至:./result_image7/female_256×256/female171000.png
# epoch:171000/200000: g_total_loss:1.992754 d_total_loss:2.608481 用时:30.703125
# 输出图片已保存至:./result_image7/female_256×256/female172000.png
# epoch:172000/200000: g_total_loss:0.988479 d_total_loss:1.520430 用时:29.834834
# 输出图片已保存至:./result_image7/female_256×256/female173000.png
# epoch:173000/200000: g_total_loss:0.722602 d_total_loss:1.799539 用时:29.661322
# 输出图片已保存至:./result_image7/female_256×256/female174000.png
# epoch:174000/200000: g_total_loss:0.710159 d_total_loss:1.335076 用时:29.204309
# 输出图片已保存至:./result_image7/female_256×256/female175000.png
# epoch:175000/200000: g_total_loss:1.471660 d_total_loss:0.593591 用时:30.594680
# 输出图片已保存至:./result_image7/female_256×256/female176000.png
# epoch:176000/200000: g_total_loss:0.643635 d_total_loss:0.983875 用时:29.984923
# 输出图片已保存至:./result_image7/female_256×256/female177000.png
# epoch:177000/200000: g_total_loss:1.397050 d_total_loss:0.831654 用时:29.292799
# 输出图片已保存至:./result_image7/female_256×256/female178000.png
# epoch:178000/200000: g_total_loss:2.966076 d_total_loss:0.186636 用时:29.415744
# 输出图片已保存至:./result_image7/female_256×256/female179000.png
# epoch:179000/200000: g_total_loss:1.545943 d_total_loss:1.950022 用时:29.042841
# 输出图片已保存至:./result_image7/female_256×256/female180000.png
# epoch:180000/200000: g_total_loss:0.887224 d_total_loss:1.550684 用时:30.094619
# 输出图片已保存至:./result_image7/female_256×256/female181000.png
# epoch:181000/200000: g_total_loss:1.835929 d_total_loss:0.926165 用时:30.569485
# 输出图片已保存至:./result_image7/female_256×256/female182000.png
# epoch:182000/200000: g_total_loss:2.037137 d_total_loss:0.781450 用时:29.457597
# 输出图片已保存至:./result_image7/female_256×256/female183000.png
# epoch:183000/200000: g_total_loss:1.127933 d_total_loss:0.656087 用时:28.186972
# 输出图片已保存至:./result_image7/female_256×256/female184000.png
# epoch:184000/200000: g_total_loss:5.520870 d_total_loss:0.140072 用时:29.416856
# 输出图片已保存至:./result_image7/female_256×256/female185000.png
# epoch:185000/200000: g_total_loss:0.776250 d_total_loss:1.347148 用时:29.868648
# 输出图片已保存至:./result_image7/female_256×256/female186000.png
# epoch:186000/200000: g_total_loss:2.413962 d_total_loss:1.152663 用时:29.351670
# 输出图片已保存至:./result_image7/female_256×256/female187000.png
# epoch:187000/200000: g_total_loss:0.484529 d_total_loss:1.558068 用时:28.806260
# 输出图片已保存至:./result_image7/female_256×256/female188000.png
# epoch:188000/200000: g_total_loss:0.694724 d_total_loss:1.208257 用时:28.966472
# 输出图片已保存至:./result_image7/female_256×256/female189000.png
# epoch:189000/200000: g_total_loss:1.818992 d_total_loss:0.460175 用时:29.218727
# 输出图片已保存至:./result_image7/female_256×256/female190000.png
# epoch:190000/200000: g_total_loss:0.382735 d_total_loss:1.908663 用时:29.421504
# 输出图片已保存至:./result_image7/female_256×256/female191000.png
# epoch:191000/200000: g_total_loss:2.368166 d_total_loss:0.962928 用时:28.941864
# 输出图片已保存至:./result_image7/female_256×256/female192000.png
# epoch:192000/200000: g_total_loss:1.979254 d_total_loss:0.615749 用时:29.178853
# 输出图片已保存至:./result_image7/female_256×256/female193000.png
# epoch:193000/200000: g_total_loss:0.475822 d_total_loss:2.177558 用时:29.118862
# 输出图片已保存至:./result_image7/female_256×256/female194000.png
# epoch:194000/200000: g_total_loss:0.933909 d_total_loss:1.222292 用时:29.077792
# 输出图片已保存至:./result_image7/female_256×256/female195000.png
# epoch:195000/200000: g_total_loss:0.721948 d_total_loss:1.092397 用时:28.327159
# 输出图片已保存至:./result_image7/female_256×256/female196000.png
# epoch:196000/200000: g_total_loss:1.769133 d_total_loss:1.362840 用时:28.666574
# 输出图片已保存至:./result_image7/female_256×256/female197000.png
# epoch:197000/200000: g_total_loss:1.455341 d_total_loss:0.499420 用时:28.066981
# 输出图片已保存至:./result_image7/female_256×256/female198000.png
# epoch:198000/200000: g_total_loss:1.034140 d_total_loss:1.166901 用时:29.876827
# 输出图片已保存至:./result_image7/female_256×256/female199000.png
# epoch:199000/200000: g_total_loss:2.322445 d_total_loss:0.810614 用时:28.907140
# 输出图片已保存至:./result_image7/female_256×256/female200000.png
# epoch:200000/200000: g_total_loss:1.964147 d_total_loss:1.026765 用时:28.081137
# 已跑完200000次
# './checkpoint7/female_256×256/female-200000'

# %%
plt.figure(figsize = (12,8))
epochtime = np.arange(0,201000,1000)
plt.plot(epochtime,g_total_loss_list,color='red',marker='o',linestyle='-',linewidth=1)
plt.xlabel('training epoch')
plt.xticks(rotation=45) # 旋转90度
plt.ylabel('total loss of generator')
plt.title('total loss of generator changed by epoch times')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize = (12,8))
epochtime = np.arange(1000,201000,1000)
plt.plot(epochtime,d_total_loss_list[1:],color='blue',marker='o',linestyle='-',linewidth=1)
plt.xlabel('training epoch')
plt.xticks(rotation=45) # 旋转90度
plt.ylabel('total loss of discriminator')
plt.title('total loss of discriminator changed by epoch times')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
print("mean of total loss of generator: {:.6f}".format(np.mean(g_total_loss_list)))
print("mean of total loss of discriminator: {:.6f}".format(np.mean(d_total_loss_list)))
# Out:
# mean of total loss of generator: 1.807312
# mean of total loss of discriminator: 1.064133

# %%
# 定义参数
batch_size = 1  # 每次测试的批次（太大可能会显存不够而报错，可调小再试）
fake_num = 500  # 生成的图片的个数
dataset_name = 'female'  # 数据集的名字  star_imgs
h, w, c = 256, 256, 3  # 数据集图片的宽和高，也是生成图片的宽和高
noise_dim = 100  # 输入噪声的维度（一般不改）

# %%
# 创建文件夹
directory = './checkpoint7/' + dataset_name + '_%s×%s' % (h, w)  # 输出参数保存的文件夹，一般不改
image_dir = './result_image7/' + dataset_name + '_%s×%s' % (h, w)  # 输出图片保存的文件夹，一般不改

# %%
# 搭建网络
generator = generator_network_dcgan(h, w, c, noise_dim=noise_dim)
discriminator = discriminator_network_dcgan(h, w, c)
# 加载参数
checkpoint = tf.train.Checkpoint(generator=generator,
                                 discriminator=discriminator)
checkpoint.restore(tf.train.latest_checkpoint(directory))  # 断点续训
# 预测
# noise_test = tf.random.normal([fake_num, 100])
noise_test = tf.random.uniform([fake_num, noise_dim], -1, 1)
fake_images = generator.predict(noise_test, batch_size=batch_size)  # (b,h,w,c)
fake_images = (fake_images.reshape(-1, h, w, c) * 127.5 + 127.5).astype('uint8')  # (b,h,w,c)

# %%
# 保存生成的图片
os.makedirs('test_from_dir7', exist_ok=True)
for i, fake_image in enumerate(fake_images):
    # i+=5000
    save_path = os.path.join('test_from_dir7', '%s.png' % (i + 1))
    cv.imwrite(save_path, fake_image)
    print('输出的单张图片已保存到：%s' % save_path)
# Out:
# 输出的单张图片已保存到：test_from_dir7/1.png
# 输出的单张图片已保存到：test_from_dir7/2.png
# 输出的单张图片已保存到：test_from_dir7/3.png
# 输出的单张图片已保存到：test_from_dir7/4.png
# 输出的单张图片已保存到：test_from_dir7/5.png
# 输出的单张图片已保存到：test_from_dir7/6.png
# 输出的单张图片已保存到：test_from_dir7/7.png
# 输出的单张图片已保存到：test_from_dir7/8.png
# 输出的单张图片已保存到：test_from_dir7/9.png
# 输出的单张图片已保存到：test_from_dir7/10.png
# 输出的单张图片已保存到：test_from_dir7/11.png
# 输出的单张图片已保存到：test_from_dir7/12.png
# 输出的单张图片已保存到：test_from_dir7/13.png
# 输出的单张图片已保存到：test_from_dir7/14.png
# 输出的单张图片已保存到：test_from_dir7/15.png
# 输出的单张图片已保存到：test_from_dir7/16.png
# 输出的单张图片已保存到：test_from_dir7/17.png
# 输出的单张图片已保存到：test_from_dir7/18.png
# 输出的单张图片已保存到：test_from_dir7/19.png
# 输出的单张图片已保存到：test_from_dir7/20.png
# 输出的单张图片已保存到：test_from_dir7/21.png
# 输出的单张图片已保存到：test_from_dir7/22.png
# 输出的单张图片已保存到：test_from_dir7/23.png
# 输出的单张图片已保存到：test_from_dir7/24.png
# 输出的单张图片已保存到：test_from_dir7/25.png
# 输出的单张图片已保存到：test_from_dir7/26.png
# 输出的单张图片已保存到：test_from_dir7/27.png
# 输出的单张图片已保存到：test_from_dir7/28.png
# 输出的单张图片已保存到：test_from_dir7/29.png
# 输出的单张图片已保存到：test_from_dir7/30.png
# 输出的单张图片已保存到：test_from_dir7/31.png
# 输出的单张图片已保存到：test_from_dir7/32.png
# 输出的单张图片已保存到：test_from_dir7/33.png
# 输出的单张图片已保存到：test_from_dir7/34.png
# 输出的单张图片已保存到：test_from_dir7/35.png
# 输出的单张图片已保存到：test_from_dir7/36.png
# 输出的单张图片已保存到：test_from_dir7/37.png
# 输出的单张图片已保存到：test_from_dir7/38.png
# 输出的单张图片已保存到：test_from_dir7/39.png
# 输出的单张图片已保存到：test_from_dir7/40.png
# 输出的单张图片已保存到：test_from_dir7/41.png
# 输出的单张图片已保存到：test_from_dir7/42.png
# 输出的单张图片已保存到：test_from_dir7/43.png
# 输出的单张图片已保存到：test_from_dir7/44.png
# 输出的单张图片已保存到：test_from_dir7/45.png
# 输出的单张图片已保存到：test_from_dir7/46.png
# 输出的单张图片已保存到：test_from_dir7/47.png
# 输出的单张图片已保存到：test_from_dir7/48.png
# 输出的单张图片已保存到：test_from_dir7/49.png
# 输出的单张图片已保存到：test_from_dir7/50.png
# 输出的单张图片已保存到：test_from_dir7/51.png
# 输出的单张图片已保存到：test_from_dir7/52.png
# 输出的单张图片已保存到：test_from_dir7/53.png
# 输出的单张图片已保存到：test_from_dir7/54.png
# 输出的单张图片已保存到：test_from_dir7/55.png
# 输出的单张图片已保存到：test_from_dir7/56.png
# 输出的单张图片已保存到：test_from_dir7/57.png
# 输出的单张图片已保存到：test_from_dir7/58.png
# 输出的单张图片已保存到：test_from_dir7/59.png
# 输出的单张图片已保存到：test_from_dir7/60.png
# 输出的单张图片已保存到：test_from_dir7/61.png
# 输出的单张图片已保存到：test_from_dir7/62.png
# 输出的单张图片已保存到：test_from_dir7/63.png
# 输出的单张图片已保存到：test_from_dir7/64.png
# 输出的单张图片已保存到：test_from_dir7/65.png
# 输出的单张图片已保存到：test_from_dir7/66.png
# 输出的单张图片已保存到：test_from_dir7/67.png
# 输出的单张图片已保存到：test_from_dir7/68.png
# 输出的单张图片已保存到：test_from_dir7/69.png
# 输出的单张图片已保存到：test_from_dir7/70.png
# 输出的单张图片已保存到：test_from_dir7/71.png
# 输出的单张图片已保存到：test_from_dir7/72.png
# 输出的单张图片已保存到：test_from_dir7/73.png
# 输出的单张图片已保存到：test_from_dir7/74.png
# 输出的单张图片已保存到：test_from_dir7/75.png
# 输出的单张图片已保存到：test_from_dir7/76.png
# 输出的单张图片已保存到：test_from_dir7/77.png
# 输出的单张图片已保存到：test_from_dir7/78.png
# 输出的单张图片已保存到：test_from_dir7/79.png
# 输出的单张图片已保存到：test_from_dir7/80.png
# 输出的单张图片已保存到：test_from_dir7/81.png
# 输出的单张图片已保存到：test_from_dir7/82.png
# 输出的单张图片已保存到：test_from_dir7/83.png
# 输出的单张图片已保存到：test_from_dir7/84.png
# 输出的单张图片已保存到：test_from_dir7/85.png
# 输出的单张图片已保存到：test_from_dir7/86.png
# 输出的单张图片已保存到：test_from_dir7/87.png
# 输出的单张图片已保存到：test_from_dir7/88.png
# 输出的单张图片已保存到：test_from_dir7/89.png
# 输出的单张图片已保存到：test_from_dir7/90.png
# 输出的单张图片已保存到：test_from_dir7/91.png
# 输出的单张图片已保存到：test_from_dir7/92.png
# 输出的单张图片已保存到：test_from_dir7/93.png
# 输出的单张图片已保存到：test_from_dir7/94.png
# 输出的单张图片已保存到：test_from_dir7/95.png
# 输出的单张图片已保存到：test_from_dir7/96.png
# 输出的单张图片已保存到：test_from_dir7/97.png
# 输出的单张图片已保存到：test_from_dir7/98.png
# 输出的单张图片已保存到：test_from_dir7/99.png
# 输出的单张图片已保存到：test_from_dir7/100.png
# 输出的单张图片已保存到：test_from_dir7/101.png
# 输出的单张图片已保存到：test_from_dir7/102.png
# 输出的单张图片已保存到：test_from_dir7/103.png
# 输出的单张图片已保存到：test_from_dir7/104.png
# 输出的单张图片已保存到：test_from_dir7/105.png
# 输出的单张图片已保存到：test_from_dir7/106.png
# 输出的单张图片已保存到：test_from_dir7/107.png
# 输出的单张图片已保存到：test_from_dir7/108.png
# 输出的单张图片已保存到：test_from_dir7/109.png
# 输出的单张图片已保存到：test_from_dir7/110.png
# 输出的单张图片已保存到：test_from_dir7/111.png
# 输出的单张图片已保存到：test_from_dir7/112.png
# 输出的单张图片已保存到：test_from_dir7/113.png
# 输出的单张图片已保存到：test_from_dir7/114.png
# 输出的单张图片已保存到：test_from_dir7/115.png
# 输出的单张图片已保存到：test_from_dir7/116.png
# 输出的单张图片已保存到：test_from_dir7/117.png
# 输出的单张图片已保存到：test_from_dir7/118.png
# 输出的单张图片已保存到：test_from_dir7/119.png
# 输出的单张图片已保存到：test_from_dir7/120.png
# 输出的单张图片已保存到：test_from_dir7/121.png
# 输出的单张图片已保存到：test_from_dir7/122.png
# 输出的单张图片已保存到：test_from_dir7/123.png
# 输出的单张图片已保存到：test_from_dir7/124.png
# 输出的单张图片已保存到：test_from_dir7/125.png
# 输出的单张图片已保存到：test_from_dir7/126.png
# 输出的单张图片已保存到：test_from_dir7/127.png
# 输出的单张图片已保存到：test_from_dir7/128.png
# 输出的单张图片已保存到：test_from_dir7/129.png
# 输出的单张图片已保存到：test_from_dir7/130.png
# 输出的单张图片已保存到：test_from_dir7/131.png
# 输出的单张图片已保存到：test_from_dir7/132.png
# 输出的单张图片已保存到：test_from_dir7/133.png
# 输出的单张图片已保存到：test_from_dir7/134.png
# 输出的单张图片已保存到：test_from_dir7/135.png
# 输出的单张图片已保存到：test_from_dir7/136.png
# 输出的单张图片已保存到：test_from_dir7/137.png
# 输出的单张图片已保存到：test_from_dir7/138.png
# 输出的单张图片已保存到：test_from_dir7/139.png
# 输出的单张图片已保存到：test_from_dir7/140.png
# 输出的单张图片已保存到：test_from_dir7/141.png
# 输出的单张图片已保存到：test_from_dir7/142.png
# 输出的单张图片已保存到：test_from_dir7/143.png
# 输出的单张图片已保存到：test_from_dir7/144.png
# 输出的单张图片已保存到：test_from_dir7/145.png
# 输出的单张图片已保存到：test_from_dir7/146.png
# 输出的单张图片已保存到：test_from_dir7/147.png
# 输出的单张图片已保存到：test_from_dir7/148.png
# 输出的单张图片已保存到：test_from_dir7/149.png
# 输出的单张图片已保存到：test_from_dir7/150.png
# 输出的单张图片已保存到：test_from_dir7/151.png
# 输出的单张图片已保存到：test_from_dir7/152.png
# 输出的单张图片已保存到：test_from_dir7/153.png
# 输出的单张图片已保存到：test_from_dir7/154.png
# 输出的单张图片已保存到：test_from_dir7/155.png
# 输出的单张图片已保存到：test_from_dir7/156.png
# 输出的单张图片已保存到：test_from_dir7/157.png
# 输出的单张图片已保存到：test_from_dir7/158.png
# 输出的单张图片已保存到：test_from_dir7/159.png
# 输出的单张图片已保存到：test_from_dir7/160.png
# 输出的单张图片已保存到：test_from_dir7/161.png
# 输出的单张图片已保存到：test_from_dir7/162.png
# 输出的单张图片已保存到：test_from_dir7/163.png
# 输出的单张图片已保存到：test_from_dir7/164.png
# 输出的单张图片已保存到：test_from_dir7/165.png
# 输出的单张图片已保存到：test_from_dir7/166.png
# 输出的单张图片已保存到：test_from_dir7/167.png
# 输出的单张图片已保存到：test_from_dir7/168.png
# 输出的单张图片已保存到：test_from_dir7/169.png
# 输出的单张图片已保存到：test_from_dir7/170.png
# 输出的单张图片已保存到：test_from_dir7/171.png
# 输出的单张图片已保存到：test_from_dir7/172.png
# 输出的单张图片已保存到：test_from_dir7/173.png
# 输出的单张图片已保存到：test_from_dir7/174.png
# 输出的单张图片已保存到：test_from_dir7/175.png
# 输出的单张图片已保存到：test_from_dir7/176.png
# 输出的单张图片已保存到：test_from_dir7/177.png
# 输出的单张图片已保存到：test_from_dir7/178.png
# 输出的单张图片已保存到：test_from_dir7/179.png
# 输出的单张图片已保存到：test_from_dir7/180.png
# 输出的单张图片已保存到：test_from_dir7/181.png
# 输出的单张图片已保存到：test_from_dir7/182.png
# 输出的单张图片已保存到：test_from_dir7/183.png
# 输出的单张图片已保存到：test_from_dir7/184.png
# 输出的单张图片已保存到：test_from_dir7/185.png
# 输出的单张图片已保存到：test_from_dir7/186.png
# 输出的单张图片已保存到：test_from_dir7/187.png
# 输出的单张图片已保存到：test_from_dir7/188.png
# 输出的单张图片已保存到：test_from_dir7/189.png
# 输出的单张图片已保存到：test_from_dir7/190.png
# 输出的单张图片已保存到：test_from_dir7/191.png
# 输出的单张图片已保存到：test_from_dir7/192.png
# 输出的单张图片已保存到：test_from_dir7/193.png
# 输出的单张图片已保存到：test_from_dir7/194.png
# 输出的单张图片已保存到：test_from_dir7/195.png
# 输出的单张图片已保存到：test_from_dir7/196.png
# 输出的单张图片已保存到：test_from_dir7/197.png
# 输出的单张图片已保存到：test_from_dir7/198.png
# 输出的单张图片已保存到：test_from_dir7/199.png
# 输出的单张图片已保存到：test_from_dir7/200.png
# 输出的单张图片已保存到：test_from_dir7/201.png
# 输出的单张图片已保存到：test_from_dir7/202.png
# 输出的单张图片已保存到：test_from_dir7/203.png
# 输出的单张图片已保存到：test_from_dir7/204.png
# 输出的单张图片已保存到：test_from_dir7/205.png
# 输出的单张图片已保存到：test_from_dir7/206.png
# 输出的单张图片已保存到：test_from_dir7/207.png
# 输出的单张图片已保存到：test_from_dir7/208.png
# 输出的单张图片已保存到：test_from_dir7/209.png
# 输出的单张图片已保存到：test_from_dir7/210.png
# 输出的单张图片已保存到：test_from_dir7/211.png
# 输出的单张图片已保存到：test_from_dir7/212.png
# 输出的单张图片已保存到：test_from_dir7/213.png
# 输出的单张图片已保存到：test_from_dir7/214.png
# 输出的单张图片已保存到：test_from_dir7/215.png
# 输出的单张图片已保存到：test_from_dir7/216.png
# 输出的单张图片已保存到：test_from_dir7/217.png
# 输出的单张图片已保存到：test_from_dir7/218.png
# 输出的单张图片已保存到：test_from_dir7/219.png
# 输出的单张图片已保存到：test_from_dir7/220.png
# 输出的单张图片已保存到：test_from_dir7/221.png
# 输出的单张图片已保存到：test_from_dir7/222.png
# 输出的单张图片已保存到：test_from_dir7/223.png
# 输出的单张图片已保存到：test_from_dir7/224.png
# 输出的单张图片已保存到：test_from_dir7/225.png
# 输出的单张图片已保存到：test_from_dir7/226.png
# 输出的单张图片已保存到：test_from_dir7/227.png
# 输出的单张图片已保存到：test_from_dir7/228.png
# 输出的单张图片已保存到：test_from_dir7/229.png
# 输出的单张图片已保存到：test_from_dir7/230.png
# 输出的单张图片已保存到：test_from_dir7/231.png
# 输出的单张图片已保存到：test_from_dir7/232.png
# 输出的单张图片已保存到：test_from_dir7/233.png
# 输出的单张图片已保存到：test_from_dir7/234.png
# 输出的单张图片已保存到：test_from_dir7/235.png
# 输出的单张图片已保存到：test_from_dir7/236.png
# 输出的单张图片已保存到：test_from_dir7/237.png
# 输出的单张图片已保存到：test_from_dir7/238.png
# 输出的单张图片已保存到：test_from_dir7/239.png
# 输出的单张图片已保存到：test_from_dir7/240.png
# 输出的单张图片已保存到：test_from_dir7/241.png
# 输出的单张图片已保存到：test_from_dir7/242.png
# 输出的单张图片已保存到：test_from_dir7/243.png
# 输出的单张图片已保存到：test_from_dir7/244.png
# 输出的单张图片已保存到：test_from_dir7/245.png
# 输出的单张图片已保存到：test_from_dir7/246.png
# 输出的单张图片已保存到：test_from_dir7/247.png
# 输出的单张图片已保存到：test_from_dir7/248.png
# 输出的单张图片已保存到：test_from_dir7/249.png
# 输出的单张图片已保存到：test_from_dir7/250.png
# 输出的单张图片已保存到：test_from_dir7/251.png
# 输出的单张图片已保存到：test_from_dir7/252.png
# 输出的单张图片已保存到：test_from_dir7/253.png
# 输出的单张图片已保存到：test_from_dir7/254.png
# 输出的单张图片已保存到：test_from_dir7/255.png
# 输出的单张图片已保存到：test_from_dir7/256.png
# 输出的单张图片已保存到：test_from_dir7/257.png
# 输出的单张图片已保存到：test_from_dir7/258.png
# 输出的单张图片已保存到：test_from_dir7/259.png
# 输出的单张图片已保存到：test_from_dir7/260.png
# 输出的单张图片已保存到：test_from_dir7/261.png
# 输出的单张图片已保存到：test_from_dir7/262.png
# 输出的单张图片已保存到：test_from_dir7/263.png
# 输出的单张图片已保存到：test_from_dir7/264.png
# 输出的单张图片已保存到：test_from_dir7/265.png
# 输出的单张图片已保存到：test_from_dir7/266.png
# 输出的单张图片已保存到：test_from_dir7/267.png
# 输出的单张图片已保存到：test_from_dir7/268.png
# 输出的单张图片已保存到：test_from_dir7/269.png
# 输出的单张图片已保存到：test_from_dir7/270.png
# 输出的单张图片已保存到：test_from_dir7/271.png
# 输出的单张图片已保存到：test_from_dir7/272.png
# 输出的单张图片已保存到：test_from_dir7/273.png
# 输出的单张图片已保存到：test_from_dir7/274.png
# 输出的单张图片已保存到：test_from_dir7/275.png
# 输出的单张图片已保存到：test_from_dir7/276.png
# 输出的单张图片已保存到：test_from_dir7/277.png
# 输出的单张图片已保存到：test_from_dir7/278.png
# 输出的单张图片已保存到：test_from_dir7/279.png
# 输出的单张图片已保存到：test_from_dir7/280.png
# 输出的单张图片已保存到：test_from_dir7/281.png
# 输出的单张图片已保存到：test_from_dir7/282.png
# 输出的单张图片已保存到：test_from_dir7/283.png
# 输出的单张图片已保存到：test_from_dir7/284.png
# 输出的单张图片已保存到：test_from_dir7/285.png
# 输出的单张图片已保存到：test_from_dir7/286.png
# 输出的单张图片已保存到：test_from_dir7/287.png
# 输出的单张图片已保存到：test_from_dir7/288.png
# 输出的单张图片已保存到：test_from_dir7/289.png
# 输出的单张图片已保存到：test_from_dir7/290.png
# 输出的单张图片已保存到：test_from_dir7/291.png
# 输出的单张图片已保存到：test_from_dir7/292.png
# 输出的单张图片已保存到：test_from_dir7/293.png
# 输出的单张图片已保存到：test_from_dir7/294.png
# 输出的单张图片已保存到：test_from_dir7/295.png
# 输出的单张图片已保存到：test_from_dir7/296.png
# 输出的单张图片已保存到：test_from_dir7/297.png
# 输出的单张图片已保存到：test_from_dir7/298.png
# 输出的单张图片已保存到：test_from_dir7/299.png
# 输出的单张图片已保存到：test_from_dir7/300.png
# 输出的单张图片已保存到：test_from_dir7/301.png
# 输出的单张图片已保存到：test_from_dir7/302.png
# 输出的单张图片已保存到：test_from_dir7/303.png
# 输出的单张图片已保存到：test_from_dir7/304.png
# 输出的单张图片已保存到：test_from_dir7/305.png
# 输出的单张图片已保存到：test_from_dir7/306.png
# 输出的单张图片已保存到：test_from_dir7/307.png
# 输出的单张图片已保存到：test_from_dir7/308.png
# 输出的单张图片已保存到：test_from_dir7/309.png
# 输出的单张图片已保存到：test_from_dir7/310.png
# 输出的单张图片已保存到：test_from_dir7/311.png
# 输出的单张图片已保存到：test_from_dir7/312.png
# 输出的单张图片已保存到：test_from_dir7/313.png
# 输出的单张图片已保存到：test_from_dir7/314.png
# 输出的单张图片已保存到：test_from_dir7/315.png
# 输出的单张图片已保存到：test_from_dir7/316.png
# 输出的单张图片已保存到：test_from_dir7/317.png
# 输出的单张图片已保存到：test_from_dir7/318.png
# 输出的单张图片已保存到：test_from_dir7/319.png
# 输出的单张图片已保存到：test_from_dir7/320.png
# 输出的单张图片已保存到：test_from_dir7/321.png
# 输出的单张图片已保存到：test_from_dir7/322.png
# 输出的单张图片已保存到：test_from_dir7/323.png
# 输出的单张图片已保存到：test_from_dir7/324.png
# 输出的单张图片已保存到：test_from_dir7/325.png
# 输出的单张图片已保存到：test_from_dir7/326.png
# 输出的单张图片已保存到：test_from_dir7/327.png
# 输出的单张图片已保存到：test_from_dir7/328.png
# 输出的单张图片已保存到：test_from_dir7/329.png
# 输出的单张图片已保存到：test_from_dir7/330.png
# 输出的单张图片已保存到：test_from_dir7/331.png
# 输出的单张图片已保存到：test_from_dir7/332.png
# 输出的单张图片已保存到：test_from_dir7/333.png
# 输出的单张图片已保存到：test_from_dir7/334.png
# 输出的单张图片已保存到：test_from_dir7/335.png
# 输出的单张图片已保存到：test_from_dir7/336.png
# 输出的单张图片已保存到：test_from_dir7/337.png
# 输出的单张图片已保存到：test_from_dir7/338.png
# 输出的单张图片已保存到：test_from_dir7/339.png
# 输出的单张图片已保存到：test_from_dir7/340.png
# 输出的单张图片已保存到：test_from_dir7/341.png
# 输出的单张图片已保存到：test_from_dir7/342.png
# 输出的单张图片已保存到：test_from_dir7/343.png
# 输出的单张图片已保存到：test_from_dir7/344.png
# 输出的单张图片已保存到：test_from_dir7/345.png
# 输出的单张图片已保存到：test_from_dir7/346.png
# 输出的单张图片已保存到：test_from_dir7/347.png
# 输出的单张图片已保存到：test_from_dir7/348.png
# 输出的单张图片已保存到：test_from_dir7/349.png
# 输出的单张图片已保存到：test_from_dir7/350.png
# 输出的单张图片已保存到：test_from_dir7/351.png
# 输出的单张图片已保存到：test_from_dir7/352.png
# 输出的单张图片已保存到：test_from_dir7/353.png
# 输出的单张图片已保存到：test_from_dir7/354.png
# 输出的单张图片已保存到：test_from_dir7/355.png
# 输出的单张图片已保存到：test_from_dir7/356.png
# 输出的单张图片已保存到：test_from_dir7/357.png
# 输出的单张图片已保存到：test_from_dir7/358.png
# 输出的单张图片已保存到：test_from_dir7/359.png
# 输出的单张图片已保存到：test_from_dir7/360.png
# 输出的单张图片已保存到：test_from_dir7/361.png
# 输出的单张图片已保存到：test_from_dir7/362.png
# 输出的单张图片已保存到：test_from_dir7/363.png
# 输出的单张图片已保存到：test_from_dir7/364.png
# 输出的单张图片已保存到：test_from_dir7/365.png
# 输出的单张图片已保存到：test_from_dir7/366.png
# 输出的单张图片已保存到：test_from_dir7/367.png
# 输出的单张图片已保存到：test_from_dir7/368.png
# 输出的单张图片已保存到：test_from_dir7/369.png
# 输出的单张图片已保存到：test_from_dir7/370.png
# 输出的单张图片已保存到：test_from_dir7/371.png
# 输出的单张图片已保存到：test_from_dir7/372.png
# 输出的单张图片已保存到：test_from_dir7/373.png
# 输出的单张图片已保存到：test_from_dir7/374.png
# 输出的单张图片已保存到：test_from_dir7/375.png
# 输出的单张图片已保存到：test_from_dir7/376.png
# 输出的单张图片已保存到：test_from_dir7/377.png
# 输出的单张图片已保存到：test_from_dir7/378.png
# 输出的单张图片已保存到：test_from_dir7/379.png
# 输出的单张图片已保存到：test_from_dir7/380.png
# 输出的单张图片已保存到：test_from_dir7/381.png
# 输出的单张图片已保存到：test_from_dir7/382.png
# 输出的单张图片已保存到：test_from_dir7/383.png
# 输出的单张图片已保存到：test_from_dir7/384.png
# 输出的单张图片已保存到：test_from_dir7/385.png
# 输出的单张图片已保存到：test_from_dir7/386.png
# 输出的单张图片已保存到：test_from_dir7/387.png
# 输出的单张图片已保存到：test_from_dir7/388.png
# 输出的单张图片已保存到：test_from_dir7/389.png
# 输出的单张图片已保存到：test_from_dir7/390.png
# 输出的单张图片已保存到：test_from_dir7/391.png
# 输出的单张图片已保存到：test_from_dir7/392.png
# 输出的单张图片已保存到：test_from_dir7/393.png
# 输出的单张图片已保存到：test_from_dir7/394.png
# 输出的单张图片已保存到：test_from_dir7/395.png
# 输出的单张图片已保存到：test_from_dir7/396.png
# 输出的单张图片已保存到：test_from_dir7/397.png
# 输出的单张图片已保存到：test_from_dir7/398.png
# 输出的单张图片已保存到：test_from_dir7/399.png
# 输出的单张图片已保存到：test_from_dir7/400.png
# 输出的单张图片已保存到：test_from_dir7/401.png
# 输出的单张图片已保存到：test_from_dir7/402.png
# 输出的单张图片已保存到：test_from_dir7/403.png
# 输出的单张图片已保存到：test_from_dir7/404.png
# 输出的单张图片已保存到：test_from_dir7/405.png
# 输出的单张图片已保存到：test_from_dir7/406.png
# 输出的单张图片已保存到：test_from_dir7/407.png
# 输出的单张图片已保存到：test_from_dir7/408.png
# 输出的单张图片已保存到：test_from_dir7/409.png
# 输出的单张图片已保存到：test_from_dir7/410.png
# 输出的单张图片已保存到：test_from_dir7/411.png
# 输出的单张图片已保存到：test_from_dir7/412.png
# 输出的单张图片已保存到：test_from_dir7/413.png
# 输出的单张图片已保存到：test_from_dir7/414.png
# 输出的单张图片已保存到：test_from_dir7/415.png
# 输出的单张图片已保存到：test_from_dir7/416.png
# 输出的单张图片已保存到：test_from_dir7/417.png
# 输出的单张图片已保存到：test_from_dir7/418.png
# 输出的单张图片已保存到：test_from_dir7/419.png
# 输出的单张图片已保存到：test_from_dir7/420.png
# 输出的单张图片已保存到：test_from_dir7/421.png
# 输出的单张图片已保存到：test_from_dir7/422.png
# 输出的单张图片已保存到：test_from_dir7/423.png
# 输出的单张图片已保存到：test_from_dir7/424.png
# 输出的单张图片已保存到：test_from_dir7/425.png
# 输出的单张图片已保存到：test_from_dir7/426.png
# 输出的单张图片已保存到：test_from_dir7/427.png
# 输出的单张图片已保存到：test_from_dir7/428.png
# 输出的单张图片已保存到：test_from_dir7/429.png
# 输出的单张图片已保存到：test_from_dir7/430.png
# 输出的单张图片已保存到：test_from_dir7/431.png
# 输出的单张图片已保存到：test_from_dir7/432.png
# 输出的单张图片已保存到：test_from_dir7/433.png
# 输出的单张图片已保存到：test_from_dir7/434.png
# 输出的单张图片已保存到：test_from_dir7/435.png
# 输出的单张图片已保存到：test_from_dir7/436.png
# 输出的单张图片已保存到：test_from_dir7/437.png
# 输出的单张图片已保存到：test_from_dir7/438.png
# 输出的单张图片已保存到：test_from_dir7/439.png
# 输出的单张图片已保存到：test_from_dir7/440.png
# 输出的单张图片已保存到：test_from_dir7/441.png
# 输出的单张图片已保存到：test_from_dir7/442.png
# 输出的单张图片已保存到：test_from_dir7/443.png
# 输出的单张图片已保存到：test_from_dir7/444.png
# 输出的单张图片已保存到：test_from_dir7/445.png
# 输出的单张图片已保存到：test_from_dir7/446.png
# 输出的单张图片已保存到：test_from_dir7/447.png
# 输出的单张图片已保存到：test_from_dir7/448.png
# 输出的单张图片已保存到：test_from_dir7/449.png
# 输出的单张图片已保存到：test_from_dir7/450.png
# 输出的单张图片已保存到：test_from_dir7/451.png
# 输出的单张图片已保存到：test_from_dir7/452.png
# 输出的单张图片已保存到：test_from_dir7/453.png
# 输出的单张图片已保存到：test_from_dir7/454.png
# 输出的单张图片已保存到：test_from_dir7/455.png
# 输出的单张图片已保存到：test_from_dir7/456.png
# 输出的单张图片已保存到：test_from_dir7/457.png
# 输出的单张图片已保存到：test_from_dir7/458.png
# 输出的单张图片已保存到：test_from_dir7/459.png
# 输出的单张图片已保存到：test_from_dir7/460.png
# 输出的单张图片已保存到：test_from_dir7/461.png
# 输出的单张图片已保存到：test_from_dir7/462.png
# 输出的单张图片已保存到：test_from_dir7/463.png
# 输出的单张图片已保存到：test_from_dir7/464.png
# 输出的单张图片已保存到：test_from_dir7/465.png
# 输出的单张图片已保存到：test_from_dir7/466.png
# 输出的单张图片已保存到：test_from_dir7/467.png
# 输出的单张图片已保存到：test_from_dir7/468.png
# 输出的单张图片已保存到：test_from_dir7/469.png
# 输出的单张图片已保存到：test_from_dir7/470.png
# 输出的单张图片已保存到：test_from_dir7/471.png
# 输出的单张图片已保存到：test_from_dir7/472.png
# 输出的单张图片已保存到：test_from_dir7/473.png
# 输出的单张图片已保存到：test_from_dir7/474.png
# 输出的单张图片已保存到：test_from_dir7/475.png
# 输出的单张图片已保存到：test_from_dir7/476.png
# 输出的单张图片已保存到：test_from_dir7/477.png
# 输出的单张图片已保存到：test_from_dir7/478.png
# 输出的单张图片已保存到：test_from_dir7/479.png
# 输出的单张图片已保存到：test_from_dir7/480.png
# 输出的单张图片已保存到：test_from_dir7/481.png
# 输出的单张图片已保存到：test_from_dir7/482.png
# 输出的单张图片已保存到：test_from_dir7/483.png
# 输出的单张图片已保存到：test_from_dir7/484.png
# 输出的单张图片已保存到：test_from_dir7/485.png
# 输出的单张图片已保存到：test_from_dir7/486.png
# 输出的单张图片已保存到：test_from_dir7/487.png
# 输出的单张图片已保存到：test_from_dir7/488.png
# 输出的单张图片已保存到：test_from_dir7/489.png
# 输出的单张图片已保存到：test_from_dir7/490.png
# 输出的单张图片已保存到：test_from_dir7/491.png
# 输出的单张图片已保存到：test_from_dir7/492.png
# 输出的单张图片已保存到：test_from_dir7/493.png
# 输出的单张图片已保存到：test_from_dir7/494.png
# 输出的单张图片已保存到：test_from_dir7/495.png
# 输出的单张图片已保存到：test_from_dir7/496.png
# 输出的单张图片已保存到：test_from_dir7/497.png
# 输出的单张图片已保存到：test_from_dir7/498.png
# 输出的单张图片已保存到：test_from_dir7/499.png
# 输出的单张图片已保存到：test_from_dir7/500.png

# %%
# 查看部分生成图片
plt.figure(figsize=(12,12))
for i in range(16):
    plt.subplot(4, 4, i + 1)
    if c == 3:
        fake_images[i] = cv.cvtColor(fake_images[i], cv.COLOR_BGR2RGB)
    plt.imshow(fake_images[i])
    plt.axis('off')
plt.show()
