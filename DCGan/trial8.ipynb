# %%
import sys, os
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow.keras import datasets, optimizers, metrics, layers, Sequential, Model, Input, losses
from load_datasets import DataLoader
import time

# %%
os.environ['KMP_DUPLICATE_LIB_OK']='True'  #防止训练过程中的kernel发生crash的情形

# %%
# 卷积层的生成器和鉴别器
def generator_network_dcgan(h, w, c, noise_dim=100):  # 输入噪声和标签，输出假图
    h_, w_ = h // 8, w // 8
    input_noise = Input(shape=(noise_dim,))  # (b,100)
    x = layers.Dense(h_ * w_ * 256)(input_noise)  #全连接层用于调整噪声的维度
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = tf.keras.activations.gelu(x,approximate=False)
    x = layers.Reshape((h_, w_, 256))(x)  # (b,h/4,w/4,256)
    
    x = layers.Conv2DTranspose(128, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/2,w/2,256)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = tf.keras.activations.gelu(x,approximate=False)

    x = layers.Conv2DTranspose(64, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/2,w/2,128)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = tf.keras.activations.gelu(x,approximate=False)

    x = layers.Conv2DTranspose(32, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h,w,64)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = tf.keras.activations.gelu(x,approximate=False)
    x = layers.Conv2DTranspose(c, (3, 3), padding='same', activation='tanh')(x)  # (b,h,w,c)
    generator = Model(input_noise, x)
    return generator

# %%
def discriminator_network_dcgan(h, w, c):  # 输入图片和标签，输出待验证的值。输出1为真，0为假
    input_image = Input(shape=(h, w, c))  # (b,h,w,c)
    x = layers.Conv2D(32, (3, 3), strides=(2, 2), padding='same')(input_image)  # (b,h/2,w/2,64)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = tf.keras.activations.gelu(x,approximate=False)
    x = layers.Dropout(0.3)(x)  #改进：在鉴别器的层之间添加dropout

    x = layers.Conv2D(64, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/4,w/4,128)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = tf.keras.activations.gelu(x,approximate=False)
    x = layers.Dropout(0.3)(x)

    x = layers.Conv2D(128, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/4,w/4,256)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = tf.keras.activations.gelu(x,approximate=False)
    x = layers.Dropout(0.3)(x)
    
    x = layers.Conv2D(256, (3, 3), strides=(2, 2), padding='same')(x)  # (b,h/4,w/4,512)
    x = layers.BatchNormalization(momentum=0.8)(x)
    x = tf.keras.activations.gelu(x,approximate=False)
    x = layers.Dropout(0.3)(x)

    x = layers.Flatten()(x)  # (b,h/4*w/4*512)
    validity = layers.Dense(1, activation=None)(x)  # (b,1) 最后一层，flatten后全连接层

    discriminator = Model(input_image, validity)
    return discriminator

# %%
# WGAN-GP梯度控制函数
def gradient_penalty(discriminator, batch_x, fake_image):
    #梯度惩罚项计算函数
    batchsz = batch_x.shape[0]

    #每个样本均随机采样t,用于插值
    t = tf.random.uniform([batchsz,1,1,1])
    #自动扩展为x的形状:[b,1,1,1] => [b,h,w,c]
    t = tf.broadcast_to(t, batch_x.shape)
    #在真假图片之间作线性插值
    interplate = t * batch_x + (1-t) * fake_image
    #在梯度环境中计算 D 对插值样本的梯度
    with tf.GradientTape() as tape:
        tape.watch([interplate])
        d_interplate_logits = discriminator(interplate)

        grads = tape.gradient(d_interplate_logits, interplate)

        #计算每个样本的梯度的范数:[b,h,w,c] => [b,-1]
        grads = tf.reshape(grads, [grads.shape[0],-1])
        gp = tf.norm(grads,axis=1)
        #计算梯度惩罚项
        gp = tf.reduce_mean((gp-1.)**2)

    return gp

# %%
def save_image(fake_image, fake_label=None, fake_num=16, save_to=''):  # X为4维的带批次的图片
    ''' 
    用于保存图片的函数
    '''
    plt.figure()
    _, h, w, c = fake_image.shape  #设定生成假图的shape（128*128*3）
    if fake_num > 1:
        for i in range(fake_num):
            plt.subplot(4, 4, i + 1)  #训练过程中的迭代以4*4=16（一次保存16张图片）
            if c == 3:  # 如果是bgr则转为rgb（通道的转换）
                plt.imshow(cv.cvtColor(fake_image[i], cv.COLOR_BGR2RGB))  #对于一般格式与BGR格式都予以显示
            if c == 1:  # 如果是灰图则显示灰图
                plt.imshow(np.squeeze(fake_image[i]), cmap='gray')
            if fake_label is not None:  # 如果有标签则传入标签（这是为了在真图与假图之间鉴别时用）
                plt.title(fake_label[i])
            plt.axis('off')
        plt.savefig(save_to)
        plt.close()
    else:  # fake_num=1时保存单张图片，否则按照多张图片的格式保存
        cv.imwrite(save_to, fake_image[0])
    print('输出图片已保存至:%s' % save_to)

# %%
def creat_dir(path):  #用于生成迭代过程中的图片以及保存后续生成的图像
    os.makedirs(path, exist_ok=True)

# %%
print('tf版本：', tf.__version__)
# 定义参数
batch_size = 5  # 每次训练的批次（太大可能会显存不够而报错，故在这里选择较小的值）
epochs = 200000  # 共迭代训练几次
g_lr = 0.0005  # 生成器学习率
d_lr = 0.0002  # 鉴别器学习率
fake_num = 16  # 生成的图片的个数（一般不改）
dataset_name = 'female'  # 数据集的名字  star_imgs  female  cat_vs_dog
h, w, c = 256, 256, 3  # 数据集图片的宽和高，也是生成图片的宽和高
noise_dim = 100  # 输入噪声的维度（一般不改）
save_step = 1000  # 每隔几次保存一次中间结果图和权重。如果是0，则不保存中间结果图和权重
# Out:
# tf版本： 2.7.0

# %%
# 创建文件夹
directory = './checkpoint8/' + dataset_name + '_%s×%s' % (h, w)  # 输出参数保存的文件夹，一般不改
image_dir = './result_image8/' + dataset_name + '_%s×%s' % (h, w)  # 输出图片保存的文件夹，一般不改
os.makedirs(directory, exist_ok=True)
os.makedirs(image_dir, exist_ok=True)
image_names = os.listdir(image_dir)

# %%
# 加载数据集和预处理
dataloader = DataLoader(dir_path=r'./datasets/%s' % dataset_name, dataset_name=dataset_name,
                        norm_range=(-1, 1), img_res=(h, w))
x_train = dataloader.load_datasets()  # 加载数据集
print('正在加载数据集...')
# Out:
# ./datasets/female [] ['3581.png', '2229.png', '6064.png', '5866.png', '5862.png', '1389.png', '3461.png', '900.png', '9765.png', '8475.png', '5627.png', '5139.png', '4985.png', '7784.png', '3012.png', '3389.png', '4843.png', '3413.png', '7193.png', '1089.png', '4793.png', '6679.png', '3993.png', '2812.png', '2142.png', '7656.png', '1783.png', '7585.png', '290.png', '4288.png', '31.png', '974.png', '35.png', '3906.png', '5631.png', '5011.png', '9335.png', '2942.png', '1351.png', '9682.png', '3494.png', '4380.png', '328.png', '7394.png', '3063.png', '690.png', '9701.png', '3106.png', '8176.png', '2781.png', '6031.png', '4497.png', '1956.png', '4605.png', '8624.png', '798.png', '923.png', '182.png', '6813.png', '5794.png', '4484.png', '3798.png', '3522.png', '465.png', '7378.png', '8646.png', '8148.png', '7139.png', '6317.png', '5906.png', '5643.png', '2543.png', '5478.png', '8035.png', '5221.png', '925.png', '865.png', '3924.png', '7136.png', '7289.png', '4425.png', '8614.png', '4277.png', '3361.png', '8961.png', '153.png', '1669.png', '3024.png', '5000.png', '5515.png', '4149.png', '1064.png', '5858.png', '3279.png', '1961.png', '2173.png', '3962.png', '277.png', '5542.png', '7532.png', '4301.png', '2982.png', '374.png', '2856.png', '1319.png', '5433.png', '9198.png', '3122.png', '9615.png', '9354.png', '4658.png', '6984.png', '4343.png', '6706.png', '4795.png', '8623.png', '8136.png', '4716.png', '834.png', '7025.png', '3256.png', '9525.png', '8487.png', '1032.png', '8364.png', '7347.png', '8257.png', '1816.png', '2426.png', '4148.png', '7684.png', '315.png', '1087.png', '7676.png', '49.png', '867.png', '8617.png', '7902.png', '1429.png', '2553.png', '1470.png', '1168.png', '8907.png', '9689.png', '187.png', '7828.png', '7319.png', '2595.png', '9268.png', '6274.png', '4977.png', '2427.png', '525.png', '8654.png', '5309.png', '4753.png', '4736.png', '3518.png', '6644.png', '6740.png', '9041.png', '4021.png', '6066.png', '484.png', '9748.png', '5679.png', '5705.png', '6728.png', '8096.png', '125.png', '2445.png', '2881.png', '5271.png', '5874.png', '2435.png', '8962.png', '9133.png', '250.png', '3432.png', '717.png', '8489.png', '2161.png', '5590.png', '8362.png', '4376.png', '6523.png', '8719.png', '7579.png', '589.png', '9777.png', '5811.png', '6833.png', '5200.png', '1146.png', '4773.png', '3597.png', '9163.png', '8902.png', '835.png', '4070.png', '4876.png', '8914.png', '642.png', '1423.png', '6290.png', '5346.png', '5625.png', '4491.png', '2439.png', '6059.png', '8451.png', '2233.png', '5920.png', '5981.png', '1649.png', '9565.png', '8412.png', '7340.png', '6430.png', '9564.png', '3125.png', '8145.png', '7079.png', '5153.png', '548.png', '5545.png', '7685.png', '1542.png', '6105.png', '1550.png', '6252.png', '3379.png', '9995.png', '8047.png', '5618.png', '1889.png', '3317.png', '9022.png', '6941.png', '2268.png', '4759.png', '118.png', '2137.png', '8682.png', '9971.png', '5599.png', '9854.png', '8286.png', '3033.png', '9687.png', '349.png', '1977.png', '8029.png', '2513.png', '6666.png', '6178.png', '2576.png', '4608.png', '7493.png', '6655.png', '1023.png', '6088.png', '8246.png', '2507.png', '7478.png', '7912.png', '4094.png', '5548.png', '8073.png', '2953.png', '7923.png', '5126.png', '8082.png', '3768.png', '9849.png', '3147.png', '2219.png', '8518.png', '830.png', '2691.png', '3276.png', '5114.png', '1033.png', '6301.png', '5379.png', '7488.png', '7406.png', '3935.png', '5763.png', '7332.png', '475.png', '6920.png', '4241.png', '5350.png', '3584.png', '4159.png', '8187.png', '2769.png', '8447.png', '9875.png', '426.png', '6351.png', '6593.png', '391.png', '3684.png', '9578.png', '1241.png', '7854.png', '1503.png', '2521.png', '9810.png', '3186.png', '2438.png', '12.png', '84.png', '3782.png', '3142.png', '4664.png', '4954.png', '3599.png', '5999.png', '5203.png', '7935.png', '4104.png', '2625.png', '5745.png', '6952.png', '9731.png', '5256.png', '7712.png', '850.png', '7187.png', '2004.png', '2132.png', '9473.png', '9 ...
# ['./datasets/female/3581.png' './datasets/female/2229.png'
#  './datasets/female/6064.png' ... './datasets/female/7223.png'
#  './datasets/female/5801.png' './datasets/female/9387.png']
# 正在加载数据集...

# %%
# 加载网络
generator = generator_network_dcgan(h, w, c, noise_dim=noise_dim)
discriminator = discriminator_network_dcgan(h, w, c)
# generator.summary()
# discriminator.summary()

# 如果采用Gelu作为激活函数，最好使用带动量的方法进行训练
g_optimizer = optimizers.Adam(lr=g_lr, beta_1=0.5)
d_optimizer = optimizers.Adam(lr=d_lr, beta_1=0.5)

# 设置随机种植可以让产生的图片不变，之后取消随机数种子
tf.random.set_seed(0)
noise_test = tf.random.normal([fake_num, noise_dim])
tf.random.set_seed(None)
# Out:
# 2022-12-24 22:08:29.246778: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-24 22:08:29.607737: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22308 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:50:00.0, compute capability: 8.6
# /usr/local/lib/python3.8/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
generator.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  dense (Dense)               (None, 262144)            26476544
#
#  batch_normalization (BatchN  (None, 262144)           1048576
#  ormalization)
#
#  tf.nn.gelu (TFOpLambda)     (None, 262144)            0
#
#  reshape (Reshape)           (None, 32, 32, 256)       0
#
#  conv2d_transpose (Conv2DTra  (None, 64, 64, 128)      295040
#  nspose)
#
#  batch_normalization_1 (Batc  (None, 64, 64, 128)      512
#  hNormalization)
#
#  tf.nn.gelu_1 (TFOpLambda)   (None, 64, 64, 128)       0
#
#  conv2d_transpose_1 (Conv2DT  (None, 128, 128, 64)     73792
#  ranspose)
#
#  batch_normalization_2 (Batc  (None, 128, 128, 64)     256
#  hNormalization)
#
#  tf.nn.gelu_2 (TFOpLambda)   (None, 128, 128, 64)      0
#
#  conv2d_transpose_2 (Conv2DT  (None, 256, 256, 32)     18464
#  ranspose)
#
#  batch_normalization_3 (Batc  (None, 256, 256, 32)     128
#  hNormalization)
#
#  tf.nn.gelu_3 (TFOpLambda)   (None, 256, 256, 32)      0
#
#  conv2d_transpose_3 (Conv2DT  (None, 256, 256, 3)      867
#  ranspose)
#
# =================================================================
# Total params: 27,914,179
# Trainable params: 27,389,443
# Non-trainable params: 524,736
# _________________________________________________________________

# %%
discriminator.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv2d (Conv2D)             (None, 128, 128, 32)      896
#
#  batch_normalization_4 (Batc  (None, 128, 128, 32)     128
#  hNormalization)
#
#  tf.nn.gelu_4 (TFOpLambda)   (None, 128, 128, 32)      0
#
#  dropout (Dropout)           (None, 128, 128, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        18496
#
#  batch_normalization_5 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  tf.nn.gelu_5 (TFOpLambda)   (None, 64, 64, 64)        0
#
#  dropout_1 (Dropout)         (None, 64, 64, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       73856
#
#  batch_normalization_6 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  tf.nn.gelu_6 (TFOpLambda)   (None, 32, 32, 128)       0
#
#  dropout_2 (Dropout)         (None, 32, 32, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)       295168
#
#  batch_normalization_7 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  tf.nn.gelu_7 (TFOpLambda)   (None, 16, 16, 256)       0
#
#  dropout_3 (Dropout)         (None, 16, 16, 256)       0
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense_1 (Dense)             (None, 1)                 65537
#
# =================================================================
# Total params: 455,873
# Trainable params: 454,913
# Non-trainable params: 960
# _________________________________________________________________

# %%
@tf.function  #tf.function用于加快运算速度
def train_step(x):
    # x = transform(x, dsize=(h, h), crop_size=(h, w))  # 使用随机裁剪
    # print('x:', x.shape)
    noise = tf.random.normal([x.shape[0], noise_dim])  # noise.shape=(b,100)
    with tf.GradientTape() as g_tape, tf.GradientTape() as d_tape:
        fake_image = generator(noise, training=True)  # (b, h, w, c)
        fake_out = discriminator(fake_image, training=True)  # (b, 1)
        real_out = discriminator(x, training=True)  # (b, 1)
        g_loss = tf.reduce_mean(
            losses.binary_crossentropy(y_true=tf.ones_like(fake_out), y_pred=fake_out, from_logits=True)) # 计算生成损失。此处换为MSE

        d1_loss = tf.reduce_mean(
            losses.binary_crossentropy(y_true=tf.ones_like(real_out), y_pred=real_out, from_logits=True))
        d2_loss = tf.reduce_mean(
            losses.binary_crossentropy(y_true=tf.zeros_like(fake_out), y_pred=fake_out, from_logits=True))  # 计算两个鉴别损失

        gp = gradient_penalty(discriminator, x, fake_image)  # 计算梯度惩罚项（wgan的内容，梯度控制）
        d_loss = d1_loss + d2_loss + 10.*gp
        #d_loss = d1_loss + d2_loss
    g_grads = g_tape.gradient(g_loss, generator.trainable_variables)
    d_grads = d_tape.gradient(d_loss, discriminator.trainable_variables)

    g_optimizer.apply_gradients(zip(g_grads, generator.trainable_variables))
    d_optimizer.apply_gradients(zip(d_grads, discriminator.trainable_variables))
    return [g_loss, d_loss]

# %%
# 创建保存参数
checkpoint = tf.train.Checkpoint(generator=generator,
                                 discriminator=discriminator)
checkpoint.restore(tf.train.latest_checkpoint(directory))  # 断点续训
manager = tf.train.CheckpointManager(checkpoint=checkpoint, directory=directory, max_to_keep=2,
                                     checkpoint_name=dataset_name)

max_num = max([int(image_name.split('.')[0][len(dataset_name):]) for image_name in image_names if
               image_name.endswith('png') or image_name.endswith('jpg')]) if image_names else 0  # 接着上次的往后保存

# %%
g_total_loss_list = []
d_total_loss_list = []

# 训练
print('数据加载完成，正在训练中...')
t1 = time.time()
for epoch in range(epochs):

    x_train = dataloader.load_batch(batch_size=batch_size)
    g_total_loss, d_total_loss = train_step(x_train)

    # 保存
    if save_step:
        if (epoch + 1) % save_step == 0 or epoch == 0:  # 每隔几个epoch保存一次
            fake_image = generator.predict(noise_test, batch_size=1)  # (b,h,w,c)
            fake_image = fake_image.reshape(-1, h, w, c) * 127.5 + 127.5  # (b,h,w,c)
            fake_image = np.clip(fake_image, 0, 255).astype('uint8')  # (b,h,w,c)
            save_to = image_dir + '/' + dataset_name + '%d.png' % (epoch + 1 + max_num)
            save_image(fake_image, fake_label=None, fake_num=fake_num, save_to=save_to)  # 保存图片
            manager.save(checkpoint_number=epoch + 1 + max_num)  # 保存参数
            g_total_loss_list.append(g_total_loss)
            d_total_loss_list.append(d_total_loss)  #每一定epoch后保存一次总损失值
            print('epoch:%d/%d:' % (epoch + 1 + max_num, epochs),
                  'g_total_loss:%.6f' % np.mean(g_total_loss),
                  'd_total_loss:%.6f' % np.mean(d_total_loss), '用时:%.6f' % (time.time() - t1))
            t1 = time.time()
    if epoch + 1 + max_num >= epochs:
        print('已跑完%s次' % epochs)
        break
manager.save(checkpoint_number=epochs)  # 训练完保存参数
# Out:
# 数据加载完成，正在训练中...
# 2022-12-24 22:08:44.191920: I tensorflow/stream_executor/cuda/cuda_blas.cc:1774] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2022-12-24 22:08:44.732084: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8101
# 输出图片已保存至:./result_image8/female_256×256/female1.png
# epoch:1/200000: g_total_loss:1.418534 d_total_loss:10.218303 用时:5.596165
# 输出图片已保存至:./result_image8/female_256×256/female1000.png
# epoch:1000/200000: g_total_loss:5.072258 d_total_loss:0.071889 用时:30.626669
# 输出图片已保存至:./result_image8/female_256×256/female2000.png
# epoch:2000/200000: g_total_loss:1.541509 d_total_loss:0.957589 用时:30.239771
# 输出图片已保存至:./result_image8/female_256×256/female3000.png
# epoch:3000/200000: g_total_loss:3.165554 d_total_loss:1.002685 用时:30.376608
# 输出图片已保存至:./result_image8/female_256×256/female4000.png
# epoch:4000/200000: g_total_loss:2.892559 d_total_loss:0.325022 用时:30.018231
# 输出图片已保存至:./result_image8/female_256×256/female5000.png
# epoch:5000/200000: g_total_loss:2.261774 d_total_loss:0.934655 用时:31.101156
# 输出图片已保存至:./result_image8/female_256×256/female6000.png
# epoch:6000/200000: g_total_loss:4.617194 d_total_loss:1.528519 用时:30.049309
# 输出图片已保存至:./result_image8/female_256×256/female7000.png
# epoch:7000/200000: g_total_loss:0.709768 d_total_loss:1.191738 用时:29.227248
# 输出图片已保存至:./result_image8/female_256×256/female8000.png
# epoch:8000/200000: g_total_loss:2.690825 d_total_loss:0.727001 用时:29.448286
# 输出图片已保存至:./result_image8/female_256×256/female9000.png
# epoch:9000/200000: g_total_loss:2.988803 d_total_loss:0.638541 用时:30.062311
# 输出图片已保存至:./result_image8/female_256×256/female10000.png
# epoch:10000/200000: g_total_loss:2.465214 d_total_loss:0.612422 用时:30.241490
# 输出图片已保存至:./result_image8/female_256×256/female11000.png
# epoch:11000/200000: g_total_loss:1.112474 d_total_loss:0.993873 用时:30.680997
# 输出图片已保存至:./result_image8/female_256×256/female12000.png
# epoch:12000/200000: g_total_loss:1.283005 d_total_loss:1.247225 用时:30.234049
# 输出图片已保存至:./result_image8/female_256×256/female13000.png
# epoch:13000/200000: g_total_loss:2.696031 d_total_loss:2.034769 用时:30.009302
# 输出图片已保存至:./result_image8/female_256×256/female14000.png
# epoch:14000/200000: g_total_loss:1.400245 d_total_loss:0.844061 用时:30.088103
# 输出图片已保存至:./result_image8/female_256×256/female15000.png
# epoch:15000/200000: g_total_loss:1.514102 d_total_loss:0.688674 用时:30.360337
# 输出图片已保存至:./result_image8/female_256×256/female16000.png
# epoch:16000/200000: g_total_loss:3.321912 d_total_loss:1.742336 用时:30.586628
# 输出图片已保存至:./result_image8/female_256×256/female17000.png
# epoch:17000/200000: g_total_loss:1.342329 d_total_loss:0.925877 用时:29.654132
# 输出图片已保存至:./result_image8/female_256×256/female18000.png
# epoch:18000/200000: g_total_loss:1.686041 d_total_loss:0.569341 用时:30.025713
# 输出图片已保存至:./result_image8/female_256×256/female19000.png
# epoch:19000/200000: g_total_loss:2.214960 d_total_loss:1.600093 用时:28.631409
# 输出图片已保存至:./result_image8/female_256×256/female20000.png
# epoch:20000/200000: g_total_loss:1.257942 d_total_loss:0.676337 用时:29.635286
# 输出图片已保存至:./result_image8/female_256×256/female21000.png
# epoch:21000/200000: g_total_loss:2.269063 d_total_loss:0.718129 用时:29.557952
# 输出图片已保存至:./result_image8/female_256×256/female22000.png
# epoch:22000/200000: g_total_loss:0.682032 d_total_loss:1.537619 用时:29.766102
# 输出图片已保存至:./result_image8/female_256×256/female23000.png
# epoch:23000/200000: g_total_loss:3.572990 d_total_loss:0.864668 用时:29.409922
# 输出图片已保存至:./result_image8/female_256×256/female24000.png
# epoch:24000/200000: g_total_loss:1.787407 d_total_loss:1.932480 用时:29.489234
# 输出图片已保存至:./result_image8/female_256×256/female25000.png
# epoch:25000/200000: g_total_loss:2.482162 d_total_loss:1.268421 用时:29.602657
# 输出图片已保存至:./result_image8/female_256×256/female26000.png
# epoch:26000/200000: g_total_loss:2.688340 d_total_loss:0.539669 用时:29.504423
# 输出图片已保存至:./result_image8/female_256×256/female27000.png
# epoch:27000/200000: g_total_loss:2.797322 d_total_loss:0.733003 用时:30.413953
# 输出图片已保存至:./result_image8/female_256×256/female28000.png
# epoch:28000/200000: g_total_loss:1.677285 d_total_loss:0.893028 用时:30.539987
# 输出图片已保存至:./result_image8/female_256×256/female29000.png
# epoch:29000/200000: g_total_loss:0.904715 d_total_loss:0.799701 用时:30.912095
# 输出图片已保存至:./result_image8/female_256×256/female30000.png
# epoch:30000/200000: g_total_loss:1.330710 d_total_loss:1.461565 用时:30.074791
# 输出图片已保存至:./result_image8/female_256×256/female31000.png
# epoch:31000/200000: g_total_loss:0.811163 d_total_loss:1.216835 用时:29.510847
# 输出图片已保存至:./result_image8/female_256×256/female32000.png
# epoch:32000/200000: g_total_loss:1.817307 d_total_loss:0.757151 用时:29.609295
# 输出图片已保存至:./result_image8/female_256×256/female33000.png
# epoch:33000/200000: g_total_loss:2.251939 d_total_loss:0.586613 用时:30.177739
# 输出图片已保存至:./result_image8/female_256×256/female34000.png
# epoch:34000/200000: g_total_loss:3.726520 d_total_loss:0.833692 用时:28.496954
# 输出图片已保存至:./result_image8/female_256×256/female35000.png
# epoch:35000/200000: g_total_loss:1.746914 d_total_loss:0.602018 用时:28.775593
# 输出图片已保存至:./result_image8/female_256×256/female36000.png
# epoch:36000/200000: g_total_loss:0.913861 d_total_loss:0.861604 用时:29.143988
# 输出图片已保存至:./result_image8/female_256×256/female37000.png
# epoch:37000/200000: g_total_loss:3.986180 d_total_loss:0.998540 用时:28.984395
# 输出图片已保存至:./result_image8/female_256×256/female38000.png
# epoch:38000/200000: g_total_loss:1.317222 d_total_loss:0.710566 用时:28.563048
# 输出图片已保存至:./result_image8/female_256×256/female39000.png
# epoch:39000/200000: g_total_loss:2.255656 d_total_loss:0.768145 用时:28.309877
# 输出图片已保存至:./result_image8/female_256×256/female40000.png
# epoch:40000/200000: g_total_loss:1.581754 d_total_loss:0.420213 用时:28.138836
# 输出图片已保存至:./result_image8/female_256×256/female41000.png
# epoch:41000/200000: g_total_loss:1.524076 d_total_loss:0.638036 用时:28.388717
# 输出图片已保存至:./result_image8/female_256×256/female42000.png
# epoch:42000/200000: g_total_loss:1.030756 d_total_loss:0.833729 用时:28.109355
# 输出图片已保存至:./result_image8/female_256×256/female43000.png
# epoch:43000/200000: g_total_loss:1.847149 d_total_loss:0.756546 用时:28.204025
# 输出图片已保存至:./result_image8/female_256×256/female44000.png
# epoch:44000/200000: g_total_loss:0.891866 d_total_loss:0.867626 用时:28.000480
# 输出图片已保存至:./result_image8/female_256×256/female45000.png
# epoch:45000/200000: g_total_loss:1.408847 d_total_loss:1.273134 用时:28.108921
# 输出图片已保存至:./result_image8/female_256×256/female46000.png
# epoch:46000/200000: g_total_loss:2.077338 d_total_loss:0.603516 用时:28.241747
# 输出图片已保存至:./result_image8/female_256×256/female47000.png
# epoch:47000/200000: g_total_loss:2.276042 d_total_loss:1.616275 用时:28.514796
# 输出图片已保存至:./result_image8/female_256×256/female48000.png
# epoch:48000/200000: g_total_loss:1.931549 d_total_loss:0.357810 用时:28.048151
# 输出图片已保存至:./result_image8/female_256×256/female49000.png
# epoch:49000/200000: g_total_loss:1.649501 d_total_loss:0.814605 用时:28.362290
# 输出图片已保存至:./result_image8/female_256×256/female50000.png
# epoch:50000/200000: g_total_loss:1.682719 d_total_loss:1.066141 用时:28.151762
# 输出图片已保存至:./result_image8/female_256×256/female51000.png
# epoch:51000/200000: g_total_loss:3.911789 d_total_loss:1.968480 用时:28.122393
# 输出图片已保存至:./result_image8/female_256×256/female52000.png
# epoch:52000/200000: g_total_loss:1.406002 d_total_loss:0.887655 用时:29.144252
# 输出图片已保存至:./result_image8/female_256×256/female53000.png
# epoch:53000/200000: g_total_loss:0.462140 d_total_loss:1.469615 用时:27.971771
# 输出图片已保存至:./result_image8/female_256×256/female54000.png
# epoch:54000/200000: g_total_loss:1.598004 d_total_loss:0.794253 用时:28.129594
# 输出图片已保存至:./result_image8/female_256×256/female55000.png
# epoch:55000/200000: g_total_loss:0.284353 d_total_loss:2.001977 用时:27.961768
# 输出图片已保存至:./result_image8/female_256×256/female56000.png
# epoch:56000/200000: g_total_loss:1.807112 d_total_loss:0.802118 用时:28.055429
# 输出图片已保存至:./result_image8/female_256×256/female57000.png
# epoch:57000/200000: g_total_loss:0.356416 d_total_loss:1.489092 用时:28.455660
# 输出图片已保存至:./result_image8/female_256×256/female58000.png
# epoch:58000/200000: g_total_loss:0.717481 d_total_loss:1.416710 用时:28.342090
# 输出图片已保存至:./result_image8/female_256×256/female59000.png
# epoch:59000/200000: g_total_loss:3.153585 d_total_loss:0.675195 用时:28.454378
# 输出图片已保存至:./result_image8/female_256×256/female60000.png
# epoch:60000/200000: g_total_loss:1.408726 d_total_loss:0.715887 用时:28.531853
# 输出图片已保存至:./result_image8/female_256×256/female61000.png
# epoch:61000/200000: g_total_loss:1.133072 d_total_loss:1.197701 用时:28.029696
# 输出图片已保存至:./result_image8/female_256×256/female62000.png
# epoch:62000/200000: g_total_loss:0.880760 d_total_loss:1.148518 用时:28.110939
# 输出图片已保存至:./result_image8/female_256×256/female63000.png
# epoch:63000/200000: g_total_loss:0.967019 d_total_loss:1.116264 用时:28.552880
# 输出图片已保存至:./result_image8/female_256×256/female64000.png
# epoch:64000/200000: g_total_loss:1.985220 d_total_loss:1.730449 用时:28.208664
# 输出图片已保存至:./result_image8/female_256×256/female65000.png
# epoch:65000/200000: g_total_loss:1.541538 d_total_loss:1.074986 用时:27.954934
# 输出图片已保存至:./result_image8/female_256×256/female66000.png
# epoch:66000/200000: g_total_loss:1.147561 d_total_loss:0.736943 用时:27.804314
# 输出图片已保存至:./result_image8/female_256×256/female67000.png
# epoch:67000/200000: g_total_loss:1.245820 d_total_loss:1.158361 用时:27.991511
# 输出图片已保存至:./result_image8/female_256×256/female68000.png
# epoch:68000/200000: g_total_loss:2.588591 d_total_loss:0.627695 用时:28.027758
# 输出图片已保存至:./result_image8/female_256×256/female69000.png
# epoch:69000/200000: g_total_loss:1.638872 d_total_loss:1.347868 用时:27.971410
# 输出图片已保存至:./result_image8/female_256×256/female70000.png
# epoch:70000/200000: g_total_loss:2.254060 d_total_loss:0.980486 用时:28.252024
# 输出图片已保存至:./result_image8/female_256×256/female71000.png
# epoch:71000/200000: g_total_loss:0.598080 d_total_loss:1.324648 用时:28.037468
# 输出图片已保存至:./result_image8/female_256×256/female72000.png
# epoch:72000/200000: g_total_loss:2.768944 d_total_loss:1.361891 用时:28.257991
# 输出图片已保存至:./result_image8/female_256×256/female73000.png
# epoch:73000/200000: g_total_loss:1.270090 d_total_loss:0.739714 用时:28.301613
# 输出图片已保存至:./result_image8/female_256×256/female74000.png
# epoch:74000/200000: g_total_loss:1.422252 d_total_loss:0.676619 用时:27.871655
# 输出图片已保存至:./result_image8/female_256×256/female75000.png
# epoch:75000/200000: g_total_loss:1.978865 d_total_loss:1.413324 用时:28.048219
# 输出图片已保存至:./result_image8/female_256×256/female76000.png
# epoch:76000/200000: g_total_loss:1.915941 d_total_loss:0.825582 用时:28.146369
# 输出图片已保存至:./result_image8/female_256×256/female77000.png
# epoch:77000/200000: g_total_loss:0.957153 d_total_loss:1.077234 用时:28.144627
# 输出图片已保存至:./result_image8/female_256×256/female78000.png
# epoch:78000/200000: g_total_loss:1.940872 d_total_loss:0.874465 用时:28.974272
# 输出图片已保存至:./result_image8/female_256×256/female79000.png
# epoch:79000/200000: g_total_loss:1.934335 d_total_loss:1.336088 用时:28.771015
# 输出图片已保存至:./result_image8/female_256×256/female80000.png
# epoch:80000/200000: g_total_loss:1.165498 d_total_loss:0.797940 用时:28.277398
# 输出图片已保存至:./result_image8/female_256×256/female81000.png
# epoch:81000/200000: g_total_loss:0.783740 d_total_loss:1.208507 用时:28.093168
# 输出图片已保存至:./result_image8/female_256×256/female82000.png
# epoch:82000/200000: g_total_loss:0.992985 d_total_loss:1.033269 用时:27.932304
# 输出图片已保存至:./result_image8/female_256×256/female83000.png
# epoch:83000/200000: g_total_loss:1.952400 d_total_loss:0.832056 用时:28.547869
# 输出图片已保存至:./result_image8/female_256×256/female84000.png
# epoch:84000/200000: g_total_loss:0.887558 d_total_loss:1.591971 用时:27.895561
# 输出图片已保存至:./result_image8/female_256×256/female85000.png
# epoch:85000/200000: g_total_loss:1.019655 d_total_loss:1.317901 用时:28.131168
# 输出图片已保存至:./result_image8/female_256×256/female86000.png
# epoch:86000/200000: g_total_loss:0.704287 d_total_loss:1.100146 用时:28.127804
# 输出图片已保存至:./result_image8/female_256×256/female87000.png
# epoch:87000/200000: g_total_loss:2.542093 d_total_loss:0.965156 用时:28.143865
# 输出图片已保存至:./result_image8/female_256×256/female88000.png
# epoch:88000/200000: g_total_loss:1.045409 d_total_loss:1.465046 用时:28.066435
# 输出图片已保存至:./result_image8/female_256×256/female89000.png
# epoch:89000/200000: g_total_loss:1.637396 d_total_loss:0.585535 用时:27.909182
# 输出图片已保存至:./result_image8/female_256×256/female90000.png
# epoch:90000/200000: g_total_loss:0.614139 d_total_loss:1.499423 用时:28.512305
# 输出图片已保存至:./result_image8/female_256×256/female91000.png
# epoch:91000/200000: g_total_loss:3.397950 d_total_loss:1.198739 用时:28.206586
# 输出图片已保存至:./result_image8/female_256×256/female92000.png
# epoch:92000/200000: g_total_loss:1.369645 d_total_loss:0.557674 用时:28.422816
# 输出图片已保存至:./result_image8/female_256×256/female93000.png
# epoch:93000/200000: g_total_loss:1.814154 d_total_loss:0.513682 用时:27.839511
# 输出图片已保存至:./result_image8/female_256×256/female94000.png
# epoch:94000/200000: g_total_loss:0.734068 d_total_loss:1.354319 用时:27.870607
# 输出图片已保存至:./result_image8/female_256×256/female95000.png
# epoch:95000/200000: g_total_loss:2.238051 d_total_loss:2.071215 用时:28.178571
# 输出图片已保存至:./result_image8/female_256×256/female96000.png
# epoch:96000/200000: g_total_loss:1.579624 d_total_loss:0.588087 用时:28.053500
# 输出图片已保存至:./result_image8/female_256×256/female97000.png
# epoch:97000/200000: g_total_loss:0.522588 d_total_loss:1.481874 用时:28.609555
# 输出图片已保存至:./result_image8/female_256×256/female98000.png
# epoch:98000/200000: g_total_loss:2.437314 d_total_loss:0.768471 用时:28.330876
# 输出图片已保存至:./result_image8/female_256×256/female99000.png
# epoch:99000/200000: g_total_loss:0.688898 d_total_loss:2.203540 用时:28.789675
# 输出图片已保存至:./result_image8/female_256×256/female100000.png
# epoch:100000/200000: g_total_loss:1.208936 d_total_loss:1.326540 用时:28.149126
# 输出图片已保存至:./result_image8/female_256×256/female101000.png
# epoch:101000/200000: g_total_loss:0.983717 d_total_loss:1.749346 用时:29.894362
# 输出图片已保存至:./result_image8/female_256×256/female102000.png
# epoch:102000/200000: g_total_loss:2.254232 d_total_loss:0.539759 用时:28.197978
# 输出图片已保存至:./result_image8/female_256×256/female103000.png
# epoch:103000/200000: g_total_loss:1.481727 d_total_loss:0.846102 用时:28.354069
# 输出图片已保存至:./result_image8/female_256×256/female104000.png
# epoch:104000/200000: g_total_loss:0.877670 d_total_loss:1.193847 用时:27.969121
# 输出图片已保存至:./result_image8/female_256×256/female105000.png
# epoch:105000/200000: g_total_loss:0.661237 d_total_loss:1.650735 用时:28.649050
# 输出图片已保存至:./result_image8/female_256×256/female106000.png
# epoch:106000/200000: g_total_loss:0.627955 d_total_loss:1.289560 用时:27.990031
# 输出图片已保存至:./result_image8/female_256×256/female107000.png
# epoch:107000/200000: g_total_loss:1.373210 d_total_loss:0.662125 用时:27.891151
# 输出图片已保存至:./result_image8/female_256×256/female108000.png
# epoch:108000/200000: g_total_loss:1.346785 d_total_loss:2.286575 用时:28.074438
# 输出图片已保存至:./result_image8/female_256×256/female109000.png
# epoch:109000/200000: g_total_loss:1.106144 d_total_loss:1.726699 用时:28.574703
# 输出图片已保存至:./result_image8/female_256×256/female110000.png
# epoch:110000/200000: g_total_loss:1.493093 d_total_loss:0.994672 用时:28.164551
# 输出图片已保存至:./result_image8/female_256×256/female111000.png
# epoch:111000/200000: g_total_loss:0.757307 d_total_loss:0.914851 用时:28.004488
# 输出图片已保存至:./result_image8/female_256×256/female112000.png
# epoch:112000/200000: g_total_loss:2.197483 d_total_loss:0.671266 用时:27.910501
# 输出图片已保存至:./result_image8/female_256×256/female113000.png
# epoch:113000/200000: g_total_loss:1.880307 d_total_loss:0.611495 用时:28.320583
# 输出图片已保存至:./result_image8/female_256×256/female114000.png
# epoch:114000/200000: g_total_loss:0.883871 d_total_loss:1.641340 用时:28.175529
# 输出图片已保存至:./result_image8/female_256×256/female115000.png
# epoch:115000/200000: g_total_loss:2.563262 d_total_loss:1.336310 用时:27.018812
# 输出图片已保存至:./result_image8/female_256×256/female116000.png
# epoch:116000/200000: g_total_loss:2.287828 d_total_loss:0.835382 用时:28.040319
# 输出图片已保存至:./result_image8/female_256×256/female117000.png
# epoch:117000/200000: g_total_loss:0.985254 d_total_loss:1.162377 用时:28.247252
# 输出图片已保存至:./result_image8/female_256×256/female118000.png
# epoch:118000/200000: g_total_loss:1.100494 d_total_loss:0.892509 用时:28.027889
# 输出图片已保存至:./result_image8/female_256×256/female119000.png
# epoch:119000/200000: g_total_loss:2.404868 d_total_loss:1.963299 用时:28.131207
# 输出图片已保存至:./result_image8/female_256×256/female120000.png
# epoch:120000/200000: g_total_loss:1.963287 d_total_loss:1.373410 用时:27.892130
# 输出图片已保存至:./result_image8/female_256×256/female121000.png
# epoch:121000/200000: g_total_loss:0.490073 d_total_loss:1.915744 用时:28.121312
# 输出图片已保存至:./result_image8/female_256×256/female122000.png
# epoch:122000/200000: g_total_loss:1.480430 d_total_loss:1.133645 用时:27.966639
# 输出图片已保存至:./result_image8/female_256×256/female123000.png
# epoch:123000/200000: g_total_loss:1.217474 d_total_loss:0.811663 用时:28.615260
# 输出图片已保存至:./result_image8/female_256×256/female124000.png
# epoch:124000/200000: g_total_loss:0.361204 d_total_loss:2.075237 用时:28.091278
# 输出图片已保存至:./result_image8/female_256×256/female125000.png
# epoch:125000/200000: g_total_loss:0.679128 d_total_loss:1.475825 用时:28.120560
# 输出图片已保存至:./result_image8/female_256×256/female126000.png
# epoch:126000/200000: g_total_loss:2.203827 d_total_loss:1.383548 用时:28.193623
# 输出图片已保存至:./result_image8/female_256×256/female127000.png
# epoch:127000/200000: g_total_loss:2.001041 d_total_loss:1.225048 用时:27.965585
# 输出图片已保存至:./result_image8/female_256×256/female128000.png
# epoch:128000/200000: g_total_loss:1.791146 d_total_loss:0.646155 用时:27.447836
# 输出图片已保存至:./result_image8/female_256×256/female129000.png
# epoch:129000/200000: g_total_loss:1.257438 d_total_loss:0.942688 用时:29.125018
# 输出图片已保存至:./result_image8/female_256×256/female130000.png
# epoch:130000/200000: g_total_loss:0.849863 d_total_loss:0.978896 用时:28.185965
# 输出图片已保存至:./result_image8/female_256×256/female131000.png
# epoch:131000/200000: g_total_loss:0.255656 d_total_loss:1.782554 用时:28.048016
# 输出图片已保存至:./result_image8/female_256×256/female132000.png
# epoch:132000/200000: g_total_loss:2.084695 d_total_loss:1.506579 用时:28.306953
# 输出图片已保存至:./result_image8/female_256×256/female133000.png
# epoch:133000/200000: g_total_loss:2.619644 d_total_loss:1.357865 用时:28.255950
# 输出图片已保存至:./result_image8/female_256×256/female134000.png
# epoch:134000/200000: g_total_loss:1.966277 d_total_loss:0.565561 用时:28.036578
# 输出图片已保存至:./result_image8/female_256×256/female135000.png
# epoch:135000/200000: g_total_loss:1.135588 d_total_loss:0.945175 用时:28.305557
# 输出图片已保存至:./result_image8/female_256×256/female136000.png
# epoch:136000/200000: g_total_loss:1.148915 d_total_loss:1.398344 用时:28.095989
# 输出图片已保存至:./result_image8/female_256×256/female137000.png
# epoch:137000/200000: g_total_loss:1.571227 d_total_loss:0.700743 用时:28.038780
# 输出图片已保存至:./result_image8/female_256×256/female138000.png
# epoch:138000/200000: g_total_loss:1.176953 d_total_loss:1.110265 用时:28.561510
# 输出图片已保存至:./result_image8/female_256×256/female139000.png
# epoch:139000/200000: g_total_loss:1.447666 d_total_loss:0.891369 用时:28.199887
# 输出图片已保存至:./result_image8/female_256×256/female140000.png
# epoch:140000/200000: g_total_loss:0.784230 d_total_loss:1.507727 用时:28.467705
# 输出图片已保存至:./result_image8/female_256×256/female141000.png
# epoch:141000/200000: g_total_loss:2.532278 d_total_loss:0.196384 用时:28.368339
# 输出图片已保存至:./result_image8/female_256×256/female142000.png
# epoch:142000/200000: g_total_loss:1.721952 d_total_loss:1.010391 用时:28.411730
# 输出图片已保存至:./result_image8/female_256×256/female143000.png
# epoch:143000/200000: g_total_loss:1.547149 d_total_loss:0.859249 用时:28.140590
# 输出图片已保存至:./result_image8/female_256×256/female144000.png
# epoch:144000/200000: g_total_loss:2.280756 d_total_loss:0.699568 用时:27.856132
# 输出图片已保存至:./result_image8/female_256×256/female145000.png
# epoch:145000/200000: g_total_loss:1.852953 d_total_loss:0.721345 用时:27.796986
# 输出图片已保存至:./result_image8/female_256×256/female146000.png
# epoch:146000/200000: g_total_loss:0.411968 d_total_loss:1.649314 用时:28.161549
# 输出图片已保存至:./result_image8/female_256×256/female147000.png
# epoch:147000/200000: g_total_loss:1.162560 d_total_loss:1.118785 用时:28.257618
# 输出图片已保存至:./result_image8/female_256×256/female148000.png
# epoch:148000/200000: g_total_loss:1.141874 d_total_loss:1.104317 用时:28.337447
# 输出图片已保存至:./result_image8/female_256×256/female149000.png
# epoch:149000/200000: g_total_loss:2.506157 d_total_loss:2.836244 用时:27.624940
# 输出图片已保存至:./result_image8/female_256×256/female150000.png
# epoch:150000/200000: g_total_loss:1.224001 d_total_loss:1.705945 用时:28.835668
# 输出图片已保存至:./result_image8/female_256×256/female151000.png
# epoch:151000/200000: g_total_loss:2.687151 d_total_loss:1.166010 用时:27.959295
# 输出图片已保存至:./result_image8/female_256×256/female152000.png
# epoch:152000/200000: g_total_loss:1.021408 d_total_loss:1.289505 用时:28.145716
# 输出图片已保存至:./result_image8/female_256×256/female153000.png
# epoch:153000/200000: g_total_loss:1.423825 d_total_loss:1.084560 用时:28.008715
# 输出图片已保存至:./result_image8/female_256×256/female154000.png
# epoch:154000/200000: g_total_loss:1.010271 d_total_loss:1.548414 用时:27.914056
# 输出图片已保存至:./result_image8/female_256×256/female155000.png
# epoch:155000/200000: g_total_loss:1.944357 d_total_loss:0.990873 用时:28.182277
# 输出图片已保存至:./result_image8/female_256×256/female156000.png
# epoch:156000/200000: g_total_loss:0.695256 d_total_loss:1.692367 用时:28.104995
# 输出图片已保存至:./result_image8/female_256×256/female157000.png
# epoch:157000/200000: g_total_loss:0.940989 d_total_loss:0.977354 用时:27.977201
# 输出图片已保存至:./result_image8/female_256×256/female158000.png
# epoch:158000/200000: g_total_loss:2.426758 d_total_loss:1.372414 用时:28.098596
# 输出图片已保存至:./result_image8/female_256×256/female159000.png
# epoch:159000/200000: g_total_loss:1.244451 d_total_loss:1.196539 用时:28.109051
# 输出图片已保存至:./result_image8/female_256×256/female160000.png
# epoch:160000/200000: g_total_loss:1.533742 d_total_loss:0.581992 用时:28.709069
# 输出图片已保存至:./result_image8/female_256×256/female161000.png
# epoch:161000/200000: g_total_loss:0.738153 d_total_loss:1.301492 用时:28.150928
# 输出图片已保存至:./result_image8/female_256×256/female162000.png
# epoch:162000/200000: g_total_loss:1.639123 d_total_loss:0.440563 用时:28.154773
# 输出图片已保存至:./result_image8/female_256×256/female163000.png
# epoch:163000/200000: g_total_loss:0.780179 d_total_loss:1.421978 用时:27.855136
# 输出图片已保存至:./result_image8/female_256×256/female164000.png
# epoch:164000/200000: g_total_loss:1.220150 d_total_loss:0.834376 用时:28.470656
# 输出图片已保存至:./result_image8/female_256×256/female165000.png
# epoch:165000/200000: g_total_loss:0.389447 d_total_loss:1.574480 用时:27.928439
# 输出图片已保存至:./result_image8/female_256×256/female166000.png
# epoch:166000/200000: g_total_loss:1.850787 d_total_loss:1.195284 用时:28.474074
# 输出图片已保存至:./result_image8/female_256×256/female167000.png
# epoch:167000/200000: g_total_loss:1.391896 d_total_loss:0.659774 用时:28.038138
# 输出图片已保存至:./result_image8/female_256×256/female168000.png
# epoch:168000/200000: g_total_loss:2.144333 d_total_loss:0.514821 用时:27.979680
# 输出图片已保存至:./result_image8/female_256×256/female169000.png
# epoch:169000/200000: g_total_loss:1.954989 d_total_loss:0.948571 用时:28.435131
# 输出图片已保存至:./result_image8/female_256×256/female170000.png
# epoch:170000/200000: g_total_loss:1.163894 d_total_loss:1.228974 用时:28.359605
# 输出图片已保存至:./result_image8/female_256×256/female171000.png
# epoch:171000/200000: g_total_loss:0.501597 d_total_loss:1.367074 用时:28.138557
# 输出图片已保存至:./result_image8/female_256×256/female172000.png
# epoch:172000/200000: g_total_loss:0.338958 d_total_loss:2.150807 用时:28.112267
# 输出图片已保存至:./result_image8/female_256×256/female173000.png
# epoch:173000/200000: g_total_loss:1.503265 d_total_loss:0.621138 用时:28.127288
# 输出图片已保存至:./result_image8/female_256×256/female174000.png
# epoch:174000/200000: g_total_loss:0.778858 d_total_loss:1.542911 用时:28.103478
# 输出图片已保存至:./result_image8/female_256×256/female175000.png
# epoch:175000/200000: g_total_loss:2.017558 d_total_loss:0.893395 用时:28.358879
# 输出图片已保存至:./result_image8/female_256×256/female176000.png
# epoch:176000/200000: g_total_loss:2.160065 d_total_loss:0.191051 用时:27.018604
# 输出图片已保存至:./result_image8/female_256×256/female177000.png
# epoch:177000/200000: g_total_loss:2.518789 d_total_loss:0.689296 用时:28.000031
# 输出图片已保存至:./result_image8/female_256×256/female178000.png
# epoch:178000/200000: g_total_loss:1.484498 d_total_loss:0.616458 用时:28.124592
# 输出图片已保存至:./result_image8/female_256×256/female179000.png
# epoch:179000/200000: g_total_loss:1.606160 d_total_loss:1.030262 用时:27.306946
# 输出图片已保存至:./result_image8/female_256×256/female180000.png
# epoch:180000/200000: g_total_loss:1.242142 d_total_loss:0.960709 用时:26.969917
# 输出图片已保存至:./result_image8/female_256×256/female181000.png
# epoch:181000/200000: g_total_loss:0.854852 d_total_loss:1.083022 用时:27.984000
# 输出图片已保存至:./result_image8/female_256×256/female182000.png
# epoch:182000/200000: g_total_loss:1.629434 d_total_loss:0.838412 用时:28.015636
# 输出图片已保存至:./result_image8/female_256×256/female183000.png
# epoch:183000/200000: g_total_loss:1.501776 d_total_loss:0.369828 用时:28.084430
# 输出图片已保存至:./result_image8/female_256×256/female184000.png
# epoch:184000/200000: g_total_loss:1.671037 d_total_loss:1.233446 用时:28.098466
# 输出图片已保存至:./result_image8/female_256×256/female185000.png
# epoch:185000/200000: g_total_loss:1.314180 d_total_loss:1.427440 用时:28.036495
# 输出图片已保存至:./result_image8/female_256×256/female186000.png
# epoch:186000/200000: g_total_loss:2.226060 d_total_loss:0.387607 用时:28.199140
# 输出图片已保存至:./result_image8/female_256×256/female187000.png
# epoch:187000/200000: g_total_loss:1.633959 d_total_loss:2.247337 用时:28.184967
# 输出图片已保存至:./result_image8/female_256×256/female188000.png
# epoch:188000/200000: g_total_loss:2.261179 d_total_loss:1.143766 用时:28.359340
# 输出图片已保存至:./result_image8/female_256×256/female189000.png
# epoch:189000/200000: g_total_loss:1.429698 d_total_loss:1.467640 用时:28.352948
# 输出图片已保存至:./result_image8/female_256×256/female190000.png
# epoch:190000/200000: g_total_loss:1.688211 d_total_loss:0.538143 用时:27.974547
# 输出图片已保存至:./result_image8/female_256×256/female191000.png
# epoch:191000/200000: g_total_loss:1.447401 d_total_loss:0.862117 用时:27.982751
# 输出图片已保存至:./result_image8/female_256×256/female192000.png
# epoch:192000/200000: g_total_loss:1.317469 d_total_loss:1.285388 用时:33.215820
# 输出图片已保存至:./result_image8/female_256×256/female193000.png
# epoch:193000/200000: g_total_loss:1.188148 d_total_loss:1.147416 用时:40.954317
# 输出图片已保存至:./result_image8/female_256×256/female194000.png
# epoch:194000/200000: g_total_loss:1.846782 d_total_loss:0.546184 用时:34.465233
# 输出图片已保存至:./result_image8/female_256×256/female195000.png
# epoch:195000/200000: g_total_loss:1.384433 d_total_loss:1.670026 用时:32.342879
# 输出图片已保存至:./result_image8/female_256×256/female196000.png
# epoch:196000/200000: g_total_loss:2.096282 d_total_loss:0.349600 用时:30.747242
# 输出图片已保存至:./result_image8/female_256×256/female197000.png
# epoch:197000/200000: g_total_loss:2.140642 d_total_loss:0.641969 用时:30.000135
# 输出图片已保存至:./result_image8/female_256×256/female198000.png
# epoch:198000/200000: g_total_loss:2.853552 d_total_loss:0.618419 用时:28.824950
# 输出图片已保存至:./result_image8/female_256×256/female199000.png
# epoch:199000/200000: g_total_loss:0.546902 d_total_loss:1.002779 用时:28.787270
# 输出图片已保存至:./result_image8/female_256×256/female200000.png
# epoch:200000/200000: g_total_loss:2.534424 d_total_loss:1.562270 用时:28.409387
# 已跑完200000次
# './checkpoint8/female_256×256/female-200000'

# %%
plt.figure(figsize = (12,8))
epochtime = np.arange(0,201000,1000)
plt.plot(epochtime,g_total_loss_list,color='red',marker='o',linestyle='-',linewidth=1)
plt.xlabel('training epoch')
plt.xticks(rotation=45) # 旋转90度
plt.ylabel('total loss of generator')
plt.title('total loss of generator changed by epoch times')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize = (12,8))
epochtime = np.arange(1000,201000,1000)
plt.plot(epochtime,d_total_loss_list[1:],color='blue',marker='o',linestyle='-',linewidth=1)
plt.xlabel('training epoch')
plt.xticks(rotation=45) # 旋转90度
plt.ylabel('total loss of discriminator')
plt.title('total loss of discriminator changed by epoch times')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
print("mean of total loss of generator: {:.6f}".format(np.mean(g_total_loss_list)))
print("mean of total loss of discriminator: {:.6f}".format(np.mean(d_total_loss_list)))
# Out:
# mean of total loss of generator: 1.628049
# mean of total loss of discriminator: 1.131328

# %%
# 定义参数
batch_size = 1  # 每次测试的批次（太大可能会显存不够而报错，可调小再试）
fake_num = 500  # 生成的图片的个数
dataset_name = 'female'  # 数据集的名字  star_imgs
h, w, c = 256, 256, 3  # 数据集图片的宽和高，也是生成图片的宽和高
noise_dim = 100  # 输入噪声的维度（一般不改）

# %%
# 创建文件夹
directory = './checkpoint8/' + dataset_name + '_%s×%s' % (h, w)  # 输出参数保存的文件夹，一般不改
image_dir = './result_image8/' + dataset_name + '_%s×%s' % (h, w)  # 输出图片保存的文件夹，一般不改

# %%
# 搭建网络
generator = generator_network_dcgan(h, w, c, noise_dim=noise_dim)
discriminator = discriminator_network_dcgan(h, w, c)
# 加载参数
checkpoint = tf.train.Checkpoint(generator=generator,
                                 discriminator=discriminator)
checkpoint.restore(tf.train.latest_checkpoint(directory))  # 断点续训
# 预测
# noise_test = tf.random.normal([fake_num, 100])
noise_test = tf.random.uniform([fake_num, noise_dim], -1, 1)
fake_images = generator.predict(noise_test, batch_size=batch_size)  # (b,h,w,c)
fake_images = (fake_images.reshape(-1, h, w, c) * 127.5 + 127.5).astype('uint8')  # (b,h,w,c)

# %%
# 保存生成的图片
os.makedirs('test_from_dir8', exist_ok=True)
for i, fake_image in enumerate(fake_images):
    # i+=5000
    save_path = os.path.join('test_from_dir8', '%s.png' % (i + 1))
    cv.imwrite(save_path, fake_image)
    print('输出的单张图片已保存到：%s' % save_path)
# Out:
# 输出的单张图片已保存到：test_from_dir8/1.png
# 输出的单张图片已保存到：test_from_dir8/2.png
# 输出的单张图片已保存到：test_from_dir8/3.png
# 输出的单张图片已保存到：test_from_dir8/4.png
# 输出的单张图片已保存到：test_from_dir8/5.png
# 输出的单张图片已保存到：test_from_dir8/6.png
# 输出的单张图片已保存到：test_from_dir8/7.png
# 输出的单张图片已保存到：test_from_dir8/8.png
# 输出的单张图片已保存到：test_from_dir8/9.png
# 输出的单张图片已保存到：test_from_dir8/10.png
# 输出的单张图片已保存到：test_from_dir8/11.png
# 输出的单张图片已保存到：test_from_dir8/12.png
# 输出的单张图片已保存到：test_from_dir8/13.png
# 输出的单张图片已保存到：test_from_dir8/14.png
# 输出的单张图片已保存到：test_from_dir8/15.png
# 输出的单张图片已保存到：test_from_dir8/16.png
# 输出的单张图片已保存到：test_from_dir8/17.png
# 输出的单张图片已保存到：test_from_dir8/18.png
# 输出的单张图片已保存到：test_from_dir8/19.png
# 输出的单张图片已保存到：test_from_dir8/20.png
# 输出的单张图片已保存到：test_from_dir8/21.png
# 输出的单张图片已保存到：test_from_dir8/22.png
# 输出的单张图片已保存到：test_from_dir8/23.png
# 输出的单张图片已保存到：test_from_dir8/24.png
# 输出的单张图片已保存到：test_from_dir8/25.png
# 输出的单张图片已保存到：test_from_dir8/26.png
# 输出的单张图片已保存到：test_from_dir8/27.png
# 输出的单张图片已保存到：test_from_dir8/28.png
# 输出的单张图片已保存到：test_from_dir8/29.png
# 输出的单张图片已保存到：test_from_dir8/30.png
# 输出的单张图片已保存到：test_from_dir8/31.png
# 输出的单张图片已保存到：test_from_dir8/32.png
# 输出的单张图片已保存到：test_from_dir8/33.png
# 输出的单张图片已保存到：test_from_dir8/34.png
# 输出的单张图片已保存到：test_from_dir8/35.png
# 输出的单张图片已保存到：test_from_dir8/36.png
# 输出的单张图片已保存到：test_from_dir8/37.png
# 输出的单张图片已保存到：test_from_dir8/38.png
# 输出的单张图片已保存到：test_from_dir8/39.png
# 输出的单张图片已保存到：test_from_dir8/40.png
# 输出的单张图片已保存到：test_from_dir8/41.png
# 输出的单张图片已保存到：test_from_dir8/42.png
# 输出的单张图片已保存到：test_from_dir8/43.png
# 输出的单张图片已保存到：test_from_dir8/44.png
# 输出的单张图片已保存到：test_from_dir8/45.png
# 输出的单张图片已保存到：test_from_dir8/46.png
# 输出的单张图片已保存到：test_from_dir8/47.png
# 输出的单张图片已保存到：test_from_dir8/48.png
# 输出的单张图片已保存到：test_from_dir8/49.png
# 输出的单张图片已保存到：test_from_dir8/50.png
# 输出的单张图片已保存到：test_from_dir8/51.png
# 输出的单张图片已保存到：test_from_dir8/52.png
# 输出的单张图片已保存到：test_from_dir8/53.png
# 输出的单张图片已保存到：test_from_dir8/54.png
# 输出的单张图片已保存到：test_from_dir8/55.png
# 输出的单张图片已保存到：test_from_dir8/56.png
# 输出的单张图片已保存到：test_from_dir8/57.png
# 输出的单张图片已保存到：test_from_dir8/58.png
# 输出的单张图片已保存到：test_from_dir8/59.png
# 输出的单张图片已保存到：test_from_dir8/60.png
# 输出的单张图片已保存到：test_from_dir8/61.png
# 输出的单张图片已保存到：test_from_dir8/62.png
# 输出的单张图片已保存到：test_from_dir8/63.png
# 输出的单张图片已保存到：test_from_dir8/64.png
# 输出的单张图片已保存到：test_from_dir8/65.png
# 输出的单张图片已保存到：test_from_dir8/66.png
# 输出的单张图片已保存到：test_from_dir8/67.png
# 输出的单张图片已保存到：test_from_dir8/68.png
# 输出的单张图片已保存到：test_from_dir8/69.png
# 输出的单张图片已保存到：test_from_dir8/70.png
# 输出的单张图片已保存到：test_from_dir8/71.png
# 输出的单张图片已保存到：test_from_dir8/72.png
# 输出的单张图片已保存到：test_from_dir8/73.png
# 输出的单张图片已保存到：test_from_dir8/74.png
# 输出的单张图片已保存到：test_from_dir8/75.png
# 输出的单张图片已保存到：test_from_dir8/76.png
# 输出的单张图片已保存到：test_from_dir8/77.png
# 输出的单张图片已保存到：test_from_dir8/78.png
# 输出的单张图片已保存到：test_from_dir8/79.png
# 输出的单张图片已保存到：test_from_dir8/80.png
# 输出的单张图片已保存到：test_from_dir8/81.png
# 输出的单张图片已保存到：test_from_dir8/82.png
# 输出的单张图片已保存到：test_from_dir8/83.png
# 输出的单张图片已保存到：test_from_dir8/84.png
# 输出的单张图片已保存到：test_from_dir8/85.png
# 输出的单张图片已保存到：test_from_dir8/86.png
# 输出的单张图片已保存到：test_from_dir8/87.png
# 输出的单张图片已保存到：test_from_dir8/88.png
# 输出的单张图片已保存到：test_from_dir8/89.png
# 输出的单张图片已保存到：test_from_dir8/90.png
# 输出的单张图片已保存到：test_from_dir8/91.png
# 输出的单张图片已保存到：test_from_dir8/92.png
# 输出的单张图片已保存到：test_from_dir8/93.png
# 输出的单张图片已保存到：test_from_dir8/94.png
# 输出的单张图片已保存到：test_from_dir8/95.png
# 输出的单张图片已保存到：test_from_dir8/96.png
# 输出的单张图片已保存到：test_from_dir8/97.png
# 输出的单张图片已保存到：test_from_dir8/98.png
# 输出的单张图片已保存到：test_from_dir8/99.png
# 输出的单张图片已保存到：test_from_dir8/100.png
# 输出的单张图片已保存到：test_from_dir8/101.png
# 输出的单张图片已保存到：test_from_dir8/102.png
# 输出的单张图片已保存到：test_from_dir8/103.png
# 输出的单张图片已保存到：test_from_dir8/104.png
# 输出的单张图片已保存到：test_from_dir8/105.png
# 输出的单张图片已保存到：test_from_dir8/106.png
# 输出的单张图片已保存到：test_from_dir8/107.png
# 输出的单张图片已保存到：test_from_dir8/108.png
# 输出的单张图片已保存到：test_from_dir8/109.png
# 输出的单张图片已保存到：test_from_dir8/110.png
# 输出的单张图片已保存到：test_from_dir8/111.png
# 输出的单张图片已保存到：test_from_dir8/112.png
# 输出的单张图片已保存到：test_from_dir8/113.png
# 输出的单张图片已保存到：test_from_dir8/114.png
# 输出的单张图片已保存到：test_from_dir8/115.png
# 输出的单张图片已保存到：test_from_dir8/116.png
# 输出的单张图片已保存到：test_from_dir8/117.png
# 输出的单张图片已保存到：test_from_dir8/118.png
# 输出的单张图片已保存到：test_from_dir8/119.png
# 输出的单张图片已保存到：test_from_dir8/120.png
# 输出的单张图片已保存到：test_from_dir8/121.png
# 输出的单张图片已保存到：test_from_dir8/122.png
# 输出的单张图片已保存到：test_from_dir8/123.png
# 输出的单张图片已保存到：test_from_dir8/124.png
# 输出的单张图片已保存到：test_from_dir8/125.png
# 输出的单张图片已保存到：test_from_dir8/126.png
# 输出的单张图片已保存到：test_from_dir8/127.png
# 输出的单张图片已保存到：test_from_dir8/128.png
# 输出的单张图片已保存到：test_from_dir8/129.png
# 输出的单张图片已保存到：test_from_dir8/130.png
# 输出的单张图片已保存到：test_from_dir8/131.png
# 输出的单张图片已保存到：test_from_dir8/132.png
# 输出的单张图片已保存到：test_from_dir8/133.png
# 输出的单张图片已保存到：test_from_dir8/134.png
# 输出的单张图片已保存到：test_from_dir8/135.png
# 输出的单张图片已保存到：test_from_dir8/136.png
# 输出的单张图片已保存到：test_from_dir8/137.png
# 输出的单张图片已保存到：test_from_dir8/138.png
# 输出的单张图片已保存到：test_from_dir8/139.png
# 输出的单张图片已保存到：test_from_dir8/140.png
# 输出的单张图片已保存到：test_from_dir8/141.png
# 输出的单张图片已保存到：test_from_dir8/142.png
# 输出的单张图片已保存到：test_from_dir8/143.png
# 输出的单张图片已保存到：test_from_dir8/144.png
# 输出的单张图片已保存到：test_from_dir8/145.png
# 输出的单张图片已保存到：test_from_dir8/146.png
# 输出的单张图片已保存到：test_from_dir8/147.png
# 输出的单张图片已保存到：test_from_dir8/148.png
# 输出的单张图片已保存到：test_from_dir8/149.png
# 输出的单张图片已保存到：test_from_dir8/150.png
# 输出的单张图片已保存到：test_from_dir8/151.png
# 输出的单张图片已保存到：test_from_dir8/152.png
# 输出的单张图片已保存到：test_from_dir8/153.png
# 输出的单张图片已保存到：test_from_dir8/154.png
# 输出的单张图片已保存到：test_from_dir8/155.png
# 输出的单张图片已保存到：test_from_dir8/156.png
# 输出的单张图片已保存到：test_from_dir8/157.png
# 输出的单张图片已保存到：test_from_dir8/158.png
# 输出的单张图片已保存到：test_from_dir8/159.png
# 输出的单张图片已保存到：test_from_dir8/160.png
# 输出的单张图片已保存到：test_from_dir8/161.png
# 输出的单张图片已保存到：test_from_dir8/162.png
# 输出的单张图片已保存到：test_from_dir8/163.png
# 输出的单张图片已保存到：test_from_dir8/164.png
# 输出的单张图片已保存到：test_from_dir8/165.png
# 输出的单张图片已保存到：test_from_dir8/166.png
# 输出的单张图片已保存到：test_from_dir8/167.png
# 输出的单张图片已保存到：test_from_dir8/168.png
# 输出的单张图片已保存到：test_from_dir8/169.png
# 输出的单张图片已保存到：test_from_dir8/170.png
# 输出的单张图片已保存到：test_from_dir8/171.png
# 输出的单张图片已保存到：test_from_dir8/172.png
# 输出的单张图片已保存到：test_from_dir8/173.png
# 输出的单张图片已保存到：test_from_dir8/174.png
# 输出的单张图片已保存到：test_from_dir8/175.png
# 输出的单张图片已保存到：test_from_dir8/176.png
# 输出的单张图片已保存到：test_from_dir8/177.png
# 输出的单张图片已保存到：test_from_dir8/178.png
# 输出的单张图片已保存到：test_from_dir8/179.png
# 输出的单张图片已保存到：test_from_dir8/180.png
# 输出的单张图片已保存到：test_from_dir8/181.png
# 输出的单张图片已保存到：test_from_dir8/182.png
# 输出的单张图片已保存到：test_from_dir8/183.png
# 输出的单张图片已保存到：test_from_dir8/184.png
# 输出的单张图片已保存到：test_from_dir8/185.png
# 输出的单张图片已保存到：test_from_dir8/186.png
# 输出的单张图片已保存到：test_from_dir8/187.png
# 输出的单张图片已保存到：test_from_dir8/188.png
# 输出的单张图片已保存到：test_from_dir8/189.png
# 输出的单张图片已保存到：test_from_dir8/190.png
# 输出的单张图片已保存到：test_from_dir8/191.png
# 输出的单张图片已保存到：test_from_dir8/192.png
# 输出的单张图片已保存到：test_from_dir8/193.png
# 输出的单张图片已保存到：test_from_dir8/194.png
# 输出的单张图片已保存到：test_from_dir8/195.png
# 输出的单张图片已保存到：test_from_dir8/196.png
# 输出的单张图片已保存到：test_from_dir8/197.png
# 输出的单张图片已保存到：test_from_dir8/198.png
# 输出的单张图片已保存到：test_from_dir8/199.png
# 输出的单张图片已保存到：test_from_dir8/200.png
# 输出的单张图片已保存到：test_from_dir8/201.png
# 输出的单张图片已保存到：test_from_dir8/202.png
# 输出的单张图片已保存到：test_from_dir8/203.png
# 输出的单张图片已保存到：test_from_dir8/204.png
# 输出的单张图片已保存到：test_from_dir8/205.png
# 输出的单张图片已保存到：test_from_dir8/206.png
# 输出的单张图片已保存到：test_from_dir8/207.png
# 输出的单张图片已保存到：test_from_dir8/208.png
# 输出的单张图片已保存到：test_from_dir8/209.png
# 输出的单张图片已保存到：test_from_dir8/210.png
# 输出的单张图片已保存到：test_from_dir8/211.png
# 输出的单张图片已保存到：test_from_dir8/212.png
# 输出的单张图片已保存到：test_from_dir8/213.png
# 输出的单张图片已保存到：test_from_dir8/214.png
# 输出的单张图片已保存到：test_from_dir8/215.png
# 输出的单张图片已保存到：test_from_dir8/216.png
# 输出的单张图片已保存到：test_from_dir8/217.png
# 输出的单张图片已保存到：test_from_dir8/218.png
# 输出的单张图片已保存到：test_from_dir8/219.png
# 输出的单张图片已保存到：test_from_dir8/220.png
# 输出的单张图片已保存到：test_from_dir8/221.png
# 输出的单张图片已保存到：test_from_dir8/222.png
# 输出的单张图片已保存到：test_from_dir8/223.png
# 输出的单张图片已保存到：test_from_dir8/224.png
# 输出的单张图片已保存到：test_from_dir8/225.png
# 输出的单张图片已保存到：test_from_dir8/226.png
# 输出的单张图片已保存到：test_from_dir8/227.png
# 输出的单张图片已保存到：test_from_dir8/228.png
# 输出的单张图片已保存到：test_from_dir8/229.png
# 输出的单张图片已保存到：test_from_dir8/230.png
# 输出的单张图片已保存到：test_from_dir8/231.png
# 输出的单张图片已保存到：test_from_dir8/232.png
# 输出的单张图片已保存到：test_from_dir8/233.png
# 输出的单张图片已保存到：test_from_dir8/234.png
# 输出的单张图片已保存到：test_from_dir8/235.png
# 输出的单张图片已保存到：test_from_dir8/236.png
# 输出的单张图片已保存到：test_from_dir8/237.png
# 输出的单张图片已保存到：test_from_dir8/238.png
# 输出的单张图片已保存到：test_from_dir8/239.png
# 输出的单张图片已保存到：test_from_dir8/240.png
# 输出的单张图片已保存到：test_from_dir8/241.png
# 输出的单张图片已保存到：test_from_dir8/242.png
# 输出的单张图片已保存到：test_from_dir8/243.png
# 输出的单张图片已保存到：test_from_dir8/244.png
# 输出的单张图片已保存到：test_from_dir8/245.png
# 输出的单张图片已保存到：test_from_dir8/246.png
# 输出的单张图片已保存到：test_from_dir8/247.png
# 输出的单张图片已保存到：test_from_dir8/248.png
# 输出的单张图片已保存到：test_from_dir8/249.png
# 输出的单张图片已保存到：test_from_dir8/250.png
# 输出的单张图片已保存到：test_from_dir8/251.png
# 输出的单张图片已保存到：test_from_dir8/252.png
# 输出的单张图片已保存到：test_from_dir8/253.png
# 输出的单张图片已保存到：test_from_dir8/254.png
# 输出的单张图片已保存到：test_from_dir8/255.png
# 输出的单张图片已保存到：test_from_dir8/256.png
# 输出的单张图片已保存到：test_from_dir8/257.png
# 输出的单张图片已保存到：test_from_dir8/258.png
# 输出的单张图片已保存到：test_from_dir8/259.png
# 输出的单张图片已保存到：test_from_dir8/260.png
# 输出的单张图片已保存到：test_from_dir8/261.png
# 输出的单张图片已保存到：test_from_dir8/262.png
# 输出的单张图片已保存到：test_from_dir8/263.png
# 输出的单张图片已保存到：test_from_dir8/264.png
# 输出的单张图片已保存到：test_from_dir8/265.png
# 输出的单张图片已保存到：test_from_dir8/266.png
# 输出的单张图片已保存到：test_from_dir8/267.png
# 输出的单张图片已保存到：test_from_dir8/268.png
# 输出的单张图片已保存到：test_from_dir8/269.png
# 输出的单张图片已保存到：test_from_dir8/270.png
# 输出的单张图片已保存到：test_from_dir8/271.png
# 输出的单张图片已保存到：test_from_dir8/272.png
# 输出的单张图片已保存到：test_from_dir8/273.png
# 输出的单张图片已保存到：test_from_dir8/274.png
# 输出的单张图片已保存到：test_from_dir8/275.png
# 输出的单张图片已保存到：test_from_dir8/276.png
# 输出的单张图片已保存到：test_from_dir8/277.png
# 输出的单张图片已保存到：test_from_dir8/278.png
# 输出的单张图片已保存到：test_from_dir8/279.png
# 输出的单张图片已保存到：test_from_dir8/280.png
# 输出的单张图片已保存到：test_from_dir8/281.png
# 输出的单张图片已保存到：test_from_dir8/282.png
# 输出的单张图片已保存到：test_from_dir8/283.png
# 输出的单张图片已保存到：test_from_dir8/284.png
# 输出的单张图片已保存到：test_from_dir8/285.png
# 输出的单张图片已保存到：test_from_dir8/286.png
# 输出的单张图片已保存到：test_from_dir8/287.png
# 输出的单张图片已保存到：test_from_dir8/288.png
# 输出的单张图片已保存到：test_from_dir8/289.png
# 输出的单张图片已保存到：test_from_dir8/290.png
# 输出的单张图片已保存到：test_from_dir8/291.png
# 输出的单张图片已保存到：test_from_dir8/292.png
# 输出的单张图片已保存到：test_from_dir8/293.png
# 输出的单张图片已保存到：test_from_dir8/294.png
# 输出的单张图片已保存到：test_from_dir8/295.png
# 输出的单张图片已保存到：test_from_dir8/296.png
# 输出的单张图片已保存到：test_from_dir8/297.png
# 输出的单张图片已保存到：test_from_dir8/298.png
# 输出的单张图片已保存到：test_from_dir8/299.png
# 输出的单张图片已保存到：test_from_dir8/300.png
# 输出的单张图片已保存到：test_from_dir8/301.png
# 输出的单张图片已保存到：test_from_dir8/302.png
# 输出的单张图片已保存到：test_from_dir8/303.png
# 输出的单张图片已保存到：test_from_dir8/304.png
# 输出的单张图片已保存到：test_from_dir8/305.png
# 输出的单张图片已保存到：test_from_dir8/306.png
# 输出的单张图片已保存到：test_from_dir8/307.png
# 输出的单张图片已保存到：test_from_dir8/308.png
# 输出的单张图片已保存到：test_from_dir8/309.png
# 输出的单张图片已保存到：test_from_dir8/310.png
# 输出的单张图片已保存到：test_from_dir8/311.png
# 输出的单张图片已保存到：test_from_dir8/312.png
# 输出的单张图片已保存到：test_from_dir8/313.png
# 输出的单张图片已保存到：test_from_dir8/314.png
# 输出的单张图片已保存到：test_from_dir8/315.png
# 输出的单张图片已保存到：test_from_dir8/316.png
# 输出的单张图片已保存到：test_from_dir8/317.png
# 输出的单张图片已保存到：test_from_dir8/318.png
# 输出的单张图片已保存到：test_from_dir8/319.png
# 输出的单张图片已保存到：test_from_dir8/320.png
# 输出的单张图片已保存到：test_from_dir8/321.png
# 输出的单张图片已保存到：test_from_dir8/322.png
# 输出的单张图片已保存到：test_from_dir8/323.png
# 输出的单张图片已保存到：test_from_dir8/324.png
# 输出的单张图片已保存到：test_from_dir8/325.png
# 输出的单张图片已保存到：test_from_dir8/326.png
# 输出的单张图片已保存到：test_from_dir8/327.png
# 输出的单张图片已保存到：test_from_dir8/328.png
# 输出的单张图片已保存到：test_from_dir8/329.png
# 输出的单张图片已保存到：test_from_dir8/330.png
# 输出的单张图片已保存到：test_from_dir8/331.png
# 输出的单张图片已保存到：test_from_dir8/332.png
# 输出的单张图片已保存到：test_from_dir8/333.png
# 输出的单张图片已保存到：test_from_dir8/334.png
# 输出的单张图片已保存到：test_from_dir8/335.png
# 输出的单张图片已保存到：test_from_dir8/336.png
# 输出的单张图片已保存到：test_from_dir8/337.png
# 输出的单张图片已保存到：test_from_dir8/338.png
# 输出的单张图片已保存到：test_from_dir8/339.png
# 输出的单张图片已保存到：test_from_dir8/340.png
# 输出的单张图片已保存到：test_from_dir8/341.png
# 输出的单张图片已保存到：test_from_dir8/342.png
# 输出的单张图片已保存到：test_from_dir8/343.png
# 输出的单张图片已保存到：test_from_dir8/344.png
# 输出的单张图片已保存到：test_from_dir8/345.png
# 输出的单张图片已保存到：test_from_dir8/346.png
# 输出的单张图片已保存到：test_from_dir8/347.png
# 输出的单张图片已保存到：test_from_dir8/348.png
# 输出的单张图片已保存到：test_from_dir8/349.png
# 输出的单张图片已保存到：test_from_dir8/350.png
# 输出的单张图片已保存到：test_from_dir8/351.png
# 输出的单张图片已保存到：test_from_dir8/352.png
# 输出的单张图片已保存到：test_from_dir8/353.png
# 输出的单张图片已保存到：test_from_dir8/354.png
# 输出的单张图片已保存到：test_from_dir8/355.png
# 输出的单张图片已保存到：test_from_dir8/356.png
# 输出的单张图片已保存到：test_from_dir8/357.png
# 输出的单张图片已保存到：test_from_dir8/358.png
# 输出的单张图片已保存到：test_from_dir8/359.png
# 输出的单张图片已保存到：test_from_dir8/360.png
# 输出的单张图片已保存到：test_from_dir8/361.png
# 输出的单张图片已保存到：test_from_dir8/362.png
# 输出的单张图片已保存到：test_from_dir8/363.png
# 输出的单张图片已保存到：test_from_dir8/364.png
# 输出的单张图片已保存到：test_from_dir8/365.png
# 输出的单张图片已保存到：test_from_dir8/366.png
# 输出的单张图片已保存到：test_from_dir8/367.png
# 输出的单张图片已保存到：test_from_dir8/368.png
# 输出的单张图片已保存到：test_from_dir8/369.png
# 输出的单张图片已保存到：test_from_dir8/370.png
# 输出的单张图片已保存到：test_from_dir8/371.png
# 输出的单张图片已保存到：test_from_dir8/372.png
# 输出的单张图片已保存到：test_from_dir8/373.png
# 输出的单张图片已保存到：test_from_dir8/374.png
# 输出的单张图片已保存到：test_from_dir8/375.png
# 输出的单张图片已保存到：test_from_dir8/376.png
# 输出的单张图片已保存到：test_from_dir8/377.png
# 输出的单张图片已保存到：test_from_dir8/378.png
# 输出的单张图片已保存到：test_from_dir8/379.png
# 输出的单张图片已保存到：test_from_dir8/380.png
# 输出的单张图片已保存到：test_from_dir8/381.png
# 输出的单张图片已保存到：test_from_dir8/382.png
# 输出的单张图片已保存到：test_from_dir8/383.png
# 输出的单张图片已保存到：test_from_dir8/384.png
# 输出的单张图片已保存到：test_from_dir8/385.png
# 输出的单张图片已保存到：test_from_dir8/386.png
# 输出的单张图片已保存到：test_from_dir8/387.png
# 输出的单张图片已保存到：test_from_dir8/388.png
# 输出的单张图片已保存到：test_from_dir8/389.png
# 输出的单张图片已保存到：test_from_dir8/390.png
# 输出的单张图片已保存到：test_from_dir8/391.png
# 输出的单张图片已保存到：test_from_dir8/392.png
# 输出的单张图片已保存到：test_from_dir8/393.png
# 输出的单张图片已保存到：test_from_dir8/394.png
# 输出的单张图片已保存到：test_from_dir8/395.png
# 输出的单张图片已保存到：test_from_dir8/396.png
# 输出的单张图片已保存到：test_from_dir8/397.png
# 输出的单张图片已保存到：test_from_dir8/398.png
# 输出的单张图片已保存到：test_from_dir8/399.png
# 输出的单张图片已保存到：test_from_dir8/400.png
# 输出的单张图片已保存到：test_from_dir8/401.png
# 输出的单张图片已保存到：test_from_dir8/402.png
# 输出的单张图片已保存到：test_from_dir8/403.png
# 输出的单张图片已保存到：test_from_dir8/404.png
# 输出的单张图片已保存到：test_from_dir8/405.png
# 输出的单张图片已保存到：test_from_dir8/406.png
# 输出的单张图片已保存到：test_from_dir8/407.png
# 输出的单张图片已保存到：test_from_dir8/408.png
# 输出的单张图片已保存到：test_from_dir8/409.png
# 输出的单张图片已保存到：test_from_dir8/410.png
# 输出的单张图片已保存到：test_from_dir8/411.png
# 输出的单张图片已保存到：test_from_dir8/412.png
# 输出的单张图片已保存到：test_from_dir8/413.png
# 输出的单张图片已保存到：test_from_dir8/414.png
# 输出的单张图片已保存到：test_from_dir8/415.png
# 输出的单张图片已保存到：test_from_dir8/416.png
# 输出的单张图片已保存到：test_from_dir8/417.png
# 输出的单张图片已保存到：test_from_dir8/418.png
# 输出的单张图片已保存到：test_from_dir8/419.png
# 输出的单张图片已保存到：test_from_dir8/420.png
# 输出的单张图片已保存到：test_from_dir8/421.png
# 输出的单张图片已保存到：test_from_dir8/422.png
# 输出的单张图片已保存到：test_from_dir8/423.png
# 输出的单张图片已保存到：test_from_dir8/424.png
# 输出的单张图片已保存到：test_from_dir8/425.png
# 输出的单张图片已保存到：test_from_dir8/426.png
# 输出的单张图片已保存到：test_from_dir8/427.png
# 输出的单张图片已保存到：test_from_dir8/428.png
# 输出的单张图片已保存到：test_from_dir8/429.png
# 输出的单张图片已保存到：test_from_dir8/430.png
# 输出的单张图片已保存到：test_from_dir8/431.png
# 输出的单张图片已保存到：test_from_dir8/432.png
# 输出的单张图片已保存到：test_from_dir8/433.png
# 输出的单张图片已保存到：test_from_dir8/434.png
# 输出的单张图片已保存到：test_from_dir8/435.png
# 输出的单张图片已保存到：test_from_dir8/436.png
# 输出的单张图片已保存到：test_from_dir8/437.png
# 输出的单张图片已保存到：test_from_dir8/438.png
# 输出的单张图片已保存到：test_from_dir8/439.png
# 输出的单张图片已保存到：test_from_dir8/440.png
# 输出的单张图片已保存到：test_from_dir8/441.png
# 输出的单张图片已保存到：test_from_dir8/442.png
# 输出的单张图片已保存到：test_from_dir8/443.png
# 输出的单张图片已保存到：test_from_dir8/444.png
# 输出的单张图片已保存到：test_from_dir8/445.png
# 输出的单张图片已保存到：test_from_dir8/446.png
# 输出的单张图片已保存到：test_from_dir8/447.png
# 输出的单张图片已保存到：test_from_dir8/448.png
# 输出的单张图片已保存到：test_from_dir8/449.png
# 输出的单张图片已保存到：test_from_dir8/450.png
# 输出的单张图片已保存到：test_from_dir8/451.png
# 输出的单张图片已保存到：test_from_dir8/452.png
# 输出的单张图片已保存到：test_from_dir8/453.png
# 输出的单张图片已保存到：test_from_dir8/454.png
# 输出的单张图片已保存到：test_from_dir8/455.png
# 输出的单张图片已保存到：test_from_dir8/456.png
# 输出的单张图片已保存到：test_from_dir8/457.png
# 输出的单张图片已保存到：test_from_dir8/458.png
# 输出的单张图片已保存到：test_from_dir8/459.png
# 输出的单张图片已保存到：test_from_dir8/460.png
# 输出的单张图片已保存到：test_from_dir8/461.png
# 输出的单张图片已保存到：test_from_dir8/462.png
# 输出的单张图片已保存到：test_from_dir8/463.png
# 输出的单张图片已保存到：test_from_dir8/464.png
# 输出的单张图片已保存到：test_from_dir8/465.png
# 输出的单张图片已保存到：test_from_dir8/466.png
# 输出的单张图片已保存到：test_from_dir8/467.png
# 输出的单张图片已保存到：test_from_dir8/468.png
# 输出的单张图片已保存到：test_from_dir8/469.png
# 输出的单张图片已保存到：test_from_dir8/470.png
# 输出的单张图片已保存到：test_from_dir8/471.png
# 输出的单张图片已保存到：test_from_dir8/472.png
# 输出的单张图片已保存到：test_from_dir8/473.png
# 输出的单张图片已保存到：test_from_dir8/474.png
# 输出的单张图片已保存到：test_from_dir8/475.png
# 输出的单张图片已保存到：test_from_dir8/476.png
# 输出的单张图片已保存到：test_from_dir8/477.png
# 输出的单张图片已保存到：test_from_dir8/478.png
# 输出的单张图片已保存到：test_from_dir8/479.png
# 输出的单张图片已保存到：test_from_dir8/480.png
# 输出的单张图片已保存到：test_from_dir8/481.png
# 输出的单张图片已保存到：test_from_dir8/482.png
# 输出的单张图片已保存到：test_from_dir8/483.png
# 输出的单张图片已保存到：test_from_dir8/484.png
# 输出的单张图片已保存到：test_from_dir8/485.png
# 输出的单张图片已保存到：test_from_dir8/486.png
# 输出的单张图片已保存到：test_from_dir8/487.png
# 输出的单张图片已保存到：test_from_dir8/488.png
# 输出的单张图片已保存到：test_from_dir8/489.png
# 输出的单张图片已保存到：test_from_dir8/490.png
# 输出的单张图片已保存到：test_from_dir8/491.png
# 输出的单张图片已保存到：test_from_dir8/492.png
# 输出的单张图片已保存到：test_from_dir8/493.png
# 输出的单张图片已保存到：test_from_dir8/494.png
# 输出的单张图片已保存到：test_from_dir8/495.png
# 输出的单张图片已保存到：test_from_dir8/496.png
# 输出的单张图片已保存到：test_from_dir8/497.png
# 输出的单张图片已保存到：test_from_dir8/498.png
# 输出的单张图片已保存到：test_from_dir8/499.png
# 输出的单张图片已保存到：test_from_dir8/500.png

# %%
# 查看部分生成图片
plt.figure(figsize=(12,12))
for i in range(16):
    plt.subplot(4, 4, i + 1)
    if c == 3:
        fake_images[i] = cv.cvtColor(fake_images[i], cv.COLOR_BGR2RGB)
    plt.imshow(fake_images[i])
    plt.axis('off')
plt.show()
